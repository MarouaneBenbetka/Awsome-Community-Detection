# %% [markdown]
# # KMeans with local expansion
# ___

# %%
from utils.utils import *
from utils.visualization import *
from utils.communities_network import *
from utils.iterative_greedy_algorithm import IG
from utils.kmeans import *
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
from netgraph import Graph

import time

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Test

# %% [markdown]
# ### 1.Reel datasets

# %% [markdown]
# #### 1.1 Karate

# %%
file_path = 'data/reel/karate/karate.gml'
G = nx.read_gml(file_path, label='id')
original_nodes = list(G.nodes())
mapping = {node: i for i, node in enumerate(G.nodes())}
G = nx.relabel_nodes(G, mapping)
adj_matrix = nx.to_numpy_array(G)
true_labels = read_community_labels_file_reel(
    'data/reel/karate/groundTruth.txt')
print(f"The graph contains {adj_matrix.shape[0]} nodes.")
# Out:
# The graph contains 34 nodes.

# %%
start_time = time.time()
Cmax, Qmax, Kbest, Labels, trace = local_expansion_kmeans(
    G, adj_matrix, 2, 16 , metric="QSim")
end_time = time.time()


for item in trace:

    item["NMI"] = calc_nmi(true_labels, communities_to_labels(
        G, item["communities"], original_nodes))

duration = end_time - start_time
nmi = trace[Kbest-2]["NMI"]

print(f"Time elapsed : {duration} s ")
print(f"NMI = {nmi}")
print(f"Modularity = {trace[Kbest-2]['Modularity']}")
print(f"Number of communities : {Kbest}")
custom_df_styling(trace)
# Out:
# No more nodes to select , k is too large
# Time elapsed : 0.5230746269226074 s
# NMI = 1.0
# Modularity = 0.37146614069691
# Number of communities : 2
# <style type="text/css">
# #T_5b333_row0_col0, #T_5b333_row0_col1, #T_5b333_row0_col2, #T_5b333_row0_col3 {
#   background-color: #A7E0E0;
#   color: black;
#   font-size: 600;
# }
# </style>
# <table id="T_5b333">
#   <thead>
#     <tr>
#       <th id="T_5b333_level0_col0" class="col_heading level0 col0" >K</th>
#       <th id="T_5b333_level0_col1" class="col_heading level0 col1" >Modularity</th>
#       <th id="T_5b333_level0_col2" class="col_heading level0 col2" >Similarity-Based Modularity</th>
#       <th id="T_5b333_level0_col3" class="col_heading level0 col3" >NMI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5b333_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_5b333_row0_col1" class="data row0 col1" >0.371466</td>
#       <td id="T_5b333_row0_col2" class="data row0 col2" >0.210634</td>
#       <td id="T_5b333_row0_col3" class="data row0 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_5b333_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_5b333_row1_col1" class="data row1 col1" >0.228468</td>
#       <td id="T_5b333_row1_col2" class="data row1 col2" >0.139135</td>
#       <td id="T_5b333_row1_col3" class="data row1 col3" >0.733340</td>
#     </tr>
#     <tr>
#       <td id="T_5b333_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_5b333_row2_col1" class="data row2 col1" >0.187295</td>
#       <td id="T_5b333_row2_col2" class="data row2 col2" >0.118549</td>
#       <td id="T_5b333_row2_col3" class="data row2 col3" >0.522512</td>
#     </tr>
#   </tbody>
# </table>

# %%
partion = {node-1: comm-1 for node,
           comm in communities_to_labels(G, Cmax, original_nodes)}
node_labels = {node: f"{node+1}" for node, comm in partion.items()}

community_to_color = {
    0: 'tab:blue',
    1: 'tab:red',
    2: 'tab:orange',
    3: 'tab:green',
    4: 'tab:pink',
}

node_color = {node: community_to_color[community_id]
              for node, community_id in partion.items()}



plt.figure(figsize=(15, 15))
Graph(
    G,
    node_color=node_color, node_edge_width=0.3, edge_alpha=.5, edge_width=.5,
    node_layout='community', node_layout_kwargs=dict(node_to_community=partion),
    edge_layout='bundled', edge_layout_kwargs=dict(k=2000), node_labels=node_labels, node_size=4, scale=(1.6, 1.6)
)
plt.show()

# %% [markdown]
# #### 1.2 Football

# %%
file_path = 'data/reel/football/football.gml'
G = nx.read_gml(file_path, label='id')
original_nodes = list(G.nodes())
mapping = {node: i for i, node in enumerate(G.nodes())}
G = nx.relabel_nodes(G, mapping)
adj_matrix = nx.to_numpy_array(G)
true_labels = read_community_labels_file_reel(
    'data/reel/football/groundTruth.txt')
print(f"The graph contains {adj_matrix.shape[0]} nodes.")
# Out:
# The graph contains 115 nodes.

# %%
start_time = time.time()
Cmax, Qmax, Kbest, Labels, trace = local_expansion_kmeans(
    G, adj_matrix, 2, 16 , alpha= .98, beta =1.02 )
end_time = time.time()


for item in trace:

    item["NMI"] = calc_nmi(true_labels, communities_to_labels(
        G, item["communities"], original_nodes))

duration = end_time - start_time
nmi = trace[Kbest-2]["NMI"]

print(f"Time elapsed : {duration} s ")
print(f"NMI = {nmi}")
print(f"Modularity = {trace[Kbest-2]['Modularity']}")
print(f"Number of communities : {Kbest}")
custom_df_styling(trace)
# Out:
# No more nodes to select , k is too large
# Time elapsed : 2.2342255115509033 s
# NMI = 0.9159301693333538
# Modularity = 0.5975386474137037
# Number of communities : 11
# <style type="text/css">
# #T_98b9b_row9_col0, #T_98b9b_row9_col1, #T_98b9b_row9_col2, #T_98b9b_row9_col3 {
#   background-color: #A7E0E0;
#   color: black;
#   font-size: 600;
# }
# </style>
# <table id="T_98b9b">
#   <thead>
#     <tr>
#       <th id="T_98b9b_level0_col0" class="col_heading level0 col0" >K</th>
#       <th id="T_98b9b_level0_col1" class="col_heading level0 col1" >Modularity</th>
#       <th id="T_98b9b_level0_col2" class="col_heading level0 col2" >Similarity-Based Modularity</th>
#       <th id="T_98b9b_level0_col3" class="col_heading level0 col3" >NMI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_98b9b_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_98b9b_row0_col1" class="data row0 col1" >0.309099</td>
#       <td id="T_98b9b_row0_col2" class="data row0 col2" >0.158927</td>
#       <td id="T_98b9b_row0_col3" class="data row0 col3" >0.373122</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_98b9b_row1_col1" class="data row1 col1" >0.445967</td>
#       <td id="T_98b9b_row1_col2" class="data row1 col2" >0.227361</td>
#       <td id="T_98b9b_row1_col3" class="data row1 col3" >0.529830</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_98b9b_row2_col1" class="data row2 col1" >0.509371</td>
#       <td id="T_98b9b_row2_col2" class="data row2 col2" >0.259063</td>
#       <td id="T_98b9b_row2_col3" class="data row2 col3" >0.629133</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_98b9b_row3_col1" class="data row3 col1" >0.570996</td>
#       <td id="T_98b9b_row3_col2" class="data row3 col2" >0.289876</td>
#       <td id="T_98b9b_row3_col3" class="data row3 col3" >0.702469</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_98b9b_row4_col1" class="data row4 col1" >0.539850</td>
#       <td id="T_98b9b_row4_col2" class="data row4 col2" >0.274303</td>
#       <td id="T_98b9b_row4_col3" class="data row4 col3" >0.720661</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_98b9b_row5_col1" class="data row5 col1" >0.573387</td>
#       <td id="T_98b9b_row5_col2" class="data row5 col2" >0.291071</td>
#       <td id="T_98b9b_row5_col3" class="data row5 col3" >0.793762</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row6_col0" class="data row6 col0" >8</td>
#       <td id="T_98b9b_row6_col1" class="data row6 col1" >0.579100</td>
#       <td id="T_98b9b_row6_col2" class="data row6 col2" >0.293928</td>
#       <td id="T_98b9b_row6_col3" class="data row6 col3" >0.837429</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row7_col0" class="data row7 col0" >9</td>
#       <td id="T_98b9b_row7_col1" class="data row7 col1" >0.584343</td>
#       <td id="T_98b9b_row7_col2" class="data row7 col2" >0.296549</td>
#       <td id="T_98b9b_row7_col3" class="data row7 col3" >0.863803</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row8_col0" class="data row8 col0" >10</td>
#       <td id="T_98b9b_row8_col1" class="data row8 col1" >0.597392</td>
#       <td id="T_98b9b_row8_col2" class="data row8 col2" >0.303074</td>
#       <td id="T_98b9b_row8_col3" class="data row8 col3" >0.906546</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row9_col0" class="data row9 col0" >11</td>
#       <td id="T_98b9b_row9_col1" class="data row9 col1" >0.597539</td>
#       <td id="T_98b9b_row9_col2" class="data row9 col2" >0.303147</td>
#       <td id="T_98b9b_row9_col3" class="data row9 col3" >0.915930</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row10_col0" class="data row10 col0" >12</td>
#       <td id="T_98b9b_row10_col1" class="data row10 col1" >0.572348</td>
#       <td id="T_98b9b_row10_col2" class="data row10 col2" >0.290552</td>
#       <td id="T_98b9b_row10_col3" class="data row10 col3" >0.904914</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row11_col0" class="data row11 col0" >13</td>
#       <td id="T_98b9b_row11_col1" class="data row11 col1" >0.565077</td>
#       <td id="T_98b9b_row11_col2" class="data row11 col2" >0.286916</td>
#       <td id="T_98b9b_row11_col3" class="data row11 col3" >0.914595</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row12_col0" class="data row12 col0" >14</td>
#       <td id="T_98b9b_row12_col1" class="data row12 col1" >0.545330</td>
#       <td id="T_98b9b_row12_col2" class="data row12 col2" >0.277043</td>
#       <td id="T_98b9b_row12_col3" class="data row12 col3" >0.906245</td>
#     </tr>
#     <tr>
#       <td id="T_98b9b_row13_col0" class="data row13 col0" >15</td>
#       <td id="T_98b9b_row13_col1" class="data row13 col1" >0.550472</td>
#       <td id="T_98b9b_row13_col2" class="data row13 col2" >0.279614</td>
#       <td id="T_98b9b_row13_col3" class="data row13 col3" >0.906370</td>
#     </tr>
#   </tbody>
# </table>

# %%
partion = {node: comm-1 for node,
           comm in communities_to_labels(G, Cmax, original_nodes)}
node_labels = {node: f"{node+1}" for node, comm in partion.items()}

community_to_color = {
    0: "#FF5733",
    1: "#33FF57",
    2: "#5733FF",
    3: "#FF33A6",
    4: "#A633FF",
    5: "#33A6FF",
    6: "#FFD133",
    7: "#33FFD1",
    8: "#D133FF",
    9: "#FFE133",
    10: "#33FFE1"
   
}

node_color = {node: community_to_color[community_id]
              for node, community_id in partion.items()}


plt.figure(figsize=(15, 15))
Graph(
    G,
    node_color=node_color, node_edge_width=0.3, edge_alpha=.5, edge_width=.5,
    node_layout='community', node_layout_kwargs=dict(node_to_community=partion),
    edge_layout='bundled', edge_layout_kwargs=dict(k=2000), node_labels=node_labels, node_size=4, scale=(1.6, 1.6)
)
plt.show()

# %% [markdown]
# #### 1.3 Dolphins

# %%
file_path = 'data/reel/dolphins/dolphins.gml'
G = nx.read_gml(file_path, label='id')
original_nodes = list(G.nodes())
mapping = {node: i for i, node in enumerate(G.nodes())}
G = nx.relabel_nodes(G, mapping)
adj_matrix = nx.to_numpy_array(G)
true_labels = read_community_labels_file_reel(
    'data/reel/dolphins/groundTruth.txt')
print(f"The graph contains {adj_matrix.shape[0]} nodes.")
# Out:
# The graph contains 62 nodes.

# %%
start_time = time.time()
Cmax, Qmax, Kbest, Labels, trace = local_expansion_kmeans(
    G, adj_matrix, 2, 16)
end_time = time.time()


for item in trace:

    item["NMI"] = calc_nmi(true_labels, communities_to_labels(
        G, item["communities"], original_nodes))

duration = end_time - start_time
nmi = trace[Kbest-2]["NMI"]

print(f"Time elapsed : {duration} s ")
print(f"NMI = {nmi}")
print(f"Modularity = {trace[Kbest-2]['Modularity']}")
print(f"Number of communities : {Kbest}")
custom_df_styling(trace)
# Out:
# No more nodes to select , k is too large
# Time elapsed : 0.5951766967773438 s
# NMI = 0.7769437310361903
# Modularity = 0.3698231873739171
# Number of communities : 2
# <style type="text/css">
# #T_a2dd9_row0_col0, #T_a2dd9_row0_col1, #T_a2dd9_row0_col2, #T_a2dd9_row0_col3 {
#   background-color: #A7E0E0;
#   color: black;
#   font-size: 600;
# }
# </style>
# <table id="T_a2dd9">
#   <thead>
#     <tr>
#       <th id="T_a2dd9_level0_col0" class="col_heading level0 col0" >K</th>
#       <th id="T_a2dd9_level0_col1" class="col_heading level0 col1" >Modularity</th>
#       <th id="T_a2dd9_level0_col2" class="col_heading level0 col2" >Similarity-Based Modularity</th>
#       <th id="T_a2dd9_level0_col3" class="col_heading level0 col3" >NMI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a2dd9_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_a2dd9_row0_col1" class="data row0 col1" >0.369823</td>
#       <td id="T_a2dd9_row0_col2" class="data row0 col2" >0.195611</td>
#       <td id="T_a2dd9_row0_col3" class="data row0 col3" >0.776944</td>
#     </tr>
#     <tr>
#       <td id="T_a2dd9_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_a2dd9_row1_col1" class="data row1 col1" >0.282880</td>
#       <td id="T_a2dd9_row1_col2" class="data row1 col2" >0.152140</td>
#       <td id="T_a2dd9_row1_col3" class="data row1 col3" >0.331389</td>
#     </tr>
#     <tr>
#       <td id="T_a2dd9_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_a2dd9_row2_col1" class="data row2 col1" >0.353032</td>
#       <td id="T_a2dd9_row2_col2" class="data row2 col2" >0.187216</td>
#       <td id="T_a2dd9_row2_col3" class="data row2 col3" >0.297585</td>
#     </tr>
#     <tr>
#       <td id="T_a2dd9_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_a2dd9_row3_col1" class="data row3 col1" >0.347534</td>
#       <td id="T_a2dd9_row3_col2" class="data row3 col2" >0.184467</td>
#       <td id="T_a2dd9_row3_col3" class="data row3 col3" >0.391953</td>
#     </tr>
#     <tr>
#       <td id="T_a2dd9_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_a2dd9_row4_col1" class="data row4 col1" >0.271627</td>
#       <td id="T_a2dd9_row4_col2" class="data row4 col2" >0.146513</td>
#       <td id="T_a2dd9_row4_col3" class="data row4 col3" >0.206640</td>
#     </tr>
#     <tr>
#       <td id="T_a2dd9_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_a2dd9_row5_col1" class="data row5 col1" >0.349432</td>
#       <td id="T_a2dd9_row5_col2" class="data row5 col2" >0.185416</td>
#       <td id="T_a2dd9_row5_col3" class="data row5 col3" >0.273392</td>
#     </tr>
#   </tbody>
# </table>

# %%
partion = {node: comm-1 for node,
           comm in communities_to_labels(G, Cmax, original_nodes)}
node_labels = {node: f"{node+1}" for node, comm in partion.items()}

community_to_color = {
    0: "#FF5733",
    1: "#33FF57",
    2: "#5733FF",
    3: "#FF33A6",
    4: "#A633FF",
    5: "#33A6FF",
    6: "#FFD133",
    7: "#33FFD1",
    8: "#D133FF",
    9: "#FFE133",
    10: "#33FFE1"

}

node_color = {node: community_to_color[community_id]
              for node, community_id in partion.items()}


plt.figure(figsize=(15, 15))
Graph(
    G,
    node_color=node_color, node_edge_width=0.3, edge_alpha=.5, edge_width=.5,
    node_layout='community', node_layout_kwargs=dict(node_to_community=partion),
    edge_layout='bundled', edge_layout_kwargs=dict(k=2000), node_labels=node_labels, node_size=4, scale=(1.6, 1.6)
)
plt.show()

# %% [markdown]
# ### Datasets Synth

# %% [markdown]
# #### 2.1 LFR .15

# %%
file_path = 'data/synth/LFR/0.15/network.dat'
G = nx.read_edgelist(file_path, nodetype=int)
original_nodes = list(G.nodes())
mapping = {node: i for i, node in enumerate(G.nodes())}
G = nx.relabel_nodes(G, mapping)
adj_matrix = nx.to_numpy_array(G)
adj_matrix.shape[0]
true_communities = read_community_labels_file_synth(
    "data/synth/LFR/0.15/community.dat")

# %%
Cmax, Qmax, Kbest, Labels, trace = local_expansion_kmeans(G, adj_matrix, 2, 7)
for item in trace:
    item["NMI"] = calc_nmi(true_communities, communities_to_labels(
        G, item["communities"], original_nodes))


custom_df_styling(trace)
# Out:
# <style type="text/css">
# #T_3c604_row2_col0, #T_3c604_row2_col1, #T_3c604_row2_col2, #T_3c604_row2_col3 {
#   background-color: #A7E0E0;
#   color: black;
#   font-size: 600;
# }
# </style>
# <table id="T_3c604">
#   <thead>
#     <tr>
#       <th id="T_3c604_level0_col0" class="col_heading level0 col0" >K</th>
#       <th id="T_3c604_level0_col1" class="col_heading level0 col1" >Modularity</th>
#       <th id="T_3c604_level0_col2" class="col_heading level0 col2" >Similarity-Based Modularity</th>
#       <th id="T_3c604_level0_col3" class="col_heading level0 col3" >NMI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3c604_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_3c604_row0_col1" class="data row0 col1" >0.406250</td>
#       <td id="T_3c604_row0_col2" class="data row0 col2" >0.207031</td>
#       <td id="T_3c604_row0_col3" class="data row0 col3" >0.666667</td>
#     </tr>
#     <tr>
#       <td id="T_3c604_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_3c604_row1_col1" class="data row1 col1" >0.500977</td>
#       <td id="T_3c604_row1_col2" class="data row1 col2" >0.254395</td>
#       <td id="T_3c604_row1_col3" class="data row1 col3" >0.857143</td>
#     </tr>
#     <tr>
#       <td id="T_3c604_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_3c604_row2_col1" class="data row2 col1" >0.601562</td>
#       <td id="T_3c604_row2_col2" class="data row2 col2" >0.304688</td>
#       <td id="T_3c604_row2_col3" class="data row2 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_3c604_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_3c604_row3_col1" class="data row3 col1" >0.496582</td>
#       <td id="T_3c604_row3_col2" class="data row3 col2" >0.252197</td>
#       <td id="T_3c604_row3_col3" class="data row3 col3" >0.941803</td>
#     </tr>
#     <tr>
#       <td id="T_3c604_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_3c604_row4_col1" class="data row4 col1" >0.443359</td>
#       <td id="T_3c604_row4_col2" class="data row4 col2" >0.225586</td>
#       <td id="T_3c604_row4_col3" class="data row4 col3" >0.894618</td>
#     </tr>
#     <tr>
#       <td id="T_3c604_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_3c604_row5_col1" class="data row5 col1" >0.375854</td>
#       <td id="T_3c604_row5_col2" class="data row5 col2" >0.191833</td>
#       <td id="T_3c604_row5_col3" class="data row5 col3" >0.847372</td>
#     </tr>
#   </tbody>
# </table>

# %%
partion = {node-1: comm-1 for node,
           comm in communities_to_labels(G, Cmax, original_nodes)}
node_labels = {node: f"{node+1}" for node, comm in partion.items()}

community_to_color = {
    0: "#FF5733",
    1: "#33FF57",
    2: "#5733FF",
    3: "#FF33A6",
    4: "#A633FF",
    5: "#33A6FF",
    6: "#FFD133",
    7: "#33FFD1",
    8: "#D133FF",
    9: "#FFE133",
    10: "#33FFE1"

}

node_color = {node: community_to_color[community_id]
              for node, community_id in partion.items()}


plt.figure(figsize=(15, 15))
Graph(
    G,
    node_color=node_color, node_edge_width=0.3, edge_alpha=.5, edge_width=.5,
    node_layout='community', node_layout_kwargs=dict(node_to_community=partion),
    edge_layout='bundled', edge_layout_kwargs=dict(k=2000), node_labels=node_labels, node_size=4, scale=(1.6, 1.6)
)
plt.show()

# %% [markdown]
# #### 2.2 LFR .40

# %%
file_path = 'data/synth/LFR/0.40/network.dat'
G = nx.read_edgelist(file_path, nodetype=int)
original_nodes = list(G.nodes())
mapping = {node: i for i, node in enumerate(G.nodes())}
G = nx.relabel_nodes(G, mapping)
adj_matrix = nx.to_numpy_array(G)
adj_matrix.shape[0]
true_communities = read_community_labels_file_synth(
    "data/synth/LFR/0.40/community.dat")

# %%
Cmax, Qmax, Kbest, Labels, trace = local_expansion_kmeans(G, adj_matrix, 2, 7)
for item in trace:
    item["NMI"] = calc_nmi(true_communities, communities_to_labels(
        G, item["communities"], original_nodes))


custom_df_styling(trace)
# Out:
# <style type="text/css">
# #T_2ff3a_row2_col0, #T_2ff3a_row2_col1, #T_2ff3a_row2_col2, #T_2ff3a_row2_col3 {
#   background-color: #A7E0E0;
#   color: black;
#   font-size: 600;
# }
# </style>
# <table id="T_2ff3a">
#   <thead>
#     <tr>
#       <th id="T_2ff3a_level0_col0" class="col_heading level0 col0" >K</th>
#       <th id="T_2ff3a_level0_col1" class="col_heading level0 col1" >Modularity</th>
#       <th id="T_2ff3a_level0_col2" class="col_heading level0 col2" >Similarity-Based Modularity</th>
#       <th id="T_2ff3a_level0_col3" class="col_heading level0 col3" >NMI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2ff3a_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_2ff3a_row0_col1" class="data row0 col1" >0.177612</td>
#       <td id="T_2ff3a_row0_col2" class="data row0 col2" >0.092712</td>
#       <td id="T_2ff3a_row0_col3" class="data row0 col3" >0.547754</td>
#     </tr>
#     <tr>
#       <td id="T_2ff3a_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_2ff3a_row1_col1" class="data row1 col1" >0.295532</td>
#       <td id="T_2ff3a_row1_col2" class="data row1 col2" >0.151672</td>
#       <td id="T_2ff3a_row1_col3" class="data row1 col3" >0.804917</td>
#     </tr>
#     <tr>
#       <td id="T_2ff3a_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_2ff3a_row2_col1" class="data row2 col1" >0.347656</td>
#       <td id="T_2ff3a_row2_col2" class="data row2 col2" >0.177734</td>
#       <td id="T_2ff3a_row2_col3" class="data row2 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_2ff3a_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_2ff3a_row3_col1" class="data row3 col1" >0.277832</td>
#       <td id="T_2ff3a_row3_col2" class="data row3 col2" >0.142822</td>
#       <td id="T_2ff3a_row3_col3" class="data row3 col3" >0.941803</td>
#     </tr>
#     <tr>
#       <td id="T_2ff3a_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_2ff3a_row4_col1" class="data row4 col1" >0.239136</td>
#       <td id="T_2ff3a_row4_col2" class="data row4 col2" >0.123474</td>
#       <td id="T_2ff3a_row4_col3" class="data row4 col3" >0.896000</td>
#     </tr>
#     <tr>
#       <td id="T_2ff3a_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_2ff3a_row5_col1" class="data row5 col1" >0.198975</td>
#       <td id="T_2ff3a_row5_col2" class="data row5 col2" >0.103394</td>
#       <td id="T_2ff3a_row5_col3" class="data row5 col3" >0.851720</td>
#     </tr>
#   </tbody>
# </table>

# %%
partion = {node-1: comm-1 for node,
           comm in communities_to_labels(G, Cmax, original_nodes)}
node_labels = {node: f"{node+1}" for node, comm in partion.items()}

community_to_color = {
    0: "#FF5733",
    1: "#33FF57",
    2: "#5733FF",
    3: "#FF33A6",
    4: "#A633FF",
    5: "#33A6FF",
    6: "#FFD133",
    7: "#33FFD1",
    8: "#D133FF",
    9: "#FFE133",
    10: "#33FFE1"

}

node_color = {node: community_to_color[community_id]
              for node, community_id in partion.items()}


plt.figure(figsize=(15, 15))
Graph(
    G,
    node_color=node_color, node_edge_width=0.3, edge_alpha=.5, edge_width=.5,
    node_layout='community', node_layout_kwargs=dict(node_to_community=partion),
    edge_layout='bundled', edge_layout_kwargs=dict(k=2000), node_labels=node_labels, node_size=4, scale=(1.6, 1.6)
)
plt.show()

# %% [markdown]
# #### 2.3 LFR .50

# %%
file_path = 'data/synth/LFR/0.50/network.dat'
G = nx.read_edgelist(file_path, nodetype=int)
original_nodes = list(G.nodes())
mapping = {node: i for i, node in enumerate(G.nodes())}
G = nx.relabel_nodes(G, mapping)
adj_matrix = nx.to_numpy_array(G)
adj_matrix.shape[0]
true_communities = read_community_labels_file_synth(
    "data/synth/LFR/0.50/community.dat")

# %%
Cmax, Qmax, Kbest, Labels, trace = local_expansion_kmeans(G, adj_matrix, 2, 7)
for item in trace:
    item["NMI"] = calc_nmi(true_communities, communities_to_labels(
        G, item["communities"], original_nodes))


custom_df_styling(trace)
# Out:
# <style type="text/css">
# #T_47ffa_row2_col0, #T_47ffa_row2_col1, #T_47ffa_row2_col2, #T_47ffa_row2_col3 {
#   background-color: #E8AABE;
#   color: black;
#   font-size: 600;
# }
# #T_47ffa_row3_col0, #T_47ffa_row3_col1, #T_47ffa_row3_col2, #T_47ffa_row3_col3 {
#   background-color: #A7E0E0;
#   color: black;
#   font-size: 600;
# }
# </style>
# <table id="T_47ffa">
#   <thead>
#     <tr>
#       <th id="T_47ffa_level0_col0" class="col_heading level0 col0" >K</th>
#       <th id="T_47ffa_level0_col1" class="col_heading level0 col1" >Modularity</th>
#       <th id="T_47ffa_level0_col2" class="col_heading level0 col2" >Similarity-Based Modularity</th>
#       <th id="T_47ffa_level0_col3" class="col_heading level0 col3" >NMI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_47ffa_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_47ffa_row0_col1" class="data row0 col1" >-0.074707</td>
#       <td id="T_47ffa_row0_col2" class="data row0 col2" >-0.033447</td>
#       <td id="T_47ffa_row0_col3" class="data row0 col3" >0.020812</td>
#     </tr>
#     <tr>
#       <td id="T_47ffa_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_47ffa_row1_col1" class="data row1 col1" >-0.026733</td>
#       <td id="T_47ffa_row1_col2" class="data row1 col2" >-0.009460</td>
#       <td id="T_47ffa_row1_col3" class="data row1 col3" >0.081691</td>
#     </tr>
#     <tr>
#       <td id="T_47ffa_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_47ffa_row2_col1" class="data row2 col1" >-0.043579</td>
#       <td id="T_47ffa_row2_col2" class="data row2 col2" >-0.017883</td>
#       <td id="T_47ffa_row2_col3" class="data row2 col3" >0.096767</td>
#     </tr>
#     <tr>
#       <td id="T_47ffa_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_47ffa_row3_col1" class="data row3 col1" >-0.004517</td>
#       <td id="T_47ffa_row3_col2" class="data row3 col2" >0.001648</td>
#       <td id="T_47ffa_row3_col3" class="data row3 col3" >0.086424</td>
#     </tr>
#     <tr>
#       <td id="T_47ffa_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_47ffa_row4_col1" class="data row4 col1" >-0.035522</td>
#       <td id="T_47ffa_row4_col2" class="data row4 col2" >-0.013855</td>
#       <td id="T_47ffa_row4_col3" class="data row4 col3" >0.082814</td>
#     </tr>
#     <tr>
#       <td id="T_47ffa_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_47ffa_row5_col1" class="data row5 col1" >-0.036377</td>
#       <td id="T_47ffa_row5_col2" class="data row5 col2" >-0.014282</td>
#       <td id="T_47ffa_row5_col3" class="data row5 col3" >0.093833</td>
#     </tr>
#   </tbody>
# </table>

# %%
partion = {node-1: comm-1 for node,
           comm in communities_to_labels(G, Cmax, original_nodes)}
node_labels = {node: f"{node+1}" for node, comm in partion.items()}

community_to_color = {
    0: "#FF5733",
    1: "#33FF57",
    2: "#5733FF",
    3: "#FF33A6",
    4: "#A633FF",
    5: "#33A6FF",
    6: "#FFD133",
    7: "#33FFD1",
    8: "#D133FF",
    9: "#FFE133",
    10: "#33FFE1"

}

node_color = {node: community_to_color[community_id]
              for node, community_id in partion.items()}


plt.figure(figsize=(15, 15))
Graph(
    G,
    node_color=node_color, node_edge_width=0.3, edge_alpha=.5, edge_width=.5,
    node_layout='community', node_layout_kwargs=dict(node_to_community=partion),
    edge_layout='bundled', edge_layout_kwargs=dict(k=2000), node_labels=node_labels, node_size=4, scale=(1.6, 1.6)
)
plt.show()
