# %%
import numpy as np
import pandas as pd
import ipywidgets

# %%
student_df = pd.read_excel("./../data/student_list.xlsx")
student_df
# Out:
#    Matricule                  Email          Nom                Prenom  \
# 0    20/0003  kh_abdelmoumen@esi.dz  ABDELMOUMEN         HATEM MOHAMED
# 1    20/0188        kn_ameur@esi.dz        AMEUR                NASSIM
# 2    20/0280    kr_baaguigui@esi.dz   BAAGUIGUI                 RAMZI
# 3    20/0278       km_bekkar@esi.dz      BEKKAR                MERWAN
# 4    20/0050     km_benbetka@esi.dz     BENBETKA              MAROUANE
# 5    20/0142   kh_benouaklil@esi.dz   BENOUAKLIL              HODHAIFA
# 6    20/0119     kw_bouhedda@esi.dz     BOUHEDDA                 WALID
# 7    20/0023     ky_boukacem@esi.dz     BOUKACEM                YOUNES
# 8    20/0260   ki_boumazouza@esi.dz   BOUMAZOUZA            INES MANEL
# 9    20/0011      km_bourzag@esi.dz      BOURZAG        MOHAMED CHAKIB
# 10   20/0132     ki_chouchou@esi.dz     CHOUCHOU        IBTISSAM FATMA
# 11   20/0015    ks_chouikrat@esi.dz    CHOUIKRAT               SABRINA
# ...

# %%
student_list_df = pd.DataFrame.from_dict({
    'id': student_df.Matricule,
    'email': student_df.Email,
    'first_name': student_df.Prenom,
    'last_name': student_df.Nom
})
student_list_df
# Out:
#          id                  email            first_name    last_name
# 0   20/0003  kh_abdelmoumen@esi.dz         HATEM MOHAMED  ABDELMOUMEN
# 1   20/0188        kn_ameur@esi.dz                NASSIM        AMEUR
# 2   20/0280    kr_baaguigui@esi.dz                RAMZI    BAAGUIGUI
# 3   20/0278       km_bekkar@esi.dz               MERWAN       BEKKAR
# 4   20/0050     km_benbetka@esi.dz              MAROUANE     BENBETKA
# 5   20/0142   kh_benouaklil@esi.dz              HODHAIFA   BENOUAKLIL
# 6   20/0119     kw_bouhedda@esi.dz                 WALID     BOUHEDDA
# 7   20/0023     ky_boukacem@esi.dz                YOUNES     BOUKACEM
# 8   20/0260   ki_boumazouza@esi.dz            INES MANEL   BOUMAZOUZA
# 9   20/0011      km_bourzag@esi.dz        MOHAMED CHAKIB      BOURZAG
# 10  20/0132     ki_chouchou@esi.dz        IBTISSAM FATMA     CHOUCHOU
# 11  20/0015    ks_chouikrat@esi.dz               SABRINA    CHOUIKRAT
# ...

# %%
student_list_df.to_csv('./../data/student_list.csv')
