# %% [markdown]
#     ## Provided Dataset Evaluation

# %%
import numpy as np
import networkx as nx
import pandas as pd
from utils.louvain import LouvainMachine

# %%
# read the provided dataset
gml_file_path = \
'./../../dataset_generation/data/evaluation/DataSets/réels/dolphins/dolphins.gml'
G = nx.read_gml(gml_file_path)

# %%
louvain = LouvainMachine(G)

# %%
louvain.solve_communities()
# Out:
# neighbor communities ['SN9', 'Haecksel', 'Fish', 'TR77', 'Grin', 'SN96']
# node: Beak, source: Beak, destination: SN9, value: 0.006289308176100629
# choosing maximum action >>>>node: Beak, source: Beak, destination: SN9, value: 0.006289308176100629
# neighbor communities ['Knit', 'SN90', 'Upbang', 'Jet', 'Number1', 'Oscar', 'Notch', 'SN100']
# node: Beescratch, source: Beescratch, destination: Knit, value: 0.006289308176100629
# choosing maximum action >>>>node: Beescratch, source: Beescratch, destination: Knit, value: 0.006289308176100629
# neighbor communities ['SN96', 'Thumper', 'Zipfel', 'Fish']
# node: Bumper, source: Bumper, destination: SN96, value: 0.006289308176100629
# choosing maximum action >>>>node: Bumper, source: Bumper, destination: SN96, value: 0.006289308176100629
# neighbor communities ['Grin', 'Double', 'Zap']
# node: CCL, source: CCL, destination: Grin, value: 0.006289308176100629
# choosing maximum action >>>>node: CCL, source: CCL, destination: Grin, value: 0.006289308176100629
# neighbor communities ['Trigger']
# node: Cross, source: Cross, destination: Trigger, value: 0.006289308176100629
# choosing maximum action >>>>node: Cross, source: Cross, destination: Trigger, value: 0.006289308176100629
# neighbor communities ['Web', 'Wave', 'Feather', 'Gallatin']
# node: DN16, source: DN16, destination: Web, value: 0.006289308176100629
# choosing maximum action >>>>node: DN16, source: DN16, destination: Web, value: 0.006289308176100629
# neighbor communities ['Feather', 'Upbang', 'Jet', 'Web', 'Wave', 'Gallatin']
# node: DN21, source: DN21, destination: Feather, value: 0.006289308176100629
# choosing maximum action >>>>node: DN21, source: DN21, destination: Feather, value: 0.006289308176100629
# neighbor communities ['Knit', 'SN9', 'PL', 'Upbang', 'Number1']
# node: DN63, source: DN63, destination: PL, value: 0.006289308176100629
# choosing maximum action >>>>node: DN63, source: DN63, destination: PL, value: 0.006289308176100629
# neighbor communities ['Topless', 'Oscar', 'SN4', 'Grin', 'Kringel', 'Zap']
# node: Double, source: Double, destination: Topless, value: 0.006289308176100629
# choosing maximum action >>>>node: Double, source: Double, destination: Topless, value: 0.006289308176100629
# neighbor communities ['SN90', 'Feather', 'Jet', 'Web', 'Ripplefluke', 'Gallatin']
# node: Feather, source: Feather, destination: Web, value: 0.012301728570863495
# choosing maximum action >>>>node: Feather, source: Feather, destination: Web, value: 0.012301728570863495
# neighbor communities ['SN96', 'SN9', 'TR77', 'Patchback']
# node: Fish, source: Fish, destination: SN96, value: 0.012380839365531427
# choosing maximum action >>>>node: Fish, source: Fish, destination: SN96, value: 0.012380839365531427
# neighbor communities ['Trigger']
# node: Five, source: Five, destination: Trigger, value: 0.006249752778766663
# choosing maximum action >>>>node: Five, source: Five, destination: Trigger, value: 0.006249752778766663
# neighbor communities ['Scabs']
# node: Fork, source: Fork, destination: Scabs, value: 0.006289308176100629
# choosing maximum action >>>>node: Fork, source: Fork, destination: Scabs, value: 0.006289308176100629
# neighbor communities ['SN90', 'Feather', 'Upbang', 'Jet', 'Web', 'Ripplefluke']
# node: Gallatin, source: Gallatin, destination: Web, value: 0.017918594992286697
# choosing maximum action >>>>node: Gallatin, source: Gallatin, destination: Web, value: 0.017918594992286697
# neighbor communities ['Shmuddel', 'SN9', 'MN83', 'Hook', 'TSN103', 'Scabs', 'TR99', 'Stripes', 'SN4', 'Grin', 'SN63']
# node: Grin, source: Grin, destination: SN9, value: 0.012103951584193664
# choosing maximum action >>>>node: Grin, source: Grin, destination: SN9, value: 0.012103951584193664
# neighbor communities ['SN9', 'MN83', 'Topless', 'Jonah', 'Vau', 'Zap']
# node: Haecksel, source: Haecksel, destination: SN9, value: 0.011747953008187968
# choosing maximum action >>>>node: Haecksel, source: Haecksel, destination: SN9, value: 0.011747953008187968
# neighbor communities ['SN9', 'Scabs', 'TR99', 'SN4', 'SN63', 'Kringel']
# node: Hook, source: Hook, destination: TR99, value: 0.006289308176100629
# choosing maximum action >>>>node: Hook, source: Hook, destination: TR99, value: 0.006289308176100629
# neighbor communities ['MN23', 'Knit', 'Feather', 'Number1', 'Web', 'Mus', 'Quasi']
# node: Jet, source: Jet, destination: Web, value: 0.01673193307226771
# choosing maximum action >>>>node: Jet, source: Jet, destination: Web, value: 0.01673193307226771
# neighbor communities ['Trigger', 'SN9', 'MN83', 'Patchback', 'Topless', 'MN105', 'Kringel']
# node: Jonah, source: Jonah, destination: MN83, value: 0.006289308176100629
# choosing maximum action >>>>node: Jonah, source: Jonah, destination: MN83, value: 0.006289308176100629
# neighbor communities ['Upbang', 'Knit', 'PL']
# node: Knit, source: Knit, destination: PL, value: 0.012420394762865394
# choosing maximum action >>>>node: Knit, source: Knit, destination: PL, value: 0.012420394762865394
# neighbor communities ['MN83', 'TR99', 'Topless', 'Oscar', 'TR77', 'SN63', 'Thumper', 'SN100']
# node: Kringel, source: Kringel, destination: TR99, value: 0.012222617776195563
# choosing maximum action >>>>node: Kringel, source: Kringel, destination: TR99, value: 0.012222617776195563
# neighbor communities ['Trigger', 'MN83', 'Scabs', 'Patchback', 'Topless', 'SN4']
# node: MN105, source: MN105, destination: Patchback, value: 0.006289308176100629
# choosing maximum action >>>>node: MN105, source: MN105, destination: Patchback, value: 0.006289308176100629
# neighbor communities ['Web']
# node: MN23, source: MN23, destination: Web, value: 0.005933309600094933
# choosing maximum action >>>>node: MN23, source: MN23, destination: Web, value: 0.005933309600094933
# neighbor communities ['Trigger', 'Topless', 'SN100']
# node: MN60, source: MN60, destination: SN100, value: 0.006289308176100629
# choosing maximum action >>>>node: MN60, source: MN60, destination: SN100, value: 0.006289308176100629
# neighbor communities ['Trigger', 'SN9', 'MN83', 'Patchback', 'Topless']
# node: MN83, source: MN83, destination: SN9, value: 0.011391954432182272
# choosing maximum action >>>>node: MN83, source: MN83, destination: SN9, value: 0.011391954432182272
# neighbor communities ['Web', 'Number1', 'Notch']
# node: Mus, source: Mus, destination: Number1, value: 0.006289308176100629
# choosing maximum action >>>>node: Mus, source: Mus, destination: Number1, value: 0.006289308176100629
# neighbor communities ['Knit', 'Number1']
# node: Notch, source: Notch, destination: Number1, value: 0.01245995016019936
# choosing maximum action >>>>node: Notch, source: Notch, destination: Number1, value: 0.01245995016019936
# neighbor communities ['Web', 'Knit', 'PL', 'Number1']
# node: Number1, source: Number1, destination: Number1, value: 0.011985285392191765
# choosing maximum action >>>>node: Number1, source: Number1, destination: Number1, value: 0.011985285392191765
# neighbor communities ['Knit', 'PL', 'TR99', 'Topless', 'TR77']
# node: Oscar, source: Oscar, destination: Knit, value: 0.006289308176100629
# choosing maximum action >>>>node: Oscar, source: Oscar, destination: Knit, value: 0.006289308176100629
# neighbor communities ['Trigger', 'SN9', 'MN83', 'TSN103', 'Patchback', 'Stripes', 'Topless', 'SMN5', 'SN96']
# node: Patchback, source: Patchback, destination: MN83, value: 0.006289308176100629
# choosing maximum action >>>>node: Patchback, source: Patchback, destination: MN83, value: 0.006289308176100629
# neighbor communities ['SN96', 'Knit', 'TR77', 'PL']
# node: PL, source: PL, destination: PL, value: 0.011985285392191765
# choosing maximum action >>>>node: PL, source: PL, destination: PL, value: 0.011985285392191765
# neighbor communities ['Web']
# node: Quasi, source: Quasi, destination: Web, value: 0.005893754202760967
# choosing maximum action >>>>node: Quasi, source: Quasi, destination: Web, value: 0.005893754202760967
# neighbor communities ['Web', 'Zig']
# node: Ripplefluke, source: Ripplefluke, destination: Web, value: 0.011273288240180373
# choosing maximum action >>>>node: Ripplefluke, source: Ripplefluke, destination: Web, value: 0.011273288240180373
# neighbor communities ['Shmuddel', 'SN9', 'Scabs', 'TR99', 'Patchback', 'Stripes', 'SN4', 'SN63']
# node: Scabs, source: Scabs, destination: TR99, value: 0.011391954432182272
# choosing maximum action >>>>node: Scabs, source: Scabs, destination: TR99, value: 0.011391954432182272
# neighbor communities ['SN9', 'TR99', 'SN4', 'Thumper', 'TR88']
# node: Shmuddel, source: Shmuddel, destination: SN4, value: 0.006289308176100629
# choosing maximum action >>>>node: Shmuddel, source: Shmuddel, destination: SN4, value: 0.006289308176100629
# neighbor communities ['MN83']
# node: SMN5, source: SMN5, destination: MN83, value: 0.006249752778766663
# choosing maximum action >>>>node: SMN5, source: SMN5, destination: MN83, value: 0.006249752778766663
# neighbor communities ['Knit', 'SN9', 'TR99', 'SN4', 'SN89', 'SN100', 'Zap']
# node: SN100, source: SN100, destination: SN89, value: 0.006289308176100629
# choosing maximum action >>>>node: SN100, source: SN100, destination: SN89, value: 0.006289308176100629
# neighbor communities ['SN9', 'TR99', 'Patchback', 'Topless', 'Stripes', 'SN4', 'Zipfel', 'SN89']
# node: SN4, source: SN4, destination: Topless, value: 0.01214350698152763
# choosing maximum action >>>>node: SN4, source: SN4, destination: Topless, value: 0.01214350698152763
# neighbor communities ['SN9', 'TSN103', 'TR99', 'Stripes', 'Whitetip', 'Thumper']
# node: SN63, source: SN63, destination: TR99, value: 0.017285708634943237
# choosing maximum action >>>>node: SN63, source: SN63, destination: TR99, value: 0.017285708634943237
# neighbor communities ['Web', 'SN89']
# node: SN89, source: SN89, destination: SN89, value: 0.006210197381432697
# choosing maximum action >>>>node: SN89, source: SN89, destination: SN89, value: 0.006210197381432697
# neighbor communities ['SN9', 'PL', 'TSN103', 'TR99', 'Topless', 'SN89']
# node: SN9, source: SN9, destination: SN9, value: 0.016652822277599778
# choosing maximum action >>>>node: SN9, source: SN9, destination: SN9, value: 0.016652822277599778
# neighbor communities ['Web', 'Knit', 'Upbang']
# node: SN90, source: SN90, destination: Web, value: 0.016296823701594083
# choosing maximum action >>>>node: SN90, source: SN90, destination: Web, value: 0.016296823701594083
# neighbor communities ['SN9', 'PL', 'TR99', 'TR77', 'SN96']
# node: SN96, source: SN96, destination: SN96, value: 0.011866619200189867
# choosing maximum action >>>>node: SN96, source: SN96, destination: SN96, value: 0.011866619200189867
# neighbor communities ['SN9', 'MN83', 'TR99', 'Topless', 'TSN83', 'TR120']
# node: Stripes, source: Stripes, destination: TR99, value: 0.01036351410149915
# choosing maximum action >>>>node: Stripes, source: Stripes, destination: TR99, value: 0.01036351410149915
# neighbor communities ['SN96', 'SN4', 'TR99']
# node: Thumper, source: Thumper, destination: TR99, value: 0.01099640045884261
# choosing maximum action >>>>node: Thumper, source: Thumper, destination: TR99, value: 0.01099640045884261
# neighbor communities ['Trigger', 'SN9', 'MN83', 'TR99', 'Patchback', 'Topless', 'SN100', 'Zap']
# node: Topless, source: Topless, destination: MN83, value: 0.011708397610854002
# choosing maximum action >>>>node: Topless, source: Topless, destination: MN83, value: 0.011708397610854002
# neighbor communities ['TR88', 'TR99']
# node: TR120, source: TR120, destination: TR88, value: 0.006289308176100629
# choosing maximum action >>>>node: TR120, source: TR120, destination: TR88, value: 0.006289308176100629
# neighbor communities ['Knit', 'SN9', 'PL', 'TR99', 'SN96']
# node: TR77, source: TR77, destination: SN96, value: 0.011866619200189867
# choosing maximum action >>>>node: TR77, source: TR77, destination: SN96, value: 0.011866619200189867
# neighbor communities ['Web']
# node: TR82, source: TR82, destination: Web, value: 0.00565642181875717
# choosing maximum action >>>>node: TR82, source: TR82, destination: Web, value: 0.00565642181875717
# neighbor communities ['TR88', 'SN4']
# node: TR88, source: TR88, destination: SN4, value: 0.006289308176100629
# choosing maximum action >>>>node: TR88, source: TR88, destination: SN4, value: 0.006289308176100629
# neighbor communities ['Trigger', 'SN9', 'MN83', 'TR99', 'SN96']
# node: TR99, source: TR99, destination: TR99, value: 0.015545271152248723
# choosing maximum action >>>>node: TR99, source: TR99, destination: TR99, value: 0.015545271152248723
# neighbor communities ['Trigger', 'SN9', 'MN83', 'TR99', 'Patchback', 'Vau', 'SN100']
# node: Trigger, source: Trigger, destination: MN83, value: 0.017285708634943237
# choosing maximum action >>>>node: Trigger, source: Trigger, destination: MN83, value: 0.017285708634943237
# neighbor communities ['SN9', 'MN83', 'TR99']
# node: TSN103, source: TSN103, destination: SN9, value: 0.011471065226850204
# choosing maximum action >>>>node: TSN103, source: TSN103, destination: SN9, value: 0.011471065226850204
# neighbor communities ['Zipfel', 'TR99']
# node: TSN83, source: TSN83, destination: Zipfel, value: 0.006289308176100629
# choosing maximum action >>>>node: TSN83, source: TSN83, destination: Zipfel, value: 0.006289308176100629
# neighbor communities ['Web', 'Knit', 'Feather', 'PL']
# node: Upbang, source: Upbang, destination: Web, value: 0.014160832245559906
# choosing maximum action >>>>node: Upbang, source: Upbang, destination: Web, value: 0.014160832245559906
# neighbor communities ['SN9', 'MN83']
# node: Vau, source: Vau, destination: MN83, value: 0.005735532613425102
# choosing maximum action >>>>node: Vau, source: Vau, destination: MN83, value: 0.005735532613425102
# neighbor communities ['Web', 'Feather']
# node: Wave, source: Wave, destination: Feather, value: 0.006289308176100629
# choosing maximum action >>>>node: Wave, source: Wave, destination: Feather, value: 0.006289308176100629
# neighbor communities ['Web', 'SN89', 'Feather']
# node: Web, source: Web, destination: Web, value: 0.03690518571259048
# choosing maximum action >>>>node: Web, source: Web, destination: Web, value: 0.03690518571259048
# neighbor communities ['TR99']
# node: Whitetip, source: Whitetip, destination: TR99, value: 0.005814643408093035
# choosing maximum action >>>>node: Whitetip, source: Whitetip, destination: TR99, value: 0.005814643408093035
# neighbor communities ['SN9', 'MN83', 'Topless', 'Grin', 'SN89']
# node: Zap, source: Zap, destination: Grin, value: 0.006289308176100629
# choosing maximum action >>>>node: Zap, source: Zap, destination: Grin, value: 0.006289308176100629
# neighbor communities ['Web']
# node: Zig, source: Zig, destination: Web, value: 0.005498200229421305
# choosing maximum action >>>>node: Zig, source: Zig, destination: Web, value: 0.005498200229421305
# neighbor communities ['SN96', 'Topless', 'Zipfel']
# node: Zipfel, source: Zipfel, destination: Topless, value: 0.006170641984098731
# choosing maximum action >>>>node: Zipfel, source: Zipfel, destination: Topless, value: 0.006170641984098731
#
# {'SN9': {'community': 'SN9', 'people_nodes': ['Beak', 'Grin', 'Haecksel', 'MN83', 'SN9', 'TSN103']}, 'Knit': {'community': 'Knit', 'people_nodes': ['Beescratch', 'Oscar']}, 'SN96': {'community': 'SN96', 'people_nodes': ['Bumper', 'Fish', 'SN96', 'TR77']}, 'Grin': {'community': 'Grin', 'people_nodes': ['CCL', 'Zap']}, 'Trigger': {'community': 'Trigger', 'people_nodes': ['Cross', 'Five']}, 'Web': {'community': 'Web', 'people_nodes': ['DN16', 'Feather', 'Gallatin', 'Jet', 'MN23', 'Quasi', 'Ripplefluke', 'SN90', 'TR82', 'Upbang', 'Web', 'Zig']}, 'Feather': {'community': 'Feather', 'people_nodes': ['DN21', 'Wave']}, 'PL': {'community': 'PL', 'people_nodes': ['DN63', 'Knit', 'PL']}, 'Topless': {'community': 'Topless', 'people_nodes': ['Double', 'SN4', 'Zipfel']}, 'Scabs': {'community': 'Scabs', 'people_nodes': ['Fork']}, 'TR99': {'community': 'TR99', 'people_nodes': ['Hook', 'Kringel', 'Scabs', 'SN63', 'Stripes', 'Thumper', 'TR99', 'Whitetip']}, 'MN83': {'community': 'MN83', 'people_nodes': ['Jonah', 'Patchback', 'SMN5', 'Topless', 'Trigger', 'Vau']}, 'Patchback': {'community': 'Patchback', 'people_nodes': ['MN105']}, 'SN100': {'community': 'SN100', 'people_nodes': ['MN60']}, 'Number1': {'community': 'Number1', 'people_nodes': ['Mus', 'Notch', 'Number1']}, 'SN4': {'community': 'SN4', 'people_nodes': ['Shmuddel', 'TR88']}, 'SN89': {'community': 'SN89', 'people_nodes': ['SN100', 'SN89']}, 'TR88': {'community': 'TR88', 'people_nodes': ['TR120']}, 'Zipfel': {'community': 'Zipfel', 'people_nodes': ['TSN83']}}
# adding edges from necessary
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Topless', 'SN4', 'Grin', 'SN96', 'SN89']
# node: SN9, source: SN9, destination: SN9, value: 0.044499822000711994
# choosing maximum action >>>>node: SN9, source: SN9, destination: SN9, value: 0.044499822000711994
# neighbor communities ['Knit', 'PL', 'TR99', 'Number1', 'Topless', 'Web', 'SN96', 'SN89']
# node: Knit, source: Knit, destination: PL, value: 0.011154622048178475
# choosing maximum action >>>>node: Knit, source: Knit, destination: PL, value: 0.011154622048178475
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Topless', 'SN96']
# node: SN96, source: SN96, destination: SN96, value: 0.028282109093785847
# choosing maximum action >>>>node: SN96, source: SN96, destination: SN96, value: 0.028282109093785847
# neighbor communities ['SN9', 'MN83', 'Topless', 'Grin', 'SN89']
# node: Grin, source: Grin, destination: Topless, value: 0.012024840789525731
# choosing maximum action >>>>node: Grin, source: Grin, destination: Topless, value: 0.012024840789525731
# neighbor communities ['MN83']
# node: Trigger, source: Trigger, destination: MN83, value: 0.011945729994857799
# choosing maximum action >>>>node: Trigger, source: Trigger, destination: MN83, value: 0.011945729994857799
# neighbor communities ['Feather', 'PL', 'Number1', 'Web', 'SN89']
# node: Web, source: Web, destination: Web, value: 0.10300225465764803
# choosing maximum action >>>>node: Web, source: Web, destination: Web, value: 0.10300225465764803
# neighbor communities ['Web', 'Feather']
# node: Feather, source: Feather, destination: Web, value: 0.03192120564851074
# choosing maximum action >>>>node: Feather, source: Feather, destination: Web, value: 0.03192120564851074
# neighbor communities ['SN9', 'PL', 'Number1', 'Web', 'SN96']
# node: PL, source: PL, destination: PL, value: 0.028835884656461374
# choosing maximum action >>>>node: PL, source: PL, destination: PL, value: 0.028835884656461374
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Patchback', 'Topless', 'SN4', 'Zipfel', 'SN96', 'SN89']
# node: Topless, source: Topless, destination: Topless, value: 0.021597246944345557
# choosing maximum action >>>>node: Topless, source: Topless, destination: Topless, value: 0.021597246944345557
# neighbor communities ['TR99']
# node: Scabs, source: Scabs, destination: TR99, value: 0.005775088010759068
# choosing maximum action >>>>node: Scabs, source: Scabs, destination: TR99, value: 0.005775088010759068
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Patchback', 'Topless', 'SN4', 'Zipfel', 'SN96', 'SN89', 'TR88']
# node: TR99, source: TR99, destination: TR99, value: 0.06645306752106324
# choosing maximum action >>>>node: TR99, source: TR99, destination: TR99, value: 0.06645306752106324
# neighbor communities ['SN9', 'MN83', 'TR99', 'Patchback', 'Topless', 'SN96', 'SN100']
# node: MN83, source: MN83, destination: MN83, value: 0.0502353546141371
# choosing maximum action >>>>node: MN83, source: MN83, destination: MN83, value: 0.0502353546141371
# neighbor communities ['Topless', 'MN83', 'TR99']
# node: Patchback, source: Patchback, destination: MN83, value: 0.022783908864364544
# choosing maximum action >>>>node: Patchback, source: Patchback, destination: MN83, value: 0.022783908864364544
# neighbor communities ['SN89', 'MN83']
# node: SN100, source: SN100, destination: MN83, value: 0.010917289664174677
# choosing maximum action >>>>node: SN100, source: SN100, destination: MN83, value: 0.010917289664174677
# neighbor communities ['Web', 'Number1', 'PL']
# node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# choosing maximum action >>>>node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# neighbor communities ['SN9', 'TR99', 'Topless', 'SN4', 'TR88']
# node: SN4, source: SN4, destination: TR99, value: 0.009255962976148096
# choosing maximum action >>>>node: SN4, source: SN4, destination: TR99, value: 0.009255962976148096
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Topless', 'Web', 'SN89']
# node: SN89, source: SN89, destination: Topless, value: 0.01099640045884261
# choosing maximum action >>>>node: SN89, source: SN89, destination: Topless, value: 0.01099640045884261
# neighbor communities ['TR99']
# node: TR88, source: TR88, destination: TR99, value: 0.011233732842846407
# choosing maximum action >>>>node: TR88, source: TR88, destination: TR99, value: 0.011233732842846407
# neighbor communities ['Topless', 'TR99']
# node: Zipfel, source: Zipfel, destination: Topless, value: 0.00565642181875717
# choosing maximum action >>>>node: Zipfel, source: Zipfel, destination: Topless, value: 0.00565642181875717
#
# {'SN9': {'community': 'SN9', 'people_nodes': ['Beak', 'Grin', 'Haecksel', 'MN83', 'SN9', 'TSN103']}, 'PL': {'community': 'PL', 'people_nodes': ['Beescratch', 'Oscar', 'DN63', 'Knit', 'PL']}, 'SN96': {'community': 'SN96', 'people_nodes': ['Bumper', 'Fish', 'SN96', 'TR77']}, 'Topless': {'community': 'Topless', 'people_nodes': ['CCL', 'Zap', 'Double', 'SN4', 'Zipfel', 'SN100', 'SN89', 'TSN83']}, 'MN83': {'community': 'MN83', 'people_nodes': ['Cross', 'Five', 'Jonah', 'Patchback', 'SMN5', 'Topless', 'Trigger', 'Vau', 'MN105', 'MN60']}, 'Web': {'community': 'Web', 'people_nodes': ['DN16', 'Feather', 'Gallatin', 'Jet', 'MN23', 'Quasi', 'Ripplefluke', 'SN90', 'TR82', 'Upbang', 'Web', 'Zig', 'DN21', 'Wave']}, 'TR99': {'community': 'TR99', 'people_nodes': ['Fork', 'Hook', 'Kringel', 'Scabs', 'SN63', 'Stripes', 'Thumper', 'TR99', 'Whitetip', 'Shmuddel', 'TR88', 'TR120']}, 'Number1': {'community': 'Number1', 'people_nodes': ['Mus', 'Notch', 'Number1']}}
# adding edges from necessary
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Topless', 'SN96']
# node: SN9, source: SN9, destination: SN9, value: 0.044499822000711994
# choosing maximum action >>>>node: SN9, source: SN9, destination: SN9, value: 0.044499822000711994
# neighbor communities ['SN9', 'PL', 'TR99', 'Number1', 'Topless', 'Web', 'SN96']
# node: PL, source: PL, destination: PL, value: 0.032751868992524025
# choosing maximum action >>>>node: PL, source: PL, destination: PL, value: 0.032751868992524025
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Topless', 'SN96']
# node: SN96, source: SN96, destination: SN96, value: 0.028282109093785847
# choosing maximum action >>>>node: SN96, source: SN96, destination: SN96, value: 0.028282109093785847
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Topless', 'Web', 'SN96']
# node: Topless, source: Topless, destination: Topless, value: 0.045923816304734785
# choosing maximum action >>>>node: Topless, source: Topless, destination: Topless, value: 0.045923816304734785
# neighbor communities ['SN9', 'MN83', 'TR99', 'Topless', 'SN96']
# node: MN83, source: MN83, destination: MN83, value: 0.07847790831058898
# choosing maximum action >>>>node: MN83, source: MN83, destination: MN83, value: 0.07847790831058898
# neighbor communities ['Web', 'Topless', 'PL', 'Number1']
# node: Web, source: Web, destination: Web, value: 0.13622878841817965
# choosing maximum action >>>>node: Web, source: Web, destination: Web, value: 0.13622878841817965
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Topless', 'SN96']
# node: TR99, source: TR99, destination: TR99, value: 0.08718009572406155
# choosing maximum action >>>>node: TR99, source: TR99, destination: TR99, value: 0.08718009572406155
# neighbor communities ['Web', 'Number1', 'PL']
# node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# choosing maximum action >>>>node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
#
# {'SN9': {'community': 'SN9', 'people_nodes': ['Beak', 'Grin', 'Haecksel', 'MN83', 'SN9', 'TSN103']}, 'PL': {'community': 'PL', 'people_nodes': ['Beescratch', 'Oscar', 'DN63', 'Knit', 'PL']}, 'SN96': {'community': 'SN96', 'people_nodes': ['Bumper', 'Fish', 'SN96', 'TR77']}, 'Topless': {'community': 'Topless', 'people_nodes': ['CCL', 'Zap', 'Double', 'SN4', 'Zipfel', 'SN100', 'SN89', 'TSN83']}, 'MN83': {'community': 'MN83', 'people_nodes': ['Cross', 'Five', 'Jonah', 'Patchback', 'SMN5', 'Topless', 'Trigger', 'Vau', 'MN105', 'MN60']}, 'Web': {'community': 'Web', 'people_nodes': ['DN16', 'Feather', 'Gallatin', 'Jet', 'MN23', 'Quasi', 'Ripplefluke', 'SN90', 'TR82', 'Upbang', 'Web', 'Zig', 'DN21', 'Wave']}, 'TR99': {'community': 'TR99', 'people_nodes': ['Fork', 'Hook', 'Kringel', 'Scabs', 'SN63', 'Stripes', 'Thumper', 'TR99', 'Whitetip', 'Shmuddel', 'TR88', 'TR120']}, 'Number1': {'community': 'Number1', 'people_nodes': ['Mus', 'Notch', 'Number1']}}
# adding edges from necessary

# %%
louvain.display_graph_history_tables(display_fn=lambda x: display(x))
# Out:
# --------------------------Graph in the phase: 1--------------------------
#          nodes   community  people_nodes
# 0         Beak        Beak        [Beak]
# 1   Beescratch  Beescratch  [Beescratch]
# 2       Bumper      Bumper      [Bumper]
# 3          CCL         CCL         [CCL]
# 4        Cross       Cross       [Cross]
# ..         ...         ...           ...
# 57         Web         Web         [Web]
# 58    Whitetip    Whitetip    [Whitetip]
# 59         Zap         Zap         [Zap]
# 60         Zig         Zig         [Zig]
# 61      Zipfel      Zipfel      [Zipfel]
#
# [62 rows x 3 columns]
#      edges   node_a    node_b  weight
# 0        1     Beak      Fish       1
# 1        2     Beak      Grin       1
# 2        3     Beak  Haecksel       1
# 3        4     Beak       SN9       1
# 4        5     Beak      SN96       1
# ..     ...      ...       ...     ...
# 154    155     TR82       Web       1
# 155    156     TR99   Trigger       1
# 156    157  Trigger       Vau       1
# 157    158    TSN83    Zipfel       1
# 158    159   Upbang       Web       1
#
# [159 rows x 4 columns]
# _______________________________________________________________________________________________________
# ---------------Possible actions for node Beak in phase 1---------------
#    node source destination     value
# 0  Beak   Beak         SN9  0.006289
# 1  Beak   Beak    Haecksel  0.006289
# 2  Beak   Beak        Fish  0.006289
# 3  Beak   Beak        TR77  0.006289
# 4  Beak   Beak        Grin  0.006289
# 5  Beak   Beak        SN96  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Beak, source: Beak, destination: SN9, value: 0.006289308176100629
# ---------------Possible actions for node Beescratch in phase 1---------------
#          node      source destination     value
# 0  Beescratch  Beescratch        Knit  0.006289
# 1  Beescratch  Beescratch        SN90  0.006289
# 2  Beescratch  Beescratch      Upbang  0.006289
# 3  Beescratch  Beescratch         Jet  0.006289
# 4  Beescratch  Beescratch     Number1  0.006289
# 5  Beescratch  Beescratch       Oscar  0.006289
# 6  Beescratch  Beescratch       Notch  0.006289
# 7  Beescratch  Beescratch       SN100  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Beescratch, source: Beescratch, destination: Knit, value: 0.006289308176100629
# ---------------Possible actions for node Bumper in phase 1---------------
#      node  source destination     value
# 0  Bumper  Bumper        SN96  0.006289
# 1  Bumper  Bumper     Thumper  0.006289
# 2  Bumper  Bumper      Zipfel  0.006289
# 3  Bumper  Bumper        Fish  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Bumper, source: Bumper, destination: SN96, value: 0.006289308176100629
# ---------------Possible actions for node CCL in phase 1---------------
#   node source destination     value
# 0  CCL    CCL        Grin  0.006289
# 1  CCL    CCL      Double  0.006289
# 2  CCL    CCL         Zap  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: CCL, source: CCL, destination: Grin, value: 0.006289308176100629
# ---------------Possible actions for node Cross in phase 1---------------
#     node source destination     value
# 0  Cross  Cross     Trigger  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Cross, source: Cross, destination: Trigger, value: 0.006289308176100629
# ---------------Possible actions for node DN16 in phase 1---------------
#    node source destination     value
# 0  DN16   DN16         Web  0.006289
# 1  DN16   DN16        Wave  0.006289
# 2  DN16   DN16     Feather  0.006289
# 3  DN16   DN16    Gallatin  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: DN16, source: DN16, destination: Web, value: 0.006289308176100629
# ---------------Possible actions for node DN21 in phase 1---------------
#    node source destination     value
# 0  DN21   DN21     Feather  0.006289
# 1  DN21   DN21      Upbang  0.006289
# 2  DN21   DN21         Jet  0.006289
# 3  DN21   DN21         Web  0.006052
# 4  DN21   DN21        Wave  0.006289
# 5  DN21   DN21    Gallatin  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: DN21, source: DN21, destination: Feather, value: 0.006289308176100629
# ---------------Possible actions for node DN63 in phase 1---------------
#    node source destination     value
# 0  DN63   DN63        Knit  0.006092
# 1  DN63   DN63         SN9  0.006092
# 2  DN63   DN63          PL  0.006289
# 3  DN63   DN63      Upbang  0.006289
# 4  DN63   DN63     Number1  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: DN63, source: DN63, destination: PL, value: 0.006289308176100629
# ---------------Possible actions for node Double in phase 1---------------
#      node  source destination     value
# 0  Double  Double     Topless  0.006289
# 1  Double  Double       Oscar  0.006289
# 2  Double  Double         SN4  0.006289
# 3  Double  Double        Grin  0.006052
# 4  Double  Double     Kringel  0.006289
# 5  Double  Double         Zap  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Double, source: Double, destination: Topless, value: 0.006289308176100629
# ---------------Possible actions for node Feather in phase 1---------------
#       node   source  destination     value
# 0  Feather  Feather         SN90  0.006289
# 1  Feather  Feather      Feather  0.006012
# 2  Feather  Feather          Jet  0.006289
# 3  Feather  Feather          Web  0.012302
# 4  Feather  Feather  Ripplefluke  0.006289
# 5  Feather  Feather     Gallatin  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Feather, source: Feather, destination: Web, value: 0.012301728570863495
# ---------------Possible actions for node Fish in phase 1---------------
#    node source destination     value
# 0  Fish   Fish        SN96  0.012381
# 1  Fish   Fish         SN9  0.006092
# 2  Fish   Fish        TR77  0.006289
# 3  Fish   Fish   Patchback  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Fish, source: Fish, destination: SN96, value: 0.012380839365531427
# ---------------Possible actions for node Five in phase 1---------------
#    node source destination    value
# 0  Five   Five     Trigger  0.00625
# the action among the previous actions that maximizes modularity gain is:
# node: Five, source: Five, destination: Trigger, value: 0.006249752778766663
# ---------------Possible actions for node Fork in phase 1---------------
#    node source destination     value
# 0  Fork   Fork       Scabs  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Fork, source: Fork, destination: Scabs, value: 0.006289308176100629
# ---------------Possible actions for node Gallatin in phase 1---------------
#        node    source  destination     value
# 0  Gallatin  Gallatin         SN90  0.006289
# 1  Gallatin  Gallatin      Feather  0.006289
# 2  Gallatin  Gallatin       Upbang  0.006289
# 3  Gallatin  Gallatin          Jet  0.006289
# 4  Gallatin  Gallatin          Web  0.017919
# 5  Gallatin  Gallatin  Ripplefluke  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Gallatin, source: Gallatin, destination: Web, value: 0.017918594992286697
# ---------------Possible actions for node Grin in phase 1---------------
#     node source destination     value
# 0   Grin   Grin    Shmuddel  0.006289
# 1   Grin   Grin         SN9  0.012104
# 2   Grin   Grin        MN83  0.006289
# 3   Grin   Grin        Hook  0.006289
# 4   Grin   Grin      TSN103  0.006289
# 5   Grin   Grin       Scabs  0.005815
# 6   Grin   Grin        TR99  0.006289
# 7   Grin   Grin     Stripes  0.006289
# 8   Grin   Grin         SN4  0.006289
# 9   Grin   Grin        Grin  0.005815
# 10  Grin   Grin        SN63  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Grin, source: Grin, destination: SN9, value: 0.012103951584193664
# ---------------Possible actions for node Haecksel in phase 1---------------
#        node    source destination     value
# 0  Haecksel  Haecksel         SN9  0.011748
# 1  Haecksel  Haecksel        MN83  0.006289
# 2  Haecksel  Haecksel     Topless  0.006012
# 3  Haecksel  Haecksel       Jonah  0.006289
# 4  Haecksel  Haecksel         Vau  0.006289
# 5  Haecksel  Haecksel         Zap  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Haecksel, source: Haecksel, destination: SN9, value: 0.011747953008187968
# ---------------Possible actions for node Hook in phase 1---------------
#    node source destination     value
# 0  Hook   Hook         SN9  0.005103
# 1  Hook   Hook       Scabs  0.006052
# 2  Hook   Hook        TR99  0.006289
# 3  Hook   Hook         SN4  0.006289
# 4  Hook   Hook        SN63  0.006289
# 5  Hook   Hook     Kringel  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Hook, source: Hook, destination: TR99, value: 0.006289308176100629
# ---------------Possible actions for node Jet in phase 1---------------
#   node source destination     value
# 0  Jet    Jet        MN23  0.006289
# 1  Jet    Jet        Knit  0.005933
# 2  Jet    Jet     Feather  0.006289
# 3  Jet    Jet     Number1  0.006289
# 4  Jet    Jet         Web  0.016732
# 5  Jet    Jet         Mus  0.006289
# 6  Jet    Jet       Quasi  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Jet, source: Jet, destination: Web, value: 0.01673193307226771
# ---------------Possible actions for node Jonah in phase 1---------------
#     node source destination     value
# 0  Jonah  Jonah     Trigger  0.005736
# 1  Jonah  Jonah         SN9  0.004905
# 2  Jonah  Jonah        MN83  0.006289
# 3  Jonah  Jonah   Patchback  0.006289
# 4  Jonah  Jonah     Topless  0.006012
# 5  Jonah  Jonah       MN105  0.006289
# 6  Jonah  Jonah     Kringel  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Jonah, source: Jonah, destination: MN83, value: 0.006289308176100629
# ---------------Possible actions for node Knit in phase 1---------------
#    node source destination     value
# 0  Knit   Knit      Upbang  0.006289
# 1  Knit   Knit        Knit  0.006131
# 2  Knit   Knit          PL  0.012420
# the action among the previous actions that maximizes modularity gain is:
# node: Knit, source: Knit, destination: PL, value: 0.012420394762865394
# ---------------Possible actions for node Kringel in phase 1---------------
#       node   source destination     value
# 0  Kringel  Kringel        MN83  0.005933
# 1  Kringel  Kringel        TR99  0.012223
# 2  Kringel  Kringel     Topless  0.005933
# 3  Kringel  Kringel       Oscar  0.006289
# 4  Kringel  Kringel        TR77  0.006289
# 5  Kringel  Kringel        SN63  0.006289
# 6  Kringel  Kringel     Thumper  0.006289
# 7  Kringel  Kringel       SN100  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Kringel, source: Kringel, destination: TR99, value: 0.012222617776195563
# ---------------Possible actions for node MN105 in phase 1---------------
#     node source destination     value
# 0  MN105  MN105     Trigger  0.005815
# 1  MN105  MN105        MN83  0.006052
# 2  MN105  MN105       Scabs  0.006052
# 3  MN105  MN105   Patchback  0.006289
# 4  MN105  MN105     Topless  0.006052
# 5  MN105  MN105         SN4  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: MN105, source: MN105, destination: Patchback, value: 0.006289308176100629
# ---------------Possible actions for node MN23 in phase 1---------------
#    node source destination     value
# 0  MN23   MN23         Web  0.005933
# the action among the previous actions that maximizes modularity gain is:
# node: MN23, source: MN23, destination: Web, value: 0.005933309600094933
# ---------------Possible actions for node MN60 in phase 1---------------
#    node source destination     value
# 0  MN60   MN60     Trigger  0.006052
# 1  MN60   MN60     Topless  0.006171
# 2  MN60   MN60       SN100  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: MN60, source: MN60, destination: SN100, value: 0.006289308176100629
# ---------------Possible actions for node MN83 in phase 1---------------
#    node source destination     value
# 0  MN83   MN83     Trigger  0.005815
# 1  MN83   MN83         SN9  0.011392
# 2  MN83   MN83        MN83  0.006052
# 3  MN83   MN83   Patchback  0.006052
# 4  MN83   MN83     Topless  0.006052
# the action among the previous actions that maximizes modularity gain is:
# node: MN83, source: MN83, destination: SN9, value: 0.011391954432182272
# ---------------Possible actions for node Mus in phase 1---------------
#   node source destination     value
# 0  Mus    Mus         Web  0.005103
# 1  Mus    Mus     Number1  0.006289
# 2  Mus    Mus       Notch  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Mus, source: Mus, destination: Number1, value: 0.006289308176100629
# ---------------Possible actions for node Notch in phase 1---------------
#     node source destination     value
# 0  Notch  Notch        Knit  0.006289
# 1  Notch  Notch     Number1  0.012460
# the action among the previous actions that maximizes modularity gain is:
# node: Notch, source: Notch, destination: Number1, value: 0.01245995016019936
# ---------------Possible actions for node Number1 in phase 1---------------
#       node   source destination     value
# 0  Number1  Number1         Web  0.004312
# 1  Number1  Number1        Knit  0.006289
# 2  Number1  Number1          PL  0.005696
# 3  Number1  Number1     Number1  0.011985
# the action among the previous actions that maximizes modularity gain is:
# node: Number1, source: Number1, destination: Number1, value: 0.011985285392191765
# ---------------Possible actions for node Oscar in phase 1---------------
#     node source destination     value
# 0  Oscar  Oscar        Knit  0.006289
# 1  Oscar  Oscar          PL  0.005696
# 2  Oscar  Oscar        TR99  0.005696
# 3  Oscar  Oscar     Topless  0.006092
# 4  Oscar  Oscar        TR77  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Oscar, source: Oscar, destination: Knit, value: 0.006289308176100629
# ---------------Possible actions for node Patchback in phase 1---------------
#         node     source destination     value
# 0  Patchback  Patchback     Trigger  0.005577
# 1  Patchback  Patchback         SN9  0.003797
# 2  Patchback  Patchback        MN83  0.006289
# 3  Patchback  Patchback      TSN103  0.006289
# 4  Patchback  Patchback   Patchback  0.005933
# 5  Patchback  Patchback     Stripes  0.006289
# 6  Patchback  Patchback     Topless  0.005933
# 7  Patchback  Patchback        SMN5  0.006289
# 8  Patchback  Patchback        SN96  0.005221
# the action among the previous actions that maximizes modularity gain is:
# node: Patchback, source: Patchback, destination: MN83, value: 0.006289308176100629
# ---------------Possible actions for node PL in phase 1---------------
#   node source destination     value
# 0   PL     PL        SN96  0.005696
# 1   PL     PL        Knit  0.006092
# 2   PL     PL        TR77  0.006289
# 3   PL     PL          PL  0.011985
# the action among the previous actions that maximizes modularity gain is:
# node: PL, source: PL, destination: PL, value: 0.011985285392191765
# ---------------Possible actions for node Quasi in phase 1---------------
#     node source destination     value
# 0  Quasi  Quasi         Web  0.005894
# the action among the previous actions that maximizes modularity gain is:
# node: Quasi, source: Quasi, destination: Web, value: 0.005893754202760967
# ---------------Possible actions for node Ripplefluke in phase 1---------------
#           node       source destination     value
# 0  Ripplefluke  Ripplefluke         Web  0.011273
# 1  Ripplefluke  Ripplefluke         Zig  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Ripplefluke, source: Ripplefluke, destination: Web, value: 0.011273288240180373
# ---------------Possible actions for node Scabs in phase 1---------------
#     node source destination     value
# 0  Scabs  Scabs    Shmuddel  0.006289
# 1  Scabs  Scabs         SN9  0.009810
# 2  Scabs  Scabs       Scabs  0.005894
# 3  Scabs  Scabs        TR99  0.011392
# 4  Scabs  Scabs   Patchback  0.006289
# 5  Scabs  Scabs     Stripes  0.006289
# 6  Scabs  Scabs         SN4  0.006289
# 7  Scabs  Scabs        SN63  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Scabs, source: Scabs, destination: TR99, value: 0.011391954432182272
# ---------------Possible actions for node Shmuddel in phase 1---------------
#        node    source destination     value
# 0  Shmuddel  Shmuddel         SN9  0.004905
# 1  Shmuddel  Shmuddel        TR99  0.005300
# 2  Shmuddel  Shmuddel         SN4  0.006289
# 3  Shmuddel  Shmuddel     Thumper  0.006289
# 4  Shmuddel  Shmuddel        TR88  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Shmuddel, source: Shmuddel, destination: SN4, value: 0.006289308176100629
# ---------------Possible actions for node SMN5 in phase 1---------------
#    node source destination    value
# 0  SMN5   SMN5        MN83  0.00625
# the action among the previous actions that maximizes modularity gain is:
# node: SMN5, source: SMN5, destination: MN83, value: 0.006249752778766663
# ---------------Possible actions for node SN100 in phase 1---------------
#     node source destination     value
# 0  SN100  SN100        Knit  0.006012
# 1  SN100  SN100         SN9  0.004351
# 2  SN100  SN100        TR99  0.004905
# 3  SN100  SN100         SN4  0.006012
# 4  SN100  SN100        SN89  0.006289
# 5  SN100  SN100       SN100  0.006012
# 6  SN100  SN100         Zap  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: SN100, source: SN100, destination: SN89, value: 0.006289308176100629
# ---------------Possible actions for node SN4 in phase 1---------------
#   node source destination     value
# 0  SN4    SN4         SN9  0.009533
# 1  SN4    SN4        TR99  0.010403
# 2  SN4    SN4   Patchback  0.006289
# 3  SN4    SN4     Topless  0.012144
# 4  SN4    SN4     Stripes  0.006289
# 5  SN4    SN4         SN4  0.005854
# 6  SN4    SN4      Zipfel  0.006289
# 7  SN4    SN4        SN89  0.005854
# the action among the previous actions that maximizes modularity gain is:
# node: SN4, source: SN4, destination: Topless, value: 0.01214350698152763
# ---------------Possible actions for node SN63 in phase 1---------------
#    node source destination     value
# 0  SN63   SN63         SN9  0.004074
# 1  SN63   SN63      TSN103  0.006289
# 2  SN63   SN63        TR99  0.017286
# 3  SN63   SN63     Stripes  0.006289
# 4  SN63   SN63    Whitetip  0.006289
# 5  SN63   SN63     Thumper  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: SN63, source: SN63, destination: TR99, value: 0.017285708634943237
# ---------------Possible actions for node SN89 in phase 1---------------
#    node source destination     value
# 0  SN89   SN89         Web  0.005261
# 1  SN89   SN89        SN89  0.006210
# the action among the previous actions that maximizes modularity gain is:
# node: SN89, source: SN89, destination: SN89, value: 0.006210197381432697
# ---------------Possible actions for node SN9 in phase 1---------------
#   node source destination     value
# 0  SN9    SN9         SN9  0.016653
# 1  SN9    SN9          PL  0.005340
# 2  SN9    SN9      TSN103  0.006289
# 3  SN9    SN9        TR99  0.003758
# 4  SN9    SN9     Topless  0.005340
# 5  SN9    SN9        SN89  0.005973
# the action among the previous actions that maximizes modularity gain is:
# node: SN9, source: SN9, destination: SN9, value: 0.016652822277599778
# ---------------Possible actions for node SN90 in phase 1---------------
#    node source destination     value
# 0  SN90   SN90         Web  0.016297
# 1  SN90   SN90        Knit  0.006092
# 2  SN90   SN90      Upbang  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: SN90, source: SN90, destination: Web, value: 0.016296823701594083
# ---------------Possible actions for node SN96 in phase 1---------------
#    node source destination     value
# 0  SN96   SN96         SN9  0.004628
# 1  SN96   SN96          PL  0.005577
# 2  SN96   SN96        TR99  0.004391
# 3  SN96   SN96        TR77  0.006289
# 4  SN96   SN96        SN96  0.011867
# the action among the previous actions that maximizes modularity gain is:
# node: SN96, source: SN96, destination: SN96, value: 0.011866619200189867
# ---------------Possible actions for node Stripes in phase 1---------------
#       node   source destination     value
# 0  Stripes  Stripes         SN9  0.004351
# 1  Stripes  Stripes        MN83  0.005736
# 2  Stripes  Stripes        TR99  0.010364
# 3  Stripes  Stripes     Topless  0.005459
# 4  Stripes  Stripes       TSN83  0.006289
# 5  Stripes  Stripes       TR120  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Stripes, source: Stripes, destination: TR99, value: 0.01036351410149915
# ---------------Possible actions for node Thumper in phase 1---------------
#       node   source destination     value
# 0  Thumper  Thumper        SN96  0.005815
# 1  Thumper  Thumper         SN4  0.006289
# 2  Thumper  Thumper        TR99  0.010996
# the action among the previous actions that maximizes modularity gain is:
# node: Thumper, source: Thumper, destination: TR99, value: 0.01099640045884261
# ---------------Possible actions for node Topless in phase 1---------------
#       node   source destination     value
# 0  Topless  Topless     Trigger  0.005419
# 1  Topless  Topless         SN9  0.009533
# 2  Topless  Topless        MN83  0.011708
# 3  Topless  Topless        TR99  0.001068
# 4  Topless  Topless   Patchback  0.006289
# 5  Topless  Topless     Topless  0.011273
# 6  Topless  Topless       SN100  0.006289
# 7  Topless  Topless         Zap  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Topless, source: Topless, destination: MN83, value: 0.011708397610854002
# ---------------Possible actions for node TR120 in phase 1---------------
#     node source destination     value
# 0  TR120  TR120        TR88  0.006289
# 1  TR120  TR120        TR99  0.005340
# the action among the previous actions that maximizes modularity gain is:
# node: TR120, source: TR120, destination: TR88, value: 0.006289308176100629
# ---------------Possible actions for node TR77 in phase 1---------------
#    node source destination     value
# 0  TR77   TR77        Knit  0.006052
# 1  TR77   TR77         SN9  0.004628
# 2  TR77   TR77          PL  0.005577
# 3  TR77   TR77        TR99  0.003441
# 4  TR77   TR77        SN96  0.011867
# the action among the previous actions that maximizes modularity gain is:
# node: TR77, source: TR77, destination: SN96, value: 0.011866619200189867
# ---------------Possible actions for node TR82 in phase 1---------------
#    node source destination     value
# 0  TR82   TR82         Web  0.005656
# the action among the previous actions that maximizes modularity gain is:
# node: TR82, source: TR82, destination: Web, value: 0.00565642181875717
# ---------------Possible actions for node TR88 in phase 1---------------
#    node source destination     value
# 0  TR88   TR88        TR88  0.006210
# 1  TR88   TR88         SN4  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: TR88, source: TR88, destination: SN4, value: 0.006289308176100629
# ---------------Possible actions for node TR99 in phase 1---------------
#    node source destination     value
# 0  TR99   TR99     Trigger  0.005736
# 1  TR99   TR99         SN9  0.004351
# 2  TR99   TR99        MN83  0.005182
# 3  TR99   TR99        TR99  0.015545
# 4  TR99   TR99        SN96  0.004905
# the action among the previous actions that maximizes modularity gain is:
# node: TR99, source: TR99, destination: TR99, value: 0.015545271152248723
# ---------------Possible actions for node Trigger in phase 1---------------
#       node   source destination     value
# 0  Trigger  Trigger     Trigger  0.011788
# 1  Trigger  Trigger         SN9  0.003520
# 2  Trigger  Trigger        MN83  0.017286
# 3  Trigger  Trigger        TR99  0.001543
# 4  Trigger  Trigger   Patchback  0.006289
# 5  Trigger  Trigger         Vau  0.006289
# 6  Trigger  Trigger       SN100  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Trigger, source: Trigger, destination: MN83, value: 0.017285708634943237
# ---------------Possible actions for node TSN103 in phase 1---------------
#      node  source destination     value
# 0  TSN103  TSN103         SN9  0.011471
# 1  TSN103  TSN103        MN83  0.005182
# 2  TSN103  TSN103        TR99  0.004391
# the action among the previous actions that maximizes modularity gain is:
# node: TSN103, source: TSN103, destination: SN9, value: 0.011471065226850204
# ---------------Possible actions for node TSN83 in phase 1---------------
#     node source destination     value
# 0  TSN83  TSN83      Zipfel  0.006289
# 1  TSN83  TSN83        TR99  0.005340
# the action among the previous actions that maximizes modularity gain is:
# node: TSN83, source: TSN83, destination: Zipfel, value: 0.006289308176100629
# ---------------Possible actions for node Upbang in phase 1---------------
#      node  source destination     value
# 0  Upbang  Upbang         Web  0.014161
# 1  Upbang  Upbang        Knit  0.006012
# 2  Upbang  Upbang     Feather  0.006289
# 3  Upbang  Upbang          PL  0.011748
# the action among the previous actions that maximizes modularity gain is:
# node: Upbang, source: Upbang, destination: Web, value: 0.014160832245559906
# ---------------Possible actions for node Vau in phase 1---------------
#   node source destination     value
# 0  Vau    Vau         SN9  0.005577
# 1  Vau    Vau        MN83  0.005736
# the action among the previous actions that maximizes modularity gain is:
# node: Vau, source: Vau, destination: MN83, value: 0.005735532613425102
# ---------------Possible actions for node Wave in phase 1---------------
#    node source destination     value
# 0  Wave   Wave         Web  0.004707
# 1  Wave   Wave     Feather  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Wave, source: Wave, destination: Feather, value: 0.006289308176100629
# ---------------Possible actions for node Web in phase 1---------------
#   node source destination     value
# 0  Web    Web         Web  0.036905
# 1  Web    Web        SN89  0.005933
# 2  Web    Web     Feather  0.005933
# the action among the previous actions that maximizes modularity gain is:
# node: Web, source: Web, destination: Web, value: 0.03690518571259048
# ---------------Possible actions for node Whitetip in phase 1---------------
#        node    source destination     value
# 0  Whitetip  Whitetip        TR99  0.005815
# the action among the previous actions that maximizes modularity gain is:
# node: Whitetip, source: Whitetip, destination: TR99, value: 0.005814643408093035
# ---------------Possible actions for node Zap in phase 1---------------
#   node source destination     value
# 0  Zap    Zap         SN9  0.004509
# 1  Zap    Zap        MN83  0.004707
# 2  Zap    Zap     Topless  0.006092
# 3  Zap    Zap        Grin  0.006289
# 4  Zap    Zap        SN89  0.006092
# the action among the previous actions that maximizes modularity gain is:
# node: Zap, source: Zap, destination: Grin, value: 0.006289308176100629
# ---------------Possible actions for node Zig in phase 1---------------
#   node source destination     value
# 0  Zig    Zig         Web  0.005498
# the action among the previous actions that maximizes modularity gain is:
# node: Zig, source: Zig, destination: Web, value: 0.005498200229421305
# ---------------Possible actions for node Zipfel in phase 1---------------
#      node  source destination     value
# 0  Zipfel  Zipfel        SN96  0.005696
# 1  Zipfel  Zipfel     Topless  0.006171
# 2  Zipfel  Zipfel      Zipfel  0.006171
# the action among the previous actions that maximizes modularity gain is:
# node: Zipfel, source: Zipfel, destination: Topless, value: 0.006170641984098731
# displayed possible actions for all the nodes in phase: 1
# ----------------------------------------------------------------
#
#
# --------------------------Graph in the phase: 2--------------------------
#         nodes  community                                       people_nodes
# 0         SN9        SN9          [Beak, Grin, Haecksel, MN83, SN9, TSN103]
# 1        Knit       Knit                                [Beescratch, Oscar]
# 2        SN96       SN96                         [Bumper, Fish, SN96, TR77]
# 3        Grin       Grin                                         [CCL, Zap]
# 4     Trigger    Trigger                                      [Cross, Five]
# 5         Web        Web  [DN16, Feather, Gallatin, Jet, MN23, Quasi, Ri...
# 6     Feather    Feather                                       [DN21, Wave]
# 7          PL         PL                                   [DN63, Knit, PL]
# 8     Topless    Topless                              [Double, SN4, Zipfel]
# 9       Scabs      Scabs                                             [Fork]
# 10       TR99       TR99  [Hook, Kringel, Scabs, SN63, Stripes, Thumper,...
# 11       MN83       MN83    [Jonah, Patchback, SMN5, Topless, Trigger, Vau]
# 12  Patchback  Patchback                                            [MN105]
# 13      SN100      SN100                                             [MN60]
# 14    Number1    Number1                              [Mus, Notch, Number1]
# 15        SN4        SN4                                   [Shmuddel, TR88]
# 16       SN89       SN89                                      [SN100, SN89]
# 17       TR88       TR88                                            [TR120]
# 18     Zipfel     Zipfel                                            [TSN83]
#     edges   node_a     node_b  weight
# 0       1      SN9       SN96       3
# 1       2      SN9        SN9       9
# 2       3      SN9       Grin       2
# 3       4      SN9         PL       1
# 4       5      SN9       TR99       7
# 5       6      SN9        SN4       1
# 6       7      SN9    Topless       2
# 7       8      SN9       MN83       8
# 8       9      SN9       SN89       1
# 9      10     Knit        Web       3
# 10     11     Knit         PL       2
# 11     12     Knit    Number1       2
# 12     13     Knit       Knit       1
# 13     14     Knit       SN89       1
# 14     15     Knit    Topless       1
# 15     16     Knit       TR99       1
# 16     17     Knit       SN96       1
# 17     18     SN96       SN96       5
# 18     19     SN96       TR99       3
# 19     20     SN96    Topless       1
# 20     21     SN96       MN83       1
# 21     22     SN96         PL       2
# 22     23     Grin    Topless       2
# 23     24     Grin       Grin       1
# 24     25     Grin       SN89       1
# 25     26     Grin       MN83       1
# 26     27  Trigger       MN83       2
# 27     28      Web        Web      21
# 28     29      Web    Feather       6
# 29     30      Web         PL       2
# 30     31      Web    Number1       2
# 31     32      Web       SN89       1
# 32     33  Feather    Feather       1
# 33     34       PL         PL       3
# 34     35       PL    Number1       1
# 35     36  Topless       TR99       4
# 36     37  Topless    Topless       2
# 37     38  Topless       MN83       2
# 38     39  Topless  Patchback       1
# 39     40  Topless        SN4       1
# 40     41  Topless       SN89       1
# 41     42  Topless     Zipfel       1
# 42     43    Scabs       TR99       1
# 43     44     TR99       TR99      13
# 44     45     TR99       MN83       4
# 45     46     TR99       SN89       1
# 46     47     TR99  Patchback       1
# 47     48     TR99        SN4       2
# 48     49     TR99       TR88       1
# 49     50     TR99     Zipfel       1
# 50     51     MN83  Patchback       4
# 51     52     MN83       MN83       8
# 52     53     MN83      SN100       2
# 53     54    SN100       SN89       1
# 54     55  Number1    Number1       3
# 55     56      SN4        SN4       1
# 56     57      SN4       TR88       1
# 57     58     SN89       SN89       1
# _______________________________________________________________________________________________________
# ---------------Possible actions for node SN9 in phase 2---------------
#   node source destination     value
# 0  SN9    SN9         SN9  0.044500
# 1  SN9    SN9        MN83  0.039555
# 2  SN9    SN9          PL  0.002255
# 3  SN9    SN9        TR99  0.026542
# 4  SN9    SN9     Topless  0.009889
# 5  SN9    SN9         SN4  0.004944
# 6  SN9    SN9        Grin  0.011234
# 7  SN9    SN9        SN96  0.012144
# 8  SN9    SN9        SN89  0.004944
# the action among the previous actions that maximizes modularity gain is:
# node: SN9, source: SN9, destination: SN9, value: 0.044499822000711994
# ---------------Possible actions for node Knit in phase 2---------------
#    node source destination     value
# 0  Knit   Knit        Knit  0.005815
# 1  Knit   Knit          PL  0.011155
# 2  Knit   Knit        TR99  0.000119
# 3  Knit   Knit     Number1  0.011155
# 4  Knit   Knit     Topless  0.005340
# 5  Knit   Knit         Web  0.008900
# 6  Knit   Knit        SN96  0.003916
# 7  Knit   Knit        SN89  0.005815
# the action among the previous actions that maximizes modularity gain is:
# node: Knit, source: Knit, destination: PL, value: 0.011154622048178475
# ---------------Possible actions for node SN96 in phase 2---------------
#    node source destination     value
# 0  SN96   SN96         SN9  0.013172
# 1  SN96   SN96        MN83  0.001226
# 2  SN96   SN96          PL  0.015071
# 3  SN96   SN96        TR99  0.010640
# 4  SN96   SN96     Topless  0.005024
# 5  SN96   SN96        SN96  0.028282
# the action among the previous actions that maximizes modularity gain is:
# node: SN96, source: SN96, destination: SN96, value: 0.028282109093785847
# ---------------Possible actions for node Grin in phase 2---------------
#    node source destination     value
# 0  Grin   Grin         SN9  0.010087
# 1  Grin   Grin        MN83  0.004074
# 2  Grin   Grin     Topless  0.012025
# 3  Grin   Grin        Grin  0.006012
# 4  Grin   Grin        SN89  0.006012
# the action among the previous actions that maximizes modularity gain is:
# node: Grin, source: Grin, destination: Topless, value: 0.012024840789525731
# ---------------Possible actions for node Trigger in phase 2---------------
#       node   source destination     value
# 0  Trigger  Trigger        MN83  0.011946
# the action among the previous actions that maximizes modularity gain is:
# node: Trigger, source: Trigger, destination: MN83, value: 0.011945729994857799
# ---------------Possible actions for node Web in phase 2---------------
#   node source destination     value
# 0  Web    Web     Feather  0.036351
# 1  Web    Web          PL  0.023140
# 2  Web    Web     Number1  0.008425
# 3  Web    Web         Web  0.103002
# 4  Web    Web        SN89  0.004905
# the action among the previous actions that maximizes modularity gain is:
# node: Web, source: Web, destination: Web, value: 0.10300225465764803
# ---------------Possible actions for node Feather in phase 2---------------
#       node   source destination     value
# 0  Feather  Feather         Web  0.031921
# 1  Feather  Feather     Feather  0.006012
# the action among the previous actions that maximizes modularity gain is:
# node: Feather, source: Feather, destination: Web, value: 0.03192120564851074
# ---------------Possible actions for node PL in phase 2---------------
#   node source destination     value
# 0   PL     PL         SN9  0.002373
# 1   PL     PL          PL  0.028836
# 2   PL     PL     Number1  0.004984
# 3   PL     PL         Web  0.000396
# 4   PL     PL        SN96  0.010403
# the action among the previous actions that maximizes modularity gain is:
# node: PL, source: PL, destination: PL, value: 0.028835884656461374
# ---------------Possible actions for node Topless in phase 2---------------
#       node   source destination     value
# 0  Topless  Topless         SN9  0.006171
# 1  Topless  Topless        MN83  0.005459
# 2  Topless  Topless          PL  0.002017
# 3  Topless  Topless        TR99  0.015901
# 4  Topless  Topless   Patchback  0.006289
# 5  Topless  Topless     Topless  0.021597
# 6  Topless  Topless         SN4  0.005577
# 7  Topless  Topless      Zipfel  0.006289
# 8  Topless  Topless        SN96  0.002729
# 9  Topless  Topless        SN89  0.005577
# the action among the previous actions that maximizes modularity gain is:
# node: Topless, source: Topless, destination: Topless, value: 0.021597246944345557
# ---------------Possible actions for node Scabs in phase 2---------------
#     node source destination     value
# 0  Scabs  Scabs        TR99  0.005775
# the action among the previous actions that maximizes modularity gain is:
# node: Scabs, source: Scabs, destination: TR99, value: 0.005775088010759068
# ---------------Possible actions for node TR99 in phase 2---------------
#     node source destination     value
# 0   TR99   TR99         SN9  0.030141
# 1   TR99   TR99        MN83  0.009731
# 2   TR99   TR99          PL -0.002967
# 3   TR99   TR99        TR99  0.066453
# 4   TR99   TR99   Patchback  0.006289
# 5   TR99   TR99     Topless  0.017444
# 6   TR99   TR99         SN4  0.011036
# 7   TR99   TR99      Zipfel  0.006289
# 8   TR99   TR99        SN96  0.011155
# 9   TR99   TR99        SN89  0.004747
# 10  TR99   TR99        TR88  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: TR99, source: TR99, destination: TR99, value: 0.06645306752106324
# ---------------Possible actions for node MN83 in phase 2---------------
#    node source destination     value
# 0  MN83   MN83         SN9  0.038923
# 1  MN83   MN83        MN83  0.050235
# 2  MN83   MN83        TR99  0.007436
# 3  MN83   MN83   Patchback  0.025157
# 4  MN83   MN83     Topless  0.012539
# 5  MN83   MN83        SN96 -0.000040
# 6  MN83   MN83       SN100  0.012579
# the action among the previous actions that maximizes modularity gain is:
# node: MN83, source: MN83, destination: MN83, value: 0.0502353546141371
# ---------------Possible actions for node Patchback in phase 2---------------
#         node     source destination     value
# 0  Patchback  Patchback     Topless  0.005103
# 1  Patchback  Patchback        MN83  0.022784
# 2  Patchback  Patchback        TR99  0.002967
# the action among the previous actions that maximizes modularity gain is:
# node: Patchback, source: Patchback, destination: MN83, value: 0.022783908864364544
# ---------------Possible actions for node SN100 in phase 2---------------
#     node source destination     value
# 0  SN100  SN100        SN89  0.006171
# 1  SN100  SN100        MN83  0.010917
# the action among the previous actions that maximizes modularity gain is:
# node: SN100, source: SN100, destination: MN83, value: 0.010917289664174677
# ---------------Possible actions for node Number1 in phase 2---------------
#       node   source destination     value
# 0  Number1  Number1         Web  0.003718
# 1  Number1  Number1     Number1  0.017919
# 2  Number1  Number1          PL  0.016969
# the action among the previous actions that maximizes modularity gain is:
# node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# ---------------Possible actions for node SN4 in phase 2---------------
#   node source destination     value
# 0  SN4    SN4         SN9  0.004153
# 1  SN4    SN4        TR99  0.009256
# 2  SN4    SN4     Topless  0.005103
# 3  SN4    SN4         SN4  0.006052
# 4  SN4    SN4        TR88  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: SN4, source: SN4, destination: TR99, value: 0.009255962976148096
# ---------------Possible actions for node SN89 in phase 2---------------
#    node source destination     value
# 0  SN89   SN89         SN9  0.003441
# 1  SN89   SN89        MN83  0.001226
# 2  SN89   SN89          PL  0.004391
# 3  SN89   SN89        TR99  0.000910
# 4  SN89   SN89     Topless  0.010996
# 5  SN89   SN89         Web -0.002571
# 6  SN89   SN89        SN89  0.005973
# the action among the previous actions that maximizes modularity gain is:
# node: SN89, source: SN89, destination: Topless, value: 0.01099640045884261
# ---------------Possible actions for node TR88 in phase 2---------------
#    node source destination     value
# 0  TR88   TR88        TR99  0.011234
# the action among the previous actions that maximizes modularity gain is:
# node: TR88, source: TR88, destination: TR99, value: 0.011233732842846407
# ---------------Possible actions for node Zipfel in phase 2---------------
#      node  source destination     value
# 0  Zipfel  Zipfel     Topless  0.005656
# 1  Zipfel  Zipfel        TR99  0.004786
# the action among the previous actions that maximizes modularity gain is:
# node: Zipfel, source: Zipfel, destination: Topless, value: 0.00565642181875717
# displayed possible actions for all the nodes in phase: 2
# ----------------------------------------------------------------
#
#
# --------------------------Graph in the phase: 3--------------------------
#      nodes community                                       people_nodes
# 0      SN9       SN9          [Beak, Grin, Haecksel, MN83, SN9, TSN103]
# 1       PL        PL                [Beescratch, Oscar, DN63, Knit, PL]
# 2     SN96      SN96                         [Bumper, Fish, SN96, TR77]
# 3  Topless   Topless  [CCL, Zap, Double, SN4, Zipfel, SN100, SN89, T...
# 4     MN83      MN83  [Cross, Five, Jonah, Patchback, SMN5, Topless,...
# 5      Web       Web  [DN16, Feather, Gallatin, Jet, MN23, Quasi, Ri...
# 6     TR99      TR99  [Fork, Hook, Kringel, Scabs, SN63, Stripes, Th...
# 7  Number1   Number1                              [Mus, Notch, Number1]
#     edges   node_a   node_b  weight
# 0       1      SN9     SN96       3
# 1       2      SN9      SN9       9
# 2       3      SN9  Topless       5
# 3       4      SN9       PL       1
# 4       5      SN9     TR99       8
# 5       6      SN9     MN83       8
# 6       7       PL      Web       5
# 7       8       PL       PL       6
# 8       9       PL  Number1       3
# 9      10       PL  Topless       2
# 10     11       PL     TR99       1
# 11     12       PL     SN96       3
# 12     13     SN96     SN96       5
# 13     14     SN96     TR99       3
# 14     15     SN96  Topless       1
# 15     16     SN96     MN83       1
# 16     17  Topless  Topless       9
# 17     18  Topless     MN83       5
# 18     19  Topless      Web       1
# 19     20  Topless     TR99       7
# 20     21     MN83     MN83      16
# 21     22     MN83     TR99       5
# 22     23      Web      Web      28
# 23     24      Web  Number1       2
# 24     25     TR99     TR99      19
# 25     26  Number1  Number1       3
# _______________________________________________________________________________________________________
# ---------------Possible actions for node SN9 in phase 3---------------
#   node source destination     value
# 0  SN9    SN9         SN9  0.044500
# 1  SN9    SN9        MN83  0.028796
# 2  SN9    SN9          PL -0.001780
# 3  SN9    SN9        TR99  0.024762
# 4  SN9    SN9     Topless  0.019343
# 5  SN9    SN9        SN96  0.012144
# the action among the previous actions that maximizes modularity gain is:
# node: SN9, source: SN9, destination: SN9, value: 0.044499822000711994
# ---------------Possible actions for node PL in phase 3---------------
#   node source destination     value
# 0   PL     PL         SN9 -0.001187
# 1   PL     PL          PL  0.032752
# 2   PL     PL        TR99 -0.009493
# 3   PL     PL     Number1  0.016376
# 4   PL     PL     Topless  0.005103
# 5   PL     PL         Web  0.008188
# 6   PL     PL        SN96  0.014715
# the action among the previous actions that maximizes modularity gain is:
# node: PL, source: PL, destination: PL, value: 0.032751868992524025
# ---------------Possible actions for node SN96 in phase 3---------------
#    node source destination     value
# 0  SN96   SN96         SN9  0.013172
# 1  SN96   SN96        MN83 -0.003837
# 2  SN96   SN96          PL  0.015071
# 3  SN96   SN96        TR99  0.006843
# 4  SN96   SN96     Topless  0.000593
# 5  SN96   SN96        SN96  0.028282
# the action among the previous actions that maximizes modularity gain is:
# node: SN96, source: SN96, destination: SN96, value: 0.028282109093785847
# ---------------Possible actions for node Topless in phase 3---------------
#       node   source destination     value
# 0  Topless  Topless         SN9  0.020767
# 1  Topless  Topless        MN83  0.012460
# 2  Topless  Topless          PL  0.005459
# 3  Topless  Topless        TR99  0.021479
# 4  Topless  Topless     Topless  0.045924
# 5  Topless  Topless         Web -0.026937
# 6  Topless  Topless        SN96  0.000356
# the action among the previous actions that maximizes modularity gain is:
# node: Topless, source: Topless, destination: Topless, value: 0.045923816304734785
# ---------------Possible actions for node MN83 in phase 3---------------
#    node source destination     value
# 0  MN83   MN83         SN9  0.037855
# 1  MN83   MN83        MN83  0.078478
# 2  MN83   MN83        TR99  0.005142
# 3  MN83   MN83     Topless  0.018987
# 4  MN83   MN83        SN96 -0.000633
# the action among the previous actions that maximizes modularity gain is:
# node: MN83, source: MN83, destination: MN83, value: 0.07847790831058898
# ---------------Possible actions for node Web in phase 3---------------
#   node source destination     value
# 0  Web    Web         Web  0.136229
# 1  Web    Web     Topless -0.006527
# 2  Web    Web          PL  0.022903
# 3  Web    Web     Number1  0.008307
# the action among the previous actions that maximizes modularity gain is:
# node: Web, source: Web, destination: Web, value: 0.13622878841817965
# ---------------Possible actions for node TR99 in phase 3---------------
#    node source destination     value
# 0  TR99   TR99         SN9  0.035007
# 1  TR99   TR99        MN83  0.004232
# 2  TR99   TR99          PL -0.003916
# 3  TR99   TR99        TR99  0.087180
# 4  TR99   TR99     Topless  0.028717
# 5  TR99   TR99        SN96  0.010364
# the action among the previous actions that maximizes modularity gain is:
# node: TR99, source: TR99, destination: TR99, value: 0.08718009572406155
# ---------------Possible actions for node Number1 in phase 3---------------
#       node   source destination     value
# 0  Number1  Number1         Web  0.003718
# 1  Number1  Number1     Number1  0.017919
# 2  Number1  Number1          PL  0.016969
# the action among the previous actions that maximizes modularity gain is:
# node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# displayed possible actions for all the nodes in phase: 3
# ----------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
for g in louvain.graph_history:
    plt.figure(figsize=(12, 7))
    nx.draw(
            g,
            with_labels=True,
            alpha=0.9,
            pos=nx.spring_layout(g, k=0.9),
            node_color='skyblue',
            node_size=4000,
            font_size=8, 
            font_color='black', 
            font_weight='bold',
            edge_color='red', width=1
            )
    plt.show()

# %%
louvain.forward_louvain()
# Out:
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Topless', 'SN96']
# node: SN9, source: SN9, destination: SN9, value: 0.044499822000711994
# choosing maximum action >>>>node: SN9, source: SN9, destination: SN9, value: 0.044499822000711994
# neighbor communities ['SN9', 'PL', 'TR99', 'Number1', 'Topless', 'Web', 'SN96']
# node: PL, source: PL, destination: PL, value: 0.032751868992524025
# choosing maximum action >>>>node: PL, source: PL, destination: PL, value: 0.032751868992524025
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Topless', 'SN96']
# node: SN96, source: SN96, destination: SN96, value: 0.028282109093785847
# choosing maximum action >>>>node: SN96, source: SN96, destination: SN96, value: 0.028282109093785847
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Topless', 'Web', 'SN96']
# node: Topless, source: Topless, destination: Topless, value: 0.045923816304734785
# choosing maximum action >>>>node: Topless, source: Topless, destination: Topless, value: 0.045923816304734785
# neighbor communities ['SN9', 'MN83', 'TR99', 'Topless', 'SN96']
# node: MN83, source: MN83, destination: MN83, value: 0.07847790831058898
# choosing maximum action >>>>node: MN83, source: MN83, destination: MN83, value: 0.07847790831058898
# neighbor communities ['Web', 'Topless', 'PL', 'Number1']
# node: Web, source: Web, destination: Web, value: 0.13622878841817965
# choosing maximum action >>>>node: Web, source: Web, destination: Web, value: 0.13622878841817965
# neighbor communities ['SN9', 'MN83', 'PL', 'TR99', 'Topless', 'SN96']
# node: TR99, source: TR99, destination: TR99, value: 0.08718009572406155
# choosing maximum action >>>>node: TR99, source: TR99, destination: TR99, value: 0.08718009572406155
# neighbor communities ['Web', 'Number1', 'PL']
# node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# choosing maximum action >>>>node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
#
# {'SN9': {'community': 'SN9', 'people_nodes': ['Beak', 'Grin', 'Haecksel', 'MN83', 'SN9', 'TSN103']}, 'PL': {'community': 'PL', 'people_nodes': ['Beescratch', 'Oscar', 'DN63', 'Knit', 'PL']}, 'SN96': {'community': 'SN96', 'people_nodes': ['Bumper', 'Fish', 'SN96', 'TR77']}, 'Topless': {'community': 'Topless', 'people_nodes': ['CCL', 'Zap', 'Double', 'SN4', 'Zipfel', 'SN100', 'SN89', 'TSN83']}, 'MN83': {'community': 'MN83', 'people_nodes': ['Cross', 'Five', 'Jonah', 'Patchback', 'SMN5', 'Topless', 'Trigger', 'Vau', 'MN105', 'MN60']}, 'Web': {'community': 'Web', 'people_nodes': ['DN16', 'Feather', 'Gallatin', 'Jet', 'MN23', 'Quasi', 'Ripplefluke', 'SN90', 'TR82', 'Upbang', 'Web', 'Zig', 'DN21', 'Wave']}, 'TR99': {'community': 'TR99', 'people_nodes': ['Fork', 'Hook', 'Kringel', 'Scabs', 'SN63', 'Stripes', 'Thumper', 'TR99', 'Whitetip', 'Shmuddel', 'TR88', 'TR120']}, 'Number1': {'community': 'Number1', 'people_nodes': ['Mus', 'Notch', 'Number1']}}
# adding edges from necessary
# False
