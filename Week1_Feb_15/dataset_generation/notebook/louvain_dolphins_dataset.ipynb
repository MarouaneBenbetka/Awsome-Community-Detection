# %% [markdown]
# ## Provided Dataset Evaluation

# %%
import numpy as np
import networkx as nx
import pandas as pd
from utils.student_graph_generation import LouvainMachine

# %%
# read the provided dataset
gml_file_path = \
'./../../dataset_generation/data/evaluation/DataSets/réels/dolphins/dolphins.gml'
G = nx.read_gml(gml_file_path)

# %%
louvain = LouvainMachine(G)
# Out:
# >> Called constructor LouvainMachine: created graph with nodes:
# ['Beak', 'Beescratch', 'Bumper', 'CCL', 'Cross', 'DN16', 'DN21', 'DN63', 'Double', 'Feather', 'Fish', 'Five', 'Fork', 'Gallatin', 'Grin', 'Haecksel', 'Hook', 'Jet', 'Jonah', 'Knit', 'Kringel', 'MN105', 'MN23', 'MN60', 'MN83', 'Mus', 'Notch', 'Number1', 'Oscar', 'Patchback', 'PL', 'Quasi', 'Ripplefluke', 'Scabs', 'Shmuddel', 'SMN5', 'SN100', 'SN4', 'SN63', 'SN89', 'SN9', 'SN90', 'SN96', 'Stripes', 'Thumper', 'Topless', 'TR120', 'TR77', 'TR82', 'TR88', 'TR99', 'Trigger', 'TSN103', 'TSN83', 'Upbang', 'Vau', 'Wave', 'Web', 'Whitetip', 'Zap', 'Zig', 'Zipfel']
# ...

# %%
louvain.solve_communities()
# Out:
# ...
# neighbor communities ['Fish', 'SN96', 'SN9', 'TR77', 'Haecksel', 'Grin']
# called louvain_assign, got the following value for improvement:  True
#
# before:
# ['Beak']
# after:
# ['Beak', 'Fish']
# ...

# %%
louvain.display_graph_history_tables(display_fn=lambda x: display(x))
# Out:
#          nodes   community  people_nodes
# 0         Beak        Beak        [Beak]
# 1   Beescratch  Beescratch  [Beescratch]
# 2       Bumper      Bumper      [Bumper]
# 3          CCL         CCL         [CCL]
# 4        Cross       Cross       [Cross]
# ..         ...         ...           ...
# 57         Web         Web         [Web]
# 58    Whitetip    Whitetip    [Whitetip]
# 59         Zap         Zap         [Zap]
# 60         Zig         Zig         [Zig]
# 61      Zipfel      Zipfel      [Zipfel]
#
# [62 rows x 3 columns]
#          nodes   community  people_nodes
# 0         Fish        Fish  [Beak, Fish]
# 1   Beescratch  Beescratch  [Beescratch]
# 2       Bumper      Bumper      [Bumper]
# 3          CCL         CCL         [CCL]
# 4        Cross       Cross       [Cross]
# ..         ...         ...           ...
# 56         Web         Web         [Web]
# 57    Whitetip    Whitetip    [Whitetip]
# 58         Zap         Zap         [Zap]
# ...
