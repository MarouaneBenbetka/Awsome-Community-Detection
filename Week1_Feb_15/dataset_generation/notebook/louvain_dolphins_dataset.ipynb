# %% [markdown]
#     ## Provided Dataset Evaluation

# %%
import numpy as np
import networkx as nx
import pandas as pd
from utils.louvain4 import LouvainMachine

# %%
# read the provided dataset
gml_file_path = \
'./../../dataset_generation/data/evaluation/DataSets/réels/dolphins/dolphins.gml'
G = nx.read_gml(gml_file_path)

# %%
louvain = LouvainMachine(G)

# %%
louvain.solve_communities()
# Out:
# neighbor communities ['Grin', 'Haecksel', 'SN96', 'TR77', 'Fish', 'SN9']
# node: Beak, source: Beak, destination: Grin, value: 0.006289308176100629
# choosing maximum action >>>>node: Beak, source: Beak, destination: Grin, value: 0.006289308176100629
# neighbor communities ['Oscar', 'Jet', 'SN100', 'Upbang', 'SN90', 'Knit', 'Number1', 'Notch']
# node: Beescratch, source: Beescratch, destination: Oscar, value: 0.006289308176100629
# choosing maximum action >>>>node: Beescratch, source: Beescratch, destination: Oscar, value: 0.006289308176100629
# neighbor communities ['Fish', 'Thumper', 'SN96', 'Zipfel']
# node: Bumper, source: Bumper, destination: Fish, value: 0.006289308176100629
# choosing maximum action >>>>node: Bumper, source: Bumper, destination: Fish, value: 0.006289308176100629
# neighbor communities ['Zap', 'Double', 'Grin']
# node: CCL, source: CCL, destination: Zap, value: 0.006289308176100629
# choosing maximum action >>>>node: CCL, source: CCL, destination: Zap, value: 0.006289308176100629
# neighbor communities ['Trigger']
# node: Cross, source: Cross, destination: Trigger, value: 0.006289308176100629
# choosing maximum action >>>>node: Cross, source: Cross, destination: Trigger, value: 0.006289308176100629
# neighbor communities ['Gallatin', 'Wave', 'Feather', 'Web']
# node: DN16, source: DN16, destination: Gallatin, value: 0.006289308176100629
# choosing maximum action >>>>node: DN16, source: DN16, destination: Gallatin, value: 0.006289308176100629
# neighbor communities ['Gallatin', 'Jet', 'Feather', 'Upbang', 'Wave', 'Web']
# node: DN21, source: DN21, destination: Jet, value: 0.006289308176100629
# choosing maximum action >>>>node: DN21, source: DN21, destination: Jet, value: 0.006289308176100629
# neighbor communities ['Upbang', 'Knit', 'Number1', 'SN9', 'PL']
# node: DN63, source: DN63, destination: Upbang, value: 0.006289308176100629
# choosing maximum action >>>>node: DN63, source: DN63, destination: Upbang, value: 0.006289308176100629
# neighbor communities ['Zap', 'Oscar', 'Topless', 'SN4', 'Kringel']
# node: Double, source: Double, destination: Zap, value: 0.012341283968197461
# choosing maximum action >>>>node: Double, source: Double, destination: Zap, value: 0.012341283968197461
# neighbor communities ['Gallatin', 'Jet', 'Web', 'SN90', 'Ripplefluke']
# node: Feather, source: Feather, destination: Gallatin, value: 0.012301728570863495
# choosing maximum action >>>>node: Feather, source: Feather, destination: Gallatin, value: 0.012301728570863495
# neighbor communities ['Patchback', 'Grin', 'SN96', 'TR77', 'Fish']
# node: Fish, source: Fish, destination: Patchback, value: 0.006289308176100629
# choosing maximum action >>>>node: Fish, source: Fish, destination: Patchback, value: 0.006289308176100629
# neighbor communities ['Trigger']
# node: Five, source: Five, destination: Trigger, value: 0.006249752778766663
# choosing maximum action >>>>node: Five, source: Five, destination: Trigger, value: 0.006249752778766663
# neighbor communities ['Scabs']
# node: Fork, source: Fork, destination: Scabs, value: 0.006289308176100629
# choosing maximum action >>>>node: Fork, source: Fork, destination: Scabs, value: 0.006289308176100629
# neighbor communities ['Gallatin', 'Jet', 'Upbang', 'SN90', 'Web', 'Ripplefluke']
# node: Gallatin, source: Gallatin, destination: Jet, value: 0.012262173173529529
# choosing maximum action >>>>node: Gallatin, source: Gallatin, destination: Jet, value: 0.012262173173529529
# neighbor communities ['Zap', 'Grin', 'TSN103', 'SN63', 'TR99', 'MN83', 'Hook', 'Scabs', 'Shmuddel', 'Stripes', 'SN4', 'SN9']
# node: Grin, source: Grin, destination: TSN103, value: 0.006289308176100629
# choosing maximum action >>>>node: Grin, source: Grin, destination: TSN103, value: 0.006289308176100629
# neighbor communities ['Zap', 'Vau', 'Grin', 'Topless', 'Jonah', 'MN83', 'SN9']
# node: Haecksel, source: Haecksel, destination: Vau, value: 0.006289308176100629
# choosing maximum action >>>>node: Haecksel, source: Haecksel, destination: Vau, value: 0.006289308176100629
# neighbor communities ['TSN103', 'SN63', 'Scabs', 'SN4', 'Kringel', 'TR99']
# node: Hook, source: Hook, destination: SN63, value: 0.006289308176100629
# choosing maximum action >>>>node: Hook, source: Hook, destination: SN63, value: 0.006289308176100629
# neighbor communities ['Oscar', 'Gallatin', 'Jet', 'MN23', 'Number1', 'Quasi', 'Web', 'Mus']
# node: Jet, source: Jet, destination: Jet, value: 0.01151062062418417
# choosing maximum action >>>>node: Jet, source: Jet, destination: Jet, value: 0.01151062062418417
# neighbor communities ['Vau', 'Patchback', 'Trigger', 'Topless', 'MN83', 'MN105', 'Kringel']
# node: Jonah, source: Jonah, destination: Topless, value: 0.006289308176100629
# choosing maximum action >>>>node: Jonah, source: Jonah, destination: Topless, value: 0.006289308176100629
# neighbor communities ['Oscar', 'PL', 'Upbang']
# node: Knit, source: Knit, destination: Upbang, value: 0.012420394762865394
# choosing maximum action >>>>node: Knit, source: Knit, destination: Upbang, value: 0.012420394762865394
# neighbor communities ['Zap', 'Oscar', 'Thumper', 'Topless', 'SN63', 'SN100', 'TR77', 'TR99']
# node: Kringel, source: Kringel, destination: SN63, value: 0.012222617776195563
# choosing maximum action >>>>node: Kringel, source: Kringel, destination: SN63, value: 0.012222617776195563
# neighbor communities ['Trigger', 'Patchback', 'Topless', 'Scabs', 'SN4']
# node: MN105, source: MN105, destination: Topless, value: 0.012341283968197461
# choosing maximum action >>>>node: MN105, source: MN105, destination: Topless, value: 0.012341283968197461
# neighbor communities ['Jet']
# node: MN23, source: MN23, destination: Jet, value: 0.006170641984098731
# choosing maximum action >>>>node: MN23, source: MN23, destination: Jet, value: 0.006170641984098731
# neighbor communities ['SN100', 'Trigger', 'Topless']
# node: MN60, source: MN60, destination: SN100, value: 0.006289308176100629
# choosing maximum action >>>>node: MN60, source: MN60, destination: SN100, value: 0.006289308176100629
# neighbor communities ['Vau', 'Patchback', 'Trigger', 'TSN103', 'Topless']
# node: MN83, source: MN83, destination: Topless, value: 0.011866619200189867
# choosing maximum action >>>>node: MN83, source: MN83, destination: Topless, value: 0.011866619200189867
# neighbor communities ['Number1', 'Notch', 'Jet']
# node: Mus, source: Mus, destination: Number1, value: 0.006289308176100629
# choosing maximum action >>>>node: Mus, source: Mus, destination: Number1, value: 0.006289308176100629
# neighbor communities ['Oscar', 'Number1']
# node: Notch, source: Notch, destination: Number1, value: 0.01245995016019936
# choosing maximum action >>>>node: Notch, source: Notch, destination: Number1, value: 0.01245995016019936
# neighbor communities ['Oscar', 'Number1', 'Jet', 'Upbang']
# node: Number1, source: Number1, destination: Number1, value: 0.011985285392191765
# choosing maximum action >>>>node: Number1, source: Number1, destination: Number1, value: 0.011985285392191765
# neighbor communities ['Zap', 'Oscar', 'SN63', 'TR77', 'PL']
# node: Oscar, source: Oscar, destination: TR77, value: 0.006289308176100629
# choosing maximum action >>>>node: Oscar, source: Oscar, destination: TR77, value: 0.006289308176100629
# neighbor communities ['Trigger', 'Patchback', 'SMN5', 'Topless', 'TSN103', 'Stripes']
# node: Patchback, source: Patchback, destination: Topless, value: 0.023377239824374035
# choosing maximum action >>>>node: Patchback, source: Patchback, destination: Topless, value: 0.023377239824374035
# neighbor communities ['SN96', 'TR77', 'Upbang']
# node: PL, source: PL, destination: TR77, value: 0.012380839365531427
# choosing maximum action >>>>node: PL, source: PL, destination: TR77, value: 0.012380839365531427
# neighbor communities ['Jet']
# node: Quasi, source: Quasi, destination: Jet, value: 0.006131086586764764
# choosing maximum action >>>>node: Quasi, source: Quasi, destination: Jet, value: 0.006131086586764764
# neighbor communities ['Gallatin', 'Zig', 'Jet']
# node: Ripplefluke, source: Ripplefluke, destination: Zig, value: 0.006289308176100629
# choosing maximum action >>>>node: Ripplefluke, source: Ripplefluke, destination: Zig, value: 0.006289308176100629
# neighbor communities ['TSN103', 'Topless', 'SN63', 'TR99', 'Scabs', 'Shmuddel', 'Stripes', 'SN4', 'SN9']
# node: Scabs, source: Scabs, destination: SN63, value: 0.011391954432182272
# choosing maximum action >>>>node: Scabs, source: Scabs, destination: SN63, value: 0.011391954432182272
# neighbor communities ['TR88', 'Thumper', 'TSN103', 'SN63', 'SN4']
# node: Shmuddel, source: Shmuddel, destination: TR88, value: 0.006289308176100629
# choosing maximum action >>>>node: Shmuddel, source: Shmuddel, destination: TR88, value: 0.006289308176100629
# neighbor communities ['Topless']
# node: SMN5, source: SMN5, destination: Topless, value: 0.005933309600094933
# choosing maximum action >>>>node: SMN5, source: SMN5, destination: Topless, value: 0.005933309600094933
# neighbor communities ['Zap', 'Oscar', 'SN63', 'SN100', 'SN4', 'SN9', 'SN89']
# node: SN100, source: SN100, destination: Oscar, value: 0.006289308176100629
# choosing maximum action >>>>node: SN100, source: SN100, destination: Oscar, value: 0.006289308176100629
# neighbor communities ['Zap', 'TR88', 'Oscar', 'TSN103', 'Topless', 'SN63', 'Zipfel', 'Stripes', 'SN9']
# node: SN4, source: SN4, destination: SN63, value: 0.010403069498833116
# choosing maximum action >>>>node: SN4, source: SN4, destination: SN63, value: 0.010403069498833116
# neighbor communities ['Thumper', 'TSN103', 'SN63', 'Whitetip', 'Stripes']
# node: SN63, source: SN63, destination: SN63, value: 0.016652822277599778
# choosing maximum action >>>>node: SN63, source: SN63, destination: SN63, value: 0.016652822277599778
# neighbor communities ['Oscar', 'Web']
# node: SN89, source: SN89, destination: Web, value: 0.006289308176100629
# choosing maximum action >>>>node: SN89, source: SN89, destination: Web, value: 0.006289308176100629
# neighbor communities ['Oscar', 'Vau', 'TSN103', 'Grin', 'SN63', 'Upbang']
# node: SN9, source: SN9, destination: TSN103, value: 0.012262173173529529
# choosing maximum action >>>>node: SN9, source: SN9, destination: TSN103, value: 0.012262173173529529
# neighbor communities ['Oscar', 'Gallatin', 'Jet', 'Upbang', 'Web']
# node: SN90, source: SN90, destination: Oscar, value: 0.006091531189430798
# choosing maximum action >>>>node: SN90, source: SN90, destination: Oscar, value: 0.006091531189430798
# neighbor communities ['Patchback', 'Grin', 'TR77', 'Fish', 'TR99']
# node: SN96, source: SN96, destination: TR77, value: 0.011866619200189867
# choosing maximum action >>>>node: SN96, source: SN96, destination: TR77, value: 0.011866619200189867
# neighbor communities ['TSN83', 'TSN103', 'Topless', 'SN63', 'TR120']
# node: Stripes, source: Stripes, destination: SN63, value: 0.016929710058937543
# choosing maximum action >>>>node: Stripes, source: Stripes, destination: SN63, value: 0.016929710058937543
# neighbor communities ['TR88', 'SN63', 'Fish']
# node: Thumper, source: Thumper, destination: SN63, value: 0.01099640045884261
# choosing maximum action >>>>node: Thumper, source: Thumper, destination: SN63, value: 0.01099640045884261
# neighbor communities ['Zap', 'Vau', 'Trigger', 'Topless', 'SN63', 'SN100', 'TR99']
# node: Topless, source: Topless, destination: Topless, value: 0.020806138997666233
# choosing maximum action >>>>node: Topless, source: Topless, destination: Topless, value: 0.020806138997666233
# neighbor communities ['TR88', 'SN63']
# node: TR120, source: TR120, destination: TR88, value: 0.006210197381432697
# choosing maximum action >>>>node: TR120, source: TR120, destination: TR88, value: 0.006210197381432697
# neighbor communities ['SN63', 'Patchback', 'Grin', 'TR77']
# node: TR77, source: TR77, destination: TR77, value: 0.0176812626082829
# choosing maximum action >>>>node: TR77, source: TR77, destination: TR77, value: 0.0176812626082829
# neighbor communities ['Web']
# node: TR82, source: TR82, destination: Web, value: 0.006249752778766663
# choosing maximum action >>>>node: TR82, source: TR82, destination: Web, value: 0.006249752778766663
# neighbor communities ['TR88']
# node: TR88, source: TR88, destination: TR88, value: 0.012420394762865394
# choosing maximum action >>>>node: TR88, source: TR88, destination: TR88, value: 0.012420394762865394
# neighbor communities ['Trigger', 'TSN103', 'Topless', 'SN63', 'TR77']
# node: TR99, source: TR99, destination: SN63, value: 0.015545271152248723
# choosing maximum action >>>>node: TR99, source: TR99, destination: SN63, value: 0.015545271152248723
# neighbor communities ['Vau', 'Trigger', 'Topless', 'SN63', 'SN100']
# node: Trigger, source: Trigger, destination: Topless, value: 0.027491001147106522
# choosing maximum action >>>>node: Trigger, source: Trigger, destination: Topless, value: 0.027491001147106522
# neighbor communities ['SN63', 'TSN103', 'Topless']
# node: TSN103, source: TSN103, destination: TSN103, value: 0.012103951584193664
# choosing maximum action >>>>node: TSN103, source: TSN103, destination: TSN103, value: 0.012103951584193664
# neighbor communities ['SN63', 'Zipfel']
# node: TSN83, source: TSN83, destination: Zipfel, value: 0.006289308176100629
# choosing maximum action >>>>node: TSN83, source: TSN83, destination: Zipfel, value: 0.006289308176100629
# neighbor communities ['Oscar', 'Web', 'Upbang', 'Jet']
# node: Upbang, source: Upbang, destination: Oscar, value: 0.012024840789525731
# choosing maximum action >>>>node: Upbang, source: Upbang, destination: Oscar, value: 0.012024840789525731
# neighbor communities ['Vau', 'Topless']
# node: Vau, source: Vau, destination: Vau, value: 0.006210197381432697
# choosing maximum action >>>>node: Vau, source: Vau, destination: Vau, value: 0.006210197381432697
# neighbor communities ['Gallatin', 'Jet']
# node: Wave, source: Wave, destination: Gallatin, value: 0.006210197381432697
# choosing maximum action >>>>node: Wave, source: Wave, destination: Gallatin, value: 0.006210197381432697
# neighbor communities ['Oscar', 'Gallatin', 'Web', 'Jet']
# node: Web, source: Web, destination: Jet, value: 0.017087931648273408
# choosing maximum action >>>>node: Web, source: Web, destination: Jet, value: 0.017087931648273408
# neighbor communities ['SN63']
# node: Whitetip, source: Whitetip, destination: SN63, value: 0.005695977216091136
# choosing maximum action >>>>node: Whitetip, source: Whitetip, destination: SN63, value: 0.005695977216091136
# neighbor communities ['Zap', 'Oscar', 'Vau', 'Topless']
# node: Zap, source: Zap, destination: Zap, value: 0.011985285392191765
# choosing maximum action >>>>node: Zap, source: Zap, destination: Zap, value: 0.011985285392191765
# neighbor communities ['Zig']
# node: Zig, source: Zig, destination: Zig, value: 0.006249752778766663
# choosing maximum action >>>>node: Zig, source: Zig, destination: Zig, value: 0.006249752778766663
# neighbor communities ['SN63', 'Fish', 'Zipfel']
# node: Zipfel, source: Zipfel, destination: Fish, value: 0.006289308176100629
# choosing maximum action >>>>node: Zipfel, source: Zipfel, destination: Fish, value: 0.006289308176100629
#
# {'Grin': {'community': 'Grin', 'people_nodes': ['Beak']}, 'Oscar': {'community': 'Oscar', 'people_nodes': ['Beescratch', 'SN100', 'SN90', 'Upbang']}, 'Fish': {'community': 'Fish', 'people_nodes': ['Bumper', 'Zipfel']}, 'Zap': {'community': 'Zap', 'people_nodes': ['CCL', 'Double', 'Zap']}, 'Trigger': {'community': 'Trigger', 'people_nodes': ['Cross', 'Five']}, 'Gallatin': {'community': 'Gallatin', 'people_nodes': ['DN16', 'Feather', 'Wave']}, 'Jet': {'community': 'Jet', 'people_nodes': ['DN21', 'Gallatin', 'Jet', 'MN23', 'Quasi', 'Web']}, 'Upbang': {'community': 'Upbang', 'people_nodes': ['DN63', 'Knit']}, 'Patchback': {'community': 'Patchback', 'people_nodes': ['Fish']}, 'Scabs': {'community': 'Scabs', 'people_nodes': ['Fork']}, 'TSN103': {'community': 'TSN103', 'people_nodes': ['Grin', 'SN9', 'TSN103']}, 'Vau': {'community': 'Vau', 'people_nodes': ['Haecksel', 'Vau']}, 'SN63': {'community': 'SN63', 'people_nodes': ['Hook', 'Kringel', 'Scabs', 'SN4', 'SN63', 'Stripes', 'Thumper', 'TR99', 'Whitetip']}, 'Topless': {'community': 'Topless', 'people_nodes': ['Jonah', 'MN105', 'MN83', 'Patchback', 'SMN5', 'Topless', 'Trigger']}, 'SN100': {'community': 'SN100', 'people_nodes': ['MN60']}, 'Number1': {'community': 'Number1', 'people_nodes': ['Mus', 'Notch', 'Number1']}, 'TR77': {'community': 'TR77', 'people_nodes': ['Oscar', 'PL', 'SN96', 'TR77']}, 'Zig': {'community': 'Zig', 'people_nodes': ['Ripplefluke', 'Zig']}, 'TR88': {'community': 'TR88', 'people_nodes': ['Shmuddel', 'TR120', 'TR88']}, 'Web': {'community': 'Web', 'people_nodes': ['SN89', 'TR82']}, 'Zipfel': {'community': 'Zipfel', 'people_nodes': ['TSN83']}}
# adding edges from necessary
# neighbor communities ['Vau', 'Patchback', 'TSN103', 'TR77']
# node: Grin, source: Grin, destination: TSN103, value: 0.011866619200189867
# choosing maximum action >>>>node: Grin, source: Grin, destination: TSN103, value: 0.011866619200189867
# neighbor communities ['Zap', 'Oscar', 'Gallatin', 'TSN103', 'Jet', 'SN63', 'SN100', 'TR77', 'Upbang', 'Web', 'Number1']
# node: Oscar, source: Oscar, destination: Jet, value: 0.030457655947153987
# choosing maximum action >>>>node: Oscar, source: Oscar, destination: Jet, value: 0.030457655947153987
# neighbor communities ['Patchback', 'SN63', 'Zipfel', 'TR77', 'Fish']
# node: Fish, source: Fish, destination: SN63, value: 0.008781298208140501
# choosing maximum action >>>>node: Fish, source: Fish, destination: SN63, value: 0.008781298208140501
# neighbor communities ['Zap', 'Vau', 'TSN103', 'Jet', 'Topless', 'SN63', 'TR77']
# node: Zap, source: Zap, destination: Zap, value: 0.017562596416281002
# choosing maximum action >>>>node: Zap, source: Zap, destination: Zap, value: 0.017562596416281002
# neighbor communities ['Topless']
# node: Trigger, source: Trigger, destination: Topless, value: 0.011391954432182272
# choosing maximum action >>>>node: Trigger, source: Trigger, destination: Topless, value: 0.011391954432182272
# neighbor communities ['Gallatin', 'Zig', 'Jet']
# node: Gallatin, source: Gallatin, destination: Jet, value: 0.042482496736679726
# choosing maximum action >>>>node: Gallatin, source: Gallatin, destination: Jet, value: 0.042482496736679726
# neighbor communities ['Number1', 'Web', 'Zig', 'Jet']
# node: Jet, source: Jet, destination: Jet, value: 0.1032791424389858
# choosing maximum action >>>>node: Jet, source: Jet, destination: Jet, value: 0.1032791424389858
# neighbor communities ['TSN103', 'Jet', 'TR77', 'Upbang', 'Number1']
# node: Upbang, source: Upbang, destination: TR77, value: 0.01099640045884261
# choosing maximum action >>>>node: Upbang, source: Upbang, destination: TR77, value: 0.01099640045884261
# neighbor communities ['TR77', 'SN63', 'TSN103', 'Topless']
# node: Patchback, source: Patchback, destination: TR77, value: 0.01099640045884261
# choosing maximum action >>>>node: Patchback, source: Patchback, destination: TR77, value: 0.01099640045884261
# neighbor communities ['SN63']
# node: Scabs, source: Scabs, destination: SN63, value: 0.005537755626755271
# choosing maximum action >>>>node: Scabs, source: Scabs, destination: SN63, value: 0.005537755626755271
# neighbor communities ['Zap', 'TR88', 'Vau', 'TSN103', 'Jet', 'Topless', 'SN63', 'TR77']
# node: TSN103, source: TSN103, destination: SN63, value: 0.03999050670463985
# choosing maximum action >>>>node: TSN103, source: TSN103, destination: SN63, value: 0.03999050670463985
# neighbor communities ['Zap', 'Vau', 'TSN103', 'Topless', 'SN63']
# node: Vau, source: Vau, destination: Topless, value: 0.01977769866698311
# choosing maximum action >>>>node: Vau, source: Vau, destination: Topless, value: 0.01977769866698311
# neighbor communities ['Zap', 'TR88', 'Topless', 'Jet', 'SN63', 'TR77', 'Zipfel']
# node: SN63, source: SN63, destination: SN63, value: 0.1166093113405324
# choosing maximum action >>>>node: SN63, source: SN63, destination: SN63, value: 0.1166093113405324
# neighbor communities ['Zap', 'Topless', 'SN63', 'SN100', 'TR77']
# node: Topless, source: Topless, destination: Topless, value: 0.10161781575095921
# choosing maximum action >>>>node: Topless, source: Topless, destination: Topless, value: 0.10161781575095921
# neighbor communities ['Topless', 'Jet']
# node: SN100, source: SN100, destination: Topless, value: 0.009967960128159488
# choosing maximum action >>>>node: SN100, source: SN100, destination: Topless, value: 0.009967960128159488
# neighbor communities ['Number1', 'TR77', 'Jet']
# node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# choosing maximum action >>>>node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# neighbor communities ['Zap', 'TSN103', 'Jet', 'SN63', 'TR77']
# node: TR77, source: TR77, destination: TR77, value: 0.0498793560381314
# choosing maximum action >>>>node: TR77, source: TR77, destination: TR77, value: 0.0498793560381314
# neighbor communities ['Zig', 'Jet']
# node: Zig, source: Zig, destination: Jet, value: 0.009255962976148096
# choosing maximum action >>>>node: Zig, source: Zig, destination: Jet, value: 0.009255962976148096
# neighbor communities ['TR88', 'SN63']
# node: TR88, source: TR88, destination: SN63, value: 0.02258613187769471
# choosing maximum action >>>>node: TR88, source: TR88, destination: SN63, value: 0.02258613187769471
# neighbor communities ['Jet']
# node: Web, source: Web, destination: Jet, value: 0.015189272576243027
# choosing maximum action >>>>node: Web, source: Web, destination: Jet, value: 0.015189272576243027
# neighbor communities ['SN63']
# node: Zipfel, source: Zipfel, destination: SN63, value: 0.009493295360151893
# choosing maximum action >>>>node: Zipfel, source: Zipfel, destination: SN63, value: 0.009493295360151893
#
# {'TSN103': {'community': 'TSN103', 'people_nodes': ['Beak']}, 'Jet': {'community': 'Jet', 'people_nodes': ['Beescratch', 'SN100', 'SN90', 'Upbang', 'DN16', 'Feather', 'Wave', 'DN21', 'Gallatin', 'Jet', 'MN23', 'Quasi', 'Web', 'Ripplefluke', 'Zig', 'SN89', 'TR82']}, 'SN63': {'community': 'SN63', 'people_nodes': ['Bumper', 'Zipfel', 'Fork', 'Grin', 'SN9', 'TSN103', 'Hook', 'Kringel', 'Scabs', 'SN4', 'SN63', 'Stripes', 'Thumper', 'TR99', 'Whitetip', 'Shmuddel', 'TR120', 'TR88', 'TSN83']}, 'Zap': {'community': 'Zap', 'people_nodes': ['CCL', 'Double', 'Zap']}, 'Topless': {'community': 'Topless', 'people_nodes': ['Cross', 'Five', 'Haecksel', 'Vau', 'Jonah', 'MN105', 'MN83', 'Patchback', 'SMN5', 'Topless', 'Trigger', 'MN60']}, 'TR77': {'community': 'TR77', 'people_nodes': ['DN63', 'Knit', 'Fish', 'Oscar', 'PL', 'SN96', 'TR77']}, 'Number1': {'community': 'Number1', 'people_nodes': ['Mus', 'Notch', 'Number1']}}
# adding edges from necessary
# neighbor communities ['SN63', 'TR77', 'Topless']
# node: TSN103, source: TSN103, destination: TR77, value: 0.016494600688263913
# choosing maximum action >>>>node: TSN103, source: TSN103, destination: TR77, value: 0.016494600688263913
# neighbor communities ['Zap', 'Topless', 'Jet', 'SN63', 'TR77', 'Number1']
# node: Jet, source: Jet, destination: Jet, value: 0.15062695304774337
# choosing maximum action >>>>node: Jet, source: Jet, destination: Jet, value: 0.15062695304774337
# neighbor communities ['Zap', 'Topless', 'Jet', 'SN63', 'TR77']
# node: SN63, source: SN63, destination: SN63, value: 0.15244650132510582
# choosing maximum action >>>>node: SN63, source: SN63, destination: SN63, value: 0.15244650132510582
# neighbor communities ['Zap', 'Topless', 'Jet', 'SN63', 'TR77']
# node: Zap, source: Zap, destination: Zap, value: 0.017562596416281002
# choosing maximum action >>>>node: Zap, source: Zap, destination: Zap, value: 0.017562596416281002
# neighbor communities ['Zap', 'Topless', 'Jet', 'SN63', 'TR77']
# node: Topless, source: Topless, destination: Topless, value: 0.11297021478580752
# choosing maximum action >>>>node: Topless, source: Topless, destination: Topless, value: 0.11297021478580752
# neighbor communities ['Zap', 'Topless', 'Jet', 'SN63', 'TR77', 'Number1']
# node: TR77, source: TR77, destination: TR77, value: 0.06839128199042759
# choosing maximum action >>>>node: TR77, source: TR77, destination: TR77, value: 0.06839128199042759
# neighbor communities ['Number1', 'TR77', 'Jet']
# node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# choosing maximum action >>>>node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
#
# {'TR77': {'community': 'TR77', 'people_nodes': ['Beak', 'DN63', 'Knit', 'Fish', 'Oscar', 'PL', 'SN96', 'TR77']}, 'Jet': {'community': 'Jet', 'people_nodes': ['Beescratch', 'SN100', 'SN90', 'Upbang', 'DN16', 'Feather', 'Wave', 'DN21', 'Gallatin', 'Jet', 'MN23', 'Quasi', 'Web', 'Ripplefluke', 'Zig', 'SN89', 'TR82']}, 'SN63': {'community': 'SN63', 'people_nodes': ['Bumper', 'Zipfel', 'Fork', 'Grin', 'SN9', 'TSN103', 'Hook', 'Kringel', 'Scabs', 'SN4', 'SN63', 'Stripes', 'Thumper', 'TR99', 'Whitetip', 'Shmuddel', 'TR120', 'TR88', 'TSN83']}, 'Zap': {'community': 'Zap', 'people_nodes': ['CCL', 'Double', 'Zap']}, 'Topless': {'community': 'Topless', 'people_nodes': ['Cross', 'Five', 'Haecksel', 'Vau', 'Jonah', 'MN105', 'MN83', 'Patchback', 'SMN5', 'Topless', 'Trigger', 'MN60']}, 'Number1': {'community': 'Number1', 'people_nodes': ['Mus', 'Notch', 'Number1']}}
# adding edges from necessary
# neighbor communities ['Zap', 'Jet', 'Topless', 'SN63', 'TR77', 'Number1']
# node: TR77, source: TR77, destination: TR77, value: 0.0668486214944029
# choosing maximum action >>>>node: TR77, source: TR77, destination: TR77, value: 0.0668486214944029
# neighbor communities ['Zap', 'Topless', 'Jet', 'SN63', 'TR77', 'Number1']
# node: Jet, source: Jet, destination: Jet, value: 0.15062695304774337
# choosing maximum action >>>>node: Jet, source: Jet, destination: Jet, value: 0.15062695304774337
# neighbor communities ['Zap', 'Topless', 'Jet', 'SN63', 'TR77']
# node: SN63, source: SN63, destination: SN63, value: 0.15244650132510582
# choosing maximum action >>>>node: SN63, source: SN63, destination: SN63, value: 0.15244650132510582
# neighbor communities ['Zap', 'Topless', 'Jet', 'SN63', 'TR77']
# node: Zap, source: Zap, destination: Zap, value: 0.017562596416281002
# choosing maximum action >>>>node: Zap, source: Zap, destination: Zap, value: 0.017562596416281002
# neighbor communities ['Zap', 'Topless', 'Jet', 'SN63', 'TR77']
# node: Topless, source: Topless, destination: Topless, value: 0.11297021478580752
# choosing maximum action >>>>node: Topless, source: Topless, destination: Topless, value: 0.11297021478580752
# neighbor communities ['Number1', 'TR77', 'Jet']
# node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# choosing maximum action >>>>node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
#
# {'TR77': {'community': 'TR77', 'people_nodes': ['Beak', 'DN63', 'Knit', 'Fish', 'Oscar', 'PL', 'SN96', 'TR77']}, 'Jet': {'community': 'Jet', 'people_nodes': ['Beescratch', 'SN100', 'SN90', 'Upbang', 'DN16', 'Feather', 'Wave', 'DN21', 'Gallatin', 'Jet', 'MN23', 'Quasi', 'Web', 'Ripplefluke', 'Zig', 'SN89', 'TR82']}, 'SN63': {'community': 'SN63', 'people_nodes': ['Bumper', 'Zipfel', 'Fork', 'Grin', 'SN9', 'TSN103', 'Hook', 'Kringel', 'Scabs', 'SN4', 'SN63', 'Stripes', 'Thumper', 'TR99', 'Whitetip', 'Shmuddel', 'TR120', 'TR88', 'TSN83']}, 'Zap': {'community': 'Zap', 'people_nodes': ['CCL', 'Double', 'Zap']}, 'Topless': {'community': 'Topless', 'people_nodes': ['Cross', 'Five', 'Haecksel', 'Vau', 'Jonah', 'MN105', 'MN83', 'Patchback', 'SMN5', 'Topless', 'Trigger', 'MN60']}, 'Number1': {'community': 'Number1', 'people_nodes': ['Mus', 'Notch', 'Number1']}}
# adding edges from necessary

# %%
louvain.display_graph_history_tables(display_fn=lambda x: display(x))
# Out:
# --------------------------Graph in the phase: 1--------------------------
#          nodes   community  people_nodes
# 0         Beak        Beak        [Beak]
# 1   Beescratch  Beescratch  [Beescratch]
# 2       Bumper      Bumper      [Bumper]
# 3          CCL         CCL         [CCL]
# 4        Cross       Cross       [Cross]
# ..         ...         ...           ...
# 57         Web         Web         [Web]
# 58    Whitetip    Whitetip    [Whitetip]
# 59         Zap         Zap         [Zap]
# 60         Zig         Zig         [Zig]
# 61      Zipfel      Zipfel      [Zipfel]
#
# [62 rows x 3 columns]
#      edges   node_a    node_b  weight
# 0        1     Beak      Fish       1
# 1        2     Beak      Grin       1
# 2        3     Beak  Haecksel       1
# 3        4     Beak       SN9       1
# 4        5     Beak      SN96       1
# ..     ...      ...       ...     ...
# 154    155     TR82       Web       1
# 155    156     TR99   Trigger       1
# 156    157  Trigger       Vau       1
# 157    158    TSN83    Zipfel       1
# 158    159   Upbang       Web       1
#
# [159 rows x 4 columns]
# _______________________________________________________________________________________________________
# ---------------Possible actions for node Beak in phase 1---------------
#    node source destination     value
# 0  Beak   Beak        Grin  0.006289
# 1  Beak   Beak    Haecksel  0.006289
# 2  Beak   Beak        SN96  0.006289
# 3  Beak   Beak        TR77  0.006289
# 4  Beak   Beak        Fish  0.006289
# 5  Beak   Beak         SN9  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Beak, source: Beak, destination: Grin, value: 0.006289308176100629
# ---------------Possible actions for node Beescratch in phase 1---------------
#          node      source destination     value
# 0  Beescratch  Beescratch       Oscar  0.006289
# 1  Beescratch  Beescratch         Jet  0.006289
# 2  Beescratch  Beescratch       SN100  0.006289
# 3  Beescratch  Beescratch      Upbang  0.006289
# 4  Beescratch  Beescratch        SN90  0.006289
# 5  Beescratch  Beescratch        Knit  0.006289
# 6  Beescratch  Beescratch     Number1  0.006289
# 7  Beescratch  Beescratch       Notch  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Beescratch, source: Beescratch, destination: Oscar, value: 0.006289308176100629
# ---------------Possible actions for node Bumper in phase 1---------------
#      node  source destination     value
# 0  Bumper  Bumper        Fish  0.006289
# 1  Bumper  Bumper     Thumper  0.006289
# 2  Bumper  Bumper        SN96  0.006289
# 3  Bumper  Bumper      Zipfel  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Bumper, source: Bumper, destination: Fish, value: 0.006289308176100629
# ---------------Possible actions for node CCL in phase 1---------------
#   node source destination     value
# 0  CCL    CCL         Zap  0.006289
# 1  CCL    CCL      Double  0.006289
# 2  CCL    CCL        Grin  0.006171
# the action among the previous actions that maximizes modularity gain is:
# node: CCL, source: CCL, destination: Zap, value: 0.006289308176100629
# ---------------Possible actions for node Cross in phase 1---------------
#     node source destination     value
# 0  Cross  Cross     Trigger  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Cross, source: Cross, destination: Trigger, value: 0.006289308176100629
# ---------------Possible actions for node DN16 in phase 1---------------
#    node source destination     value
# 0  DN16   DN16    Gallatin  0.006289
# 1  DN16   DN16        Wave  0.006289
# 2  DN16   DN16     Feather  0.006289
# 3  DN16   DN16         Web  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: DN16, source: DN16, destination: Gallatin, value: 0.006289308176100629
# ---------------Possible actions for node DN21 in phase 1---------------
#    node source destination     value
# 0  DN21   DN21    Gallatin  0.006052
# 1  DN21   DN21         Jet  0.006289
# 2  DN21   DN21     Feather  0.006289
# 3  DN21   DN21      Upbang  0.006289
# 4  DN21   DN21        Wave  0.006289
# 5  DN21   DN21         Web  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: DN21, source: DN21, destination: Jet, value: 0.006289308176100629
# ---------------Possible actions for node DN63 in phase 1---------------
#    node source destination     value
# 0  DN63   DN63      Upbang  0.006289
# 1  DN63   DN63        Knit  0.006289
# 2  DN63   DN63     Number1  0.006289
# 3  DN63   DN63         SN9  0.006289
# 4  DN63   DN63          PL  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: DN63, source: DN63, destination: Upbang, value: 0.006289308176100629
# ---------------Possible actions for node Double in phase 1---------------
#      node  source destination     value
# 0  Double  Double         Zap  0.012341
# 1  Double  Double       Oscar  0.006052
# 2  Double  Double     Topless  0.006289
# 3  Double  Double         SN4  0.006289
# 4  Double  Double     Kringel  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Double, source: Double, destination: Zap, value: 0.012341283968197461
# ---------------Possible actions for node Feather in phase 1---------------
#       node   source  destination     value
# 0  Feather  Feather     Gallatin  0.012302
# 1  Feather  Feather          Jet  0.012302
# 2  Feather  Feather          Web  0.006289
# 3  Feather  Feather         SN90  0.006289
# 4  Feather  Feather  Ripplefluke  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Feather, source: Feather, destination: Gallatin, value: 0.012301728570863495
# ---------------Possible actions for node Fish in phase 1---------------
#    node source destination     value
# 0  Fish   Fish   Patchback  0.006289
# 1  Fish   Fish        Grin  0.006092
# 2  Fish   Fish        SN96  0.006289
# 3  Fish   Fish        TR77  0.006289
# 4  Fish   Fish        Fish  0.006092
# the action among the previous actions that maximizes modularity gain is:
# node: Fish, source: Fish, destination: Patchback, value: 0.006289308176100629
# ---------------Possible actions for node Five in phase 1---------------
#    node source destination    value
# 0  Five   Five     Trigger  0.00625
# the action among the previous actions that maximizes modularity gain is:
# node: Five, source: Five, destination: Trigger, value: 0.006249752778766663
# ---------------Possible actions for node Fork in phase 1---------------
#    node source destination     value
# 0  Fork   Fork       Scabs  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Fork, source: Fork, destination: Scabs, value: 0.006289308176100629
# ---------------Possible actions for node Gallatin in phase 1---------------
#        node    source  destination     value
# 0  Gallatin  Gallatin     Gallatin  0.011629
# 1  Gallatin  Gallatin          Jet  0.012262
# 2  Gallatin  Gallatin       Upbang  0.005973
# 3  Gallatin  Gallatin         SN90  0.006289
# 4  Gallatin  Gallatin          Web  0.006289
# 5  Gallatin  Gallatin  Ripplefluke  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Gallatin, source: Gallatin, destination: Jet, value: 0.012262173173529529
# ---------------Possible actions for node Grin in phase 1---------------
#     node source destination     value
# 0   Grin   Grin         Zap  0.004865
# 1   Grin   Grin        Grin  0.005815
# 2   Grin   Grin      TSN103  0.006289
# 3   Grin   Grin        SN63  0.006289
# 4   Grin   Grin        TR99  0.006289
# 5   Grin   Grin        MN83  0.006289
# 6   Grin   Grin        Hook  0.006289
# 7   Grin   Grin       Scabs  0.005815
# 8   Grin   Grin    Shmuddel  0.006289
# 9   Grin   Grin     Stripes  0.006289
# 10  Grin   Grin         SN4  0.006289
# 11  Grin   Grin         SN9  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Grin, source: Grin, destination: TSN103, value: 0.006289308176100629
# ---------------Possible actions for node Haecksel in phase 1---------------
#        node    source destination     value
# 0  Haecksel  Haecksel         Zap  0.005459
# 1  Haecksel  Haecksel         Vau  0.006289
# 2  Haecksel  Haecksel        Grin  0.006289
# 3  Haecksel  Haecksel     Topless  0.006289
# 4  Haecksel  Haecksel       Jonah  0.006289
# 5  Haecksel  Haecksel        MN83  0.006289
# 6  Haecksel  Haecksel         SN9  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Haecksel, source: Haecksel, destination: Vau, value: 0.006289308176100629
# ---------------Possible actions for node Hook in phase 1---------------
#    node source destination     value
# 0  Hook   Hook      TSN103  0.006052
# 1  Hook   Hook        SN63  0.006289
# 2  Hook   Hook       Scabs  0.006052
# 3  Hook   Hook         SN4  0.006289
# 4  Hook   Hook     Kringel  0.006289
# 5  Hook   Hook        TR99  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Hook, source: Hook, destination: SN63, value: 0.006289308176100629
# ---------------Possible actions for node Jet in phase 1---------------
#   node source destination     value
# 0  Jet    Jet       Oscar  0.005933
# 1  Jet    Jet    Gallatin  0.005933
# 2  Jet    Jet         Jet  0.011511
# 3  Jet    Jet        MN23  0.006289
# 4  Jet    Jet     Number1  0.006289
# 5  Jet    Jet       Quasi  0.006289
# 6  Jet    Jet         Web  0.006289
# 7  Jet    Jet         Mus  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Jet, source: Jet, destination: Jet, value: 0.01151062062418417
# ---------------Possible actions for node Jonah in phase 1---------------
#     node source destination     value
# 0  Jonah  Jonah         Vau  0.006012
# 1  Jonah  Jonah   Patchback  0.006012
# 2  Jonah  Jonah     Trigger  0.005736
# 3  Jonah  Jonah     Topless  0.006289
# 4  Jonah  Jonah        MN83  0.006289
# 5  Jonah  Jonah       MN105  0.006289
# 6  Jonah  Jonah     Kringel  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Jonah, source: Jonah, destination: Topless, value: 0.006289308176100629
# ---------------Possible actions for node Knit in phase 1---------------
#    node source destination     value
# 0  Knit   Knit       Oscar  0.006131
# 1  Knit   Knit          PL  0.006289
# 2  Knit   Knit      Upbang  0.012420
# the action among the previous actions that maximizes modularity gain is:
# node: Knit, source: Knit, destination: Upbang, value: 0.012420394762865394
# ---------------Possible actions for node Kringel in phase 1---------------
#       node   source destination     value
# 0  Kringel  Kringel         Zap  0.005221
# 1  Kringel  Kringel       Oscar  0.005933
# 2  Kringel  Kringel     Thumper  0.006289
# 3  Kringel  Kringel     Topless  0.005933
# 4  Kringel  Kringel        SN63  0.012223
# 5  Kringel  Kringel       SN100  0.006289
# 6  Kringel  Kringel        TR77  0.006289
# 7  Kringel  Kringel        TR99  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Kringel, source: Kringel, destination: SN63, value: 0.012222617776195563
# ---------------Possible actions for node MN105 in phase 1---------------
#     node source destination     value
# 0  MN105  MN105     Trigger  0.005815
# 1  MN105  MN105   Patchback  0.006052
# 2  MN105  MN105     Topless  0.012341
# 3  MN105  MN105       Scabs  0.006052
# 4  MN105  MN105         SN4  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: MN105, source: MN105, destination: Topless, value: 0.012341283968197461
# ---------------Possible actions for node MN23 in phase 1---------------
#    node source destination     value
# 0  MN23   MN23         Jet  0.006171
# the action among the previous actions that maximizes modularity gain is:
# node: MN23, source: MN23, destination: Jet, value: 0.006170641984098731
# ---------------Possible actions for node MN60 in phase 1---------------
#    node source destination     value
# 0  MN60   MN60       SN100  0.006289
# 1  MN60   MN60     Trigger  0.006052
# 2  MN60   MN60     Topless  0.005933
# the action among the previous actions that maximizes modularity gain is:
# node: MN60, source: MN60, destination: SN100, value: 0.006289308176100629
# ---------------Possible actions for node MN83 in phase 1---------------
#    node source destination     value
# 0  MN83   MN83         Vau  0.006052
# 1  MN83   MN83   Patchback  0.006052
# 2  MN83   MN83     Trigger  0.005815
# 3  MN83   MN83      TSN103  0.006052
# 4  MN83   MN83     Topless  0.011867
# the action among the previous actions that maximizes modularity gain is:
# node: MN83, source: MN83, destination: Topless, value: 0.011866619200189867
# ---------------Possible actions for node Mus in phase 1---------------
#   node source destination     value
# 0  Mus    Mus     Number1  0.006289
# 1  Mus    Mus       Notch  0.006289
# 2  Mus    Mus         Jet  0.005815
# the action among the previous actions that maximizes modularity gain is:
# node: Mus, source: Mus, destination: Number1, value: 0.006289308176100629
# ---------------Possible actions for node Notch in phase 1---------------
#     node source destination     value
# 0  Notch  Notch       Oscar  0.006171
# 1  Notch  Notch     Number1  0.012460
# the action among the previous actions that maximizes modularity gain is:
# node: Notch, source: Notch, destination: Number1, value: 0.01245995016019936
# ---------------Possible actions for node Number1 in phase 1---------------
#       node   source destination     value
# 0  Number1  Number1       Oscar  0.006092
# 1  Number1  Number1     Number1  0.011985
# 2  Number1  Number1         Jet  0.005498
# 3  Number1  Number1      Upbang  0.005696
# the action among the previous actions that maximizes modularity gain is:
# node: Number1, source: Number1, destination: Number1, value: 0.011985285392191765
# ---------------Possible actions for node Oscar in phase 1---------------
#     node source destination     value
# 0  Oscar  Oscar         Zap  0.005696
# 1  Oscar  Oscar       Oscar  0.006092
# 2  Oscar  Oscar        SN63  0.005696
# 3  Oscar  Oscar        TR77  0.006289
# 4  Oscar  Oscar          PL  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Oscar, source: Oscar, destination: TR77, value: 0.006289308176100629
# ---------------Possible actions for node Patchback in phase 1---------------
#         node     source destination     value
# 0  Patchback  Patchback     Trigger  0.005577
# 1  Patchback  Patchback   Patchback  0.005933
# 2  Patchback  Patchback        SMN5  0.006289
# 3  Patchback  Patchback     Topless  0.023377
# 4  Patchback  Patchback      TSN103  0.005933
# 5  Patchback  Patchback     Stripes  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Patchback, source: Patchback, destination: Topless, value: 0.023377239824374035
# ---------------Possible actions for node PL in phase 1---------------
#   node source destination     value
# 0   PL     PL        SN96  0.006289
# 1   PL     PL        TR77  0.012381
# 2   PL     PL      Upbang  0.011985
# the action among the previous actions that maximizes modularity gain is:
# node: PL, source: PL, destination: TR77, value: 0.012380839365531427
# ---------------Possible actions for node Quasi in phase 1---------------
#     node source destination     value
# 0  Quasi  Quasi         Jet  0.006131
# the action among the previous actions that maximizes modularity gain is:
# node: Quasi, source: Quasi, destination: Jet, value: 0.006131086586764764
# ---------------Possible actions for node Ripplefluke in phase 1---------------
#           node       source destination     value
# 0  Ripplefluke  Ripplefluke    Gallatin  0.006171
# 1  Ripplefluke  Ripplefluke         Zig  0.006289
# 2  Ripplefluke  Ripplefluke         Jet  0.005696
# the action among the previous actions that maximizes modularity gain is:
# node: Ripplefluke, source: Ripplefluke, destination: Zig, value: 0.006289308176100629
# ---------------Possible actions for node Scabs in phase 1---------------
#     node source destination     value
# 0  Scabs  Scabs      TSN103  0.005894
# 1  Scabs  Scabs     Topless  0.002729
# 2  Scabs  Scabs        SN63  0.011392
# 3  Scabs  Scabs        TR99  0.006289
# 4  Scabs  Scabs       Scabs  0.005894
# 5  Scabs  Scabs    Shmuddel  0.006289
# 6  Scabs  Scabs     Stripes  0.006289
# 7  Scabs  Scabs         SN4  0.006289
# 8  Scabs  Scabs         SN9  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Scabs, source: Scabs, destination: SN63, value: 0.011391954432182272
# ---------------Possible actions for node Shmuddel in phase 1---------------
#        node    source destination     value
# 0  Shmuddel  Shmuddel        TR88  0.006289
# 1  Shmuddel  Shmuddel     Thumper  0.006289
# 2  Shmuddel  Shmuddel      TSN103  0.006092
# 3  Shmuddel  Shmuddel        SN63  0.005300
# 4  Shmuddel  Shmuddel         SN4  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Shmuddel, source: Shmuddel, destination: TR88, value: 0.006289308176100629
# ---------------Possible actions for node SMN5 in phase 1---------------
#    node source destination     value
# 0  SMN5   SMN5     Topless  0.005933
# the action among the previous actions that maximizes modularity gain is:
# node: SMN5, source: SMN5, destination: Topless, value: 0.005933309600094933
# ---------------Possible actions for node SN100 in phase 1---------------
#     node source destination     value
# 0  SN100  SN100         Zap  0.005459
# 1  SN100  SN100       Oscar  0.006289
# 2  SN100  SN100        SN63  0.004905
# 3  SN100  SN100       SN100  0.006012
# 4  SN100  SN100         SN4  0.006289
# 5  SN100  SN100         SN9  0.006289
# 6  SN100  SN100        SN89  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: SN100, source: SN100, destination: Oscar, value: 0.006289308176100629
# ---------------Possible actions for node SN4 in phase 1---------------
#   node source destination     value
# 0  SN4    SN4         Zap  0.004984
# 1  SN4    SN4        TR88  0.005854
# 2  SN4    SN4       Oscar  0.005854
# 3  SN4    SN4      TSN103  0.005854
# 4  SN4    SN4     Topless  0.008228
# 5  SN4    SN4        SN63  0.010403
# 6  SN4    SN4      Zipfel  0.006289
# 7  SN4    SN4     Stripes  0.006289
# 8  SN4    SN4         SN9  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: SN4, source: SN4, destination: SN63, value: 0.010403069498833116
# ---------------Possible actions for node SN63 in phase 1---------------
#    node source destination     value
# 0  SN63   SN63     Thumper  0.006289
# 1  SN63   SN63      TSN103  0.012262
# 2  SN63   SN63        SN63  0.016653
# 3  SN63   SN63    Whitetip  0.006289
# 4  SN63   SN63     Stripes  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: SN63, source: SN63, destination: SN63, value: 0.016652822277599778
# ---------------Possible actions for node SN89 in phase 1---------------
#    node source destination     value
# 0  SN89   SN89       Oscar  0.006210
# 1  SN89   SN89         Web  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: SN89, source: SN89, destination: Web, value: 0.006289308176100629
# ---------------Possible actions for node SN9 in phase 1---------------
#   node source destination     value
# 0  SN9    SN9       Oscar  0.005973
# 1  SN9    SN9         Vau  0.005973
# 2  SN9    SN9      TSN103  0.012262
# 3  SN9    SN9        Grin  0.006289
# 4  SN9    SN9        SN63  0.010364
# 5  SN9    SN9      Upbang  0.005340
# the action among the previous actions that maximizes modularity gain is:
# node: SN9, source: SN9, destination: TSN103, value: 0.012262173173529529
# ---------------Possible actions for node SN90 in phase 1---------------
#    node source destination     value
# 0  SN90   SN90       Oscar  0.006092
# 1  SN90   SN90    Gallatin  0.006092
# 2  SN90   SN90         Jet  0.005300
# 3  SN90   SN90      Upbang  0.005696
# 4  SN90   SN90         Web  0.006092
# the action among the previous actions that maximizes modularity gain is:
# node: SN90, source: SN90, destination: Oscar, value: 0.006091531189430798
# ---------------Possible actions for node SN96 in phase 1---------------
#    node source destination     value
# 0  SN96   SN96   Patchback  0.006289
# 1  SN96   SN96        Grin  0.006289
# 2  SN96   SN96        TR77  0.011867
# 3  SN96   SN96        Fish  0.006289
# 4  SN96   SN96        TR99  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: SN96, source: SN96, destination: TR77, value: 0.011866619200189867
# ---------------Possible actions for node Stripes in phase 1---------------
#       node   source destination     value
# 0  Stripes  Stripes       TSN83  0.006289
# 1  Stripes  Stripes      TSN103  0.005459
# 2  Stripes  Stripes     Topless  0.003520
# 3  Stripes  Stripes        SN63  0.016930
# 4  Stripes  Stripes       TR120  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Stripes, source: Stripes, destination: SN63, value: 0.016929710058937543
# ---------------Possible actions for node Thumper in phase 1---------------
#       node   source destination     value
# 0  Thumper  Thumper        TR88  0.006131
# 1  Thumper  Thumper        SN63  0.010996
# 2  Thumper  Thumper        Fish  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Thumper, source: Thumper, destination: SN63, value: 0.01099640045884261
# ---------------Possible actions for node Topless in phase 1---------------
#       node   source destination     value
# 0  Topless  Topless         Zap  0.011273
# 1  Topless  Topless         Vau  0.005854
# 2  Topless  Topless     Trigger  0.005419
# 3  Topless  Topless     Topless  0.020806
# 4  Topless  Topless        SN63  0.001068
# 5  Topless  Topless       SN100  0.006289
# 6  Topless  Topless        TR99  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Topless, source: Topless, destination: Topless, value: 0.020806138997666233
# ---------------Possible actions for node TR120 in phase 1---------------
#     node source destination    value
# 0  TR120  TR120        TR88  0.00621
# 1  TR120  TR120        SN63  0.00534
# the action among the previous actions that maximizes modularity gain is:
# node: TR120, source: TR120, destination: TR88, value: 0.006210197381432697
# ---------------Possible actions for node TR77 in phase 1---------------
#    node source destination     value
# 0  TR77   TR77        SN63  0.003441
# 1  TR77   TR77   Patchback  0.006289
# 2  TR77   TR77        Grin  0.006289
# 3  TR77   TR77        TR77  0.017681
# the action among the previous actions that maximizes modularity gain is:
# node: TR77, source: TR77, destination: TR77, value: 0.0176812626082829
# ---------------Possible actions for node TR82 in phase 1---------------
#    node source destination    value
# 0  TR82   TR82         Web  0.00625
# the action among the previous actions that maximizes modularity gain is:
# node: TR82, source: TR82, destination: Web, value: 0.006249752778766663
# ---------------Possible actions for node TR88 in phase 1---------------
#    node source destination    value
# 0  TR88   TR88        TR88  0.01242
# the action among the previous actions that maximizes modularity gain is:
# node: TR88, source: TR88, destination: TR88, value: 0.012420394762865394
# ---------------Possible actions for node TR99 in phase 1---------------
#    node source destination     value
# 0  TR99   TR99     Trigger  0.005736
# 1  TR99   TR99      TSN103  0.005459
# 2  TR99   TR99     Topless  0.003520
# 3  TR99   TR99        SN63  0.015545
# 4  TR99   TR99        TR77  0.004905
# the action among the previous actions that maximizes modularity gain is:
# node: TR99, source: TR99, destination: SN63, value: 0.015545271152248723
# ---------------Possible actions for node Trigger in phase 1---------------
#       node   source destination     value
# 0  Trigger  Trigger         Vau  0.005894
# 1  Trigger  Trigger     Trigger  0.011788
# 2  Trigger  Trigger     Topless  0.027491
# 3  Trigger  Trigger        SN63  0.000356
# 4  Trigger  Trigger       SN100  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: Trigger, source: Trigger, destination: Topless, value: 0.027491001147106522
# ---------------Possible actions for node TSN103 in phase 1---------------
#      node  source destination     value
# 0  TSN103  TSN103        SN63  0.003916
# 1  TSN103  TSN103      TSN103  0.012104
# 2  TSN103  TSN103     Topless  0.003916
# the action among the previous actions that maximizes modularity gain is:
# node: TSN103, source: TSN103, destination: TSN103, value: 0.012103951584193664
# ---------------Possible actions for node TSN83 in phase 1---------------
#     node source destination     value
# 0  TSN83  TSN83        SN63  0.005103
# 1  TSN83  TSN83      Zipfel  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: TSN83, source: TSN83, destination: Zipfel, value: 0.006289308176100629
# ---------------Possible actions for node Upbang in phase 1---------------
#      node  source destination     value
# 0  Upbang  Upbang       Oscar  0.012025
# 1  Upbang  Upbang         Web  0.005736
# 2  Upbang  Upbang      Upbang  0.011748
# 3  Upbang  Upbang         Jet  0.011194
# the action among the previous actions that maximizes modularity gain is:
# node: Upbang, source: Upbang, destination: Oscar, value: 0.012024840789525731
# ---------------Possible actions for node Vau in phase 1---------------
#   node source destination     value
# 0  Vau    Vau         Vau  0.006210
# 1  Vau    Vau     Topless  0.005103
# the action among the previous actions that maximizes modularity gain is:
# node: Vau, source: Vau, destination: Vau, value: 0.006210197381432697
# ---------------Possible actions for node Wave in phase 1---------------
#    node source destination     value
# 0  Wave   Wave    Gallatin  0.006210
# 1  Wave   Wave         Jet  0.005894
# the action among the previous actions that maximizes modularity gain is:
# node: Wave, source: Wave, destination: Gallatin, value: 0.006210197381432697
# ---------------Possible actions for node Web in phase 1---------------
#   node source destination     value
# 0  Web    Web       Oscar  0.011155
# 1  Web    Web    Gallatin  0.011867
# 2  Web    Web         Web  0.011867
# 3  Web    Web         Jet  0.017088
# the action among the previous actions that maximizes modularity gain is:
# node: Web, source: Web, destination: Jet, value: 0.017087931648273408
# ---------------Possible actions for node Whitetip in phase 1---------------
#        node    source destination     value
# 0  Whitetip  Whitetip        SN63  0.005696
# the action among the previous actions that maximizes modularity gain is:
# node: Whitetip, source: Whitetip, destination: SN63, value: 0.005695977216091136
# ---------------Possible actions for node Zap in phase 1---------------
#   node source destination     value
# 0  Zap    Zap         Zap  0.011985
# 1  Zap    Zap       Oscar  0.005498
# 2  Zap    Zap         Vau  0.006092
# 3  Zap    Zap     Topless  0.003323
# the action among the previous actions that maximizes modularity gain is:
# node: Zap, source: Zap, destination: Zap, value: 0.011985285392191765
# ---------------Possible actions for node Zig in phase 1---------------
#   node source destination    value
# 0  Zig    Zig         Zig  0.00625
# the action among the previous actions that maximizes modularity gain is:
# node: Zig, source: Zig, destination: Zig, value: 0.006249752778766663
# ---------------Possible actions for node Zipfel in phase 1---------------
#      node  source destination     value
# 0  Zipfel  Zipfel        SN63  0.004391
# 1  Zipfel  Zipfel        Fish  0.006289
# 2  Zipfel  Zipfel      Zipfel  0.006171
# the action among the previous actions that maximizes modularity gain is:
# node: Zipfel, source: Zipfel, destination: Fish, value: 0.006289308176100629
# displayed possible actions for all the nodes in phase: 1
# ----------------------------------------------------------------
#
#
# --------------------------Graph in the phase: 2--------------------------
#         nodes  community                                       people_nodes
# 0        Grin       Grin                                             [Beak]
# 1       Oscar      Oscar                  [Beescratch, SN100, SN90, Upbang]
# 2        Fish       Fish                                   [Bumper, Zipfel]
# 3         Zap        Zap                                 [CCL, Double, Zap]
# 4     Trigger    Trigger                                      [Cross, Five]
# 5    Gallatin   Gallatin                              [DN16, Feather, Wave]
# 6         Jet        Jet            [DN21, Gallatin, Jet, MN23, Quasi, Web]
# 7      Upbang     Upbang                                       [DN63, Knit]
# 8   Patchback  Patchback                                             [Fish]
# 9       Scabs      Scabs                                             [Fork]
# 10     TSN103     TSN103                                [Grin, SN9, TSN103]
# 11        Vau        Vau                                    [Haecksel, Vau]
# 12       SN63       SN63  [Hook, Kringel, Scabs, SN4, SN63, Stripes, Thu...
# 13    Topless    Topless  [Jonah, MN105, MN83, Patchback, SMN5, Topless,...
# 14      SN100      SN100                                             [MN60]
# 15    Number1    Number1                              [Mus, Notch, Number1]
# 16       TR77       TR77                            [Oscar, PL, SN96, TR77]
# 17        Zig        Zig                                 [Ripplefluke, Zig]
# 18       TR88       TR88                            [Shmuddel, TR120, TR88]
# 19        Web        Web                                       [SN89, TR82]
# 20     Zipfel     Zipfel                                            [TSN83]
#     edges     node_a     node_b  weight
# 0       1       Grin  Patchback       1
# 1       2       Grin     TSN103       2
# 2       3       Grin        Vau       1
# 3       4       Grin       TR77       2
# 4       5      Oscar        Jet       6
# 5       6      Oscar     Upbang       3
# 6       7      Oscar    Number1       2
# 7       8      Oscar       TR77       1
# 8       9      Oscar      Oscar       4
# 9      10      Oscar   Gallatin       1
# 10     11      Oscar       SN63       2
# 11     12      Oscar      SN100       1
# 12     13      Oscar        Web       1
# 13     14      Oscar     TSN103       1
# 14     15      Oscar        Zap       1
# 15     16       Fish  Patchback       1
# 16     17       Fish       TR77       1
# 17     18       Fish       SN63       2
# 18     19       Fish       Fish       1
# 19     20       Fish     Zipfel       1
# 20     21        Zap        Zap       3
# 21     22        Zap     TSN103       1
# 22     23        Zap       SN63       2
# 23     24        Zap       TR77       1
# 24     25        Zap    Topless       2
# 25     26        Zap        Vau       1
# 26     27    Trigger    Topless       2
# 27     28   Gallatin   Gallatin       2
# 28     29   Gallatin        Jet       7
# 29     30   Gallatin        Zig       1
# 30     31        Jet        Jet       8
# 31     32        Jet        Zig       1
# 32     33        Jet    Number1       2
# 33     34        Jet        Web       2
# 34     35     Upbang     Upbang       1
# 35     36     Upbang    Number1       1
# 36     37     Upbang       TR77       2
# 37     38     Upbang     TSN103       1
# 38     39  Patchback    Topless       1
# 39     40  Patchback       TR77       2
# 40     41      Scabs       SN63       1
# 41     42     TSN103       SN63       9
# 42     43     TSN103    Topless       2
# 43     44     TSN103       TR88       1
# 44     45     TSN103     TSN103       3
# 45     46     TSN103        Vau       1
# 46     47        Vau    Topless       4
# 47     48        Vau        Vau       1
# 48     49       SN63       SN63      16
# 49     50       SN63    Topless       7
# 50     51       SN63       TR77       3
# 51     52       SN63       TR88       4
# 52     53       SN63     Zipfel       1
# 53     54    Topless    Topless      15
# 54     55    Topless      SN100       2
# 55     56    Number1    Number1       3
# 56     57       TR77       TR77       5
# 57     58        Zig        Zig       1
# 58     59       TR88       TR88       2
# _______________________________________________________________________________________________________
# ---------------Possible actions for node Grin in phase 2---------------
#    node source destination     value
# 0  Grin   Grin         Vau  0.006052
# 1  Grin   Grin   Patchback  0.006289
# 2  Grin   Grin      TSN103  0.011867
# 3  Grin   Grin        TR77  0.011392
# the action among the previous actions that maximizes modularity gain is:
# node: Grin, source: Grin, destination: TSN103, value: 0.011866619200189867
# ---------------Possible actions for node Oscar in phase 2---------------
#      node source destination     value
# 0   Oscar  Oscar         Zap  0.003560
# 1   Oscar  Oscar       Oscar  0.021518
# 2   Oscar  Oscar    Gallatin  0.004470
# 3   Oscar  Oscar      TSN103  0.001740
# 4   Oscar  Oscar         Jet  0.030458
# 5   Oscar  Oscar        SN63 -0.001978
# 6   Oscar  Oscar       SN100  0.006289
# 7   Oscar  Oscar        TR77  0.001740
# 8   Oscar  Oscar      Upbang  0.017958
# 9   Oscar  Oscar         Web  0.006289
# 10  Oscar  Oscar     Number1  0.009849
# the action among the previous actions that maximizes modularity gain is:
# node: Oscar, source: Oscar, destination: Jet, value: 0.030457655947153987
# ---------------Possible actions for node Fish in phase 2---------------
#    node source destination     value
# 0  Fish   Fish   Patchback  0.006289
# 1  Fish   Fish        SN63  0.008781
# 2  Fish   Fish      Zipfel  0.006289
# 3  Fish   Fish        TR77  0.005103
# 4  Fish   Fish        Fish  0.006052
# the action among the previous actions that maximizes modularity gain is:
# node: Fish, source: Fish, destination: SN63, value: 0.008781298208140501
# ---------------Possible actions for node Zap in phase 2---------------
#   node source destination     value
# 0  Zap    Zap         Zap  0.017563
# 1  Zap    Zap         Vau  0.005854
# 2  Zap    Zap      TSN103  0.004114
# 3  Zap    Zap         Jet -0.001543
# 4  Zap    Zap     Topless  0.006052
# 5  Zap    Zap        SN63  0.004312
# 6  Zap    Zap        TR77  0.004114
# the action among the previous actions that maximizes modularity gain is:
# node: Zap, source: Zap, destination: Zap, value: 0.017562596416281002
# ---------------Possible actions for node Trigger in phase 2---------------
#       node   source destination     value
# 0  Trigger  Trigger     Topless  0.011392
# the action among the previous actions that maximizes modularity gain is:
# node: Trigger, source: Trigger, destination: Topless, value: 0.011391954432182272
# ---------------Possible actions for node Gallatin in phase 2---------------
#        node    source destination     value
# 0  Gallatin  Gallatin    Gallatin  0.011708
# 1  Gallatin  Gallatin         Zig  0.005854
# 2  Gallatin  Gallatin         Jet  0.042482
# the action among the previous actions that maximizes modularity gain is:
# node: Gallatin, source: Gallatin, destination: Jet, value: 0.042482496736679726
# ---------------Possible actions for node Jet in phase 2---------------
#   node source destination     value
# 0  Jet    Jet     Number1  0.009493
# 1  Jet    Jet         Web  0.012579
# 2  Jet    Jet         Zig  0.005261
# 3  Jet    Jet         Jet  0.103279
# the action among the previous actions that maximizes modularity gain is:
# node: Jet, source: Jet, destination: Jet, value: 0.1032791424389858
# ---------------Possible actions for node Upbang in phase 2---------------
#      node  source destination     value
# 0  Upbang  Upbang      TSN103  0.004707
# 1  Upbang  Upbang         Jet  0.010008
# 2  Upbang  Upbang        TR77  0.010996
# 3  Upbang  Upbang      Upbang  0.005973
# 4  Upbang  Upbang     Number1  0.005340
# the action among the previous actions that maximizes modularity gain is:
# node: Upbang, source: Upbang, destination: TR77, value: 0.01099640045884261
# ---------------Possible actions for node Patchback in phase 2---------------
#         node     source destination     value
# 0  Patchback  Patchback        TR77  0.010996
# 1  Patchback  Patchback        SN63  0.002532
# 2  Patchback  Patchback      TSN103  0.005300
# 3  Patchback  Patchback     Topless  0.002927
# the action among the previous actions that maximizes modularity gain is:
# node: Patchback, source: Patchback, destination: TR77, value: 0.01099640045884261
# ---------------Possible actions for node Scabs in phase 2---------------
#     node source destination     value
# 0  Scabs  Scabs        SN63  0.005538
# the action among the previous actions that maximizes modularity gain is:
# node: Scabs, source: Scabs, destination: SN63, value: 0.005537755626755271
# ---------------Possible actions for node TSN103 in phase 2---------------
#      node  source destination     value
# 0  TSN103  TSN103         Zap  0.003797
# 1  TSN103  TSN103        TR88  0.004628
# 2  TSN103  TSN103         Vau  0.005459
# 3  TSN103  TSN103      TSN103  0.027293
# 4  TSN103  TSN103         Jet -0.016969
# 5  TSN103  TSN103     Topless -0.001543
# 6  TSN103  TSN103        SN63  0.039991
# 7  TSN103  TSN103        TR77 -0.002017
# the action among the previous actions that maximizes modularity gain is:
# node: TSN103, source: TSN103, destination: SN63, value: 0.03999050670463985
# ---------------Possible actions for node Vau in phase 2---------------
#   node source destination     value
# 0  Vau    Vau         Zap  0.005340
# 1  Vau    Vau         Vau  0.005973
# 2  Vau    Vau      TSN103  0.006289
# 3  Vau    Vau     Topless  0.019778
# 4  Vau    Vau        SN63 -0.003837
# the action among the previous actions that maximizes modularity gain is:
# node: Vau, source: Vau, destination: Topless, value: 0.01977769866698311
# ---------------Possible actions for node SN63 in phase 2---------------
#    node source destination     value
# 0  SN63   SN63         Zap  0.007001
# 1  SN63   SN63        TR88  0.021439
# 2  SN63   SN63     Topless  0.003125
# 3  SN63   SN63         Jet -0.039476
# 4  SN63   SN63        SN63  0.116609
# 5  SN63   SN63        TR77  0.000277
# 6  SN63   SN63      Zipfel  0.006289
# the action among the previous actions that maximizes modularity gain is:
# node: SN63, source: SN63, destination: SN63, value: 0.1166093113405324
# ---------------Possible actions for node Topless in phase 2---------------
#       node   source destination     value
# 0  Topless  Topless         Zap  0.008425
# 1  Topless  Topless     Topless  0.101618
# 2  Topless  Topless        SN63  0.012302
# 3  Topless  Topless       SN100  0.012579
# 4  Topless  Topless        TR77 -0.007555
# the action among the previous actions that maximizes modularity gain is:
# node: Topless, source: Topless, destination: Topless, value: 0.10161781575095921
# ---------------Possible actions for node SN100 in phase 2---------------
#     node source destination     value
# 0  SN100  SN100     Topless  0.009968
# 1  SN100  SN100         Jet  0.002967
# the action among the previous actions that maximizes modularity gain is:
# node: SN100, source: SN100, destination: Topless, value: 0.009967960128159488
# ---------------Possible actions for node Number1 in phase 2---------------
#       node   source destination     value
# 0  Number1  Number1     Number1  0.017919
# 1  Number1  Number1        TR77  0.003125
# 2  Number1  Number1         Jet  0.016297
# the action among the previous actions that maximizes modularity gain is:
# node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# ---------------Possible actions for node TR77 in phase 2---------------
#    node source destination     value
# 0  TR77   TR77         Zap  0.004272
# 1  TR77   TR77      TSN103  0.012579
# 2  TR77   TR77         Jet -0.012539
# 3  TR77   TR77        SN63  0.003639
# 4  TR77   TR77        TR77  0.049879
# the action among the previous actions that maximizes modularity gain is:
# node: TR77, source: TR77, destination: TR77, value: 0.0498793560381314
# ---------------Possible actions for node Zig in phase 2---------------
#   node source destination     value
# 0  Zig    Zig         Zig  0.006171
# 1  Zig    Zig         Jet  0.009256
# the action among the previous actions that maximizes modularity gain is:
# node: Zig, source: Zig, destination: Jet, value: 0.009255962976148096
# ---------------Possible actions for node TR88 in phase 2---------------
#    node source destination     value
# 0  TR88   TR88        TR88  0.012025
# 1  TR88   TR88        SN63  0.022586
# the action among the previous actions that maximizes modularity gain is:
# node: TR88, source: TR88, destination: SN63, value: 0.02258613187769471
# ---------------Possible actions for node Web in phase 2---------------
#   node source destination     value
# 0  Web    Web         Jet  0.015189
# the action among the previous actions that maximizes modularity gain is:
# node: Web, source: Web, destination: Jet, value: 0.015189272576243027
# ---------------Possible actions for node Zipfel in phase 2---------------
#      node  source destination     value
# 0  Zipfel  Zipfel        SN63  0.009493
# the action among the previous actions that maximizes modularity gain is:
# node: Zipfel, source: Zipfel, destination: SN63, value: 0.009493295360151893
# displayed possible actions for all the nodes in phase: 2
# ----------------------------------------------------------------
#
#
# --------------------------Graph in the phase: 3--------------------------
#      nodes community                                       people_nodes
# 0   TSN103    TSN103                                             [Beak]
# 1      Jet       Jet  [Beescratch, SN100, SN90, Upbang, DN16, Feathe...
# 2     SN63      SN63  [Bumper, Zipfel, Fork, Grin, SN9, TSN103, Hook...
# 3      Zap       Zap                                 [CCL, Double, Zap]
# 4  Topless   Topless  [Cross, Five, Haecksel, Vau, Jonah, MN105, MN8...
# 5     TR77      TR77          [DN63, Knit, Fish, Oscar, PL, SN96, TR77]
# 6  Number1   Number1                              [Mus, Notch, Number1]
#     edges   node_a   node_b  weight
# 0       1   TSN103     TR77       3
# 1       2   TSN103     SN63       2
# 2       3   TSN103  Topless       1
# 3       4      Jet      Jet      34
# 4       5      Jet     TR77       4
# 5       6      Jet  Number1       4
# 6       7      Jet     SN63       3
# 7       8      Jet  Topless       1
# 8       9      Jet      Zap       1
# 9      10     SN63     TR77       6
# 10     11     SN63     SN63      41
# 11     12     SN63      Zap       3
# 12     13     SN63  Topless      10
# 13     14      Zap      Zap       3
# 14     15      Zap     TR77       1
# 15     16      Zap  Topless       3
# 16     17  Topless  Topless      24
# 17     18  Topless     TR77       1
# 18     19     TR77     TR77      10
# 19     20     TR77  Number1       1
# 20     21  Number1  Number1       3
# _______________________________________________________________________________________________________
# ---------------Possible actions for node TSN103 in phase 3---------------
#      node  source destination     value
# 0  TSN103  TSN103        SN63  0.002848
# 1  TSN103  TSN103        TR77  0.016495
# 2  TSN103  TSN103     Topless  0.000593
# the action among the previous actions that maximizes modularity gain is:
# node: TSN103, source: TSN103, destination: TR77, value: 0.016494600688263913
# ---------------Possible actions for node Jet in phase 3---------------
#   node source destination     value
# 0  Jet    Jet         Zap  0.000712
# 1  Jet    Jet     Topless -0.038329
# 2  Jet    Jet         Jet  0.150627
# 3  Jet    Jet        SN63 -0.057355
# 4  Jet    Jet        TR77  0.000989
# 5  Jet    Jet     Number1  0.019580
# the action among the previous actions that maximizes modularity gain is:
# node: Jet, source: Jet, destination: Jet, value: 0.15062695304774337
# ---------------Possible actions for node SN63 in phase 3---------------
#    node source destination     value
# 0  SN63   SN63         Zap  0.011155
# 1  SN63   SN63     Topless  0.001187
# 2  SN63   SN63         Jet -0.068550
# 3  SN63   SN63        SN63  0.152447
# 4  SN63   SN63        TR77  0.016890
# the action among the previous actions that maximizes modularity gain is:
# node: SN63, source: SN63, destination: SN63, value: 0.15244650132510582
# ---------------Possible actions for node Zap in phase 3---------------
#   node source destination     value
# 0  Zap    Zap         Zap  0.017563
# 1  Zap    Zap     Topless  0.008425
# 2  Zap    Zap         Jet -0.008504
# 3  Zap    Zap        SN63  0.001028
# 4  Zap    Zap        TR77  0.000633
# the action among the previous actions that maximizes modularity gain is:
# node: Zap, source: Zap, destination: Zap, value: 0.017562596416281002
# ---------------Possible actions for node Topless in phase 3---------------
#       node   source destination     value
# 0  Topless  Topless         Zap  0.014121
# 1  Topless  Topless     Topless  0.112970
# 2  Topless  Topless         Jet -0.047506
# 3  Topless  Topless        SN63 -0.001978
# 4  Topless  Topless        TR77 -0.007990
# the action among the previous actions that maximizes modularity gain is:
# node: Topless, source: Topless, destination: Topless, value: 0.11297021478580752
# ---------------Possible actions for node TR77 in phase 3---------------
#    node source destination     value
# 0  TR77   TR77         Zap  0.003204
# 1  TR77   TR77     Topless -0.018393
# 2  TR77   TR77         Jet -0.009810
# 3  TR77   TR77        SN63 -0.004430
# 4  TR77   TR77        TR77  0.068391
# 5  TR77   TR77     Number1  0.003204
# the action among the previous actions that maximizes modularity gain is:
# node: TR77, source: TR77, destination: TR77, value: 0.06839128199042759
# ---------------Possible actions for node Number1 in phase 3---------------
#       node   source destination     value
# 0  Number1  Number1     Number1  0.017919
# 1  Number1  Number1        TR77  0.002176
# 2  Number1  Number1         Jet  0.014398
# the action among the previous actions that maximizes modularity gain is:
# node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# displayed possible actions for all the nodes in phase: 3
# ----------------------------------------------------------------
#
#
# --------------------------Graph in the phase: 4--------------------------
#      nodes community                                       people_nodes
# 0     TR77      TR77    [Beak, DN63, Knit, Fish, Oscar, PL, SN96, TR77]
# 1      Jet       Jet  [Beescratch, SN100, SN90, Upbang, DN16, Feathe...
# 2     SN63      SN63  [Bumper, Zipfel, Fork, Grin, SN9, TSN103, Hook...
# 3      Zap       Zap                                 [CCL, Double, Zap]
# 4  Topless   Topless  [Cross, Five, Haecksel, Vau, Jonah, MN105, MN8...
# 5  Number1   Number1                              [Mus, Notch, Number1]
#     edges   node_a   node_b  weight
# 0       1     TR77     TR77      13
# 1       2     TR77     SN63       8
# 2       3     TR77  Topless       2
# 3       4     TR77      Jet       4
# 4       5     TR77      Zap       1
# 5       6     TR77  Number1       1
# 6       7      Jet      Jet      34
# 7       8      Jet  Number1       4
# 8       9      Jet     SN63       3
# 9      10      Jet  Topless       1
# 10     11      Jet      Zap       1
# 11     12     SN63     SN63      41
# 12     13     SN63      Zap       3
# 13     14     SN63  Topless      10
# 14     15      Zap      Zap       3
# 15     16      Zap  Topless       3
# 16     17  Topless  Topless      24
# 17     18  Number1  Number1       3
# _______________________________________________________________________________________________________
# ---------------Possible actions for node TR77 in phase 4---------------
#    node source destination     value
# 0  TR77   TR77         Zap  0.002848
# 1  TR77   TR77         Jet -0.013844
# 2  TR77   TR77     Topless -0.014952
# 3  TR77   TR77        SN63  0.003283
# 4  TR77   TR77        TR77  0.066849
# 5  TR77   TR77     Number1  0.002848
# the action among the previous actions that maximizes modularity gain is:
# node: TR77, source: TR77, destination: TR77, value: 0.0668486214944029
# ---------------Possible actions for node Jet in phase 4---------------
#   node source destination     value
# 0  Jet    Jet         Zap  0.000712
# 1  Jet    Jet     Topless -0.038329
# 2  Jet    Jet         Jet  0.150627
# 3  Jet    Jet        SN63 -0.057355
# 4  Jet    Jet        TR77  0.000989
# 5  Jet    Jet     Number1  0.019580
# the action among the previous actions that maximizes modularity gain is:
# node: Jet, source: Jet, destination: Jet, value: 0.15062695304774337
# ---------------Possible actions for node SN63 in phase 4---------------
#    node source destination     value
# 0  SN63   SN63         Zap  0.011155
# 1  SN63   SN63     Topless  0.001187
# 2  SN63   SN63         Jet -0.068550
# 3  SN63   SN63        SN63  0.152447
# 4  SN63   SN63        TR77  0.016890
# the action among the previous actions that maximizes modularity gain is:
# node: SN63, source: SN63, destination: SN63, value: 0.15244650132510582
# ---------------Possible actions for node Zap in phase 4---------------
#   node source destination     value
# 0  Zap    Zap         Zap  0.017563
# 1  Zap    Zap     Topless  0.008425
# 2  Zap    Zap         Jet -0.008504
# 3  Zap    Zap        SN63  0.001028
# 4  Zap    Zap        TR77  0.000633
# the action among the previous actions that maximizes modularity gain is:
# node: Zap, source: Zap, destination: Zap, value: 0.017562596416281002
# ---------------Possible actions for node Topless in phase 4---------------
#       node   source destination     value
# 0  Topless  Topless         Zap  0.014121
# 1  Topless  Topless     Topless  0.112970
# 2  Topless  Topless         Jet -0.047506
# 3  Topless  Topless        SN63 -0.001978
# 4  Topless  Topless        TR77 -0.007990
# the action among the previous actions that maximizes modularity gain is:
# node: Topless, source: Topless, destination: Topless, value: 0.11297021478580752
# ---------------Possible actions for node Number1 in phase 4---------------
#       node   source destination     value
# 0  Number1  Number1     Number1  0.017919
# 1  Number1  Number1        TR77  0.002176
# 2  Number1  Number1         Jet  0.014398
# the action among the previous actions that maximizes modularity gain is:
# node: Number1, source: Number1, destination: Number1, value: 0.017918594992286697
# displayed possible actions for all the nodes in phase: 4
# ----------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
for g in louvain.graph_history:
    plt.figure(figsize=(12, 7))
    nx.draw(
            g,
            with_labels=True,
            alpha=0.9,
            pos=nx.spring_layout(g, k=0.9),
            node_color='skyblue',
            node_size=4000,
            font_size=8, 
            font_color='black', 
            font_weight='bold',
            edge_color='red', width=1
            )
    plt.show()

# %%
louvain.compute_modularity()
# Out:
# ---------------------------------------------------------------------------
# NotAPartition                             Traceback (most recent call last)
# <ipython-input-7-af5d42cd3c61> in <module>
# ----> 1 louvain.compute_modularity()
#
# c:\Users\ramzi\OneDrive\Bureau\AcademicResources\S2\PRJ\Week1_Feb_15\dataset_generation\notebook\utils\louvain4.py in compute_modularity(self)
#     435     def compute_modularity(self):
#     436         partition = {node: self.graph.nodes[node]['community'] for node in self.graph.nodes()}
# --> 437         modularity = nx.community.modularity(partition, self.graph)
#     438         return modularity
#
# d:\Anaconda\lib\site-packages\networkx\algorithms\community\quality.py in modularity(G, communities, weight)
#     309         communities = list(communities)
#     310     if not is_partition(G, communities):
# --> 311         raise NotAPartition(G, communities)
#     312
#     313     directed = G.is_directed()
#
# NotAPartition: {'TR77': 'TR77', 'Jet': 'Jet', 'SN63': 'SN63', 'Zap': 'Zap', 'Topless': 'Topless', 'Number1': 'Number1'} is not a valid partition of the graph ['TR77', 'Jet', 'SN63', 'Zap', 'Topless', 'Number1']
