# %%
import numpy as np
import pandas as pd
import ipywidgets

# %%
student_data = pd.read_csv('./../data/student_list.csv')
student_data
# Out:
#     Unnamed: 0       id                  email            first_name  \
# 0            0  20/0003  kh_abdelmoumen@esi.dz         HATEM MOHAMED
# 1            1  20/0188        kn_ameur@esi.dz                NASSIM
# 2            2  20/0280    kr_baaguigui@esi.dz                RAMZI
# 3            3  20/0278       km_bekkar@esi.dz               MERWAN
# 4            4  20/0050     km_benbetka@esi.dz              MAROUANE
# 5            5  20/0142   kh_benouaklil@esi.dz              HODHAIFA
# 6            6  20/0119     kw_bouhedda@esi.dz                 WALID
# 7            7  20/0023     ky_boukacem@esi.dz                YOUNES
# 8            8  20/0260   ki_boumazouza@esi.dz            INES MANEL
# 9            9  20/0011      km_bourzag@esi.dz        MOHAMED CHAKIB
# 10          10  20/0132     ki_chouchou@esi.dz        IBTISSAM FATMA
# 11          11  20/0015    ks_chouikrat@esi.dz               SABRINA
# 12          12  20/0160        ky_daoud@esi.dz                YOUCEF
# ...

# %%
# the goal of this notebook is to develop a tool that allows us to generate the data
# for the teams that have been working together in the few past TPs
