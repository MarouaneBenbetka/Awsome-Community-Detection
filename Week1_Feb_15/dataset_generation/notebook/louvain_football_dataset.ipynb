# %% [markdown]
#     ## Provided Dataset Evaluation

# %% [markdown]
#     ## Provided Dataset Evaluation

# %%
import numpy as np
import networkx as nx
import pandas as pd
from utils.louvain4 import LouvainMachine

# %%
# read the provided dataset
gml_file_path = \
'./../../dataset_generation/data/evaluation/DataSets/réels/football/football.gml'
G = nx.read_gml(gml_file_path)

# %%
louvain = LouvainMachine(G)

# %%
louvain.solve_communities()
# Out:
# neighbor communities ['Wyoming', 'SanDiegoState', 'AirForce', 'NewMexico', 'Utah', 'UtahState', 'MississippiState', 'NevadaLasVegas', 'Virginia', 'Syracuse', 'FloridaState', 'ColoradoState']
# node: BrighamYoung, source: BrighamYoung, destination: Wyoming, value: 0.0016313213703099511
# choosing maximum action >>>>node: BrighamYoung, source: BrighamYoung, destination: Wyoming, value: 0.0016313213703099511
# neighbor communities ['Wyoming', 'Florida', 'MiamiFlorida', 'NorthCarolina', 'Louisville', 'GeorgiaTech', 'NorthCarolinaState', 'Clemson', 'Virginia', 'WakeForest', 'Maryland', 'Duke']
# node: FloridaState, source: FloridaState, destination: Florida, value: 0.0016313213703099511
# choosing maximum action >>>>node: FloridaState, source: FloridaState, destination: Florida, value: 0.0016313213703099511
# neighbor communities ['Nebraska', 'Minnesota', 'Northwestern', 'KansasState', 'IowaState', 'Wisconsin', 'WesternMichigan', 'MichiganState', 'OhioState', 'Indiana', 'Illinois', 'PennState']
# node: Iowa, source: Iowa, destination: Nebraska, value: 0.0016313213703099511
# choosing maximum action >>>>node: Iowa, source: Iowa, destination: Nebraska, value: 0.0016313213703099511
# neighbor communities ['NorthTexas', 'Nebraska', 'Colorado', 'Kansas', 'TexasA&M', 'Missouri', 'TexasTech', 'Oklahoma', 'IowaState', 'LouisianaTech', 'BallState']
# node: KansasState, source: KansasState, destination: Nebraska, value: 0.003230708227661143
# choosing maximum action >>>>node: KansasState, source: KansasState, destination: Nebraska, value: 0.003230708227661143
# neighbor communities ['Wyoming', 'SanDiegoState', 'BoiseState', 'AirForce', 'NewMexicoState', 'TexasTech', 'Utah', 'OregonState', 'NevadaLasVegas', 'ColoradoState']
# node: NewMexico, source: NewMexico, destination: Wyoming, value: 0.003233369437074373
# choosing maximum action >>>>node: NewMexico, source: NewMexico, destination: Wyoming, value: 0.003233369437074373
# neighbor communities ['Wyoming', 'NorthTexas', 'Nebraska', 'Kansas', 'Baylor', 'TexasA&M', 'OklahomaState', 'Oklahoma', 'UtahState', 'Texas', 'LouisianaLafayette']
# node: TexasTech, source: TexasTech, destination: Nebraska, value: 0.0031668392017436247
# choosing maximum action >>>>node: TexasTech, source: TexasTech, destination: Nebraska, value: 0.0031668392017436247
# neighbor communities ['Nebraska', 'Michigan', 'Minnesota', 'SouthernCalifornia', 'MichiganState', 'LouisianaTech', 'Purdue', 'Pittsburgh', 'Toledo', 'OhioState', 'Indiana', 'Illinois']
# node: PennState, source: PennState, destination: Michigan, value: 0.0016313213703099511
# choosing maximum action >>>>node: PennState, source: PennState, destination: Michigan, value: 0.0016313213703099511
# neighbor communities ['Michigan', 'ArizonaState', 'Arizona', 'Colorado', 'Oregon', 'UCLA', 'Stanford', 'WashingtonState', 'NotreDame', 'OregonState', 'SanJoseState', 'California']
# node: SouthernCalifornia, source: SouthernCalifornia, destination: ArizonaState, value: 0.0016313213703099511
# choosing maximum action >>>>node: SouthernCalifornia, source: SouthernCalifornia, destination: ArizonaState, value: 0.0016313213703099511
# neighbor communities ['ArizonaState', 'SanDiegoState', 'Arizona', 'Oregon', 'Stanford', 'UCLA', 'WashingtonState', 'Washington', 'UtahState', 'California', 'ColoradoState']
# node: ArizonaState, source: ArizonaState, destination: SanDiegoState, value: 0.0016313213703099511
# choosing maximum action >>>>node: ArizonaState, source: ArizonaState, destination: SanDiegoState, value: 0.0016313213703099511
# neighbor communities ['Wyoming', 'SanDiegoState', 'Arizona', 'AirForce', 'Utah', 'OregonState', 'NevadaLasVegas', 'ColoradoState', 'Illinois']
# node: SanDiegoState, source: SanDiegoState, destination: Wyoming, value: 0.004806144200293265
# choosing maximum action >>>>node: SanDiegoState, source: SanDiegoState, destination: Wyoming, value: 0.004806144200293265
# neighbor communities ['NorthTexas', 'Nebraska', 'Minnesota', 'Missouri', 'TexasA&M', 'OklahomaState', 'Oklahoma', 'IowaState', 'Texas']
# node: Baylor, source: Baylor, destination: Nebraska, value: 0.0031295822699584056
# choosing maximum action >>>>node: Baylor, source: Baylor, destination: Nebraska, value: 0.0031295822699584056
# neighbor communities ['Nebraska', 'BoiseState', 'NewMexicoState', 'UtahState', 'NevadaLasVegas', 'LouisianaLafayette', 'Idaho', 'ArkansasState']
# node: NorthTexas, source: NorthTexas, destination: Nebraska, value: 0.0047076794520037575
# choosing maximum action >>>>node: NorthTexas, source: NorthTexas, destination: Nebraska, value: 0.0047076794520037575
# neighbor communities ['Akron', 'CentralMichigan', 'Northwestern', 'CentralFlorida', 'EasternMichigan', 'Toledo', 'Buffalo', 'WesternMichigan', 'BallState', 'Auburn']
# node: NorthernIllinois, source: NorthernIllinois, destination: Akron, value: 0.0016313213703099511
# choosing maximum action >>>>node: NorthernIllinois, source: NorthernIllinois, destination: Akron, value: 0.0016313213703099511
# neighbor communities ['Akron', 'Nebraska', 'Michigan', 'TexasChristian', 'Minnesota', 'Wisconsin', 'Purdue', 'MichiganState', 'Duke', 'Indiana', 'Illinois']
# node: Northwestern, source: Northwestern, destination: TexasChristian, value: 0.0016313213703099511
# choosing maximum action >>>>node: Northwestern, source: Northwestern, destination: TexasChristian, value: 0.0016313213703099511
# neighbor communities ['Akron', 'CentralMichigan', 'Nebraska', 'Kent', 'Ohio', 'EasternMichigan', 'Marshall', 'Wisconsin', 'BallState', 'Toledo']
# node: WesternMichigan, source: WesternMichigan, destination: CentralMichigan, value: 0.0016313213703099511
# choosing maximum action >>>>node: WesternMichigan, source: WesternMichigan, destination: CentralMichigan, value: 0.0016313213703099511
# neighbor communities ['CentralMichigan', 'Nebraska', 'Michigan', 'TexasChristian', 'Minnesota', 'Oregon', 'Cincinnati', 'Purdue', 'Hawaii', 'MichiganState', 'OhioState', 'Indiana']
# node: Wisconsin, source: Wisconsin, destination: Minnesota, value: 0.0016313213703099511
# choosing maximum action >>>>node: Wisconsin, source: Wisconsin, destination: Minnesota, value: 0.0016313213703099511
# neighbor communities ['Wyoming', 'CentralMichigan', 'TexasA&M', 'AirForce', 'Utah', 'Nevada', 'NevadaLasVegas', 'Auburn', 'ColoradoState']
# node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.0047183242896566766
# choosing maximum action >>>>node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.0047183242896566766
# neighbor communities ['Wyoming', 'Akron', 'Vanderbilt', 'Florida', 'Georgia', 'LouisianaState', 'Alabama', 'Mississippi', 'Arkansas', 'LouisianaTech', 'MississippiState']
# node: Auburn, source: Auburn, destination: Vanderbilt, value: 0.0016313213703099511
# choosing maximum action >>>>node: Auburn, source: Auburn, destination: Vanderbilt, value: 0.0016313213703099511
# neighbor communities ['Akron', 'CentralMichigan', 'Kent', 'Ohio', 'CentralFlorida', 'Connecticut', 'MiamiOhio', 'VirginiaTech', 'Marshall', 'BowlingGreenState', 'Buffalo']
# node: Akron, source: Akron, destination: Kent, value: 0.0016313213703099511
# choosing maximum action >>>>node: Akron, source: Akron, destination: Kent, value: 0.0016313213703099511
# neighbor communities ['Temple', 'Kent', 'CentralFlorida', 'MiamiFlorida', 'BostonCollege', 'Virginia', 'Pittsburgh', 'WestVirginia', 'Syracuse', 'EastCarolina', 'Rutgers']
# node: VirginiaTech, source: VirginiaTech, destination: Temple, value: 0.0016313213703099511
# choosing maximum action >>>>node: VirginiaTech, source: VirginiaTech, destination: Temple, value: 0.0016313213703099511
# neighbor communities ['Vanderbilt', 'CentralFlorida', 'UCLA', 'LouisianaState', 'Mississippi', 'Arkansas', 'MississippiState', 'SouthCarolina', 'Tennessee', 'SouthernMississippi']
# node: Alabama, source: Alabama, destination: Vanderbilt, value: 0.003233369437074373
# choosing maximum action >>>>node: Alabama, source: Alabama, destination: Vanderbilt, value: 0.003233369437074373
# neighbor communities ['Vanderbilt', 'Michigan', 'ArizonaState', 'SanDiegoState', 'Arizona', 'FresnoState', 'Oregon', 'Stanford', 'Washington', 'OregonState', 'California']
# node: UCLA, source: UCLA, destination: ArizonaState, value: 0.0016313213703099511
# choosing maximum action >>>>node: UCLA, source: UCLA, destination: ArizonaState, value: 0.0016313213703099511
# neighbor communities ['Wyoming', 'ArizonaState', 'SanDiegoState', 'Oregon', 'WashingtonState', 'Stanford', 'Washington', 'Utah', 'OregonState', 'OhioState']
# node: Arizona, source: Arizona, destination: ArizonaState, value: 0.003233369437074373
# choosing maximum action >>>>node: Arizona, source: Arizona, destination: ArizonaState, value: 0.003233369437074373
# neighbor communities ['Wyoming', 'WashingtonState', 'ArizonaState', 'AirForce', 'UtahState', 'NevadaLasVegas', 'California', 'ColoradoState']
# node: Utah, source: Utah, destination: Wyoming, value: 0.006349645659966628
# choosing maximum action >>>>node: Utah, source: Utah, destination: Wyoming, value: 0.006349645659966628
# neighbor communities ['Nebraska', 'TexasChristian', 'BoiseState', 'NewMexicoState', 'Oklahoma', 'Mississippi', 'NorthCarolinaState', 'UtahState', 'Idaho', 'Memphis']
# node: ArkansasState, source: ArkansasState, destination: BoiseState, value: 0.0016313213703099511
# choosing maximum action >>>>node: ArkansasState, source: ArkansasState, destination: BoiseState, value: 0.0016313213703099511
# neighbor communities ['Florida', 'BoiseState', 'NorthCarolina', 'Clemson', 'GeorgiaTech', 'Virginia', 'WakeForest', 'Maryland', 'SouthernMethodist', 'Duke', 'Indiana']
# node: NorthCarolinaState, source: NorthCarolinaState, destination: NorthCarolina, value: 0.0016313213703099511
# choosing maximum action >>>>node: NorthCarolinaState, source: NorthCarolinaState, destination: NorthCarolina, value: 0.0016313213703099511
# neighbor communities ['Akron', 'CentralMichigan', 'Nebraska', 'Florida', 'Connecticut', 'MiamiOhio', 'EasternMichigan', 'Buffalo', 'Toledo']
# node: BallState, source: BallState, destination: CentralMichigan, value: 0.003236030646487603
# choosing maximum action >>>>node: BallState, source: BallState, destination: CentralMichigan, value: 0.003236030646487603
# neighbor communities ['CentralMichigan', 'Vanderbilt', 'Florida', 'Georgia', 'MiddleTennesseeState', 'LouisianaState', 'Kentucky', 'MississippiState', 'SouthCarolina', 'Tennessee']
# node: Florida, source: Florida, destination: Vanderbilt, value: 0.003174822829983314
# choosing maximum action >>>>node: Florida, source: Florida, destination: Vanderbilt, value: 0.003174822829983314
# neighbor communities ['Wyoming', 'CentralMichigan', 'Nebraska', 'WashingtonState', 'BoiseState', 'NewMexicoState', 'UtahState', 'Arkansas', 'Idaho']
# node: BoiseState, source: BoiseState, destination: WashingtonState, value: 0.0016313213703099511
# choosing maximum action >>>>node: BoiseState, source: BoiseState, destination: WashingtonState, value: 0.0016313213703099511
# neighbor communities ['Temple', 'MiamiFlorida', 'Connecticut', 'NotreDame', 'Pittsburgh', 'WestVirginia', 'Syracuse', 'Army', 'Navy', 'Rutgers']
# node: BostonCollege, source: BostonCollege, destination: Temple, value: 0.003233369437074373
# choosing maximum action >>>>node: BostonCollege, source: BostonCollege, destination: Temple, value: 0.003233369437074373
# neighbor communities ['Temple', 'MiamiFlorida', 'NotreDame', 'Idaho', 'Pittsburgh', 'Maryland', 'Syracuse', 'EastCarolina', 'Rutgers']
# node: WestVirginia, source: WestVirginia, destination: Temple, value: 0.004806144200293265
# choosing maximum action >>>>node: WestVirginia, source: WestVirginia, destination: Temple, value: 0.004806144200293265
# neighbor communities ['Temple', 'Ohio', 'Kent', 'Michigan', 'MiamiOhio', 'EasternMichigan', 'Marshall', 'Buffalo', 'Pittsburgh', 'Toledo']
# node: BowlingGreenState, source: BowlingGreenState, destination: Kent, value: 0.003233369437074373
# choosing maximum action >>>>node: BowlingGreenState, source: BowlingGreenState, destination: Kent, value: 0.003233369437074373
# neighbor communities ['Kent', 'TexasChristian', 'Michigan', 'ArizonaState', 'Minnesota', 'Purdue', 'Rice', 'MichiganState', 'OhioState', 'Indiana', 'Illinois']
# node: Michigan, source: Michigan, destination: Purdue, value: 0.0016313213703099511
# choosing maximum action >>>>node: Michigan, source: Michigan, destination: Purdue, value: 0.0016313213703099511
# neighbor communities ['Wyoming', 'Temple', 'Florida', 'NorthCarolina', 'Clemson', 'GeorgiaTech', 'WakeForest', 'Maryland', 'Duke']
# node: Virginia, source: Virginia, destination: NorthCarolina, value: 0.003236030646487603
# choosing maximum action >>>>node: Virginia, source: Virginia, destination: NorthCarolina, value: 0.003236030646487603
# neighbor communities ['Akron', 'Kent', 'CentralMichigan', 'Ohio', 'Connecticut', 'MiamiOhio', 'Marshall', 'Syracuse', 'Rutgers']
# node: Buffalo, source: Buffalo, destination: Kent, value: 0.004806144200293265
# choosing maximum action >>>>node: Buffalo, source: Buffalo, destination: Kent, value: 0.004806144200293265
# neighbor communities ['Wyoming', 'Temple', 'Kent', 'Cincinnati', 'MiamiFlorida', 'Pittsburgh', 'EastCarolina', 'Rutgers']
# node: Syracuse, source: Syracuse, destination: Temple, value: 0.006349645659966628
# choosing maximum action >>>>node: Syracuse, source: Syracuse, destination: Temple, value: 0.006349645659966628
# neighbor communities ['Temple', 'Akron', 'Kent', 'Vanderbilt', 'GeorgiaTech', 'EasternMichigan', 'LouisianaTech', 'LouisianaMonroe']
# node: CentralFlorida, source: CentralFlorida, destination: Akron, value: 0.0016313213703099511
# choosing maximum action >>>>node: CentralFlorida, source: CentralFlorida, destination: Akron, value: 0.0016313213703099511
# neighbor communities ['Akron', 'Florida', 'Georgia', 'NorthCarolina', 'Clemson', 'WakeForest', 'Maryland', 'Navy', 'Duke']
# node: GeorgiaTech, source: GeorgiaTech, destination: NorthCarolina, value: 0.004806144200293265
# choosing maximum action >>>>node: GeorgiaTech, source: GeorgiaTech, destination: NorthCarolina, value: 0.004806144200293265
# neighbor communities ['Wyoming', 'Akron', 'CentralMichigan', 'Kent', 'WashingtonState', 'Ohio', 'EasternMichigan', 'Purdue', 'Toledo']
# node: CentralMichigan, source: CentralMichigan, destination: CentralMichigan, value: 0.003174822829983314
# choosing maximum action >>>>node: CentralMichigan, source: CentralMichigan, destination: CentralMichigan, value: 0.003174822829983314
# neighbor communities ['CentralMichigan', 'Kent', 'TexasChristian', 'Michigan', 'Minnesota', 'NotreDame', 'Purdue', 'MichiganState', 'OhioState', 'Indiana']
# node: Purdue, source: Purdue, destination: Minnesota, value: 0.003233369437074373
# choosing maximum action >>>>node: Purdue, source: Purdue, destination: Minnesota, value: 0.003233369437074373
# neighbor communities ['Nebraska', 'ArizonaState', 'Kansas', 'TexasA&M', 'Missouri', 'OklahomaState', 'Washington', 'IowaState', 'Texas', 'ColoradoState']
# node: Colorado, source: Colorado, destination: Nebraska, value: 0.002969909705164609
# choosing maximum action >>>>node: Colorado, source: Colorado, destination: Nebraska, value: 0.002969909705164609
# neighbor communities ['Wyoming', 'Nebraska', 'SanDiegoState', 'AirForce', 'Nevada', 'NevadaLasVegas']
# node: ColoradoState, source: ColoradoState, destination: Wyoming, value: 0.007890485910226761
# choosing maximum action >>>>node: ColoradoState, source: ColoradoState, destination: Wyoming, value: 0.007890485910226761
# neighbor communities ['Temple', 'CentralMichigan', 'Kent', 'MiddleTennesseeState', 'Louisville', 'EasternMichigan']
# node: Connecticut, source: Connecticut, destination: Kent, value: 0.003150871945264245
# choosing maximum action >>>>node: Connecticut, source: Connecticut, destination: Kent, value: 0.003150871945264245
# neighbor communities ['Temple', 'Akron', 'Kent', 'CentralMichigan', 'MiamiOhio', 'SouthCarolina', 'Toledo']
# node: EasternMichigan, source: EasternMichigan, destination: CentralMichigan, value: 0.004806144200293265
# choosing maximum action >>>>node: EasternMichigan, source: EasternMichigan, destination: CentralMichigan, value: 0.004806144200293265
# neighbor communities ['Temple', 'AlabamaBirmingham', 'Louisville', 'Houston', 'Memphis', 'SouthernMississippi', 'Tulane', 'Army', 'Duke']
# node: EastCarolina, source: EastCarolina, destination: Temple, value: 0.00460123107547456
# choosing maximum action >>>>node: EastCarolina, source: EastCarolina, destination: Temple, value: 0.00460123107547456
# neighbor communities ['Temple', 'Vanderbilt', 'Florida', 'TexasChristian', 'NorthCarolina', 'Clemson', 'WakeForest', 'Maryland']
# node: Duke, source: Duke, destination: NorthCarolina, value: 0.006349645659966628
# choosing maximum action >>>>node: Duke, source: Duke, destination: NorthCarolina, value: 0.006349645659966628
# neighbor communities ['TexasElPaso', 'ArizonaState', 'TexasChristian', 'Tulsa', 'OhioState', 'Nevada', 'Rice', 'SanJoseState', 'Hawaii', 'California', 'SouthernMethodist']
# node: FresnoState, source: FresnoState, destination: TexasElPaso, value: 0.0016313213703099511
# choosing maximum action >>>>node: FresnoState, source: FresnoState, destination: TexasElPaso, value: 0.0016313213703099511
# neighbor communities ['Nebraska', 'Michigan', 'ArizonaState', 'Minnesota', 'TexasElPaso', 'MiamiOhio', 'Purdue', 'MichiganState', 'Illinois']
# node: OhioState, source: OhioState, destination: Minnesota, value: 0.004806144200293265
# choosing maximum action >>>>node: OhioState, source: OhioState, destination: Minnesota, value: 0.004806144200293265
# neighbor communities ['Temple', 'Cincinnati', 'LouisianaState', 'Louisville', 'Texas', 'Rice', 'Memphis', 'SouthernMississippi', 'Tulane', 'Army', 'SouthernMethodist']
# node: Houston, source: Houston, destination: Cincinnati, value: 0.0016313213703099511
# choosing maximum action >>>>node: Houston, source: Houston, destination: Cincinnati, value: 0.0016313213703099511
# neighbor communities ['TexasElPaso', 'TexasChristian', 'Tulsa', 'Cincinnati', 'Oklahoma', 'Nevada', 'Purdue', 'SanJoseState', 'Hawaii', 'SouthernMethodist']
# node: Rice, source: Rice, destination: TexasElPaso, value: 0.003233369437074373
# choosing maximum action >>>>node: Rice, source: Rice, destination: TexasElPaso, value: 0.003233369437074373
# neighbor communities ['Temple', 'Nebraska', 'WashingtonState', 'Oregon', 'BoiseState', 'Washington', 'NewMexicoState', 'UtahState']
# node: Idaho, source: Idaho, destination: WashingtonState, value: 0.003238691855900833
# choosing maximum action >>>>node: Idaho, source: Idaho, destination: WashingtonState, value: 0.003238691855900833
# neighbor communities ['Nebraska', 'Oregon', 'ArizonaState', 'SanDiegoState', 'WashingtonState', 'Stanford', 'MiamiFlorida', 'OregonState', 'California']
# node: Washington, source: Washington, destination: ArizonaState, value: 0.003174822829983314
# choosing maximum action >>>>node: Washington, source: Washington, destination: ArizonaState, value: 0.003174822829983314
# neighbor communities ['AlabamaBirmingham', 'Nebraska', 'Missouri', 'Oklahoma', 'IowaState', 'Texas', 'SouthernMethodist']
# node: Kansas, source: Kansas, destination: Nebraska, value: 0.006205940351652213
# choosing maximum action >>>>node: Kansas, source: Kansas, destination: Nebraska, value: 0.006205940351652213
# neighbor communities ['TexasElPaso', 'Nebraska', 'TexasChristian', 'Tulsa', 'Cincinnati', 'NorthCarolina', 'Nevada', 'SanJoseState', 'Tulane', 'Hawaii']
# node: SouthernMethodist, source: SouthernMethodist, destination: TexasElPaso, value: 0.004798160572053575
# choosing maximum action >>>>node: SouthernMethodist, source: SouthernMethodist, destination: TexasElPaso, value: 0.004798160572053575
# neighbor communities ['CentralMichigan', 'Kent', 'Ohio', 'Minnesota', 'MiamiOhio', 'Marshall', 'Pittsburgh']
# node: Kent, source: Kent, destination: Kent, value: 0.004681067357871458
# choosing maximum action >>>>node: Kent, source: Kent, destination: Kent, value: 0.004681067357871458
# neighbor communities ['Temple', 'Kent', 'Michigan', 'MiamiFlorida', 'NorthCarolina', 'Rutgers']
# node: Pittsburgh, source: Pittsburgh, destination: Temple, value: 0.007776053905457873
# choosing maximum action >>>>node: Pittsburgh, source: Pittsburgh, destination: Temple, value: 0.007776053905457873
# neighbor communities ['Vanderbilt', 'Georgia', 'LouisianaState', 'Louisville', 'Mississippi', 'MississippiState', 'SouthCarolina', 'Tennessee', 'Indiana']
# node: Kentucky, source: Kentucky, destination: Vanderbilt, value: 0.0031295822699584056
# choosing maximum action >>>>node: Kentucky, source: Kentucky, destination: Vanderbilt, value: 0.0031295822699584056
# neighbor communities ['Temple', 'Kent', 'Florida', 'Vanderbilt', 'AlabamaBirmingham', 'Cincinnati', 'SouthernMississippi', 'Tulane', 'Army']
# node: Louisville, source: Louisville, destination: Cincinnati, value: 0.003236030646487603
# choosing maximum action >>>>node: Louisville, source: Louisville, destination: Cincinnati, value: 0.003236030646487603
# neighbor communities ['Akron', 'Vanderbilt', 'Nebraska', 'Michigan', 'Tulsa', 'MiddleTennesseeState', 'MiamiFlorida', 'LouisianaLafayette', 'LouisianaMonroe', 'Hawaii']
# node: LouisianaTech, source: LouisianaTech, destination: Michigan, value: 0.0016313213703099511
# choosing maximum action >>>>node: LouisianaTech, source: LouisianaTech, destination: Michigan, value: 0.0016313213703099511
# neighbor communities ['Akron', 'Michigan', 'Minnesota', 'MiddleTennesseeState', 'Arkansas', 'Tennessee', 'LouisianaLafayette', 'Memphis']
# node: LouisianaMonroe, source: LouisianaMonroe, destination: MiddleTennesseeState, value: 0.0016313213703099511
# choosing maximum action >>>>node: LouisianaMonroe, source: LouisianaMonroe, destination: MiddleTennesseeState, value: 0.0016313213703099511
# neighbor communities ['Ohio', 'Nebraska', 'Michigan', 'TexasChristian', 'Minnesota', 'MiddleTennesseeState', 'Indiana', 'Illinois']
# node: Minnesota, source: Minnesota, destination: Minnesota, value: 0.0047183242896566766
# choosing maximum action >>>>node: Minnesota, source: Minnesota, destination: Minnesota, value: 0.0047183242896566766
# neighbor communities ['Ohio', 'CentralMichigan', 'Kent', 'Vanderbilt', 'Minnesota', 'Cincinnati', 'Marshall']
# node: MiamiOhio, source: MiamiOhio, destination: Kent, value: 0.00629109905287557
# choosing maximum action >>>>node: MiamiOhio, source: MiamiOhio, destination: Kent, value: 0.00629109905287557
# neighbor communities ['Kent', 'Vanderbilt', 'Georgia', 'NorthCarolina', 'Mississippi', 'SouthCarolina', 'Tennessee', 'WakeForest']
# node: Vanderbilt, source: Vanderbilt, destination: Vanderbilt, value: 0.0063203723564210995
# choosing maximum action >>>>node: Vanderbilt, source: Vanderbilt, destination: Vanderbilt, value: 0.0063203723564210995
# neighbor communities ['Kent', 'Vanderbilt', 'Michigan', 'AlabamaBirmingham', 'MiddleTennesseeState', 'MississippiState', 'LouisianaLafayette', 'Maryland', 'Illinois']
# node: MiddleTennesseeState, source: MiddleTennesseeState, destination: AlabamaBirmingham, value: 0.0016313213703099511
# choosing maximum action >>>>node: MiddleTennesseeState, source: MiddleTennesseeState, destination: AlabamaBirmingham, value: 0.0016313213703099511
# neighbor communities ['Wyoming', 'AlabamaBirmingham', 'Nebraska', 'Michigan', 'TexasChristian', 'Minnesota', 'Purdue', 'MichiganState', 'California', 'Indiana']
# node: Illinois, source: Illinois, destination: Minnesota, value: 0.0030870029193467265
# choosing maximum action >>>>node: Illinois, source: Illinois, destination: Minnesota, value: 0.0030870029193467265
# neighbor communities ['Wyoming', 'Vanderbilt', 'AlabamaBirmingham', 'LouisianaState', 'Mississippi', 'Arkansas', 'SouthCarolina', 'Memphis']
# node: MississippiState, source: MississippiState, destination: Vanderbilt, value: 0.0063203723564210995
# choosing maximum action >>>>node: MississippiState, source: MississippiState, destination: Vanderbilt, value: 0.0063203723564210995
# neighbor communities ['Temple', 'Vanderbilt', 'AlabamaBirmingham', 'MiddleTennesseeState', 'BoiseState', 'Cincinnati', 'Tennessee', 'SouthernMississippi', 'Tulane', 'Army']
# node: Memphis, source: Memphis, destination: Cincinnati, value: 0.003174822829983314
# choosing maximum action >>>>node: Memphis, source: Memphis, destination: Cincinnati, value: 0.003174822829983314
# neighbor communities ['Wyoming', 'TexasElPaso', 'Oregon', 'TexasChristian', 'Tulsa', 'NevadaLasVegas', 'SanJoseState', 'Hawaii']
# node: Nevada, source: Nevada, destination: TexasElPaso, value: 0.006333678403487249
# choosing maximum action >>>>node: Nevada, source: Nevada, destination: TexasElPaso, value: 0.006333678403487249
# neighbor communities ['TexasElPaso', 'WashingtonState', 'ArizonaState', 'SanDiegoState', 'Minnesota', 'OregonState', 'California']
# node: Oregon, source: Oregon, destination: ArizonaState, value: 0.006378918963512158
# choosing maximum action >>>>node: Oregon, source: Oregon, destination: ArizonaState, value: 0.006378918963512158
# neighbor communities ['Wyoming', 'Nebraska', 'WashingtonState', 'TexasElPaso', 'Tulsa', 'Georgia', 'BoiseState', 'UtahState', 'SouthCarolina', 'Army']
# node: NewMexicoState, source: NewMexicoState, destination: WashingtonState, value: 0.003174822829983314
# choosing maximum action >>>>node: NewMexicoState, source: NewMexicoState, destination: WashingtonState, value: 0.003174822829983314
# neighbor communities ['CentralMichigan', 'Vanderbilt', 'WashingtonState', 'Georgia', 'Clemson', 'Arkansas', 'Tennessee']
# node: SouthCarolina, source: SouthCarolina, destination: Vanderbilt, value: 0.007834600512548933
# choosing maximum action >>>>node: SouthCarolina, source: SouthCarolina, destination: Vanderbilt, value: 0.007834600512548933
# neighbor communities ['CentralMichigan', 'Kent', 'Minnesota', 'IowaState', 'Marshall']
# node: Ohio, source: Ohio, destination: Kent, value: 0.007837261721962162
# choosing maximum action >>>>node: Ohio, source: Ohio, destination: Kent, value: 0.007837261721962162
# neighbor communities ['Kent', 'Nebraska', 'Missouri', 'TexasA&M', 'OklahomaState', 'NevadaLasVegas']
# node: IowaState, source: IowaState, destination: Nebraska, value: 0.009319555365131236
# choosing maximum action >>>>node: IowaState, source: IowaState, destination: Nebraska, value: 0.009319555365131236
# neighbor communities ['TexasElPaso', 'ArizonaState', 'Nebraska', 'TexasChristian', 'Tulsa', 'Stanford', 'Hawaii']
# node: SanJoseState, source: SanJoseState, destination: TexasElPaso, value: 0.007863873816094461
# choosing maximum action >>>>node: SanJoseState, source: SanJoseState, destination: TexasElPaso, value: 0.007863873816094461
# neighbor communities ['Nebraska', 'TexasElPaso', 'Missouri', 'NotreDame', 'Oklahoma']
# node: Nebraska, source: Nebraska, destination: Nebraska, value: 0.010775236914168013
# choosing maximum action >>>>node: Nebraska, source: Nebraska, destination: Nebraska, value: 0.010775236914168013
# neighbor communities ['Temple', 'Vanderbilt', 'AlabamaBirmingham', 'OklahomaState', 'Cincinnati', 'Tennessee', 'Tulane']
# node: SouthernMississippi, source: SouthernMississippi, destination: Cincinnati, value: 0.006392225010578308
# choosing maximum action >>>>node: SouthernMississippi, source: SouthernMississippi, destination: Cincinnati, value: 0.006392225010578308
# neighbor communities ['Vanderbilt', 'Georgia', 'MiddleTennesseeState', 'Cincinnati', 'LouisianaState', 'Arkansas']
# node: Tennessee, source: Tennessee, destination: Vanderbilt, value: 0.007688233994821286
# choosing maximum action >>>>node: Tennessee, source: Tennessee, destination: Vanderbilt, value: 0.007688233994821286
# neighbor communities ['TexasElPaso', 'ArizonaState', 'SanDiegoState', 'WashingtonState', 'NotreDame', 'Texas', 'OregonState', 'California']
# node: Stanford, source: Stanford, destination: ArizonaState, value: 0.006261825749330041
# choosing maximum action >>>>node: Stanford, source: Stanford, destination: ArizonaState, value: 0.006261825749330041
# neighbor communities ['Wyoming', 'WashingtonState', 'ArizonaState', 'SanDiegoState', 'OregonState', 'California']
# node: WashingtonState, source: WashingtonState, destination: ArizonaState, value: 0.007776053905457873
# choosing maximum action >>>>node: WashingtonState, source: WashingtonState, destination: ArizonaState, value: 0.007776053905457873
# neighbor communities ['Temple', 'CentralMichigan', 'Kent', 'MiamiFlorida', 'Maryland', 'Navy', 'Rutgers']
# node: Temple, source: Temple, destination: Temple, value: 0.007629687387730227
# choosing maximum action >>>>node: Temple, source: Temple, destination: Temple, value: 0.007629687387730227
# neighbor communities ['Temple', 'TexasChristian', 'NorthCarolina', 'NotreDame', 'AirForce', 'WakeForest', 'Tulane', 'Toledo', 'Army', 'Rutgers']
# node: Navy, source: Navy, destination: Temple, value: 0.002735723276800375
# choosing maximum action >>>>node: Navy, source: Navy, destination: Temple, value: 0.002735723276800375
# neighbor communities ['Wyoming', 'Nebraska', 'TexasElPaso', 'OklahomaState', 'NotreDame', 'Oklahoma', 'Texas']
# node: TexasA&M, source: TexasA&M, destination: Nebraska, value: 0.00751259417354811
# choosing maximum action >>>>node: TexasA&M, source: TexasA&M, destination: Nebraska, value: 0.00751259417354811
# neighbor communities ['Temple', 'Nebraska', 'ArizonaState', 'Minnesota', 'AirForce', 'MichiganState', 'Rutgers']
# node: NotreDame, source: NotreDame, destination: Temple, value: 0.0043084980400192666
# choosing maximum action >>>>node: NotreDame, source: NotreDame, destination: Temple, value: 0.0043084980400192666
# neighbor communities ['TexasElPaso', 'WashingtonState', 'Nebraska', 'TexasChristian', 'Tulsa', 'Oklahoma', 'Hawaii']
# node: TexasElPaso, source: TexasElPaso, destination: TexasElPaso, value: 0.007717507298366815
# choosing maximum action >>>>node: TexasElPaso, source: TexasElPaso, destination: TexasElPaso, value: 0.007717507298366815
# neighbor communities ['Nebraska', 'TexasElPaso', 'OklahomaState', 'BoiseState', 'Texas']
# node: Oklahoma, source: Oklahoma, destination: Nebraska, value: 0.008997549026130414
# choosing maximum action >>>>node: Oklahoma, source: Oklahoma, destination: Nebraska, value: 0.008997549026130414
# neighbor communities ['Temple', 'Akron', 'Kent', 'CentralMichigan', 'Michigan', 'Marshall']
# node: Toledo, source: Toledo, destination: CentralMichigan, value: 0.006381580172925388
# choosing maximum action >>>>node: Toledo, source: Toledo, destination: CentralMichigan, value: 0.006381580172925388
# neighbor communities ['Temple', 'TexasElPaso', 'Cincinnati', 'Mississippi', 'LouisianaLafayette', 'Army']
# node: Tulane, source: Tulane, destination: Cincinnati, value: 0.00789314711963999
# choosing maximum action >>>>node: Tulane, source: Tulane, destination: Cincinnati, value: 0.00789314711963999
# neighbor communities ['Vanderbilt', 'Georgia', 'BoiseState', 'LouisianaState', 'Cincinnati', 'Arkansas', 'NevadaLasVegas']
# node: Mississippi, source: Mississippi, destination: Vanderbilt, value: 0.00754186747709364
# choosing maximum action >>>>node: Mississippi, source: Mississippi, destination: Vanderbilt, value: 0.00754186747709364
# neighbor communities ['TexasElPaso', 'Michigan', 'WashingtonState', 'TexasChristian', 'OklahomaState', 'NorthCarolina', 'Hawaii']
# node: Tulsa, source: Tulsa, destination: TexasElPaso, value: 0.009308910527478316
# choosing maximum action >>>>node: Tulsa, source: Tulsa, destination: TexasElPaso, value: 0.009308910527478316
# neighbor communities ['Temple', 'Florida', 'TexasElPaso', 'NorthCarolina', 'Clemson', 'Marshall', 'WakeForest', 'Maryland']
# node: NorthCarolina, source: NorthCarolina, destination: NorthCarolina, value: 0.0062325524457845114
# choosing maximum action >>>>node: NorthCarolina, source: NorthCarolina, destination: NorthCarolina, value: 0.0062325524457845114
# neighbor communities ['Wyoming', 'Nebraska', 'WashingtonState', 'SanDiegoState', 'BoiseState']
# node: UtahState, source: UtahState, destination: WashingtonState, value: 0.0048221114567726445
# choosing maximum action >>>>node: UtahState, source: UtahState, destination: WashingtonState, value: 0.0048221114567726445
# neighbor communities ['Temple', 'AlabamaBirmingham', 'WashingtonState', 'Cincinnati', 'AirForce']
# node: Army, source: Army, destination: Cincinnati, value: 0.007746780601912345
# choosing maximum action >>>>node: Army, source: Army, destination: Cincinnati, value: 0.007746780601912345
# neighbor communities ['Temple', 'Kent', 'AlabamaBirmingham', 'Minnesota', 'Cincinnati', 'Indiana']
# node: Cincinnati, source: Cincinnati, destination: Cincinnati, value: 0.009231735454494648
# choosing maximum action >>>>node: Cincinnati, source: Cincinnati, destination: Cincinnati, value: 0.009231735454494648
# neighbor communities ['Wyoming', 'Cincinnati', 'NevadaLasVegas', 'Temple']
# node: AirForce, source: AirForce, destination: Wyoming, value: 0.009388746809875215
# choosing maximum action >>>>node: AirForce, source: AirForce, destination: Wyoming, value: 0.009388746809875215
# neighbor communities ['Temple', 'MiamiFlorida', 'Kent']
# node: Rutgers, source: Rutgers, destination: Temple, value: 0.012438492797436723
# choosing maximum action >>>>node: Rutgers, source: Rutgers, destination: Temple, value: 0.012438492797436723
# neighbor communities ['Vanderbilt', 'WashingtonState', 'Arkansas', 'NorthCarolina']
# node: Georgia, source: Georgia, destination: Vanderbilt, value: 0.010727335144729875
# choosing maximum action >>>>node: Georgia, source: Georgia, destination: Vanderbilt, value: 0.010727335144729875
# neighbor communities ['AlabamaBirmingham', 'Cincinnati', 'Vanderbilt', 'Arkansas']
# node: LouisianaState, source: LouisianaState, destination: Vanderbilt, value: 0.010541050485803779
# choosing maximum action >>>>node: LouisianaState, source: LouisianaState, destination: Vanderbilt, value: 0.010541050485803779
# neighbor communities ['AlabamaBirmingham', 'Nebraska', 'Michigan', 'MiddleTennesseeState', 'Cincinnati', 'Texas']
# node: LouisianaLafayette, source: LouisianaLafayette, destination: AlabamaBirmingham, value: 0.003241353065314063
# choosing maximum action >>>>node: LouisianaLafayette, source: LouisianaLafayette, destination: AlabamaBirmingham, value: 0.003241353065314063
# neighbor communities ['AlabamaBirmingham', 'Nebraska', 'ArizonaState', 'Missouri', 'OklahomaState', 'Cincinnati']
# node: Texas, source: Texas, destination: Nebraska, value: 0.008821909204857238
# choosing maximum action >>>>node: Texas, source: Texas, destination: Nebraska, value: 0.008821909204857238
# neighbor communities ['CentralMichigan', 'Kent', 'MichiganState', 'NorthCarolina']
# node: Marshall, source: Marshall, destination: Kent, value: 0.009335522621610616
# choosing maximum action >>>>node: Marshall, source: Marshall, destination: Kent, value: 0.009335522621610616
# neighbor communities ['Temple', 'Kent', 'Nebraska', 'Michigan', 'TexasChristian', 'Minnesota', 'Missouri', 'Purdue']
# node: MichiganState, source: MichiganState, destination: Minnesota, value: 0.00629109905287557
# choosing maximum action >>>>node: MichiganState, source: MichiganState, destination: Minnesota, value: 0.00629109905287557
# neighbor communities ['Temple', 'Michigan', 'Florida', 'ArizonaState']
# node: MiamiFlorida, source: MiamiFlorida, destination: Temple, value: 0.010594274674068378
# choosing maximum action >>>>node: MiamiFlorida, source: MiamiFlorida, destination: Temple, value: 0.010594274674068378
# neighbor communities ['Nebraska', 'Clemson', 'Minnesota', 'OklahomaState']
# node: Missouri, source: Missouri, destination: Nebraska, value: 0.010381377921009982
# choosing maximum action >>>>node: Missouri, source: Missouri, destination: Nebraska, value: 0.010381377921009982
# neighbor communities ['Vanderbilt', 'Florida', 'Nebraska', 'NorthCarolina', 'WakeForest', 'Maryland']
# node: Clemson, source: Clemson, destination: NorthCarolina, value: 0.007890485910226761
# choosing maximum action >>>>node: Clemson, source: Clemson, destination: NorthCarolina, value: 0.007890485910226761
# neighbor communities ['Wyoming', 'Vanderbilt', 'Nebraska', 'TexasElPaso', 'Hawaii']
# node: NevadaLasVegas, source: NevadaLasVegas, destination: Wyoming, value: 0.010748624820035715
# choosing maximum action >>>>node: NevadaLasVegas, source: NevadaLasVegas, destination: Wyoming, value: 0.010748624820035715
# neighbor communities ['Temple', 'Vanderbilt', 'Florida', 'NorthCarolina', 'Maryland']
# node: WakeForest, source: WakeForest, destination: NorthCarolina, value: 0.009388746809875215
# choosing maximum action >>>>node: WakeForest, source: WakeForest, destination: NorthCarolina, value: 0.009388746809875215
# neighbor communities ['Vanderbilt', 'Nebraska', 'Michigan', 'TexasChristian', 'Minnesota', 'Cincinnati', 'NorthCarolina', 'Purdue']
# node: Indiana, source: Indiana, destination: Minnesota, value: 0.006174005838693453
# choosing maximum action >>>>node: Indiana, source: Indiana, destination: Minnesota, value: 0.006174005838693453
# neighbor communities ['Cincinnati', 'Nebraska', 'TexasElPaso']
# node: OklahomaState, source: OklahomaState, destination: Nebraska, value: 0.011826414632393839
# choosing maximum action >>>>node: OklahomaState, source: OklahomaState, destination: Nebraska, value: 0.011826414632393839
# neighbor communities ['Wyoming', 'California', 'ArizonaState']
# node: OregonState, source: OregonState, destination: ArizonaState, value: 0.010940231897788269
# choosing maximum action >>>>node: OregonState, source: OregonState, destination: ArizonaState, value: 0.010940231897788269
# neighbor communities ['Temple', 'NorthCarolina', 'Florida', 'AlabamaBirmingham']
# node: Maryland, source: Maryland, destination: NorthCarolina, value: 0.010804510217713543
# choosing maximum action >>>>node: Maryland, source: Maryland, destination: NorthCarolina, value: 0.010804510217713543
# neighbor communities ['Temple', 'TexasChristian', 'TexasElPaso', 'BoiseState', 'Hawaii']
# node: TexasChristian, source: TexasChristian, destination: TexasElPaso, value: 0.010804510217713543
# choosing maximum action >>>>node: TexasChristian, source: TexasChristian, destination: TexasElPaso, value: 0.010804510217713543
# neighbor communities ['Wyoming', 'TexasElPaso', 'ArizonaState', 'SanDiegoState', 'Minnesota']
# node: California, source: California, destination: ArizonaState, value: 0.010687417003531426
# choosing maximum action >>>>node: California, source: California, destination: ArizonaState, value: 0.010687417003531426
# neighbor communities ['Temple', 'AlabamaBirmingham', 'Nebraska', 'Vanderbilt', 'Cincinnati']
# node: AlabamaBirmingham, source: AlabamaBirmingham, destination: Cincinnati, value: 0.007650977063036067
# choosing maximum action >>>>node: AlabamaBirmingham, source: AlabamaBirmingham, destination: Cincinnati, value: 0.007650977063036067
# neighbor communities ['MiddleTennesseeState', 'Vanderbilt', 'WashingtonState']
# node: Arkansas, source: Arkansas, destination: Vanderbilt, value: 0.011986087197187634
# choosing maximum action >>>>node: Arkansas, source: Arkansas, destination: Vanderbilt, value: 0.011986087197187634
# neighbor communities ['Wyoming', 'TexasElPaso', 'Michigan', 'Minnesota']
# node: Hawaii, source: Hawaii, destination: TexasElPaso, value: 0.012230918463204789
# choosing maximum action >>>>node: Hawaii, source: Hawaii, destination: TexasElPaso, value: 0.012230918463204789
#
# {'Wyoming': {'community': 'Wyoming', 'people_nodes': ['BrighamYoung', 'NewMexico', 'SanDiegoState', 'Wyoming', 'Utah', 'ColoradoState', 'AirForce', 'NevadaLasVegas']}, 'Florida': {'community': 'Florida', 'people_nodes': ['FloridaState']}, 'Nebraska': {'community': 'Nebraska', 'people_nodes': ['Iowa', 'KansasState', 'TexasTech', 'Baylor', 'NorthTexas', 'Colorado', 'Kansas', 'IowaState', 'Nebraska', 'TexasA&M', 'Oklahoma', 'Texas', 'Missouri', 'OklahomaState']}, 'Michigan': {'community': 'Michigan', 'people_nodes': ['PennState', 'LouisianaTech']}, 'ArizonaState': {'community': 'ArizonaState', 'people_nodes': ['SouthernCalifornia', 'UCLA', 'Arizona', 'Washington', 'Oregon', 'Stanford', 'WashingtonState', 'OregonState', 'California']}, 'SanDiegoState': {'community': 'SanDiegoState', 'people_nodes': ['ArizonaState']}, 'Akron': {'community': 'Akron', 'people_nodes': ['NorthernIllinois', 'CentralFlorida']}, 'TexasChristian': {'community': 'TexasChristian', 'people_nodes': ['Northwestern']}, 'CentralMichigan': {'community': 'CentralMichigan', 'people_nodes': ['WesternMichigan', 'BallState', 'CentralMichigan', 'EasternMichigan', 'Toledo']}, 'Minnesota': {'community': 'Minnesota', 'people_nodes': ['Wisconsin', 'Purdue', 'OhioState', 'Minnesota', 'Illinois', 'MichiganState', 'Indiana']}, 'Vanderbilt': {'community': 'Vanderbilt', 'people_nodes': ['Auburn', 'Alabama', 'Florida', 'Kentucky', 'Vanderbilt', 'MississippiState', 'SouthCarolina', 'Tennessee', 'Mississippi', 'Georgia', 'LouisianaState', 'Arkansas']}, 'Kent': {'community': 'Kent', 'people_nodes': ['Akron', 'BowlingGreenState', 'Buffalo', 'Connecticut', 'Kent', 'MiamiOhio', 'Ohio', 'Marshall']}, 'Temple': {'community': 'Temple', 'people_nodes': ['VirginiaTech', 'BostonCollege', 'WestVirginia', 'Syracuse', 'EastCarolina', 'Pittsburgh', 'Temple', 'Navy', 'NotreDame', 'Rutgers', 'MiamiFlorida']}, 'BoiseState': {'community': 'BoiseState', 'people_nodes': ['ArkansasState']}, 'NorthCarolina': {'community': 'NorthCarolina', 'people_nodes': ['NorthCarolinaState', 'Virginia', 'GeorgiaTech', 'Duke', 'NorthCarolina', 'Clemson', 'WakeForest', 'Maryland']}, 'WashingtonState': {'community': 'WashingtonState', 'people_nodes': ['BoiseState', 'Idaho', 'NewMexicoState', 'UtahState']}, 'Purdue': {'community': 'Purdue', 'people_nodes': ['Michigan']}, 'TexasElPaso': {'community': 'TexasElPaso', 'people_nodes': ['FresnoState', 'Rice', 'SouthernMethodist', 'Nevada', 'SanJoseState', 'TexasElPaso', 'Tulsa', 'TexasChristian', 'Hawaii']}, 'Cincinnati': {'community': 'Cincinnati', 'people_nodes': ['Houston', 'Louisville', 'Memphis', 'SouthernMississippi', 'Tulane', 'Army', 'Cincinnati', 'AlabamaBirmingham']}, 'MiddleTennesseeState': {'community': 'MiddleTennesseeState', 'people_nodes': ['LouisianaMonroe']}, 'AlabamaBirmingham': {'community': 'AlabamaBirmingham', 'people_nodes': ['MiddleTennesseeState', 'LouisianaLafayette']}}
# adding edges from necessary
# neighbor communities ['Wyoming', 'Temple', 'Vanderbilt', 'Florida', 'WashingtonState', 'Nebraska', 'ArizonaState', 'SanDiegoState', 'Minnesota', 'CentralMichigan', 'NorthCarolina', 'TexasElPaso', 'Cincinnati']
# node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# choosing maximum action >>>>node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# neighbor communities ['Wyoming', 'Temple', 'Vanderbilt', 'Cincinnati', 'NorthCarolina']
# node: Florida, source: Florida, destination: NorthCarolina, value: 0.01215640459963435
# choosing maximum action >>>>node: Florida, source: Florida, destination: NorthCarolina, value: 0.01215640459963435
# neighbor communities ['Wyoming', 'CentralMichigan', 'AlabamaBirmingham', 'Nebraska', 'Michigan', 'TexasChristian', 'Minnesota', 'WashingtonState', 'ArizonaState', 'BoiseState', 'Cincinnati', 'TexasElPaso', 'Kent', 'NorthCarolina', 'Temple']
# node: Nebraska, source: Nebraska, destination: Nebraska, value: 0.07400823378192453
# choosing maximum action >>>>node: Nebraska, source: Nebraska, destination: Nebraska, value: 0.07400823378192453
# neighbor communities ['Temple', 'CentralMichigan', 'Vanderbilt', 'Nebraska', 'ArizonaState', 'Michigan', 'Minnesota', 'Akron', 'MiddleTennesseeState', 'AlabamaBirmingham', 'TexasElPaso', 'Purdue']
# node: Michigan, source: Michigan, destination: Minnesota, value: 0.008893761859014446
# choosing maximum action >>>>node: Michigan, source: Michigan, destination: Minnesota, value: 0.008893761859014446
# neighbor communities ['Wyoming', 'Temple', 'Vanderbilt', 'Nebraska', 'ArizonaState', 'SanDiegoState', 'Minnesota', 'TexasElPaso', 'WashingtonState', 'Purdue']
# node: ArizonaState, source: ArizonaState, destination: ArizonaState, value: 0.04649665086795345
# choosing maximum action >>>>node: ArizonaState, source: ArizonaState, destination: ArizonaState, value: 0.04649665086795345
# neighbor communities ['Wyoming', 'WashingtonState', 'ArizonaState']
# node: SanDiegoState, source: SanDiegoState, destination: ArizonaState, value: 0.012113825249022672
# choosing maximum action >>>>node: SanDiegoState, source: SanDiegoState, destination: ArizonaState, value: 0.012113825249022672
# neighbor communities ['Temple', 'CentralMichigan', 'Kent', 'Vanderbilt', 'TexasChristian', 'Akron', 'Minnesota', 'MiddleTennesseeState', 'NorthCarolina']
# node: Akron, source: Akron, destination: CentralMichigan, value: 0.009335522621610616
# choosing maximum action >>>>node: Akron, source: Akron, destination: CentralMichigan, value: 0.009335522621610616
# neighbor communities ['CentralMichigan', 'Nebraska', 'TexasElPaso', 'Minnesota', 'NorthCarolina', 'Purdue']
# node: TexasChristian, source: TexasChristian, destination: Minnesota, value: 0.009114642240312531
# choosing maximum action >>>>node: TexasChristian, source: TexasChristian, destination: Minnesota, value: 0.009114642240312531
# neighbor communities ['Wyoming', 'CentralMichigan', 'Kent', 'Nebraska', 'Vanderbilt', 'WashingtonState', 'Minnesota', 'Temple']
# node: CentralMichigan, source: CentralMichigan, destination: CentralMichigan, value: 0.024246278963937953
# choosing maximum action >>>>node: CentralMichigan, source: CentralMichigan, destination: CentralMichigan, value: 0.024246278963937953
# neighbor communities ['Wyoming', 'CentralMichigan', 'Kent', 'Nebraska', 'ArizonaState', 'TexasElPaso', 'Minnesota', 'Temple', 'Vanderbilt', 'Cincinnati', 'NorthCarolina', 'MiddleTennesseeState', 'AlabamaBirmingham', 'Purdue']
# node: Minnesota, source: Minnesota, destination: Minnesota, value: 0.040892143843691206
# choosing maximum action >>>>node: Minnesota, source: Minnesota, destination: Minnesota, value: 0.040892143843691206
# neighbor communities ['Wyoming', 'CentralMichigan', 'Vanderbilt', 'AlabamaBirmingham', 'ArizonaState', 'WashingtonState', 'Minnesota', 'Kent', 'MiddleTennesseeState', 'Cincinnati', 'NorthCarolina', 'BoiseState']
# node: Vanderbilt, source: Vanderbilt, destination: Vanderbilt, value: 0.06808438162807469
# choosing maximum action >>>>node: Vanderbilt, source: Vanderbilt, destination: Vanderbilt, value: 0.06808438162807469
# neighbor communities ['Temple', 'CentralMichigan', 'Vanderbilt', 'Nebraska', 'Kent', 'AlabamaBirmingham', 'Minnesota', 'Cincinnati', 'NorthCarolina', 'Purdue']
# node: Kent, source: Kent, destination: Kent, value: 0.03397033815988014
# choosing maximum action >>>>node: Kent, source: Kent, destination: Kent, value: 0.03397033815988014
# neighbor communities ['Wyoming', 'CentralMichigan', 'Kent', 'Nebraska', 'ArizonaState', 'Temple', 'Minnesota', 'WashingtonState', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: Temple, source: Temple, destination: Temple, value: 0.0537990094978564
# choosing maximum action >>>>node: Temple, source: Temple, destination: Temple, value: 0.0537990094978564
# neighbor communities ['Vanderbilt', 'Nebraska', 'WashingtonState', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: BoiseState, source: BoiseState, destination: WashingtonState, value: 0.006365612916446008
# choosing maximum action >>>>node: BoiseState, source: BoiseState, destination: WashingtonState, value: 0.006365612916446008
# neighbor communities ['Wyoming', 'CentralMichigan', 'Vanderbilt', 'Nebraska', 'Kent', 'Temple', 'Minnesota', 'WashingtonState', 'TexasElPaso', 'AlabamaBirmingham', 'NorthCarolina']
# node: NorthCarolina, source: NorthCarolina, destination: NorthCarolina, value: 0.05326676761521041
# choosing maximum action >>>>node: NorthCarolina, source: NorthCarolina, destination: NorthCarolina, value: 0.05326676761521041
# neighbor communities ['Wyoming', 'CentralMichigan', 'Vanderbilt', 'Nebraska', 'ArizonaState', 'Temple', 'WashingtonState', 'TexasElPaso', 'Cincinnati']
# node: WashingtonState, source: WashingtonState, destination: WashingtonState, value: 0.01546162669086593
# choosing maximum action >>>>node: WashingtonState, source: WashingtonState, destination: WashingtonState, value: 0.01546162669086593
# neighbor communities ['Kent', 'TexasElPaso', 'ArizonaState', 'Minnesota']
# node: Purdue, source: Purdue, destination: Minnesota, value: 0.012201645159659259
# ...
# adding edges from necessary
# neighbor communities ['Wyoming', 'Temple', 'Vanderbilt', 'Nebraska', 'WashingtonState', 'ArizonaState', 'Minnesota', 'CentralMichigan', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# choosing maximum action >>>>node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# neighbor communities ['Wyoming', 'Temple', 'Vanderbilt', 'Nebraska', 'CentralMichigan', 'Kent', 'Minnesota', 'WashingtonState', 'TexasElPaso', 'Cincinnati', 'NorthCarolina', 'AlabamaBirmingham']
# node: NorthCarolina, source: NorthCarolina, destination: NorthCarolina, value: 0.0528835534597053
# choosing maximum action >>>>node: NorthCarolina, source: NorthCarolina, destination: NorthCarolina, value: 0.0528835534597053
# neighbor communities ['Wyoming', 'CentralMichigan', 'AlabamaBirmingham', 'Nebraska', 'WashingtonState', 'ArizonaState', 'Minnesota', 'TexasElPaso', 'Kent', 'Cincinnati', 'NorthCarolina', 'Temple']
# node: Nebraska, source: Nebraska, destination: Nebraska, value: 0.07400823378192453
# choosing maximum action >>>>node: Nebraska, source: Nebraska, destination: Nebraska, value: 0.07400823378192453
# neighbor communities ['Wyoming', 'Temple', 'CentralMichigan', 'Nebraska', 'ArizonaState', 'Vanderbilt', 'Minnesota', 'AlabamaBirmingham', 'TexasElPaso', 'Cincinnati', 'NorthCarolina', 'Kent']
# node: Minnesota, source: Minnesota, destination: Minnesota, value: 0.05198938709686004
# choosing maximum action >>>>node: Minnesota, source: Minnesota, destination: Minnesota, value: 0.05198938709686004
# neighbor communities ['Wyoming', 'Temple', 'Vanderbilt', 'Nebraska', 'ArizonaState', 'TexasElPaso', 'Minnesota', 'WashingtonState']
# node: ArizonaState, source: ArizonaState, destination: ArizonaState, value: 0.057801468455354214
# choosing maximum action >>>>node: ArizonaState, source: ArizonaState, destination: ArizonaState, value: 0.057801468455354214
# neighbor communities ['Wyoming', 'CentralMichigan', 'Vanderbilt', 'Nebraska', 'Kent', 'Temple', 'Minnesota', 'AlabamaBirmingham', 'WashingtonState', 'NorthCarolina']
# node: CentralMichigan, source: CentralMichigan, destination: CentralMichigan, value: 0.025379954173973904
# choosing maximum action >>>>node: CentralMichigan, source: CentralMichigan, destination: CentralMichigan, value: 0.025379954173973904
# neighbor communities ['Wyoming', 'CentralMichigan', 'Vanderbilt', 'AlabamaBirmingham', 'ArizonaState', 'WashingtonState', 'Minnesota', 'Kent', 'Cincinnati', 'NorthCarolina']
# node: Vanderbilt, source: Vanderbilt, destination: Vanderbilt, value: 0.06808438162807469
# choosing maximum action >>>>node: Vanderbilt, source: Vanderbilt, destination: Vanderbilt, value: 0.06808438162807469
# neighbor communities ['Temple', 'CentralMichigan', 'Vanderbilt', 'Nebraska', 'Kent', 'AlabamaBirmingham', 'Minnesota', 'Cincinnati', 'NorthCarolina']
# node: Kent, source: Kent, destination: Kent, value: 0.03397033815988014
# choosing maximum action >>>>node: Kent, source: Kent, destination: Kent, value: 0.03397033815988014
# neighbor communities ['Wyoming', 'CentralMichigan', 'Kent', 'Nebraska', 'ArizonaState', 'Temple', 'Minnesota', 'WashingtonState', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: Temple, source: Temple, destination: Temple, value: 0.0537990094978564
# choosing maximum action >>>>node: Temple, source: Temple, destination: Temple, value: 0.0537990094978564
# neighbor communities ['Wyoming', 'CentralMichigan', 'Vanderbilt', 'Nebraska', 'ArizonaState', 'Temple', 'WashingtonState', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: WashingtonState, source: WashingtonState, destination: WashingtonState, value: 0.015301954126072133
# choosing maximum action >>>>node: WashingtonState, source: WashingtonState, destination: WashingtonState, value: 0.015301954126072133
# neighbor communities ['Wyoming', 'Temple', 'Nebraska', 'ArizonaState', 'WashingtonState', 'Minnesota', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: TexasElPaso, source: TexasElPaso, destination: TexasElPaso, value: 0.05240453576532391
# choosing maximum action >>>>node: TexasElPaso, source: TexasElPaso, destination: TexasElPaso, value: 0.05240453576532391
# neighbor communities ['Wyoming', 'Temple', 'Vanderbilt', 'Nebraska', 'Kent', 'WashingtonState', 'Minnesota', 'TexasElPaso', 'AlabamaBirmingham', 'Cincinnati', 'NorthCarolina']
# node: Cincinnati, source: Cincinnati, destination: Cincinnati, value: 0.035255702306470196
# choosing maximum action >>>>node: Cincinnati, source: Cincinnati, destination: Cincinnati, value: 0.035255702306470196
# neighbor communities ['CentralMichigan', 'Vanderbilt', 'Nebraska', 'Kent', 'AlabamaBirmingham', 'Minnesota', 'Cincinnati', 'NorthCarolina']
# node: AlabamaBirmingham, source: AlabamaBirmingham, destination: Minnesota, value: 0.005990382389180586
# choosing maximum action >>>>node: AlabamaBirmingham, source: AlabamaBirmingham, destination: Minnesota, value: 0.005990382389180586
#
# {'Wyoming': {'community': 'Wyoming', 'people_nodes': ['BrighamYoung', 'NewMexico', 'SanDiegoState', 'Wyoming', 'Utah', 'ColoradoState', 'AirForce', 'NevadaLasVegas']}, 'NorthCarolina': {'community': 'NorthCarolina', 'people_nodes': ['FloridaState', 'NorthCarolinaState', 'Virginia', 'GeorgiaTech', 'Duke', 'NorthCarolina', 'Clemson', 'WakeForest', 'Maryland']}, 'Nebraska': {'community': 'Nebraska', 'people_nodes': ['Iowa', 'KansasState', 'TexasTech', 'Baylor', 'NorthTexas', 'Colorado', 'Kansas', 'IowaState', 'Nebraska', 'TexasA&M', 'Oklahoma', 'Texas', 'Missouri', 'OklahomaState']}, 'Minnesota': {'community': 'Minnesota', 'people_nodes': ['PennState', 'LouisianaTech', 'Northwestern', 'Wisconsin', 'Purdue', 'OhioState', 'Minnesota', 'Illinois', 'MichiganState', 'Indiana', 'Michigan', 'LouisianaMonroe', 'MiddleTennesseeState', 'LouisianaLafayette']}, 'ArizonaState': {'community': 'ArizonaState', 'people_nodes': ['SouthernCalifornia', 'UCLA', 'Arizona', 'Washington', 'Oregon', 'Stanford', 'WashingtonState', 'OregonState', 'California', 'ArizonaState']}, 'CentralMichigan': {'community': 'CentralMichigan', 'people_nodes': ['NorthernIllinois', 'CentralFlorida', 'WesternMichigan', 'BallState', 'CentralMichigan', 'EasternMichigan', 'Toledo']}, 'Vanderbilt': {'community': 'Vanderbilt', 'people_nodes': ['Auburn', 'Alabama', 'Florida', 'Kentucky', 'Vanderbilt', 'MississippiState', 'SouthCarolina', 'Tennessee', 'Mississippi', 'Georgia', 'LouisianaState', 'Arkansas']}, 'Kent': {'community': 'Kent', 'people_nodes': ['Akron', 'BowlingGreenState', 'Buffalo', 'Connecticut', 'Kent', 'MiamiOhio', 'Ohio', 'Marshall']}, 'Temple': {'community': 'Temple', 'people_nodes': ['VirginiaTech', 'BostonCollege', 'WestVirginia', 'Syracuse', 'EastCarolina', 'Pittsburgh', 'Temple', 'Navy', 'NotreDame', 'Rutgers', 'MiamiFlorida']}, 'WashingtonState': {'community': 'WashingtonState', 'people_nodes': ['ArkansasState', 'BoiseState', 'Idaho', 'NewMexicoState', 'UtahState']}, 'TexasElPaso': {'community': 'TexasElPaso', 'people_nodes': ['FresnoState', 'Rice', 'SouthernMethodist', 'Nevada', 'SanJoseState', 'TexasElPaso', 'Tulsa', 'TexasChristian', 'Hawaii']}, 'Cincinnati': {'community': 'Cincinnati', 'people_nodes': ['Houston', 'Louisville', 'Memphis', 'SouthernMississippi', 'Tulane', 'Army', 'Cincinnati', 'AlabamaBirmingham']}}
# adding edges from necessary
# neighbor communities ['Wyoming', 'Temple', 'Vanderbilt', 'Nebraska', 'WashingtonState', 'ArizonaState', 'Minnesota', 'CentralMichigan', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# choosing maximum action >>>>node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# neighbor communities ['Wyoming', 'Temple', 'Vanderbilt', 'Nebraska', 'CentralMichigan', 'Kent', 'Minnesota', 'WashingtonState', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: NorthCarolina, source: NorthCarolina, destination: NorthCarolina, value: 0.0528835534597053
# choosing maximum action >>>>node: NorthCarolina, source: NorthCarolina, destination: NorthCarolina, value: 0.0528835534597053
# neighbor communities ['Wyoming', 'CentralMichigan', 'Kent', 'Nebraska', 'WashingtonState', 'ArizonaState', 'Minnesota', 'TexasElPaso', 'Temple', 'Cincinnati', 'NorthCarolina']
# node: Nebraska, source: Nebraska, destination: Nebraska, value: 0.07400823378192453
# choosing maximum action >>>>node: Nebraska, source: Nebraska, destination: Nebraska, value: 0.07400823378192453
# neighbor communities ['Wyoming', 'Temple', 'CentralMichigan', 'Nebraska', 'ArizonaState', 'Vanderbilt', 'Minnesota', 'TexasElPaso', 'Kent', 'Cincinnati', 'NorthCarolina']
# node: Minnesota, source: Minnesota, destination: Minnesota, value: 0.061194510457222386
# choosing maximum action >>>>node: Minnesota, source: Minnesota, destination: Minnesota, value: 0.061194510457222386
# neighbor communities ['Wyoming', 'Temple', 'Vanderbilt', 'Nebraska', 'ArizonaState', 'TexasElPaso', 'Minnesota', 'WashingtonState']
# node: ArizonaState, source: ArizonaState, destination: ArizonaState, value: 0.057801468455354214
# choosing maximum action >>>>node: ArizonaState, source: ArizonaState, destination: ArizonaState, value: 0.057801468455354214
# neighbor communities ['Wyoming', 'CentralMichigan', 'Vanderbilt', 'Nebraska', 'Kent', 'Temple', 'Minnesota', 'WashingtonState', 'NorthCarolina']
# node: CentralMichigan, source: CentralMichigan, destination: CentralMichigan, value: 0.025379954173973904
# choosing maximum action >>>>node: CentralMichigan, source: CentralMichigan, destination: CentralMichigan, value: 0.025379954173973904
# neighbor communities ['Wyoming', 'CentralMichigan', 'Vanderbilt', 'Kent', 'ArizonaState', 'WashingtonState', 'Minnesota', 'Cincinnati', 'NorthCarolina']
# node: Vanderbilt, source: Vanderbilt, destination: Vanderbilt, value: 0.06808438162807469
# choosing maximum action >>>>node: Vanderbilt, source: Vanderbilt, destination: Vanderbilt, value: 0.06808438162807469
# neighbor communities ['Temple', 'CentralMichigan', 'Vanderbilt', 'Nebraska', 'Kent', 'Minnesota', 'Cincinnati', 'NorthCarolina']
# node: Kent, source: Kent, destination: Kent, value: 0.03397033815988014
# choosing maximum action >>>>node: Kent, source: Kent, destination: Kent, value: 0.03397033815988014
# neighbor communities ['Wyoming', 'CentralMichigan', 'Kent', 'Nebraska', 'ArizonaState', 'Temple', 'Minnesota', 'WashingtonState', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: Temple, source: Temple, destination: Temple, value: 0.0537990094978564
# choosing maximum action >>>>node: Temple, source: Temple, destination: Temple, value: 0.0537990094978564
# neighbor communities ['Wyoming', 'CentralMichigan', 'Vanderbilt', 'Nebraska', 'ArizonaState', 'Temple', 'WashingtonState', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: WashingtonState, source: WashingtonState, destination: WashingtonState, value: 0.015301954126072133
# choosing maximum action >>>>node: WashingtonState, source: WashingtonState, destination: WashingtonState, value: 0.015301954126072133
# neighbor communities ['Wyoming', 'Temple', 'Nebraska', 'ArizonaState', 'WashingtonState', 'Minnesota', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: TexasElPaso, source: TexasElPaso, destination: TexasElPaso, value: 0.05240453576532391
# choosing maximum action >>>>node: TexasElPaso, source: TexasElPaso, destination: TexasElPaso, value: 0.05240453576532391
# neighbor communities ['Wyoming', 'Temple', 'Vanderbilt', 'Nebraska', 'Kent', 'WashingtonState', 'Minnesota', 'TexasElPaso', 'Cincinnati', 'NorthCarolina']
# node: Cincinnati, source: Cincinnati, destination: Cincinnati, value: 0.035255702306470196
# choosing maximum action >>>>node: Cincinnati, source: Cincinnati, destination: Cincinnati, value: 0.035255702306470196
#
# {'Wyoming': {'community': 'Wyoming', 'people_nodes': ['BrighamYoung', 'NewMexico', 'SanDiegoState', 'Wyoming', 'Utah', 'ColoradoState', 'AirForce', 'NevadaLasVegas']}, 'NorthCarolina': {'community': 'NorthCarolina', 'people_nodes': ['FloridaState', 'NorthCarolinaState', 'Virginia', 'GeorgiaTech', 'Duke', 'NorthCarolina', 'Clemson', 'WakeForest', 'Maryland']}, 'Nebraska': {'community': 'Nebraska', 'people_nodes': ['Iowa', 'KansasState', 'TexasTech', 'Baylor', 'NorthTexas', 'Colorado', 'Kansas', 'IowaState', 'Nebraska', 'TexasA&M', 'Oklahoma', 'Texas', 'Missouri', 'OklahomaState']}, 'Minnesota': {'community': 'Minnesota', 'people_nodes': ['PennState', 'LouisianaTech', 'Northwestern', 'Wisconsin', 'Purdue', 'OhioState', 'Minnesota', 'Illinois', 'MichiganState', 'Indiana', 'Michigan', 'LouisianaMonroe', 'MiddleTennesseeState', 'LouisianaLafayette']}, 'ArizonaState': {'community': 'ArizonaState', 'people_nodes': ['SouthernCalifornia', 'UCLA', 'Arizona', 'Washington', 'Oregon', 'Stanford', 'WashingtonState', 'OregonState', 'California', 'ArizonaState']}, 'CentralMichigan': {'community': 'CentralMichigan', 'people_nodes': ['NorthernIllinois', 'CentralFlorida', 'WesternMichigan', 'BallState', 'CentralMichigan', 'EasternMichigan', 'Toledo']}, 'Vanderbilt': {'community': 'Vanderbilt', 'people_nodes': ['Auburn', 'Alabama', 'Florida', 'Kentucky', 'Vanderbilt', 'MississippiState', 'SouthCarolina', 'Tennessee', 'Mississippi', 'Georgia', 'LouisianaState', 'Arkansas']}, 'Kent': {'community': 'Kent', 'people_nodes': ['Akron', 'BowlingGreenState', 'Buffalo', 'Connecticut', 'Kent', 'MiamiOhio', 'Ohio', 'Marshall']}, 'Temple': {'community': 'Temple', 'people_nodes': ['VirginiaTech', 'BostonCollege', 'WestVirginia', 'Syracuse', 'EastCarolina', 'Pittsburgh', 'Temple', 'Navy', 'NotreDame', 'Rutgers', 'MiamiFlorida']}, 'WashingtonState': {'community': 'WashingtonState', 'people_nodes': ['ArkansasState', 'BoiseState', 'Idaho', 'NewMexicoState', 'UtahState']}, 'TexasElPaso': {'community': 'TexasElPaso', 'people_nodes': ['FresnoState', 'Rice', 'SouthernMethodist', 'Nevada', 'SanJoseState', 'TexasElPaso', 'Tulsa', 'TexasChristian', 'Hawaii']}, 'Cincinnati': {'community': 'Cincinnati', 'people_nodes': ['Houston', 'Louisville', 'Memphis', 'SouthernMississippi', 'Tulane', 'Army', 'Cincinnati', 'AlabamaBirmingham']}}
# adding edges from necessary

# %%
louvain.display_graph_history_tables(display_fn=lambda x: display(x))
# Out:
# --------------------------Graph in the phase: 1--------------------------
#                  nodes          community         people_nodes
# 0         BrighamYoung       BrighamYoung       [BrighamYoung]
# 1         FloridaState       FloridaState       [FloridaState]
# 2                 Iowa               Iowa               [Iowa]
# 3          KansasState        KansasState        [KansasState]
# 4            NewMexico          NewMexico          [NewMexico]
# ..                 ...                ...                  ...
# 110     TexasChristian     TexasChristian     [TexasChristian]
# 111         California         California         [California]
# 112  AlabamaBirmingham  AlabamaBirmingham  [AlabamaBirmingham]
# 113           Arkansas           Arkansas           [Arkansas]
# 114             Hawaii             Hawaii             [Hawaii]
#
# [115 rows x 3 columns]
#      edges          node_a         node_b  weight
# 0        1    BrighamYoung   FloridaState       1
# 1        2    BrighamYoung      NewMexico       1
# 2        3    BrighamYoung  SanDiegoState       1
# 3        4    BrighamYoung        Wyoming       1
# 4        5    BrighamYoung           Utah       1
# ..     ...             ...            ...     ...
# 608    609         Clemson       Maryland       1
# 609    610  NevadaLasVegas         Hawaii       1
# 610    611      WakeForest       Maryland       1
# 611    612     OregonState     California       1
# 612    613  TexasChristian         Hawaii       1
#
# [613 rows x 4 columns]
# _______________________________________________________________________________________________________
# ---------------Possible actions for node BrighamYoung in phase 1---------------
#             node        source       destination     value
# 0   BrighamYoung  BrighamYoung           Wyoming  0.001631
# 1   BrighamYoung  BrighamYoung     SanDiegoState  0.001631
# 2   BrighamYoung  BrighamYoung          AirForce  0.001631
# 3   BrighamYoung  BrighamYoung         NewMexico  0.001631
# 4   BrighamYoung  BrighamYoung              Utah  0.001631
# 5   BrighamYoung  BrighamYoung         UtahState  0.001631
# 6   BrighamYoung  BrighamYoung  MississippiState  0.001631
# 7   BrighamYoung  BrighamYoung    NevadaLasVegas  0.001631
# 8   BrighamYoung  BrighamYoung          Virginia  0.001631
# 9   BrighamYoung  BrighamYoung          Syracuse  0.001631
# 10  BrighamYoung  BrighamYoung      FloridaState  0.001631
# 11  BrighamYoung  BrighamYoung     ColoradoState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: BrighamYoung, source: BrighamYoung, destination: Wyoming, value: 0.0016313213703099511
# ---------------Possible actions for node FloridaState in phase 1---------------
#             node        source         destination     value
# 0   FloridaState  FloridaState             Wyoming  0.001599
# 1   FloridaState  FloridaState             Florida  0.001631
# 2   FloridaState  FloridaState        MiamiFlorida  0.001631
# 3   FloridaState  FloridaState       NorthCarolina  0.001631
# 4   FloridaState  FloridaState          Louisville  0.001631
# 5   FloridaState  FloridaState         GeorgiaTech  0.001631
# 6   FloridaState  FloridaState  NorthCarolinaState  0.001631
# 7   FloridaState  FloridaState             Clemson  0.001631
# 8   FloridaState  FloridaState            Virginia  0.001631
# 9   FloridaState  FloridaState          WakeForest  0.001631
# 10  FloridaState  FloridaState            Maryland  0.001631
# 11  FloridaState  FloridaState                Duke  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: FloridaState, source: FloridaState, destination: Florida, value: 0.0016313213703099511
# ---------------Possible actions for node Iowa in phase 1---------------
#     node source      destination     value
# 0   Iowa   Iowa         Nebraska  0.001631
# 1   Iowa   Iowa        Minnesota  0.001631
# 2   Iowa   Iowa     Northwestern  0.001631
# 3   Iowa   Iowa      KansasState  0.001631
# 4   Iowa   Iowa        IowaState  0.001631
# 5   Iowa   Iowa        Wisconsin  0.001631
# 6   Iowa   Iowa  WesternMichigan  0.001631
# 7   Iowa   Iowa    MichiganState  0.001631
# 8   Iowa   Iowa        OhioState  0.001631
# 9   Iowa   Iowa          Indiana  0.001631
# 10  Iowa   Iowa         Illinois  0.001631
# 11  Iowa   Iowa        PennState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Iowa, source: Iowa, destination: Nebraska, value: 0.0016313213703099511
# ---------------Possible actions for node KansasState in phase 1---------------
#            node       source    destination     value
# 0   KansasState  KansasState     NorthTexas  0.001631
# 1   KansasState  KansasState       Nebraska  0.003231
# 2   KansasState  KansasState       Colorado  0.001631
# 3   KansasState  KansasState         Kansas  0.001631
# 4   KansasState  KansasState       TexasA&M  0.001631
# 5   KansasState  KansasState       Missouri  0.001631
# 6   KansasState  KansasState      TexasTech  0.001631
# 7   KansasState  KansasState       Oklahoma  0.001631
# 8   KansasState  KansasState      IowaState  0.001631
# 9   KansasState  KansasState  LouisianaTech  0.001631
# 10  KansasState  KansasState      BallState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: KansasState, source: KansasState, destination: Nebraska, value: 0.003230708227661143
# ---------------Possible actions for node NewMexico in phase 1---------------
#         node     source     destination     value
# 0  NewMexico  NewMexico         Wyoming  0.003233
# 1  NewMexico  NewMexico   SanDiegoState  0.001631
# 2  NewMexico  NewMexico      BoiseState  0.001631
# 3  NewMexico  NewMexico        AirForce  0.001631
# 4  NewMexico  NewMexico  NewMexicoState  0.001631
# 5  NewMexico  NewMexico       TexasTech  0.001631
# 6  NewMexico  NewMexico            Utah  0.001631
# 7  NewMexico  NewMexico     OregonState  0.001631
# 8  NewMexico  NewMexico  NevadaLasVegas  0.001631
# 9  NewMexico  NewMexico   ColoradoState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: NewMexico, source: NewMexico, destination: Wyoming, value: 0.003233369437074373
# ---------------Possible actions for node TexasTech in phase 1---------------
#          node     source         destination     value
# 0   TexasTech  TexasTech             Wyoming  0.001536
# 1   TexasTech  TexasTech          NorthTexas  0.001631
# 2   TexasTech  TexasTech            Nebraska  0.003167
# 3   TexasTech  TexasTech              Kansas  0.001631
# 4   TexasTech  TexasTech              Baylor  0.001631
# 5   TexasTech  TexasTech            TexasA&M  0.001631
# 6   TexasTech  TexasTech       OklahomaState  0.001631
# 7   TexasTech  TexasTech            Oklahoma  0.001631
# 8   TexasTech  TexasTech           UtahState  0.001631
# 9   TexasTech  TexasTech               Texas  0.001631
# 10  TexasTech  TexasTech  LouisianaLafayette  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: TexasTech, source: TexasTech, destination: Nebraska, value: 0.0031668392017436247
# ---------------Possible actions for node PennState in phase 1---------------
#          node     source         destination     value
# 0   PennState  PennState            Nebraska  0.001472
# 1   PennState  PennState            Michigan  0.001631
# 2   PennState  PennState           Minnesota  0.001631
# 3   PennState  PennState  SouthernCalifornia  0.001631
# 4   PennState  PennState       MichiganState  0.001631
# 5   PennState  PennState       LouisianaTech  0.001631
# 6   PennState  PennState              Purdue  0.001631
# 7   PennState  PennState          Pittsburgh  0.001631
# 8   PennState  PennState              Toledo  0.001631
# 9   PennState  PennState           OhioState  0.001631
# 10  PennState  PennState             Indiana  0.001631
# 11  PennState  PennState            Illinois  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: PennState, source: PennState, destination: Michigan, value: 0.0016313213703099511
# ---------------Possible actions for node SouthernCalifornia in phase 1---------------
#                   node              source      destination     value
# 0   SouthernCalifornia  SouthernCalifornia         Michigan  0.001599
# 1   SouthernCalifornia  SouthernCalifornia     ArizonaState  0.001631
# 2   SouthernCalifornia  SouthernCalifornia          Arizona  0.001631
# 3   SouthernCalifornia  SouthernCalifornia         Colorado  0.001631
# 4   SouthernCalifornia  SouthernCalifornia           Oregon  0.001631
# 5   SouthernCalifornia  SouthernCalifornia             UCLA  0.001631
# 6   SouthernCalifornia  SouthernCalifornia         Stanford  0.001631
# 7   SouthernCalifornia  SouthernCalifornia  WashingtonState  0.001631
# 8   SouthernCalifornia  SouthernCalifornia        NotreDame  0.001631
# 9   SouthernCalifornia  SouthernCalifornia      OregonState  0.001631
# 10  SouthernCalifornia  SouthernCalifornia     SanJoseState  0.001631
# 11  SouthernCalifornia  SouthernCalifornia       California  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: SouthernCalifornia, source: SouthernCalifornia, destination: ArizonaState, value: 0.0016313213703099511
# ---------------Possible actions for node ArizonaState in phase 1---------------
#             node        source      destination     value
# 0   ArizonaState  ArizonaState     ArizonaState  0.001602
# 1   ArizonaState  ArizonaState    SanDiegoState  0.001631
# 2   ArizonaState  ArizonaState          Arizona  0.001631
# 3   ArizonaState  ArizonaState           Oregon  0.001631
# 4   ArizonaState  ArizonaState         Stanford  0.001631
# 5   ArizonaState  ArizonaState             UCLA  0.001631
# 6   ArizonaState  ArizonaState  WashingtonState  0.001631
# 7   ArizonaState  ArizonaState       Washington  0.001631
# 8   ArizonaState  ArizonaState        UtahState  0.001631
# 9   ArizonaState  ArizonaState       California  0.001631
# 10  ArizonaState  ArizonaState    ColoradoState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: ArizonaState, source: ArizonaState, destination: SanDiegoState, value: 0.0016313213703099511
# ---------------Possible actions for node SanDiegoState in phase 1---------------
#             node         source     destination     value
# 0  SanDiegoState  SanDiegoState         Wyoming  0.004806
# 1  SanDiegoState  SanDiegoState   SanDiegoState  0.001602
# 2  SanDiegoState  SanDiegoState         Arizona  0.001631
# 3  SanDiegoState  SanDiegoState        AirForce  0.001631
# 4  SanDiegoState  SanDiegoState            Utah  0.001631
# 5  SanDiegoState  SanDiegoState     OregonState  0.001631
# 6  SanDiegoState  SanDiegoState  NevadaLasVegas  0.001631
# 7  SanDiegoState  SanDiegoState   ColoradoState  0.001631
# 8  SanDiegoState  SanDiegoState        Illinois  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: SanDiegoState, source: SanDiegoState, destination: Wyoming, value: 0.004806144200293265
# ---------------Possible actions for node Baylor in phase 1---------------
#      node  source    destination     value
# 0  Baylor  Baylor     NorthTexas  0.001631
# 1  Baylor  Baylor       Nebraska  0.003130
# 2  Baylor  Baylor      Minnesota  0.001631
# 3  Baylor  Baylor       Missouri  0.001631
# 4  Baylor  Baylor       TexasA&M  0.001631
# 5  Baylor  Baylor  OklahomaState  0.001631
# 6  Baylor  Baylor       Oklahoma  0.001631
# 7  Baylor  Baylor      IowaState  0.001631
# 8  Baylor  Baylor          Texas  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Baylor, source: Baylor, destination: Nebraska, value: 0.0031295822699584056
# ---------------Possible actions for node NorthTexas in phase 1---------------
#          node      source         destination     value
# 0  NorthTexas  NorthTexas            Nebraska  0.004708
# 1  NorthTexas  NorthTexas          BoiseState  0.001631
# 2  NorthTexas  NorthTexas      NewMexicoState  0.001631
# 3  NorthTexas  NorthTexas           UtahState  0.001631
# 4  NorthTexas  NorthTexas      NevadaLasVegas  0.001631
# 5  NorthTexas  NorthTexas  LouisianaLafayette  0.001631
# 6  NorthTexas  NorthTexas               Idaho  0.001631
# 7  NorthTexas  NorthTexas       ArkansasState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: NorthTexas, source: NorthTexas, destination: Nebraska, value: 0.0047076794520037575
# ---------------Possible actions for node NorthernIllinois in phase 1---------------
#                node            source      destination     value
# 0  NorthernIllinois  NorthernIllinois            Akron  0.001631
# 1  NorthernIllinois  NorthernIllinois  CentralMichigan  0.001631
# 2  NorthernIllinois  NorthernIllinois     Northwestern  0.001631
# 3  NorthernIllinois  NorthernIllinois   CentralFlorida  0.001631
# 4  NorthernIllinois  NorthernIllinois  EasternMichigan  0.001631
# 5  NorthernIllinois  NorthernIllinois           Toledo  0.001631
# 6  NorthernIllinois  NorthernIllinois          Buffalo  0.001631
# 7  NorthernIllinois  NorthernIllinois  WesternMichigan  0.001631
# 8  NorthernIllinois  NorthernIllinois        BallState  0.001631
# 9  NorthernIllinois  NorthernIllinois           Auburn  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: NorthernIllinois, source: NorthernIllinois, destination: Akron, value: 0.0016313213703099511
# ---------------Possible actions for node Northwestern in phase 1---------------
#             node        source     destination     value
# 0   Northwestern  Northwestern           Akron  0.001602
# 1   Northwestern  Northwestern        Nebraska  0.001339
# 2   Northwestern  Northwestern        Michigan  0.001602
# 3   Northwestern  Northwestern  TexasChristian  0.001631
# 4   Northwestern  Northwestern       Minnesota  0.001631
# 5   Northwestern  Northwestern       Wisconsin  0.001631
# 6   Northwestern  Northwestern          Purdue  0.001631
# 7   Northwestern  Northwestern   MichiganState  0.001631
# 8   Northwestern  Northwestern            Duke  0.001631
# 9   Northwestern  Northwestern         Indiana  0.001631
# 10  Northwestern  Northwestern        Illinois  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Northwestern, source: Northwestern, destination: TexasChristian, value: 0.0016313213703099511
# ---------------Possible actions for node WesternMichigan in phase 1---------------
#               node           source      destination     value
# 0  WesternMichigan  WesternMichigan            Akron  0.001605
# 1  WesternMichigan  WesternMichigan  CentralMichigan  0.001631
# 2  WesternMichigan  WesternMichigan         Nebraska  0.001365
# 3  WesternMichigan  WesternMichigan             Kent  0.001631
# 4  WesternMichigan  WesternMichigan             Ohio  0.001631
# 5  WesternMichigan  WesternMichigan  EasternMichigan  0.001631
# 6  WesternMichigan  WesternMichigan         Marshall  0.001631
# 7  WesternMichigan  WesternMichigan        Wisconsin  0.001631
# 8  WesternMichigan  WesternMichigan        BallState  0.001631
# 9  WesternMichigan  WesternMichigan           Toledo  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: WesternMichigan, source: WesternMichigan, destination: CentralMichigan, value: 0.0016313213703099511
# ---------------Possible actions for node Wisconsin in phase 1---------------
#          node     source      destination     value
# 0   Wisconsin  Wisconsin  CentralMichigan  0.001599
# 1   Wisconsin  Wisconsin         Nebraska  0.001312
# 2   Wisconsin  Wisconsin         Michigan  0.001599
# 3   Wisconsin  Wisconsin   TexasChristian  0.001599
# 4   Wisconsin  Wisconsin        Minnesota  0.001631
# 5   Wisconsin  Wisconsin           Oregon  0.001631
# 6   Wisconsin  Wisconsin       Cincinnati  0.001631
# 7   Wisconsin  Wisconsin           Purdue  0.001631
# 8   Wisconsin  Wisconsin           Hawaii  0.001631
# 9   Wisconsin  Wisconsin    MichiganState  0.001631
# 10  Wisconsin  Wisconsin        OhioState  0.001631
# 11  Wisconsin  Wisconsin          Indiana  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Wisconsin, source: Wisconsin, destination: Minnesota, value: 0.0016313213703099511
# ---------------Possible actions for node Wyoming in phase 1---------------
#       node   source      destination     value
# 0  Wyoming  Wyoming          Wyoming  0.004718
# 1  Wyoming  Wyoming  CentralMichigan  0.001602
# 2  Wyoming  Wyoming         TexasA&M  0.001631
# 3  Wyoming  Wyoming         AirForce  0.001631
# 4  Wyoming  Wyoming             Utah  0.001631
# 5  Wyoming  Wyoming           Nevada  0.001631
# 6  Wyoming  Wyoming   NevadaLasVegas  0.001631
# 7  Wyoming  Wyoming           Auburn  0.001631
# 8  Wyoming  Wyoming    ColoradoState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.0047183242896566766
# ---------------Possible actions for node Auburn in phase 1---------------
#       node  source       destination     value
# 0   Auburn  Auburn           Wyoming  0.001456
# 1   Auburn  Auburn             Akron  0.001602
# 2   Auburn  Auburn        Vanderbilt  0.001631
# 3   Auburn  Auburn           Florida  0.001602
# 4   Auburn  Auburn           Georgia  0.001631
# 5   Auburn  Auburn    LouisianaState  0.001631
# 6   Auburn  Auburn           Alabama  0.001631
# 7   Auburn  Auburn       Mississippi  0.001631
# 8   Auburn  Auburn          Arkansas  0.001631
# 9   Auburn  Auburn     LouisianaTech  0.001631
# 10  Auburn  Auburn  MississippiState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Auburn, source: Auburn, destination: Vanderbilt, value: 0.0016313213703099511
# ---------------Possible actions for node Akron in phase 1---------------
#      node source        destination     value
# 0   Akron  Akron              Akron  0.001602
# 1   Akron  Akron    CentralMichigan  0.001602
# 2   Akron  Akron               Kent  0.001631
# 3   Akron  Akron               Ohio  0.001631
# 4   Akron  Akron     CentralFlorida  0.001631
# 5   Akron  Akron        Connecticut  0.001631
# 6   Akron  Akron          MiamiOhio  0.001631
# 7   Akron  Akron       VirginiaTech  0.001631
# 8   Akron  Akron           Marshall  0.001631
# 9   Akron  Akron  BowlingGreenState  0.001631
# 10  Akron  Akron            Buffalo  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Akron, source: Akron, destination: Kent, value: 0.0016313213703099511
# ---------------Possible actions for node VirginiaTech in phase 1---------------
#             node        source     destination     value
# 0   VirginiaTech  VirginiaTech          Temple  0.001631
# 1   VirginiaTech  VirginiaTech            Kent  0.001602
# 2   VirginiaTech  VirginiaTech  CentralFlorida  0.001631
# 3   VirginiaTech  VirginiaTech    MiamiFlorida  0.001631
# 4   VirginiaTech  VirginiaTech   BostonCollege  0.001631
# 5   VirginiaTech  VirginiaTech        Virginia  0.001631
# 6   VirginiaTech  VirginiaTech      Pittsburgh  0.001631
# 7   VirginiaTech  VirginiaTech    WestVirginia  0.001631
# 8   VirginiaTech  VirginiaTech        Syracuse  0.001631
# 9   VirginiaTech  VirginiaTech    EastCarolina  0.001631
# 10  VirginiaTech  VirginiaTech         Rutgers  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: VirginiaTech, source: VirginiaTech, destination: Temple, value: 0.0016313213703099511
# ---------------Possible actions for node Alabama in phase 1---------------
#       node   source          destination     value
# 0  Alabama  Alabama           Vanderbilt  0.003233
# 1  Alabama  Alabama       CentralFlorida  0.001631
# 2  Alabama  Alabama                 UCLA  0.001631
# 3  Alabama  Alabama       LouisianaState  0.001631
# 4  Alabama  Alabama          Mississippi  0.001631
# 5  Alabama  Alabama             Arkansas  0.001631
# 6  Alabama  Alabama     MississippiState  0.001631
# 7  Alabama  Alabama        SouthCarolina  0.001631
# 8  Alabama  Alabama            Tennessee  0.001631
# 9  Alabama  Alabama  SouthernMississippi  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Alabama, source: Alabama, destination: Vanderbilt, value: 0.003233369437074373
# ---------------Possible actions for node UCLA in phase 1---------------
#     node source    destination     value
# 0   UCLA   UCLA     Vanderbilt  0.001544
# 1   UCLA   UCLA       Michigan  0.001602
# 2   UCLA   UCLA   ArizonaState  0.001631
# 3   UCLA   UCLA  SanDiegoState  0.001631
# 4   UCLA   UCLA        Arizona  0.001631
# 5   UCLA   UCLA    FresnoState  0.001631
# 6   UCLA   UCLA         Oregon  0.001631
# 7   UCLA   UCLA       Stanford  0.001631
# 8   UCLA   UCLA     Washington  0.001631
# 9   UCLA   UCLA    OregonState  0.001631
# 10  UCLA   UCLA     California  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: UCLA, source: UCLA, destination: ArizonaState, value: 0.0016313213703099511
# ---------------Possible actions for node Arizona in phase 1---------------
#       node   source      destination     value
# 0  Arizona  Arizona          Wyoming  0.001456
# 1  Arizona  Arizona     ArizonaState  0.003233
# 2  Arizona  Arizona    SanDiegoState  0.001631
# 3  Arizona  Arizona           Oregon  0.001631
# 4  Arizona  Arizona  WashingtonState  0.001631
# 5  Arizona  Arizona         Stanford  0.001631
# 6  Arizona  Arizona       Washington  0.001631
# 7  Arizona  Arizona             Utah  0.001631
# 8  Arizona  Arizona      OregonState  0.001631
# 9  Arizona  Arizona        OhioState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Arizona, source: Arizona, destination: ArizonaState, value: 0.003233369437074373
# ---------------Possible actions for node Utah in phase 1---------------
#    node source      destination     value
# 0  Utah   Utah          Wyoming  0.006350
# 1  Utah   Utah  WashingtonState  0.001631
# 2  Utah   Utah     ArizonaState  0.001544
# 3  Utah   Utah         AirForce  0.001631
# 4  Utah   Utah        UtahState  0.001631
# 5  Utah   Utah   NevadaLasVegas  0.001631
# 6  Utah   Utah       California  0.001631
# 7  Utah   Utah    ColoradoState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Utah, source: Utah, destination: Wyoming, value: 0.006349645659966628
# ---------------Possible actions for node ArkansasState in phase 1---------------
#             node         source         destination     value
# 0  ArkansasState  ArkansasState            Nebraska  0.001365
# 1  ArkansasState  ArkansasState      TexasChristian  0.001605
# 2  ArkansasState  ArkansasState          BoiseState  0.001631
# 3  ArkansasState  ArkansasState      NewMexicoState  0.001631
# 4  ArkansasState  ArkansasState            Oklahoma  0.001631
# 5  ArkansasState  ArkansasState         Mississippi  0.001631
# 6  ArkansasState  ArkansasState  NorthCarolinaState  0.001631
# 7  ArkansasState  ArkansasState           UtahState  0.001631
# 8  ArkansasState  ArkansasState               Idaho  0.001631
# 9  ArkansasState  ArkansasState             Memphis  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: ArkansasState, source: ArkansasState, destination: BoiseState, value: 0.0016313213703099511
# ---------------Possible actions for node NorthCarolinaState in phase 1---------------
#                   node              source        destination     value
# 0   NorthCarolinaState  NorthCarolinaState            Florida  0.001602
# 1   NorthCarolinaState  NorthCarolinaState         BoiseState  0.001602
# 2   NorthCarolinaState  NorthCarolinaState      NorthCarolina  0.001631
# 3   NorthCarolinaState  NorthCarolinaState            Clemson  0.001631
# 4   NorthCarolinaState  NorthCarolinaState        GeorgiaTech  0.001631
# 5   NorthCarolinaState  NorthCarolinaState           Virginia  0.001631
# 6   NorthCarolinaState  NorthCarolinaState         WakeForest  0.001631
# 7   NorthCarolinaState  NorthCarolinaState           Maryland  0.001631
# 8   NorthCarolinaState  NorthCarolinaState  SouthernMethodist  0.001631
# 9   NorthCarolinaState  NorthCarolinaState               Duke  0.001631
# 10  NorthCarolinaState  NorthCarolinaState            Indiana  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: NorthCarolinaState, source: NorthCarolinaState, destination: NorthCarolina, value: 0.0016313213703099511
# ---------------Possible actions for node BallState in phase 1---------------
#         node     source      destination     value
# 0  BallState  BallState            Akron  0.001631
# 1  BallState  BallState  CentralMichigan  0.003236
# 2  BallState  BallState         Nebraska  0.001365
# 3  BallState  BallState          Florida  0.001605
# 4  BallState  BallState      Connecticut  0.001631
# 5  BallState  BallState        MiamiOhio  0.001631
# 6  BallState  BallState  EasternMichigan  0.001631
# 7  BallState  BallState          Buffalo  0.001631
# 8  BallState  BallState           Toledo  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: BallState, source: BallState, destination: CentralMichigan, value: 0.003236030646487603
# ---------------Possible actions for node Florida in phase 1---------------
#       node   source           destination     value
# 0  Florida  Florida       CentralMichigan  0.001544
# 1  Florida  Florida            Vanderbilt  0.003175
# 2  Florida  Florida               Florida  0.001602
# 3  Florida  Florida               Georgia  0.001631
# 4  Florida  Florida  MiddleTennesseeState  0.001631
# 5  Florida  Florida        LouisianaState  0.001631
# 6  Florida  Florida              Kentucky  0.001631
# 7  Florida  Florida      MississippiState  0.001631
# 8  Florida  Florida         SouthCarolina  0.001631
# 9  Florida  Florida             Tennessee  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Florida, source: Florida, destination: Vanderbilt, value: 0.003174822829983314
# ---------------Possible actions for node BoiseState in phase 1---------------
#          node      source      destination     value
# 0  BoiseState  BoiseState          Wyoming  0.001392
# 1  BoiseState  BoiseState  CentralMichigan  0.001559
# 2  BoiseState  BoiseState         Nebraska  0.001392
# 3  BoiseState  BoiseState  WashingtonState  0.001631
# 4  BoiseState  BoiseState       BoiseState  0.001607
# 5  BoiseState  BoiseState   NewMexicoState  0.001631
# 6  BoiseState  BoiseState        UtahState  0.001631
# 7  BoiseState  BoiseState         Arkansas  0.001631
# 8  BoiseState  BoiseState            Idaho  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: BoiseState, source: BoiseState, destination: WashingtonState, value: 0.0016313213703099511
# ---------------Possible actions for node BostonCollege in phase 1---------------
#             node         source   destination     value
# 0  BostonCollege  BostonCollege        Temple  0.003233
# 1  BostonCollege  BostonCollege  MiamiFlorida  0.001631
# 2  BostonCollege  BostonCollege   Connecticut  0.001631
# 3  BostonCollege  BostonCollege     NotreDame  0.001631
# 4  BostonCollege  BostonCollege    Pittsburgh  0.001631
# 5  BostonCollege  BostonCollege  WestVirginia  0.001631
# 6  BostonCollege  BostonCollege      Syracuse  0.001631
# 7  BostonCollege  BostonCollege          Army  0.001631
# 8  BostonCollege  BostonCollege          Navy  0.001631
# 9  BostonCollege  BostonCollege       Rutgers  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: BostonCollege, source: BostonCollege, destination: Temple, value: 0.003233369437074373
# ---------------Possible actions for node WestVirginia in phase 1---------------
#            node        source   destination     value
# 0  WestVirginia  WestVirginia        Temple  0.004806
# 1  WestVirginia  WestVirginia  MiamiFlorida  0.001631
# 2  WestVirginia  WestVirginia     NotreDame  0.001631
# 3  WestVirginia  WestVirginia         Idaho  0.001631
# 4  WestVirginia  WestVirginia    Pittsburgh  0.001631
# 5  WestVirginia  WestVirginia      Maryland  0.001631
# 6  WestVirginia  WestVirginia      Syracuse  0.001631
# 7  WestVirginia  WestVirginia  EastCarolina  0.001631
# 8  WestVirginia  WestVirginia       Rutgers  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: WestVirginia, source: WestVirginia, destination: Temple, value: 0.004806144200293265
# ---------------Possible actions for node BowlingGreenState in phase 1---------------
#                 node             source      destination     value
# 0  BowlingGreenState  BowlingGreenState           Temple  0.001456
# 1  BowlingGreenState  BowlingGreenState             Ohio  0.001631
# 2  BowlingGreenState  BowlingGreenState             Kent  0.003233
# 3  BowlingGreenState  BowlingGreenState         Michigan  0.001602
# 4  BowlingGreenState  BowlingGreenState        MiamiOhio  0.001631
# 5  BowlingGreenState  BowlingGreenState  EasternMichigan  0.001631
# 6  BowlingGreenState  BowlingGreenState         Marshall  0.001631
# 7  BowlingGreenState  BowlingGreenState          Buffalo  0.001631
# 8  BowlingGreenState  BowlingGreenState       Pittsburgh  0.001631
# 9  BowlingGreenState  BowlingGreenState           Toledo  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: BowlingGreenState, source: BowlingGreenState, destination: Kent, value: 0.003233369437074373
# ---------------Possible actions for node Michigan in phase 1---------------
#         node    source     destination     value
# 0   Michigan  Michigan            Kent  0.001544
# 1   Michigan  Michigan  TexasChristian  0.001602
# 2   Michigan  Michigan        Michigan  0.001602
# 3   Michigan  Michigan    ArizonaState  0.001544
# 4   Michigan  Michigan       Minnesota  0.001602
# 5   Michigan  Michigan          Purdue  0.001631
# 6   Michigan  Michigan            Rice  0.001631
# 7   Michigan  Michigan   MichiganState  0.001631
# 8   Michigan  Michigan       OhioState  0.001631
# 9   Michigan  Michigan         Indiana  0.001631
# 10  Michigan  Michigan        Illinois  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Michigan, source: Michigan, destination: Purdue, value: 0.0016313213703099511
# ---------------Possible actions for node Virginia in phase 1---------------
#        node    source    destination     value
# 0  Virginia  Virginia        Wyoming  0.001365
# 1  Virginia  Virginia         Temple  0.001472
# 2  Virginia  Virginia        Florida  0.001631
# 3  Virginia  Virginia  NorthCarolina  0.003236
# 4  Virginia  Virginia        Clemson  0.001631
# 5  Virginia  Virginia    GeorgiaTech  0.001631
# 6  Virginia  Virginia     WakeForest  0.001631
# 7  Virginia  Virginia       Maryland  0.001631
# 8  Virginia  Virginia           Duke  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Virginia, source: Virginia, destination: NorthCarolina, value: 0.003236030646487603
# ---------------Possible actions for node Buffalo in phase 1---------------
#       node   source      destination     value
# 0  Buffalo  Buffalo            Akron  0.001631
# 1  Buffalo  Buffalo             Kent  0.004806
# 2  Buffalo  Buffalo  CentralMichigan  0.001544
# 3  Buffalo  Buffalo             Ohio  0.001631
# 4  Buffalo  Buffalo      Connecticut  0.001631
# 5  Buffalo  Buffalo        MiamiOhio  0.001631
# 6  Buffalo  Buffalo         Marshall  0.001631
# 7  Buffalo  Buffalo         Syracuse  0.001631
# 8  Buffalo  Buffalo          Rutgers  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Buffalo, source: Buffalo, destination: Kent, value: 0.004806144200293265
# ---------------Possible actions for node Syracuse in phase 1---------------
#        node    source   destination     value
# 0  Syracuse  Syracuse       Wyoming  0.001339
# 1  Syracuse  Syracuse        Temple  0.006350
# 2  Syracuse  Syracuse          Kent  0.001456
# 3  Syracuse  Syracuse    Cincinnati  0.001631
# 4  Syracuse  Syracuse  MiamiFlorida  0.001631
# 5  Syracuse  Syracuse    Pittsburgh  0.001631
# 6  Syracuse  Syracuse  EastCarolina  0.001631
# 7  Syracuse  Syracuse       Rutgers  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Syracuse, source: Syracuse, destination: Temple, value: 0.006349645659966628
# ---------------Possible actions for node CentralFlorida in phase 1---------------
#              node          source      destination     value
# 0  CentralFlorida  CentralFlorida           Temple  0.001418
# 1  CentralFlorida  CentralFlorida            Akron  0.001631
# 2  CentralFlorida  CentralFlorida             Kent  0.001504
# 3  CentralFlorida  CentralFlorida       Vanderbilt  0.001525
# 4  CentralFlorida  CentralFlorida      GeorgiaTech  0.001631
# 5  CentralFlorida  CentralFlorida  EasternMichigan  0.001631
# 6  CentralFlorida  CentralFlorida    LouisianaTech  0.001631
# 7  CentralFlorida  CentralFlorida  LouisianaMonroe  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: CentralFlorida, source: CentralFlorida, destination: Akron, value: 0.0016313213703099511
# ---------------Possible actions for node GeorgiaTech in phase 1---------------
#           node       source    destination     value
# 0  GeorgiaTech  GeorgiaTech          Akron  0.001602
# 1  GeorgiaTech  GeorgiaTech        Florida  0.001631
# 2  GeorgiaTech  GeorgiaTech        Georgia  0.001631
# 3  GeorgiaTech  GeorgiaTech  NorthCarolina  0.004806
# 4  GeorgiaTech  GeorgiaTech        Clemson  0.001631
# 5  GeorgiaTech  GeorgiaTech     WakeForest  0.001631
# 6  GeorgiaTech  GeorgiaTech       Maryland  0.001631
# 7  GeorgiaTech  GeorgiaTech           Navy  0.001631
# 8  GeorgiaTech  GeorgiaTech           Duke  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: GeorgiaTech, source: GeorgiaTech, destination: NorthCarolina, value: 0.004806144200293265
# ---------------Possible actions for node CentralMichigan in phase 1---------------
#               node           source      destination     value
# 0  CentralMichigan  CentralMichigan          Wyoming  0.001339
# 1  CentralMichigan  CentralMichigan            Akron  0.001602
# 2  CentralMichigan  CentralMichigan  CentralMichigan  0.003175
# 3  CentralMichigan  CentralMichigan             Kent  0.003087
# 4  CentralMichigan  CentralMichigan  WashingtonState  0.001602
# 5  CentralMichigan  CentralMichigan             Ohio  0.001631
# 6  CentralMichigan  CentralMichigan  EasternMichigan  0.001631
# 7  CentralMichigan  CentralMichigan           Purdue  0.001602
# 8  CentralMichigan  CentralMichigan           Toledo  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: CentralMichigan, source: CentralMichigan, destination: CentralMichigan, value: 0.003174822829983314
# ---------------Possible actions for node Purdue in phase 1---------------
#      node  source      destination     value
# 0  Purdue  Purdue  CentralMichigan  0.001544
# 1  Purdue  Purdue             Kent  0.001456
# 2  Purdue  Purdue   TexasChristian  0.001602
# 3  Purdue  Purdue         Michigan  0.001631
# 4  Purdue  Purdue        Minnesota  0.003233
# 5  Purdue  Purdue        NotreDame  0.001631
# 6  Purdue  Purdue           Purdue  0.001602
# 7  Purdue  Purdue    MichiganState  0.001631
# 8  Purdue  Purdue        OhioState  0.001631
# 9  Purdue  Purdue          Indiana  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Purdue, source: Purdue, destination: Minnesota, value: 0.003233369437074373
# ---------------Possible actions for node Colorado in phase 1---------------
#        node    source    destination     value
# 0  Colorado  Colorado       Nebraska  0.002970
# 1  Colorado  Colorado   ArizonaState  0.001544
# 2  Colorado  Colorado         Kansas  0.001631
# 3  Colorado  Colorado       TexasA&M  0.001631
# 4  Colorado  Colorado       Missouri  0.001631
# 5  Colorado  Colorado  OklahomaState  0.001631
# 6  Colorado  Colorado     Washington  0.001631
# 7  Colorado  Colorado      IowaState  0.001631
# 8  Colorado  Colorado          Texas  0.001631
# 9  Colorado  Colorado  ColoradoState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Colorado, source: Colorado, destination: Nebraska, value: 0.002969909705164609
# ---------------Possible actions for node ColoradoState in phase 1---------------
#             node         source     destination     value
# 0  ColoradoState  ColoradoState         Wyoming  0.007890
# 1  ColoradoState  ColoradoState        Nebraska  0.001312
# 2  ColoradoState  ColoradoState   SanDiegoState  0.001631
# 3  ColoradoState  ColoradoState        AirForce  0.001631
# 4  ColoradoState  ColoradoState          Nevada  0.001631
# 5  ColoradoState  ColoradoState  NevadaLasVegas  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: ColoradoState, source: ColoradoState, destination: Wyoming, value: 0.007890485910226761
# ---------------Possible actions for node Connecticut in phase 1---------------
#           node       source           destination     value
# 0  Connecticut  Connecticut                Temple  0.001445
# 1  Connecticut  Connecticut       CentralMichigan  0.001575
# 2  Connecticut  Connecticut                  Kent  0.003151
# 3  Connecticut  Connecticut  MiddleTennesseeState  0.001631
# 4  Connecticut  Connecticut            Louisville  0.001631
# 5  Connecticut  Connecticut       EasternMichigan  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Connecticut, source: Connecticut, destination: Kent, value: 0.003150871945264245
# ---------------Possible actions for node EasternMichigan in phase 1---------------
#               node           source      destination     value
# 0  EasternMichigan  EasternMichigan           Temple  0.001339
# 1  EasternMichigan  EasternMichigan            Akron  0.003233
# 2  EasternMichigan  EasternMichigan             Kent  0.003028
# 3  EasternMichigan  EasternMichigan  CentralMichigan  0.004806
# 4  EasternMichigan  EasternMichigan        MiamiOhio  0.001631
# 5  EasternMichigan  EasternMichigan    SouthCarolina  0.001631
# 6  EasternMichigan  EasternMichigan           Toledo  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: EasternMichigan, source: EasternMichigan, destination: CentralMichigan, value: 0.004806144200293265
# ---------------Possible actions for node EastCarolina in phase 1---------------
#            node        source          destination     value
# 0  EastCarolina  EastCarolina               Temple  0.004601
# 1  EastCarolina  EastCarolina    AlabamaBirmingham  0.001631
# 2  EastCarolina  EastCarolina           Louisville  0.001631
# 3  EastCarolina  EastCarolina              Houston  0.001631
# 4  EastCarolina  EastCarolina              Memphis  0.001631
# 5  EastCarolina  EastCarolina  SouthernMississippi  0.001631
# 6  EastCarolina  EastCarolina               Tulane  0.001631
# 7  EastCarolina  EastCarolina                 Army  0.001631
# 8  EastCarolina  EastCarolina                 Duke  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: EastCarolina, source: EastCarolina, destination: Temple, value: 0.00460123107547456
# ---------------Possible actions for node Duke in phase 1---------------
#    node source     destination     value
# 0  Duke   Duke          Temple  0.001251
# 1  Duke   Duke      Vanderbilt  0.001485
# 2  Duke   Duke         Florida  0.001631
# 3  Duke   Duke  TexasChristian  0.001602
# 4  Duke   Duke   NorthCarolina  0.006350
# 5  Duke   Duke         Clemson  0.001631
# 6  Duke   Duke      WakeForest  0.001631
# 7  Duke   Duke        Maryland  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Duke, source: Duke, destination: NorthCarolina, value: 0.006349645659966628
# ---------------Possible actions for node FresnoState in phase 1---------------
#            node       source        destination     value
# 0   FresnoState  FresnoState        TexasElPaso  0.001631
# 1   FresnoState  FresnoState       ArizonaState  0.001544
# 2   FresnoState  FresnoState     TexasChristian  0.001602
# 3   FresnoState  FresnoState              Tulsa  0.001631
# 4   FresnoState  FresnoState          OhioState  0.001631
# 5   FresnoState  FresnoState             Nevada  0.001631
# 6   FresnoState  FresnoState               Rice  0.001631
# 7   FresnoState  FresnoState       SanJoseState  0.001631
# 8   FresnoState  FresnoState             Hawaii  0.001631
# 9   FresnoState  FresnoState         California  0.001631
# 10  FresnoState  FresnoState  SouthernMethodist  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: FresnoState, source: FresnoState, destination: TexasElPaso, value: 0.0016313213703099511
# ---------------Possible actions for node OhioState in phase 1---------------
#         node     source    destination     value
# 0  OhioState  OhioState       Nebraska  0.001280
# 1  OhioState  OhioState       Michigan  0.001631
# 2  OhioState  OhioState   ArizonaState  0.001544
# 3  OhioState  OhioState      Minnesota  0.004806
# 4  OhioState  OhioState    TexasElPaso  0.001602
# 5  OhioState  OhioState      MiamiOhio  0.001631
# 6  OhioState  OhioState         Purdue  0.001631
# 7  OhioState  OhioState  MichiganState  0.001631
# 8  OhioState  OhioState       Illinois  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: OhioState, source: OhioState, destination: Minnesota, value: 0.004806144200293265
# ---------------Possible actions for node Houston in phase 1---------------
#        node   source          destination     value
# 0   Houston  Houston               Temple  0.001251
# 1   Houston  Houston           Cincinnati  0.001631
# 2   Houston  Houston       LouisianaState  0.001631
# 3   Houston  Houston           Louisville  0.001631
# 4   Houston  Houston                Texas  0.001631
# 5   Houston  Houston                 Rice  0.001631
# 6   Houston  Houston              Memphis  0.001631
# 7   Houston  Houston  SouthernMississippi  0.001631
# 8   Houston  Houston               Tulane  0.001631
# 9   Houston  Houston                 Army  0.001631
# 10  Houston  Houston    SouthernMethodist  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Houston, source: Houston, destination: Cincinnati, value: 0.0016313213703099511
# ---------------Possible actions for node Rice in phase 1---------------
#    node source        destination     value
# 0  Rice   Rice        TexasElPaso  0.003233
# 1  Rice   Rice     TexasChristian  0.001602
# 2  Rice   Rice              Tulsa  0.001631
# 3  Rice   Rice         Cincinnati  0.001602
# 4  Rice   Rice           Oklahoma  0.001631
# 5  Rice   Rice             Nevada  0.001631
# 6  Rice   Rice             Purdue  0.001631
# 7  Rice   Rice       SanJoseState  0.001631
# 8  Rice   Rice             Hawaii  0.001631
# 9  Rice   Rice  SouthernMethodist  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Rice, source: Rice, destination: TexasElPaso, value: 0.003233369437074373
# ---------------Possible actions for node Idaho in phase 1---------------
#     node source      destination     value
# 0  Idaho  Idaho           Temple  0.001320
# 1  Idaho  Idaho         Nebraska  0.001344
# 2  Idaho  Idaho  WashingtonState  0.003239
# 3  Idaho  Idaho           Oregon  0.001631
# 4  Idaho  Idaho       BoiseState  0.001631
# 5  Idaho  Idaho       Washington  0.001631
# 6  Idaho  Idaho   NewMexicoState  0.001631
# 7  Idaho  Idaho        UtahState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Idaho, source: Idaho, destination: WashingtonState, value: 0.003238691855900833
# ---------------Possible actions for node Washington in phase 1---------------
#          node      source      destination     value
# 0  Washington  Washington         Nebraska  0.001280
# 1  Washington  Washington           Oregon  0.001631
# 2  Washington  Washington     ArizonaState  0.003175
# 3  Washington  Washington    SanDiegoState  0.001631
# 4  Washington  Washington  WashingtonState  0.003175
# 5  Washington  Washington         Stanford  0.001631
# 6  Washington  Washington     MiamiFlorida  0.001631
# 7  Washington  Washington      OregonState  0.001631
# 8  Washington  Washington       California  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Washington, source: Washington, destination: ArizonaState, value: 0.003174822829983314
# ---------------Possible actions for node Kansas in phase 1---------------
#      node  source        destination     value
# 0  Kansas  Kansas  AlabamaBirmingham  0.001631
# 1  Kansas  Kansas           Nebraska  0.006206
# 2  Kansas  Kansas           Missouri  0.001631
# 3  Kansas  Kansas           Oklahoma  0.001631
# 4  Kansas  Kansas          IowaState  0.001631
# 5  Kansas  Kansas              Texas  0.001631
# 6  Kansas  Kansas  SouthernMethodist  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Kansas, source: Kansas, destination: Nebraska, value: 0.006205940351652213
# ---------------Possible actions for node SouthernMethodist in phase 1---------------
#                 node             source     destination     value
# 0  SouthernMethodist  SouthernMethodist     TexasElPaso  0.004798
# 1  SouthernMethodist  SouthernMethodist        Nebraska  0.001120
# 2  SouthernMethodist  SouthernMethodist  TexasChristian  0.001599
# 3  SouthernMethodist  SouthernMethodist           Tulsa  0.001631
# 4  SouthernMethodist  SouthernMethodist      Cincinnati  0.001599
# 5  SouthernMethodist  SouthernMethodist   NorthCarolina  0.001312
# 6  SouthernMethodist  SouthernMethodist          Nevada  0.001631
# 7  SouthernMethodist  SouthernMethodist    SanJoseState  0.001631
# 8  SouthernMethodist  SouthernMethodist          Tulane  0.001631
# 9  SouthernMethodist  SouthernMethodist          Hawaii  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: SouthernMethodist, source: SouthernMethodist, destination: TexasElPaso, value: 0.004798160572053575
# ---------------Possible actions for node Kent in phase 1---------------
#    node source      destination     value
# 0  Kent   Kent  CentralMichigan  0.003103
# 1  Kent   Kent             Kent  0.004681
# 2  Kent   Kent             Ohio  0.001631
# 3  Kent   Kent        Minnesota  0.001472
# 4  Kent   Kent        MiamiOhio  0.001631
# 5  Kent   Kent         Marshall  0.001631
# 6  Kent   Kent       Pittsburgh  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Kent, source: Kent, destination: Kent, value: 0.004681067357871458
# ---------------Possible actions for node Pittsburgh in phase 1---------------
#          node      source    destination     value
# 0  Pittsburgh  Pittsburgh         Temple  0.007776
# 1  Pittsburgh  Pittsburgh           Kent  0.003028
# 2  Pittsburgh  Pittsburgh       Michigan  0.001631
# 3  Pittsburgh  Pittsburgh   MiamiFlorida  0.001631
# 4  Pittsburgh  Pittsburgh  NorthCarolina  0.001339
# 5  Pittsburgh  Pittsburgh        Rutgers  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Pittsburgh, source: Pittsburgh, destination: Temple, value: 0.007776053905457873
# ---------------Possible actions for node Kentucky in phase 1---------------
#        node    source       destination     value
# 0  Kentucky  Kentucky        Vanderbilt  0.003130
# 1  Kentucky  Kentucky           Georgia  0.001631
# 2  Kentucky  Kentucky    LouisianaState  0.001631
# 3  Kentucky  Kentucky        Louisville  0.001631
# 4  Kentucky  Kentucky       Mississippi  0.001631
# 5  Kentucky  Kentucky  MississippiState  0.001631
# 6  Kentucky  Kentucky     SouthCarolina  0.001631
# 7  Kentucky  Kentucky         Tennessee  0.001631
# 8  Kentucky  Kentucky           Indiana  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Kentucky, source: Kentucky, destination: Vanderbilt, value: 0.0031295822699584056
# ---------------Possible actions for node Louisville in phase 1---------------
#          node      source          destination     value
# 0  Louisville  Louisville               Temple  0.001152
# 1  Louisville  Louisville                 Kent  0.001418
# 2  Louisville  Louisville              Florida  0.001631
# ...
# 8   Temple  Temple      TexasElPaso -0.006129
# 9   Temple  Temple       Cincinnati  0.012771
# 10  Temple  Temple    NorthCarolina  0.005290
# the action among the previous actions that maximizes modularity gain is:
# node: Temple, source: Temple, destination: Temple, value: 0.0537990094978564
# ---------------Possible actions for node WashingtonState in phase 3---------------
#               node           source      destination     value
# 0  WashingtonState  WashingtonState          Wyoming  0.003694
# 1  WashingtonState  WashingtonState  CentralMichigan -0.000088
# 2  WashingtonState  WashingtonState       Vanderbilt  0.001671
# 3  WashingtonState  WashingtonState         Nebraska  0.005958
# 4  WashingtonState  WashingtonState     ArizonaState  0.004112
# 5  WashingtonState  WashingtonState           Temple -0.002211
# 6  WashingtonState  WashingtonState  WashingtonState  0.015302
# 7  WashingtonState  WashingtonState      TexasElPaso  0.001253
# 8  WashingtonState  WashingtonState       Cincinnati  0.000836
# 9  WashingtonState  WashingtonState    NorthCarolina -0.002009
# the action among the previous actions that maximizes modularity gain is:
# node: WashingtonState, source: WashingtonState, destination: WashingtonState, value: 0.015301954126072133
# ---------------Possible actions for node TexasElPaso in phase 3---------------
#           node       source      destination     value
# 0  TexasElPaso  TexasElPaso          Wyoming  0.001607
# 1  TexasElPaso  TexasElPaso           Temple -0.005043
# 2  TexasElPaso  TexasElPaso         Nebraska  0.000303
# 3  TexasElPaso  TexasElPaso     ArizonaState  0.001131
# 4  TexasElPaso  TexasElPaso  WashingtonState  0.003138
# 5  TexasElPaso  TexasElPaso        Minnesota  0.003289
# 6  TexasElPaso  TexasElPaso      TexasElPaso  0.052405
# 7  TexasElPaso  TexasElPaso       Cincinnati  0.000679
# 8  TexasElPaso  TexasElPaso    NorthCarolina -0.003060
# the action among the previous actions that maximizes modularity gain is:
# node: TexasElPaso, source: TexasElPaso, destination: TexasElPaso, value: 0.05240453576532391
# ---------------Possible actions for node Cincinnati in phase 3---------------
#           node      source        destination     value
# 0   Cincinnati  Cincinnati            Wyoming -0.002914
# 1   Cincinnati  Cincinnati             Temple  0.011776
# 2   Cincinnati  Cincinnati         Vanderbilt  0.005259
# 3   Cincinnati  Cincinnati           Nebraska -0.003872
# 4   Cincinnati  Cincinnati               Kent -0.000471
# 5   Cincinnati  Cincinnati    WashingtonState  0.001639
# 6   Cincinnati  Cincinnati          Minnesota -0.002744
# 7   Cincinnati  Cincinnati        TexasElPaso -0.000950
# 8   Cincinnati  Cincinnati  AlabamaBirmingham  0.006038
# 9   Cincinnati  Cincinnati         Cincinnati  0.035256
# 10  Cincinnati  Cincinnati      NorthCarolina -0.004213
# the action among the previous actions that maximizes modularity gain is:
# node: Cincinnati, source: Cincinnati, destination: Cincinnati, value: 0.035255702306470196
# ---------------Possible actions for node AlabamaBirmingham in phase 3---------------
#                 node             source        destination     value
# 0  AlabamaBirmingham  AlabamaBirmingham    CentralMichigan  0.000636
# 1  AlabamaBirmingham  AlabamaBirmingham         Vanderbilt  0.003715
# 2  AlabamaBirmingham  AlabamaBirmingham           Nebraska  0.001732
# 3  AlabamaBirmingham  AlabamaBirmingham               Kent  0.000285
# 4  AlabamaBirmingham  AlabamaBirmingham  AlabamaBirmingham  0.004718
# 5  AlabamaBirmingham  AlabamaBirmingham          Minnesota  0.005990
# 6  AlabamaBirmingham  AlabamaBirmingham         Cincinnati  0.005120
# 7  AlabamaBirmingham  AlabamaBirmingham      NorthCarolina -0.000476
# the action among the previous actions that maximizes modularity gain is:
# node: AlabamaBirmingham, source: AlabamaBirmingham, destination: Minnesota, value: 0.005990382389180586
# displayed possible actions for all the nodes in phase: 3
# ----------------------------------------------------------------
#
#
# --------------------------Graph in the phase: 4--------------------------
#               nodes        community  \
# 0           Wyoming          Wyoming
# 1     NorthCarolina    NorthCarolina
# 2          Nebraska         Nebraska
# 3         Minnesota        Minnesota
# 4      ArizonaState     ArizonaState
# 5   CentralMichigan  CentralMichigan
# 6        Vanderbilt       Vanderbilt
# 7              Kent             Kent
# 8            Temple           Temple
# 9   WashingtonState  WashingtonState
# 10      TexasElPaso      TexasElPaso
# 11       Cincinnati       Cincinnati
#
#                                          people_nodes
# 0   [BrighamYoung, NewMexico, SanDiegoState, Wyomi...
# 1   [FloridaState, NorthCarolinaState, Virginia, G...
# 2   [Iowa, KansasState, TexasTech, Baylor, NorthTe...
# 3   [PennState, LouisianaTech, Northwestern, Wisco...
# 4   [SouthernCalifornia, UCLA, Arizona, Washington...
# 5   [NorthernIllinois, CentralFlorida, WesternMich...
# 6   [Auburn, Alabama, Florida, Kentucky, Vanderbil...
# 7   [Akron, BowlingGreenState, Buffalo, Connecticu...
# 8   [VirginiaTech, BostonCollege, WestVirginia, Sy...
# 9   [ArkansasState, BoiseState, Idaho, NewMexicoSt...
# 10  [FresnoState, Rice, SouthernMethodist, Nevada,...
# 11  [Houston, Louisville, Memphis, SouthernMississ...
#     edges           node_a           node_b  weight
# 0       1          Wyoming    NorthCarolina       2
# 1       2          Wyoming          Wyoming      28
# 2       3          Wyoming           Temple       3
# 3       4          Wyoming       Vanderbilt       3
# 4       5          Wyoming  WashingtonState       4
# ..    ...              ...              ...     ...
# 60     61  WashingtonState       Cincinnati       2
# 61     62  WashingtonState      TexasElPaso       3
# 62     63      TexasElPaso      TexasElPaso      36
# 63     64      TexasElPaso       Cincinnati       3
# 64     65       Cincinnati       Cincinnati      24
#
# [65 rows x 4 columns]
# _______________________________________________________________________________________________________
# ---------------Possible actions for node Wyoming in phase 4---------------
#        node   source      destination     value
# 0   Wyoming  Wyoming          Wyoming  0.041206
# 1   Wyoming  Wyoming           Temple -0.001174
# 2   Wyoming  Wyoming       Vanderbilt -0.002770
# 3   Wyoming  Wyoming         Nebraska -0.000466
# 4   Wyoming  Wyoming  WashingtonState  0.004929
# 5   Wyoming  Wyoming     ArizonaState  0.006664
# 6   Wyoming  Wyoming        Minnesota -0.005554
# 7   Wyoming  Wyoming  CentralMichigan -0.001083
# 8   Wyoming  Wyoming      TexasElPaso  0.000777
# 9   Wyoming  Wyoming       Cincinnati -0.002201
# 10  Wyoming  Wyoming    NorthCarolina -0.002486
# the action among the previous actions that maximizes modularity gain is:
# node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# ---------------Possible actions for node NorthCarolina in phase 4---------------
#              node         source      destination     value
# 0   NorthCarolina  NorthCarolina          Wyoming -0.001283
# 1   NorthCarolina  NorthCarolina           Temple  0.006882
# 2   NorthCarolina  NorthCarolina       Vanderbilt  0.000365
# 3   NorthCarolina  NorthCarolina         Nebraska -0.007135
# 4   NorthCarolina  NorthCarolina  CentralMichigan -0.001128
# 5   NorthCarolina  NorthCarolina             Kent -0.002102
# 6   NorthCarolina  NorthCarolina        Minnesota -0.002411
# 7   NorthCarolina  NorthCarolina  WashingtonState  0.000008
# 8   NorthCarolina  NorthCarolina      TexasElPaso -0.002581
# 9   NorthCarolina  NorthCarolina       Cincinnati -0.002265
# 10  NorthCarolina  NorthCarolina    NorthCarolina  0.052884
# the action among the previous actions that maximizes modularity gain is:
# node: NorthCarolina, source: NorthCarolina, destination: NorthCarolina, value: 0.0528835534597053
# ---------------Possible actions for node Nebraska in phase 4---------------
#         node    source      destination     value
# 0   Nebraska  Nebraska          Wyoming  0.000854
# 1   Nebraska  Nebraska  CentralMichigan -0.001171
# 2   Nebraska  Nebraska             Kent -0.004367
# 3   Nebraska  Nebraska         Nebraska  0.074008
# 4   Nebraska  Nebraska  WashingtonState  0.008811
# 5   Nebraska  Nebraska     ArizonaState -0.005538
# 6   Nebraska  Nebraska        Minnesota  0.011103
# 7   Nebraska  Nebraska      TexasElPaso  0.000399
# 8   Nebraska  Nebraska           Temple -0.006648
# 9   Nebraska  Nebraska       Cincinnati -0.001365
# 10  Nebraska  Nebraska    NorthCarolina -0.007757
# the action among the previous actions that maximizes modularity gain is:
# node: Nebraska, source: Nebraska, destination: Nebraska, value: 0.07400823378192453
# ---------------Possible actions for node Minnesota in phase 4---------------
#          node     source      destination     value
# 0   Minnesota  Minnesota          Wyoming -0.005969
# 1   Minnesota  Minnesota           Temple -0.003790
# 2   Minnesota  Minnesota  CentralMichigan  0.005173
# 3   Minnesota  Minnesota         Nebraska  0.008181
# 4   Minnesota  Minnesota     ArizonaState -0.002701
# 5   Minnesota  Minnesota       Vanderbilt -0.003241
# 6   Minnesota  Minnesota        Minnesota  0.061195
# 7   Minnesota  Minnesota      TexasElPaso  0.000016
# 8   Minnesota  Minnesota             Kent  0.003545
# 9   Minnesota  Minnesota       Cincinnati  0.003273
# 10  Minnesota  Minnesota    NorthCarolina -0.004878
# the action among the previous actions that maximizes modularity gain is:
# node: Minnesota, source: Minnesota, destination: Minnesota, value: 0.061194510457222386
# ---------------Possible actions for node ArizonaState in phase 4---------------
#            node        source      destination     value
# 0  ArizonaState  ArizonaState          Wyoming  0.007835
# 1  ArizonaState  ArizonaState           Temple -0.002185
# 2  ArizonaState  ArizonaState       Vanderbilt -0.007310
# 3  ArizonaState  ArizonaState         Nebraska -0.005165
# 4  ArizonaState  ArizonaState     ArizonaState  0.057801
# 5  ArizonaState  ArizonaState      TexasElPaso  0.001450
# 6  ArizonaState  ArizonaState        Minnesota -0.000226
# 7  ArizonaState  ArizonaState  WashingtonState  0.006294
# the action among the previous actions that maximizes modularity gain is:
# node: ArizonaState, source: ArizonaState, destination: ArizonaState, value: 0.057801468455354214
# ---------------Possible actions for node CentralMichigan in phase 4---------------
#               node           source      destination     value
# 0  CentralMichigan  CentralMichigan          Wyoming -0.002243
# 1  CentralMichigan  CentralMichigan  CentralMichigan  0.025380
# 2  CentralMichigan  CentralMichigan       Vanderbilt -0.000117
# 3  CentralMichigan  CentralMichigan         Nebraska -0.004210
# 4  CentralMichigan  CentralMichigan             Kent  0.024550
# 5  CentralMichigan  CentralMichigan           Temple -0.000365
# 6  CentralMichigan  CentralMichigan        Minnesota  0.003561
# 7  CentralMichigan  CentralMichigan  WashingtonState  0.000247
# 8  CentralMichigan  CentralMichigan    NorthCarolina -0.003350
# the action among the previous actions that maximizes modularity gain is:
# node: CentralMichigan, source: CentralMichigan, destination: CentralMichigan, value: 0.025379954173973904
# ---------------Possible actions for node Vanderbilt in phase 4---------------
#          node      source      destination     value
# 0  Vanderbilt  Vanderbilt          Wyoming -0.001067
# 1  Vanderbilt  Vanderbilt  CentralMichigan  0.002906
# 2  Vanderbilt  Vanderbilt       Vanderbilt  0.068084
# 3  Vanderbilt  Vanderbilt             Kent -0.003265
# 4  Vanderbilt  Vanderbilt     ArizonaState -0.006885
# 5  Vanderbilt  Vanderbilt  WashingtonState  0.004396
# 6  Vanderbilt  Vanderbilt        Minnesota  0.000208
# 7  Vanderbilt  Vanderbilt       Cincinnati  0.007941
# 8  Vanderbilt  Vanderbilt    NorthCarolina  0.000492
# the action among the previous actions that maximizes modularity gain is:
# node: Vanderbilt, source: Vanderbilt, destination: Vanderbilt, value: 0.06808438162807469
# ---------------Possible actions for node Kent in phase 4---------------
#    node source      destination     value
# 0  Kent   Kent           Temple  0.005554
# 1  Kent   Kent  CentralMichigan  0.025109
# 2  Kent   Kent       Vanderbilt -0.005777
# 3  Kent   Kent         Nebraska -0.006704
# 4  Kent   Kent             Kent  0.033970
# 5  Kent   Kent        Minnesota  0.002842
# 6  Kent   Kent       Cincinnati -0.000442
# 7  Kent   Kent    NorthCarolina -0.003925
# the action among the previous actions that maximizes modularity gain is:
# node: Kent, source: Kent, destination: Kent, value: 0.03397033815988014
# ---------------Possible actions for node Temple in phase 4---------------
#       node  source      destination     value
# 0   Temple  Temple          Wyoming -0.001142
# 1   Temple  Temple  CentralMichigan  0.001229
# 2   Temple  Temple             Kent  0.006461
# 3   Temple  Temple         Nebraska -0.008377
# 4   Temple  Temple     ArizonaState -0.003728
# 5   Temple  Temple           Temple  0.053799
# 6   Temple  Temple        Minnesota -0.003175
# 7   Temple  Temple  WashingtonState -0.000524
# 8   Temple  Temple      TexasElPaso -0.006129
# 9   Temple  Temple       Cincinnati  0.012771
# 10  Temple  Temple    NorthCarolina  0.005290
# the action among the previous actions that maximizes modularity gain is:
# node: Temple, source: Temple, destination: Temple, value: 0.0537990094978564
# ---------------Possible actions for node WashingtonState in phase 4---------------
#               node           source      destination     value
# 0  WashingtonState  WashingtonState          Wyoming  0.003694
# 1  WashingtonState  WashingtonState  CentralMichigan -0.000088
# 2  WashingtonState  WashingtonState       Vanderbilt  0.001671
# 3  WashingtonState  WashingtonState         Nebraska  0.005958
# 4  WashingtonState  WashingtonState     ArizonaState  0.004112
# 5  WashingtonState  WashingtonState           Temple -0.002211
# 6  WashingtonState  WashingtonState  WashingtonState  0.015302
# 7  WashingtonState  WashingtonState      TexasElPaso  0.001253
# 8  WashingtonState  WashingtonState       Cincinnati  0.000836
# 9  WashingtonState  WashingtonState    NorthCarolina -0.002009
# the action among the previous actions that maximizes modularity gain is:
# node: WashingtonState, source: WashingtonState, destination: WashingtonState, value: 0.015301954126072133
# ---------------Possible actions for node TexasElPaso in phase 4---------------
#           node       source      destination     value
# 0  TexasElPaso  TexasElPaso          Wyoming  0.001607
# 1  TexasElPaso  TexasElPaso           Temple -0.005043
# 2  TexasElPaso  TexasElPaso         Nebraska  0.000303
# 3  TexasElPaso  TexasElPaso     ArizonaState  0.001131
# 4  TexasElPaso  TexasElPaso  WashingtonState  0.003138
# 5  TexasElPaso  TexasElPaso        Minnesota  0.001884
# 6  TexasElPaso  TexasElPaso      TexasElPaso  0.052405
# 7  TexasElPaso  TexasElPaso       Cincinnati  0.000679
# 8  TexasElPaso  TexasElPaso    NorthCarolina -0.003060
# the action among the previous actions that maximizes modularity gain is:
# node: TexasElPaso, source: TexasElPaso, destination: TexasElPaso, value: 0.05240453576532391
# ---------------Possible actions for node Cincinnati in phase 4---------------
#          node      source      destination     value
# 0  Cincinnati  Cincinnati          Wyoming -0.002914
# 1  Cincinnati  Cincinnati           Temple  0.011776
# 2  Cincinnati  Cincinnati       Vanderbilt  0.005259
# 3  Cincinnati  Cincinnati         Nebraska -0.003872
# 4  Cincinnati  Cincinnati             Kent -0.000471
# 5  Cincinnati  Cincinnati  WashingtonState  0.001639
# 6  Cincinnati  Cincinnati        Minnesota  0.002483
# 7  Cincinnati  Cincinnati      TexasElPaso -0.000950
# 8  Cincinnati  Cincinnati       Cincinnati  0.035256
# 9  Cincinnati  Cincinnati    NorthCarolina -0.004213
# the action among the previous actions that maximizes modularity gain is:
# node: Cincinnati, source: Cincinnati, destination: Cincinnati, value: 0.035255702306470196
# displayed possible actions for all the nodes in phase: 4
# ----------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
for g in louvain.graph_history:
    plt.figure(figsize=(12, 7))
    nx.draw(
            g,
            with_labels=True,
            alpha=0.9,
            pos=nx.spring_layout(g, k=0.9),
            node_color='skyblue',
            node_size=4000,
            font_size=8, 
            font_color='black', 
            font_weight='bold',
            edge_color='red', width=1
            )
    plt.show()

# %%
# we need a way to map the fina obtained communities to the group truth
# this is doable
football_graph = nx.read_gml('./../data/evaluation/DataSets/réels/football/football.gml')
