# %% [markdown]
#     ## Provided Dataset Evaluation

# %% [markdown]
#     ## Provided Dataset Evaluation

# %%
import numpy as np
import networkx as nx
import pandas as pd
from utils.louvain4 import LouvainMachine

# %%
# read the provided dataset
gml_file_path = \
'./../../dataset_generation/data/evaluation/DataSets/réels/football/football.gml'
G = nx.read_gml(gml_file_path)

# %%
louvain = LouvainMachine(G)

# %%
louvain.solve_communities()
# Out:
# neighbor communities ['Wyoming', 'NevadaLasVegas', 'ColoradoState', 'Syracuse', 'AirForce', 'UtahState', 'FloridaState', 'MississippiState', 'Virginia', 'Utah', 'NewMexico', 'SanDiegoState']
# node: BrighamYoung, source: BrighamYoung, destination: Wyoming, value: 0.0016313213703099511
# choosing maximum action >>>>node: BrighamYoung, source: BrighamYoung, destination: Wyoming, value: 0.0016313213703099511
# neighbor communities ['Wyoming', 'Duke', 'Clemson', 'WakeForest', 'NorthCarolinaState', 'Maryland', 'NorthCarolina', 'GeorgiaTech', 'Virginia', 'MiamiFlorida', 'Louisville', 'Florida']
# node: FloridaState, source: FloridaState, destination: Duke, value: 0.0016313213703099511
# choosing maximum action >>>>node: FloridaState, source: FloridaState, destination: Duke, value: 0.0016313213703099511
# neighbor communities ['Wisconsin', 'Minnesota', 'IowaState', 'MichiganState', 'Northwestern', 'WesternMichigan', 'Indiana', 'OhioState', 'Nebraska', 'KansasState', 'Illinois', 'PennState']
# node: Iowa, source: Iowa, destination: Wisconsin, value: 0.0016313213703099511
# choosing maximum action >>>>node: Iowa, source: Iowa, destination: Wisconsin, value: 0.0016313213703099511
# neighbor communities ['Colorado', 'Wisconsin', 'IowaState', 'BallState', 'Kansas', 'NorthTexas', 'TexasA&M', 'Oklahoma', 'Missouri', 'LouisianaTech', 'TexasTech', 'Nebraska']
# node: KansasState, source: KansasState, destination: Colorado, value: 0.0016313213703099511
# choosing maximum action >>>>node: KansasState, source: KansasState, destination: Colorado, value: 0.0016313213703099511
# neighbor communities ['Wyoming', 'NewMexicoState', 'NevadaLasVegas', 'BoiseState', 'ColoradoState', 'AirForce', 'TexasTech', 'OregonState', 'Utah', 'SanDiegoState']
# node: NewMexico, source: NewMexico, destination: Wyoming, value: 0.003233369437074373
# choosing maximum action >>>>node: NewMexico, source: NewMexico, destination: Wyoming, value: 0.003233369437074373
# neighbor communities ['Wyoming', 'Colorado', 'Oklahoma', 'Texas', 'Kansas', 'TexasA&M', 'Baylor', 'NorthTexas', 'OklahomaState', 'LouisianaLafayette', 'UtahState', 'Nebraska']
# node: TexasTech, source: TexasTech, destination: Oklahoma, value: 0.0016313213703099511
# choosing maximum action >>>>node: TexasTech, source: TexasTech, destination: Oklahoma, value: 0.0016313213703099511
# neighbor communities ['Wisconsin', 'Michigan', 'MichiganState', 'Purdue', 'LouisianaTech', 'Toledo', 'Minnesota', 'SouthernCalifornia', 'Indiana', 'Pittsburgh', 'OhioState', 'Illinois']
# node: PennState, source: PennState, destination: Michigan, value: 0.0016313213703099511
# choosing maximum action >>>>node: PennState, source: PennState, destination: Michigan, value: 0.0016313213703099511
# neighbor communities ['Oregon', 'Arizona', 'WashingtonState', 'Colorado', 'Michigan', 'ArizonaState', 'California', 'Stanford', 'OregonState', 'UCLA', 'NotreDame', 'SanJoseState']
# node: SouthernCalifornia, source: SouthernCalifornia, destination: Oregon, value: 0.0016313213703099511
# choosing maximum action >>>>node: SouthernCalifornia, source: SouthernCalifornia, destination: Oregon, value: 0.0016313213703099511
# neighbor communities ['Oregon', 'Arizona', 'WashingtonState', 'Washington', 'ColoradoState', 'California', 'Stanford', 'UtahState', 'UCLA', 'SanDiegoState']
# node: ArizonaState, source: ArizonaState, destination: Oregon, value: 0.003233369437074373
# choosing maximum action >>>>node: ArizonaState, source: ArizonaState, destination: Oregon, value: 0.003233369437074373
# neighbor communities ['Wyoming', 'Oregon', 'Arizona', 'NevadaLasVegas', 'ColoradoState', 'AirForce', 'OregonState', 'Utah', 'Illinois']
# node: SanDiegoState, source: SanDiegoState, destination: Wyoming, value: 0.004806144200293265
# choosing maximum action >>>>node: SanDiegoState, source: SanDiegoState, destination: Wyoming, value: 0.004806144200293265
# neighbor communities ['Oklahoma', 'IowaState', 'Texas', 'TexasA&M', 'NorthTexas', 'OklahomaState', 'Missouri', 'Minnesota', 'Nebraska']
# node: Baylor, source: Baylor, destination: Oklahoma, value: 0.003236030646487603
# choosing maximum action >>>>node: Baylor, source: Baylor, destination: Oklahoma, value: 0.003236030646487603
# neighbor communities ['NewMexicoState', 'Colorado', 'Oklahoma', 'NevadaLasVegas', 'BoiseState', 'LouisianaLafayette', 'UtahState', 'ArkansasState', 'Idaho']
# node: NorthTexas, source: NorthTexas, destination: Oklahoma, value: 0.003182806458223004
# choosing maximum action >>>>node: NorthTexas, source: NorthTexas, destination: Oklahoma, value: 0.003182806458223004
# neighbor communities ['BallState', 'EasternMichigan', 'Akron', 'Northwestern', 'CentralFlorida', 'Buffalo', 'Toledo', 'WesternMichigan', 'Auburn', 'CentralMichigan']
# node: NorthernIllinois, source: NorthernIllinois, destination: BallState, value: 0.0016313213703099511
# choosing maximum action >>>>node: NorthernIllinois, source: NorthernIllinois, destination: BallState, value: 0.0016313213703099511
# neighbor communities ['Duke', 'Wisconsin', 'BallState', 'Michigan', 'MichiganState', 'Purdue', 'Indiana', 'Minnesota', 'TexasChristian', 'Illinois']
# node: Northwestern, source: Northwestern, destination: Wisconsin, value: 0.003233369437074373
# choosing maximum action >>>>node: Northwestern, source: Northwestern, destination: Wisconsin, value: 0.003233369437074373
# neighbor communities ['Wisconsin', 'BallState', 'EasternMichigan', 'Ohio', 'Kent', 'Toledo', 'Marshall', 'CentralMichigan']
# node: WesternMichigan, source: WesternMichigan, destination: BallState, value: 0.003236030646487603
# choosing maximum action >>>>node: WesternMichigan, source: WesternMichigan, destination: BallState, value: 0.003236030646487603
# neighbor communities ['Oregon', 'Wisconsin', 'BallState', 'Michigan', 'Cincinnati', 'MichiganState', 'Hawaii', 'Purdue', 'Minnesota', 'Indiana', 'OhioState']
# node: Wisconsin, source: Wisconsin, destination: Wisconsin, value: 0.0031668392017436247
# choosing maximum action >>>>node: Wisconsin, source: Wisconsin, destination: Wisconsin, value: 0.0031668392017436247
# neighbor communities ['Wyoming', 'NevadaLasVegas', 'Nevada', 'TexasA&M', 'ColoradoState', 'AirForce', 'Utah', 'Auburn', 'CentralMichigan']
# node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.0047183242896566766
# choosing maximum action >>>>node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.0047183242896566766
# neighbor communities ['Wyoming', 'BallState', 'LouisianaState', 'Mississippi', 'LouisianaTech', 'Alabama', 'Arkansas', 'MississippiState', 'Georgia', 'Vanderbilt', 'Florida']
# node: Auburn, source: Auburn, destination: LouisianaState, value: 0.0016313213703099511
# choosing maximum action >>>>node: Auburn, source: Auburn, destination: LouisianaState, value: 0.0016313213703099511
# neighbor communities ['BowlingGreenState', 'Connecticut', 'BallState', 'Ohio', 'CentralFlorida', 'Kent', 'Buffalo', 'VirginiaTech', 'Marshall', 'MiamiOhio', 'CentralMichigan']
# node: Akron, source: Akron, destination: BowlingGreenState, value: 0.0016313213703099511
# choosing maximum action >>>>node: Akron, source: Akron, destination: BowlingGreenState, value: 0.0016313213703099511
# neighbor communities ['BowlingGreenState', 'Rutgers', 'BostonCollege', 'WestVirginia', 'EastCarolina', 'CentralFlorida', 'Temple', 'Virginia', 'MiamiFlorida', 'Pittsburgh', 'Syracuse']
# node: VirginiaTech, source: VirginiaTech, destination: Rutgers, value: 0.0016313213703099511
# choosing maximum action >>>>node: VirginiaTech, source: VirginiaTech, destination: Rutgers, value: 0.0016313213703099511
# neighbor communities ['SouthernMississippi', 'Mississippi', 'CentralFlorida', 'Tennessee', 'Arkansas', 'MississippiState', 'UCLA', 'SouthCarolina', 'LouisianaState', 'Vanderbilt']
# node: Alabama, source: Alabama, destination: LouisianaState, value: 0.003233369437074373
# choosing maximum action >>>>node: Alabama, source: Alabama, destination: LouisianaState, value: 0.003233369437074373
# neighbor communities ['Oregon', 'Arizona', 'Washington', 'Michigan', 'California', 'Stanford', 'OregonState', 'FresnoState', 'LouisianaState']
# node: UCLA, source: UCLA, destination: Oregon, value: 0.004806144200293265
# choosing maximum action >>>>node: UCLA, source: UCLA, destination: Oregon, value: 0.004806144200293265
# neighbor communities ['Oregon', 'Wyoming', 'WashingtonState', 'Washington', 'Stanford', 'OregonState', 'Utah', 'OhioState']
# node: Arizona, source: Arizona, destination: Oregon, value: 0.006349645659966628
# choosing maximum action >>>>node: Arizona, source: Arizona, destination: Oregon, value: 0.006349645659966628
# neighbor communities ['Wyoming', 'Oregon', 'WashingtonState', 'NevadaLasVegas', 'ColoradoState', 'AirForce', 'California', 'UtahState']
# node: Utah, source: Utah, destination: Wyoming, value: 0.006349645659966628
# choosing maximum action >>>>node: Utah, source: Utah, destination: Wyoming, value: 0.006349645659966628
# neighbor communities ['NewMexicoState', 'Oklahoma', 'NorthCarolinaState', 'Memphis', 'Mississippi', 'BoiseState', 'UtahState', 'Idaho', 'TexasChristian']
# node: ArkansasState, source: ArkansasState, destination: Oklahoma, value: 0.0031295822699584056
# choosing maximum action >>>>node: ArkansasState, source: ArkansasState, destination: Oklahoma, value: 0.0031295822699584056
# neighbor communities ['Duke', 'Clemson', 'Oklahoma', 'WakeForest', 'SouthernMethodist', 'Maryland', 'NorthCarolina', 'GeorgiaTech', 'Virginia', 'Indiana']
# node: NorthCarolinaState, source: NorthCarolinaState, destination: Duke, value: 0.003233369437074373
# choosing maximum action >>>>node: NorthCarolinaState, source: NorthCarolinaState, destination: Duke, value: 0.003233369437074373
# neighbor communities ['Connecticut', 'Colorado', 'BallState', 'EasternMichigan', 'Buffalo', 'Toledo', 'MiamiOhio', 'Florida', 'CentralMichigan']
# node: BallState, source: BallState, destination: BallState, value: 0.003182806458223004
# choosing maximum action >>>>node: BallState, source: BallState, destination: BallState, value: 0.003182806458223004
# neighbor communities ['Duke', 'BallState', 'MiddleTennesseeState', 'Tennessee', 'MississippiState', 'SouthCarolina', 'Georgia', 'LouisianaState', 'Vanderbilt', 'Kentucky']
# node: Florida, source: Florida, destination: LouisianaState, value: 0.003174822829983314
# choosing maximum action >>>>node: Florida, source: Florida, destination: LouisianaState, value: 0.003174822829983314
# neighbor communities ['Wyoming', 'NewMexicoState', 'WashingtonState', 'Oklahoma', 'UtahState', 'Arkansas', 'Idaho', 'CentralMichigan']
# node: BoiseState, source: BoiseState, destination: Oklahoma, value: 0.0030949865475864164
# choosing maximum action >>>>node: BoiseState, source: BoiseState, destination: Oklahoma, value: 0.0030949865475864164
# neighbor communities ['Rutgers', 'WestVirginia', 'Connecticut', 'Army', 'Navy', 'Temple', 'NotreDame', 'MiamiFlorida', 'Pittsburgh', 'Syracuse']
# node: BostonCollege, source: BostonCollege, destination: Rutgers, value: 0.003233369437074373
# choosing maximum action >>>>node: BostonCollege, source: BostonCollege, destination: Rutgers, value: 0.003233369437074373
# neighbor communities ['Rutgers', 'EastCarolina', 'Maryland', 'Temple', 'NotreDame', 'MiamiFlorida', 'Idaho', 'Pittsburgh', 'Syracuse']
# node: WestVirginia, source: WestVirginia, destination: Rutgers, value: 0.004806144200293265
# choosing maximum action >>>>node: WestVirginia, source: WestVirginia, destination: Rutgers, value: 0.004806144200293265
# neighbor communities ['BowlingGreenState', 'EasternMichigan', 'Michigan', 'Ohio', 'Kent', 'Buffalo', 'Temple', 'Toledo', 'Marshall', 'Pittsburgh', 'MiamiOhio']
# node: BowlingGreenState, source: BowlingGreenState, destination: EasternMichigan, value: 0.0016313213703099511
# choosing maximum action >>>>node: BowlingGreenState, source: BowlingGreenState, destination: EasternMichigan, value: 0.0016313213703099511
# neighbor communities ['Oregon', 'Wisconsin', 'EasternMichigan', 'Michigan', 'MichiganState', 'Purdue', 'Rice', 'Indiana', 'OhioState', 'Illinois']
# node: Michigan, source: Michigan, destination: Wisconsin, value: 0.003174822829983314
# choosing maximum action >>>>node: Michigan, source: Michigan, destination: Wisconsin, value: 0.003174822829983314
# neighbor communities ['Wyoming', 'Rutgers', 'Duke', 'Clemson', 'WakeForest', 'Maryland', 'NorthCarolina', 'GeorgiaTech']
# node: Virginia, source: Virginia, destination: Duke, value: 0.0048141278285329546
# choosing maximum action >>>>node: Virginia, source: Virginia, destination: Duke, value: 0.0048141278285329546
# neighbor communities ['BowlingGreenState', 'Rutgers', 'Connecticut', 'BallState', 'EasternMichigan', 'Ohio', 'Kent', 'Marshall', 'MiamiOhio', 'Syracuse']
# node: Buffalo, source: Buffalo, destination: BallState, value: 0.003174822829983314
# choosing maximum action >>>>node: Buffalo, source: Buffalo, destination: BallState, value: 0.003174822829983314
# neighbor communities ['Wyoming', 'Rutgers', 'EastCarolina', 'BallState', 'Cincinnati', 'Temple', 'MiamiFlorida', 'Pittsburgh']
# node: Syracuse, source: Syracuse, destination: Rutgers, value: 0.006349645659966628
# choosing maximum action >>>>node: Syracuse, source: Syracuse, destination: Rutgers, value: 0.006349645659966628
# neighbor communities ['BowlingGreenState', 'Rutgers', 'BallState', 'EasternMichigan', 'LouisianaTech', 'GeorgiaTech', 'LouisianaState', 'LouisianaMonroe']
# node: CentralFlorida, source: CentralFlorida, destination: BowlingGreenState, value: 0.0016313213703099511
# choosing maximum action >>>>node: CentralFlorida, source: CentralFlorida, destination: BowlingGreenState, value: 0.0016313213703099511
# neighbor communities ['BowlingGreenState', 'Duke', 'Clemson', 'WakeForest', 'Maryland', 'Navy', 'NorthCarolina', 'Georgia']
# node: GeorgiaTech, source: GeorgiaTech, destination: Duke, value: 0.006349645659966628
# choosing maximum action >>>>node: GeorgiaTech, source: GeorgiaTech, destination: Duke, value: 0.006349645659966628
# neighbor communities ['Wyoming', 'BowlingGreenState', 'Oklahoma', 'BallState', 'EasternMichigan', 'Ohio', 'Purdue', 'Kent', 'Toledo']
# node: CentralMichigan, source: CentralMichigan, destination: BallState, value: 0.004747597593202206
# choosing maximum action >>>>node: CentralMichigan, source: CentralMichigan, destination: BallState, value: 0.004747597593202206
# neighbor communities ['Wisconsin', 'BallState', 'Michigan', 'MichiganState', 'Kent', 'NotreDame', 'Minnesota', 'Indiana', 'OhioState']
# node: Purdue, source: Purdue, destination: Wisconsin, value: 0.004747597593202206
# choosing maximum action >>>>node: Purdue, source: Purdue, destination: Wisconsin, value: 0.004747597593202206
# neighbor communities ['Oregon', 'Colorado', 'Washington', 'IowaState', 'Kansas', 'TexasA&M', 'Texas', 'OklahomaState', 'ColoradoState', 'Missouri', 'Nebraska']
# node: Colorado, source: Colorado, destination: Washington, value: 0.0016313213703099511
# choosing maximum action >>>>node: Colorado, source: Colorado, destination: Washington, value: 0.0016313213703099511
# neighbor communities ['Wyoming', 'Oregon', 'Washington', 'Nevada', 'NevadaLasVegas', 'AirForce']
# node: ColoradoState, source: ColoradoState, destination: Wyoming, value: 0.007890485910226761
# choosing maximum action >>>>node: ColoradoState, source: ColoradoState, destination: Wyoming, value: 0.007890485910226761
# neighbor communities ['BowlingGreenState', 'Rutgers', 'BallState', 'EasternMichigan', 'MiddleTennesseeState', 'Louisville']
# node: Connecticut, source: Connecticut, destination: BallState, value: 0.0031136150134790258
# choosing maximum action >>>>node: Connecticut, source: Connecticut, destination: BallState, value: 0.0031136150134790258
# neighbor communities ['BowlingGreenState', 'BallState', 'EasternMichigan', 'Toledo', 'Temple', 'SouthCarolina', 'MiamiOhio']
# node: EasternMichigan, source: EasternMichigan, destination: BallState, value: 0.007863873816094461
# choosing maximum action >>>>node: EasternMichigan, source: EasternMichigan, destination: BallState, value: 0.007863873816094461
# neighbor communities ['Rutgers', 'Duke', 'Army', 'SouthernMississippi', 'Memphis', 'Houston', 'Tulane', 'Louisville', 'AlabamaBirmingham']
# node: EastCarolina, source: EastCarolina, destination: Rutgers, value: 0.00460123107547456
# choosing maximum action >>>>node: EastCarolina, source: EastCarolina, destination: Rutgers, value: 0.00460123107547456
# neighbor communities ['Rutgers', 'Duke', 'Clemson', 'Wisconsin', 'WakeForest', 'Maryland', 'NorthCarolina', 'Vanderbilt']
# node: Duke, source: Duke, destination: Duke, value: 0.0062325524457845114
# choosing maximum action >>>>node: Duke, source: Duke, destination: Duke, value: 0.0062325524457845114
# neighbor communities ['Oregon', 'Nevada', 'SouthernMethodist', 'Tulsa', 'TexasElPaso', 'California', 'Hawaii', 'Rice', 'SanJoseState', 'OhioState', 'TexasChristian']
# node: FresnoState, source: FresnoState, destination: Nevada, value: 0.0016313213703099511
# choosing maximum action >>>>node: FresnoState, source: FresnoState, destination: Nevada, value: 0.0016313213703099511
# neighbor communities ['Oregon', 'Wisconsin', 'Nevada', 'Michigan', 'MichiganState', 'Illinois', 'Minnesota', 'MiamiOhio']
# node: OhioState, source: OhioState, destination: Wisconsin, value: 0.00629109905287557
# choosing maximum action >>>>node: OhioState, source: OhioState, destination: Wisconsin, value: 0.00629109905287557
# neighbor communities ['Rutgers', 'Texas', 'Army', 'SouthernMississippi', 'Memphis', 'SouthernMethodist', 'Cincinnati', 'Tulane', 'Rice', 'LouisianaState', 'Louisville']
# node: Houston, source: Houston, destination: Texas, value: 0.0016313213703099511
# choosing maximum action >>>>node: Houston, source: Houston, destination: Texas, value: 0.0016313213703099511
# neighbor communities ['Texas', 'Wisconsin', 'Nevada', 'Oklahoma', 'SouthernMethodist', 'Tulsa', 'TexasElPaso', 'Hawaii', 'SanJoseState', 'TexasChristian']
# node: Rice, source: Rice, destination: Nevada, value: 0.003233369437074373
# choosing maximum action >>>>node: Rice, source: Rice, destination: Nevada, value: 0.003233369437074373
# neighbor communities ['Rutgers', 'Oregon', 'NewMexicoState', 'WashingtonState', 'Washington', 'Oklahoma', 'UtahState']
# node: Idaho, source: Idaho, destination: Oklahoma, value: 0.004678406148458228
# choosing maximum action >>>>node: Idaho, source: Idaho, destination: Oklahoma, value: 0.004678406148458228
# neighbor communities ['Oregon', 'WashingtonState', 'Oklahoma', 'Washington', 'California', 'Stanford', 'OregonState', 'MiamiFlorida']
# node: Washington, source: Washington, destination: Oregon, value: 0.0062325524457845114
# choosing maximum action >>>>node: Washington, source: Washington, destination: Oregon, value: 0.0062325524457845114
# neighbor communities ['Colorado', 'Washington', 'Oklahoma', 'IowaState', 'Texas', 'SouthernMethodist', 'Missouri', 'Nebraska', 'AlabamaBirmingham']
# node: Kansas, source: Kansas, destination: Oklahoma, value: 0.00294329761103231
# choosing maximum action >>>>node: Kansas, source: Kansas, destination: Oklahoma, value: 0.00294329761103231
# neighbor communities ['Duke', 'Oklahoma', 'Texas', 'Nevada', 'Tulsa', 'TexasElPaso', 'Hawaii', 'SanJoseState', 'Tulane', 'TexasChristian']
# node: SouthernMethodist, source: SouthernMethodist, destination: Nevada, value: 0.004798160572053575
# choosing maximum action >>>>node: SouthernMethodist, source: SouthernMethodist, destination: Nevada, value: 0.004798160572053575
# neighbor communities ['BowlingGreenState', 'Wisconsin', 'BallState', 'EasternMichigan', 'Ohio', 'Marshall', 'Pittsburgh', 'MiamiOhio']
# node: Kent, source: Kent, destination: BallState, value: 0.004494782698945363
# choosing maximum action >>>>node: Kent, source: Kent, destination: BallState, value: 0.004494782698945363
# neighbor communities ['Rutgers', 'BallState', 'EasternMichigan', 'Michigan', 'NorthCarolina', 'Temple', 'MiamiFlorida']
# node: Pittsburgh, source: Pittsburgh, destination: Rutgers, value: 0.007776053905457873
# choosing maximum action >>>>node: Pittsburgh, source: Pittsburgh, destination: Rutgers, value: 0.007776053905457873
# neighbor communities ['Mississippi', 'Tennessee', 'MississippiState', 'SouthCarolina', 'Indiana', 'Georgia', 'LouisianaState', 'Louisville', 'Vanderbilt']
# node: Kentucky, source: Kentucky, destination: LouisianaState, value: 0.0031295822699584056
# choosing maximum action >>>>node: Kentucky, source: Kentucky, destination: LouisianaState, value: 0.0031295822699584056
# neighbor communities ['Rutgers', 'Duke', 'Texas', 'Army', 'BallState', 'SouthernMississippi', 'Cincinnati', 'LouisianaState', 'Tulane', 'AlabamaBirmingham']
# node: Louisville, source: Louisville, destination: Army, value: 0.0016313213703099511
# choosing maximum action >>>>node: Louisville, source: Louisville, destination: Army, value: 0.0016313213703099511
# neighbor communities ['BowlingGreenState', 'Colorado', 'MiddleTennesseeState', 'Michigan', 'Tulsa', 'LouisianaLafayette', 'MiamiFlorida', 'Hawaii', 'LouisianaState', 'LouisianaMonroe']
# node: LouisianaTech, source: LouisianaTech, destination: Colorado, value: 0.0016313213703099511
# choosing maximum action >>>>node: LouisianaTech, source: LouisianaTech, destination: Colorado, value: 0.0016313213703099511
# neighbor communities ['BowlingGreenState', 'Colorado', 'MiddleTennesseeState', 'Memphis', 'LouisianaLafayette', 'Tennessee', 'Arkansas', 'Minnesota']
# node: LouisianaMonroe, source: LouisianaMonroe, destination: MiddleTennesseeState, value: 0.0016313213703099511
# choosing maximum action >>>>node: LouisianaMonroe, source: LouisianaMonroe, destination: MiddleTennesseeState, value: 0.0016313213703099511
# neighbor communities ['Oklahoma', 'Wisconsin', 'MiddleTennesseeState', 'Michigan', 'Ohio', 'Indiana', 'Illinois']
# node: Minnesota, source: Minnesota, destination: Wisconsin, value: 0.007805327209003403
# choosing maximum action >>>>node: Minnesota, source: Minnesota, destination: Wisconsin, value: 0.007805327209003403
# neighbor communities ['BowlingGreenState', 'Wisconsin', 'BallState', 'EasternMichigan', 'Cincinnati', 'Ohio', 'Marshall', 'Vanderbilt']
# node: MiamiOhio, source: MiamiOhio, destination: BallState, value: 0.005998366017420277
# choosing maximum action >>>>node: MiamiOhio, source: MiamiOhio, destination: BallState, value: 0.005998366017420277
# neighbor communities ['Duke', 'WakeForest', 'BallState', 'Mississippi', 'Tennessee', 'SouthCarolina', 'Georgia', 'LouisianaState']
# node: Vanderbilt, source: Vanderbilt, destination: LouisianaState, value: 0.0063203723564210995
# choosing maximum action >>>>node: Vanderbilt, source: Vanderbilt, destination: LouisianaState, value: 0.0063203723564210995
# neighbor communities ['Colorado', 'BallState', 'MiddleTennesseeState', 'Maryland', 'LouisianaLafayette', 'MississippiState', 'LouisianaState', 'Illinois', 'AlabamaBirmingham']
# node: MiddleTennesseeState, source: MiddleTennesseeState, destination: Maryland, value: 0.0016313213703099511
# choosing maximum action >>>>node: MiddleTennesseeState, source: MiddleTennesseeState, destination: Maryland, value: 0.0016313213703099511
# neighbor communities ['Wyoming', 'Wisconsin', 'Michigan', 'MichiganState', 'Maryland', 'California', 'Indiana']
# node: Illinois, source: Illinois, destination: Wisconsin, value: 0.0076589606912757565
# choosing maximum action >>>>node: Illinois, source: Illinois, destination: Wisconsin, value: 0.0076589606912757565
# neighbor communities ['Wyoming', 'Memphis', 'Mississippi', 'Maryland', 'Arkansas', 'SouthCarolina', 'LouisianaState']
# node: MississippiState, source: MississippiState, destination: LouisianaState, value: 0.007834600512548933
# choosing maximum action >>>>node: MississippiState, source: MississippiState, destination: LouisianaState, value: 0.007834600512548933
# neighbor communities ['Rutgers', 'Texas', 'Oklahoma', 'SouthernMississippi', 'MiddleTennesseeState', 'Army', 'Cincinnati', 'Tennessee', 'LouisianaState', 'Tulane', 'AlabamaBirmingham']
# node: Memphis, source: Memphis, destination: SouthernMississippi, value: 0.0016313213703099511
# choosing maximum action >>>>node: Memphis, source: Memphis, destination: SouthernMississippi, value: 0.0016313213703099511
# neighbor communities ['Wyoming', 'Oregon', 'NevadaLasVegas', 'Nevada', 'Tulsa', 'TexasElPaso', 'Hawaii', 'SanJoseState', 'TexasChristian']
# node: Nevada, source: Nevada, destination: Nevada, value: 0.004702357033177298
# choosing maximum action >>>>node: Nevada, source: Nevada, destination: Nevada, value: 0.004702357033177298
# neighbor communities ['Oregon', 'WashingtonState', 'Oklahoma', 'Wisconsin', 'Nevada', 'California', 'OregonState']
# node: Oregon, source: Oregon, destination: Oregon, value: 0.007746780601912345
# choosing maximum action >>>>node: Oregon, source: Oregon, destination: Oregon, value: 0.007746780601912345
# neighbor communities ['Wyoming', 'Oklahoma', 'Army', 'Tulsa', 'TexasElPaso', 'UtahState', 'SouthCarolina', 'Georgia']
# node: NewMexicoState, source: NewMexicoState, destination: Oklahoma, value: 0.0061154592316023946
# choosing maximum action >>>>node: NewMexicoState, source: NewMexicoState, destination: Oklahoma, value: 0.0061154592316023946
# neighbor communities ['Clemson', 'Oklahoma', 'BallState', 'Tennessee', 'Arkansas', 'Georgia', 'LouisianaState']
# node: SouthCarolina, source: SouthCarolina, destination: LouisianaState, value: 0.007688233994821286
# choosing maximum action >>>>node: SouthCarolina, source: SouthCarolina, destination: LouisianaState, value: 0.007688233994821286
# neighbor communities ['BowlingGreenState', 'Wisconsin', 'IowaState', 'BallState', 'EasternMichigan', 'Marshall']
# node: Ohio, source: Ohio, destination: BallState, value: 0.007571140780639168
# choosing maximum action >>>>node: Ohio, source: Ohio, destination: BallState, value: 0.007571140780639168
# neighbor communities ['Colorado', 'Washington', 'Oklahoma', 'BallState', 'Wisconsin', 'TexasA&M', 'NevadaLasVegas', 'OklahomaState', 'Missouri', 'Nebraska']
# node: IowaState, source: IowaState, destination: Oklahoma, value: 0.002735723276800375
# choosing maximum action >>>>node: IowaState, source: IowaState, destination: Oklahoma, value: 0.002735723276800375
# neighbor communities ['Oregon', 'Nevada', 'Tulsa', 'TexasElPaso', 'Stanford', 'Hawaii', 'Nebraska', 'TexasChristian']
# node: SanJoseState, source: SanJoseState, destination: Nevada, value: 0.006349645659966628
# choosing maximum action >>>>node: SanJoseState, source: SanJoseState, destination: Nevada, value: 0.006349645659966628
# neighbor communities ['Colorado', 'Washington', 'Oklahoma', 'Wisconsin', 'Nevada', 'NotreDame', 'Missouri']
# node: Nebraska, source: Nebraska, destination: Oklahoma, value: 0.007571140780639168
# choosing maximum action >>>>node: Nebraska, source: Nebraska, destination: Oklahoma, value: 0.007571140780639168
# neighbor communities ['Rutgers', 'Texas', 'Army', 'SouthernMississippi', 'OklahomaState', 'Cincinnati', 'Tennessee', 'LouisianaState', 'Tulane', 'AlabamaBirmingham']
# node: SouthernMississippi, source: SouthernMississippi, destination: OklahomaState, value: 0.0016313213703099511
# choosing maximum action >>>>node: SouthernMississippi, source: SouthernMississippi, destination: OklahomaState, value: 0.0016313213703099511
# neighbor communities ['OklahomaState', 'SouthernMississippi', 'MiddleTennesseeState', 'Arkansas', 'Georgia', 'LouisianaState']
# node: Tennessee, source: Tennessee, destination: LouisianaState, value: 0.00917318884740359
# choosing maximum action >>>>node: Tennessee, source: Tennessee, destination: LouisianaState, value: 0.00917318884740359
# neighbor communities ['Oregon', 'WashingtonState', 'Texas', 'Nevada', 'California', 'OregonState', 'NotreDame']
# node: Stanford, source: Stanford, destination: Oregon, value: 0.007746780601912345
# choosing maximum action >>>>node: Stanford, source: Stanford, destination: Oregon, value: 0.007746780601912345
# neighbor communities ['Oregon', 'Wyoming', 'Oklahoma', 'California', 'OregonState']
# node: WashingtonState, source: WashingtonState, destination: Oregon, value: 0.009231735454494648
# choosing maximum action >>>>node: WashingtonState, source: WashingtonState, destination: Oregon, value: 0.009231735454494648
# neighbor communities ['Rutgers', 'BallState', 'EasternMichigan', 'Maryland', 'Navy', 'MiamiFlorida']
# node: Temple, source: Temple, destination: Rutgers, value: 0.009261008758040179
# choosing maximum action >>>>node: Temple, source: Temple, destination: Rutgers, value: 0.009261008758040179
# neighbor communities ['Rutgers', 'Duke', 'WakeForest', 'Army', 'AirForce', 'Toledo', 'NotreDame', 'Tulane', 'TexasChristian']
# node: Navy, source: Navy, destination: Rutgers, value: 0.00419140482583715
# choosing maximum action >>>>node: Navy, source: Navy, destination: Rutgers, value: 0.00419140482583715
# neighbor communities ['Wyoming', 'Colorado', 'Washington', 'Oklahoma', 'Texas', 'OklahomaState', 'TexasElPaso', 'NotreDame']
# node: TexasA&M, source: TexasA&M, destination: Oklahoma, value: 0.005793452892601572
# choosing maximum action >>>>node: TexasA&M, source: TexasA&M, destination: Oklahoma, value: 0.005793452892601572
# neighbor communities ['Oregon', 'Rutgers', 'Wisconsin', 'Oklahoma', 'AirForce', 'MichiganState']
# node: NotreDame, source: NotreDame, destination: Rutgers, value: 0.005734906285510513
# choosing maximum action >>>>node: NotreDame, source: NotreDame, destination: Rutgers, value: 0.005734906285510513
# neighbor communities ['Oklahoma', 'Nevada', 'Tulsa', 'Hawaii', 'TexasChristian']
# node: TexasElPaso, source: TexasElPaso, destination: Nevada, value: 0.007863873816094461
# choosing maximum action >>>>node: TexasElPaso, source: TexasElPaso, destination: Nevada, value: 0.007863873816094461
# neighbor communities ['Colorado', 'OklahomaState', 'Texas', 'Oklahoma', 'Nevada']
# node: Oklahoma, source: Oklahoma, destination: Oklahoma, value: 0.008939002419039355
# choosing maximum action >>>>node: Oklahoma, source: Oklahoma, destination: Oklahoma, value: 0.008939002419039355
# neighbor communities ['Rutgers', 'BallState', 'EasternMichigan', 'Michigan', 'Marshall']
# node: Toledo, source: Toledo, destination: BallState, value: 0.00750993296413488
# choosing maximum action >>>>node: Toledo, source: Toledo, destination: BallState, value: 0.00750993296413488
# neighbor communities ['Rutgers', 'Texas', 'Army', 'SouthernMississippi', 'Nevada', 'OklahomaState', 'Mississippi', 'Cincinnati', 'LouisianaLafayette']
# node: Tulane, source: Tulane, destination: Army, value: 0.003233369437074373
# choosing maximum action >>>>node: Tulane, source: Tulane, destination: Army, value: 0.003233369437074373
# neighbor communities ['NevadaLasVegas', 'Oklahoma', 'Army', 'Arkansas', 'Georgia', 'LouisianaState']
# node: Mississippi, source: Mississippi, destination: LouisianaState, value: 0.008997549026130414
# choosing maximum action >>>>node: Mississippi, source: Mississippi, destination: LouisianaState, value: 0.008997549026130414
# neighbor communities ['Colorado', 'OklahomaState', 'Oklahoma', 'Nevada', 'NorthCarolina', 'Hawaii', 'TexasChristian']
# node: Tulsa, source: Tulsa, destination: Nevada, value: 0.009308910527478316
# choosing maximum action >>>>node: Tulsa, source: Tulsa, destination: Nevada, value: 0.009308910527478316
# neighbor communities ['Rutgers', 'Duke', 'Clemson', 'WakeForest', 'Nevada', 'Maryland', 'Marshall']
# node: NorthCarolina, source: NorthCarolina, destination: Duke, value: 0.007863873816094461
# choosing maximum action >>>>node: NorthCarolina, source: NorthCarolina, destination: Duke, value: 0.007863873816094461
# neighbor communities ['Wyoming', 'Oklahoma', 'Oregon']
# node: UtahState, source: UtahState, destination: Oklahoma, value: 0.009093352565006691
# choosing maximum action >>>>node: UtahState, source: UtahState, destination: Oklahoma, value: 0.009093352565006691
# neighbor communities ['Rutgers', 'Oklahoma', 'Texas', 'SouthernMississippi', 'Army', 'Cincinnati', 'AirForce', 'AlabamaBirmingham']
# node: Army, source: Army, destination: Rutgers, value: 0.003986491701018445
# choosing maximum action >>>>node: Army, source: Army, destination: Rutgers, value: 0.003986491701018445
# neighbor communities ['Rutgers', 'Texas', 'Wisconsin', 'BallState', 'Army', 'SouthernMississippi', 'OklahomaState', 'Indiana', 'AlabamaBirmingham']
# node: Cincinnati, source: Cincinnati, destination: Army, value: 0.003233369437074373
# choosing maximum action >>>>node: Cincinnati, source: Cincinnati, destination: Army, value: 0.003233369437074373
# neighbor communities ['Wyoming', 'Rutgers', 'NevadaLasVegas']
# node: AirForce, source: AirForce, destination: Wyoming, value: 0.009388746809875215
# choosing maximum action >>>>node: AirForce, source: AirForce, destination: Wyoming, value: 0.009388746809875215
# neighbor communities ['Rutgers', 'BallState', 'MiamiFlorida']
# node: Rutgers, source: Rutgers, destination: Rutgers, value: 0.01214575976198143
# choosing maximum action >>>>node: Rutgers, source: Rutgers, destination: Rutgers, value: 0.01214575976198143
# neighbor communities ['LouisianaState', 'Duke', 'Oklahoma', 'Arkansas']
# node: Georgia, source: Georgia, destination: LouisianaState, value: 0.010541050485803779
# choosing maximum action >>>>node: Georgia, source: Georgia, destination: LouisianaState, value: 0.010541050485803779
# neighbor communities ['LouisianaState', 'Arkansas', 'Texas', 'AlabamaBirmingham']
# node: LouisianaState, source: LouisianaState, destination: LouisianaState, value: 0.010354765826877683
# choosing maximum action >>>>node: LouisianaState, source: LouisianaState, destination: LouisianaState, value: 0.010354765826877683
# neighbor communities ['Colorado', 'Oklahoma', 'Army', 'Texas', 'MiddleTennesseeState', 'Maryland', 'AlabamaBirmingham']
# node: LouisianaLafayette, source: LouisianaLafayette, destination: Oklahoma, value: 0.00251750410491552
# choosing maximum action >>>>node: LouisianaLafayette, source: LouisianaLafayette, destination: Oklahoma, value: 0.00251750410491552
# neighbor communities ['Oregon', 'Washington', 'Texas', 'Oklahoma', 'OklahomaState', 'Missouri']
# node: Texas, source: Texas, destination: Oklahoma, value: 0.008704815990675121
# choosing maximum action >>>>node: Texas, source: Texas, destination: Oklahoma, value: 0.008704815990675121
# neighbor communities ['BowlingGreenState', 'Duke', 'BallState', 'EasternMichigan', 'MichiganState']
# node: Marshall, source: Marshall, destination: BallState, value: 0.008936341209626126
# choosing maximum action >>>>node: Marshall, source: Marshall, destination: BallState, value: 0.008936341209626126
# neighbor communities ['Rutgers', 'Wisconsin', 'BallState', 'Michigan', 'Missouri']
# node: MichiganState, source: MichiganState, destination: Wisconsin, value: 0.010775236914168013
# choosing maximum action >>>>node: MichiganState, source: MichiganState, destination: Wisconsin, value: 0.010775236914168013
# neighbor communities ['Rutgers', 'Duke', 'Colorado', 'Oregon']
# node: MiamiFlorida, source: MiamiFlorida, destination: Rutgers, value: 0.01051443839167148
# choosing maximum action >>>>node: MiamiFlorida, source: MiamiFlorida, destination: Rutgers, value: 0.01051443839167148
# neighbor communities ['Colorado', 'Washington', 'Wisconsin', 'Oklahoma', 'Clemson', 'OklahomaState']
# node: Missouri, source: Missouri, destination: Oklahoma, value: 0.007012286803860882
# choosing maximum action >>>>node: Missouri, source: Missouri, destination: Oklahoma, value: 0.007012286803860882
# neighbor communities ['Duke', 'WakeForest', 'Oklahoma', 'Maryland', 'LouisianaState']
# node: Clemson, source: Clemson, destination: Duke, value: 0.009388746809875215
# choosing maximum action >>>>node: Clemson, source: Clemson, destination: Duke, value: 0.009388746809875215
# neighbor communities ['Wyoming', 'Oklahoma', 'Nevada', 'Hawaii', 'LouisianaState']
# node: NevadaLasVegas, source: NevadaLasVegas, destination: Wyoming, value: 0.010748624820035715
# choosing maximum action >>>>node: NevadaLasVegas, source: NevadaLasVegas, destination: Wyoming, value: 0.010748624820035715
# neighbor communities ['Rutgers', 'LouisianaState', 'Duke', 'Maryland']
# node: WakeForest, source: WakeForest, destination: Duke, value: 0.010860395615391372
# choosing maximum action >>>>node: WakeForest, source: WakeForest, destination: Duke, value: 0.010860395615391372
# neighbor communities ['Duke', 'Wisconsin', 'Army', 'Michigan', 'LouisianaState']
# node: Indiana, source: Indiana, destination: Wisconsin, value: 0.010570323789349308
# choosing maximum action >>>>node: Indiana, source: Indiana, destination: Wisconsin, value: 0.010570323789349308
# neighbor communities ['Washington', 'Nevada', 'Oklahoma', 'OklahomaState']
# node: OklahomaState, source: OklahomaState, destination: Oklahoma, value: 0.010141869073819289
# choosing maximum action >>>>node: OklahomaState, source: OklahomaState, destination: Oklahoma, value: 0.010141869073819289
# neighbor communities ['Wyoming', 'California', 'Oregon']
# node: OregonState, source: OregonState, destination: Oregon, value: 0.010753947238862175
# choosing maximum action >>>>node: OregonState, source: OregonState, destination: Oregon, value: 0.010753947238862175
# neighbor communities ['Rutgers', 'Duke', 'Maryland']
# node: Maryland, source: Maryland, destination: Duke, value: 0.012230918463204789
# choosing maximum action >>>>node: Maryland, source: Maryland, destination: Duke, value: 0.012230918463204789
# neighbor communities ['Rutgers', 'Oklahoma', 'Wisconsin', 'Nevada', 'Hawaii']
# node: TexasChristian, source: TexasChristian, destination: Nevada, value: 0.010804510217713543
# choosing maximum action >>>>node: TexasChristian, source: TexasChristian, destination: Nevada, value: 0.010804510217713543
# neighbor communities ['Oregon', 'Wyoming', 'Wisconsin', 'Nevada']
# node: California, source: California, destination: Oregon, value: 0.012113825249022672
# choosing maximum action >>>>node: California, source: California, destination: Oregon, value: 0.012113825249022672
# neighbor communities ['Rutgers', 'Oklahoma', 'Army', 'SouthernMississippi', 'OklahomaState', 'Maryland', 'LouisianaState']
# node: AlabamaBirmingham, source: AlabamaBirmingham, destination: Army, value: 0.003182806458223004
# choosing maximum action >>>>node: AlabamaBirmingham, source: AlabamaBirmingham, destination: Army, value: 0.003182806458223004
# neighbor communities ['LouisianaState', 'MiddleTennesseeState', 'Oklahoma']
# node: Arkansas, source: Arkansas, destination: LouisianaState, value: 0.011986087197187634
# choosing maximum action >>>>node: Arkansas, source: Arkansas, destination: LouisianaState, value: 0.011986087197187634
# neighbor communities ['Wyoming', 'Colorado', 'Wisconsin', 'Nevada']
# node: Hawaii, source: Hawaii, destination: Nevada, value: 0.012230918463204789
# choosing maximum action >>>>node: Hawaii, source: Hawaii, destination: Nevada, value: 0.012230918463204789
#
# {'Wyoming': {'community': 'Wyoming', 'people_nodes': ['BrighamYoung', 'NewMexico', 'SanDiegoState', 'Wyoming', 'Utah', 'ColoradoState', 'AirForce', 'NevadaLasVegas']}, 'Duke': {'community': 'Duke', 'people_nodes': ['FloridaState', 'NorthCarolinaState', 'Virginia', 'GeorgiaTech', 'Duke', 'NorthCarolina', 'Clemson', 'WakeForest', 'Maryland']}, 'Wisconsin': {'community': 'Wisconsin', 'people_nodes': ['Iowa', 'Northwestern', 'Wisconsin', 'Michigan', 'Purdue', 'OhioState', 'Minnesota', 'Illinois', 'MichiganState', 'Indiana']}, 'Colorado': {'community': 'Colorado', 'people_nodes': ['KansasState', 'LouisianaTech']}, 'Oklahoma': {'community': 'Oklahoma', 'people_nodes': ['TexasTech', 'Baylor', 'NorthTexas', 'ArkansasState', 'BoiseState', 'Idaho', 'Kansas', 'NewMexicoState', 'IowaState', 'Nebraska', 'TexasA&M', 'Oklahoma', 'UtahState', 'LouisianaLafayette', 'Texas', 'Missouri', 'OklahomaState']}, 'Michigan': {'community': 'Michigan', 'people_nodes': ['PennState']}, 'Oregon': {'community': 'Oregon', 'people_nodes': ['SouthernCalifornia', 'ArizonaState', 'UCLA', 'Arizona', 'Washington', 'Oregon', 'Stanford', 'WashingtonState', 'OregonState', 'California']}, 'BallState': {'community': 'BallState', 'people_nodes': ['NorthernIllinois', 'WesternMichigan', 'BallState', 'Buffalo', 'CentralMichigan', 'Connecticut', 'EasternMichigan', 'Kent', 'MiamiOhio', 'Ohio', 'Toledo', 'Marshall']}, 'LouisianaState': {'community': 'LouisianaState', 'people_nodes': ['Auburn', 'Alabama', 'Florida', 'Kentucky', 'Vanderbilt', 'MississippiState', 'SouthCarolina', 'Tennessee', 'Mississippi', 'Georgia', 'LouisianaState', 'Arkansas']}, 'BowlingGreenState': {'community': 'BowlingGreenState', 'people_nodes': ['Akron', 'CentralFlorida']}, 'Rutgers': {'community': 'Rutgers', 'people_nodes': ['VirginiaTech', 'BostonCollege', 'WestVirginia', 'Syracuse', 'EastCarolina', 'Pittsburgh', 'Temple', 'Navy', 'NotreDame', 'Army', 'Rutgers', 'MiamiFlorida']}, 'EasternMichigan': {'community': 'EasternMichigan', 'people_nodes': ['BowlingGreenState']}, 'Washington': {'community': 'Washington', 'people_nodes': ['Colorado']}, 'Nevada': {'community': 'Nevada', 'people_nodes': ['FresnoState', 'Rice', 'SouthernMethodist', 'Nevada', 'SanJoseState', 'TexasElPaso', 'Tulsa', 'TexasChristian', 'Hawaii']}, 'Texas': {'community': 'Texas', 'people_nodes': ['Houston']}, 'Army': {'community': 'Army', 'people_nodes': ['Louisville', 'Tulane', 'Cincinnati', 'AlabamaBirmingham']}, 'MiddleTennesseeState': {'community': 'MiddleTennesseeState', 'people_nodes': ['LouisianaMonroe']}, 'Maryland': {'community': 'Maryland', 'people_nodes': ['MiddleTennesseeState']}, 'SouthernMississippi': {'community': 'SouthernMississippi', 'people_nodes': ['Memphis']}, 'OklahomaState': {'community': 'OklahomaState', 'people_nodes': ['SouthernMississippi']}}
# adding edges from necessary
# neighbor communities ['Wyoming', 'Rutgers', 'Duke', 'Oregon', 'Oklahoma', 'Wisconsin', 'BallState', 'Nevada', 'Washington', 'LouisianaState']
# node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# choosing maximum action >>>>node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# neighbor communities ['Wyoming', 'Rutgers', 'Duke', 'BowlingGreenState', 'Wisconsin', 'Army', 'Oklahoma', 'Nevada', 'BallState', 'Maryland', 'LouisianaState']
# node: Duke, source: Duke, destination: Duke, value: 0.0528835534597053
# choosing maximum action >>>>node: Duke, source: Duke, destination: Duke, value: 0.0528835534597053
# neighbor communities ['Wyoming', 'Oregon', 'Duke', 'Rutgers', 'Colorado', 'Wisconsin', 'Oklahoma', 'BallState', 'Nevada', 'Army', 'Michigan', 'EasternMichigan', 'MiddleTennesseeState', 'Maryland', 'LouisianaState']
# node: Wisconsin, source: Wisconsin, destination: Wisconsin, value: 0.051446500376561136
# choosing maximum action >>>>node: Wisconsin, source: Wisconsin, destination: Wisconsin, value: 0.051446500376561136
# neighbor communities ['BowlingGreenState', 'Rutgers', 'Colorado', 'Oklahoma', 'Washington', 'BallState', 'Wisconsin', 'MiddleTennesseeState', 'Michigan', 'Nevada', 'Maryland', 'LouisianaState']
# node: Colorado, source: Colorado, destination: Oklahoma, value: 0.011608195460508983
# choosing maximum action >>>>node: Colorado, source: Colorado, destination: Oklahoma, value: 0.011608195460508983
# neighbor communities ['Wyoming', 'Oregon', 'Duke', 'Rutgers', 'Oklahoma', 'Wisconsin', 'SouthernMississippi', 'Nevada', 'BallState', 'Washington', 'Texas', 'Army', 'MiddleTennesseeState', 'Maryland', 'OklahomaState', 'LouisianaState']
# node: Oklahoma, source: Oklahoma, destination: Oklahoma, value: 0.08399309150036326
# choosing maximum action >>>>node: Oklahoma, source: Oklahoma, destination: Oklahoma, value: 0.08399309150036326
# neighbor communities ['Oregon', 'Rutgers', 'Oklahoma', 'Wisconsin', 'BallState']
# node: Michigan, source: Michigan, destination: Wisconsin, value: 0.011900928495964276
# choosing maximum action >>>>node: Michigan, source: Michigan, destination: Wisconsin, value: 0.011900928495964276
# neighbor communities ['Wyoming', 'Oregon', 'Rutgers', 'Oklahoma', 'Washington', 'Wisconsin', 'Nevada', 'LouisianaState']
# node: Oregon, source: Oregon, destination: Oregon, value: 0.057801468455354214
# choosing maximum action >>>>node: Oregon, source: Oregon, destination: Oregon, value: 0.057801468455354214
# neighbor communities ['Wyoming', 'BowlingGreenState', 'Duke', 'Rutgers', 'Oklahoma', 'Wisconsin', 'BallState', 'EasternMichigan', 'Army', 'Maryland', 'LouisianaState']
# node: BallState, source: BallState, destination: BallState, value: 0.05369788354015366
# choosing maximum action >>>>node: BallState, source: BallState, destination: BallState, value: 0.05369788354015366
# neighbor communities ['Wyoming', 'Oregon', 'Duke', 'BowlingGreenState', 'Oklahoma', 'Wisconsin', 'BallState', 'OklahomaState', 'Texas', 'Army', 'MiddleTennesseeState', 'SouthernMississippi', 'Maryland', 'LouisianaState']
# node: LouisianaState, source: LouisianaState, destination: LouisianaState, value: 0.06808438162807469
# choosing maximum action >>>>node: LouisianaState, source: LouisianaState, destination: LouisianaState, value: 0.06808438162807469
# neighbor communities ['Rutgers', 'BowlingGreenState', 'Duke', 'Oklahoma', 'BallState', 'EasternMichigan', 'MiddleTennesseeState', 'LouisianaState']
# node: BowlingGreenState, source: BowlingGreenState, destination: BallState, value: 0.014492946464450233
# choosing maximum action >>>>node: BowlingGreenState, source: BowlingGreenState, destination: BallState, value: 0.014492946464450233
# neighbor communities ['Wyoming', 'Oregon', 'Duke', 'Rutgers', 'Oklahoma', 'Wisconsin', 'BallState', 'EasternMichigan', 'Army', 'Texas', 'SouthernMississippi', 'OklahomaState', 'Nevada']
# node: Rutgers, source: Rutgers, destination: Rutgers, value: 0.05717342303383195
# choosing maximum action >>>>node: Rutgers, source: Rutgers, destination: Rutgers, value: 0.05717342303383195
# neighbor communities ['BallState', 'Rutgers', 'Wisconsin']
# node: EasternMichigan, source: EasternMichigan, destination: BallState, value: 0.011616179088748672
# choosing maximum action >>>>node: EasternMichigan, source: EasternMichigan, destination: BallState, value: 0.011616179088748672
# neighbor communities ['Wyoming', 'Oklahoma', 'Oregon']
# node: Washington, source: Washington, destination: Oklahoma, value: 0.011147806232020205
# choosing maximum action >>>>node: Washington, source: Washington, destination: Oklahoma, value: 0.011147806232020205
# neighbor communities ['Wyoming', 'Oregon', 'Duke', 'Rutgers', 'Oklahoma', 'Wisconsin', 'Nevada', 'Texas', 'Army']
# node: Nevada, source: Nevada, destination: Nevada, value: 0.05240453576532391
# choosing maximum action >>>>node: Nevada, source: Nevada, destination: Nevada, value: 0.05240453576532391
# neighbor communities ['Rutgers', 'Oklahoma', 'Army', 'Nevada', 'SouthernMississippi', 'OklahomaState', 'LouisianaState']
# node: Texas, source: Texas, destination: Army, value: 0.004747597593202206
# choosing maximum action >>>>node: Texas, source: Texas, destination: Army, value: 0.004747597593202206
# neighbor communities ['Rutgers', 'Duke', 'Oklahoma', 'Wisconsin', 'BallState', 'Nevada', 'Army', 'OklahomaState', 'SouthernMississippi', 'Maryland', 'LouisianaState']
# node: Army, source: Army, destination: Army, value: 0.012262852976163547
# choosing maximum action >>>>node: Army, source: Army, destination: Army, value: 0.012262852976163547
# neighbor communities ['Oklahoma', 'Wisconsin', 'BallState', 'SouthernMississippi', 'Maryland', 'LouisianaState']
# node: MiddleTennesseeState, source: MiddleTennesseeState, destination: LouisianaState, value: 0.002240738325939607
# choosing maximum action >>>>node: MiddleTennesseeState, source: MiddleTennesseeState, destination: LouisianaState, value: 0.002240738325939607
# neighbor communities ['Duke', 'Oklahoma', 'Wisconsin', 'BallState', 'Army', 'LouisianaState']
# node: Maryland, source: Maryland, destination: LouisianaState, value: 0.0036964198749763815
# choosing maximum action >>>>node: Maryland, source: Maryland, destination: LouisianaState, value: 0.0036964198749763815
# neighbor communities ['Rutgers', 'OklahomaState', 'Oklahoma', 'Army', 'LouisianaState']
# node: SouthernMississippi, source: SouthernMississippi, destination: Army, value: 0.00629109905287557
# choosing maximum action >>>>node: SouthernMississippi, source: SouthernMississippi, destination: Army, value: 0.00629109905287557
# neighbor communities ['Rutgers', 'LouisianaState', 'Oklahoma', 'Army']
# node: OklahomaState, source: OklahomaState, destination: Army, value: 0.009468583092272113
# choosing maximum action >>>>node: OklahomaState, source: OklahomaState, destination: Army, value: 0.009468583092272113
#
# {'Wyoming': {'community': 'Wyoming', 'people_nodes': ['BrighamYoung', 'NewMexico', 'SanDiegoState', 'Wyoming', 'Utah', 'ColoradoState', 'AirForce', 'NevadaLasVegas']}, 'Duke': {'community': 'Duke', 'people_nodes': ['FloridaState', 'NorthCarolinaState', 'Virginia', 'GeorgiaTech', 'Duke', 'NorthCarolina', 'Clemson', 'WakeForest', 'Maryland']}, 'Wisconsin': {'community': 'Wisconsin', 'people_nodes': ['Iowa', 'Northwestern', 'Wisconsin', 'Michigan', 'Purdue', 'OhioState', 'Minnesota', 'Illinois', 'MichiganState', 'Indiana', 'PennState']}, 'Oklahoma': {'community': 'Oklahoma', 'people_nodes': ['KansasState', 'LouisianaTech', 'TexasTech', 'Baylor', 'NorthTexas', 'ArkansasState', 'BoiseState', 'Idaho', 'Kansas', 'NewMexicoState', 'IowaState', 'Nebraska', 'TexasA&M', 'Oklahoma', 'UtahState', 'LouisianaLafayette', 'Texas', 'Missouri', 'OklahomaState', 'Colorado']}, 'Oregon': {'community': 'Oregon', 'people_nodes': ['SouthernCalifornia', 'ArizonaState', 'UCLA', 'Arizona', 'Washington', 'Oregon', 'Stanford', 'WashingtonState', 'OregonState', 'California']}, 'BallState': {'community': 'BallState', 'people_nodes': ['NorthernIllinois', 'WesternMichigan', 'BallState', 'Buffalo', 'CentralMichigan', 'Connecticut', 'EasternMichigan', 'Kent', 'MiamiOhio', 'Ohio', 'Toledo', 'Marshall', 'Akron', 'CentralFlorida', 'BowlingGreenState']}, 'LouisianaState': {'community': 'LouisianaState', 'people_nodes': ['Auburn', 'Alabama', 'Florida', 'Kentucky', 'Vanderbilt', 'MississippiState', 'SouthCarolina', 'Tennessee', 'Mississippi', 'Georgia', 'LouisianaState', 'Arkansas', 'LouisianaMonroe', 'MiddleTennesseeState']}, 'Rutgers': {'community': 'Rutgers', 'people_nodes': ['VirginiaTech', 'BostonCollege', 'WestVirginia', 'Syracuse', 'EastCarolina', 'Pittsburgh', 'Temple', 'Navy', 'NotreDame', 'Army', 'Rutgers', 'MiamiFlorida']}, 'Nevada': {'community': 'Nevada', 'people_nodes': ['FresnoState', 'Rice', 'SouthernMethodist', 'Nevada', 'SanJoseState', 'TexasElPaso', 'Tulsa', 'TexasChristian', 'Hawaii']}, 'Army': {'community': 'Army', 'people_nodes': ['Houston', 'Louisville', 'Tulane', 'Cincinnati', 'AlabamaBirmingham', 'Memphis', 'SouthernMississippi']}}
# adding edges from necessary
# neighbor communities ['Wyoming', 'Rutgers', 'Duke', 'Oregon', 'Oklahoma', 'Wisconsin', 'BallState', 'Nevada', 'LouisianaState']
# node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# choosing maximum action >>>>node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# neighbor communities ['Wyoming', 'Rutgers', 'Duke', 'Wisconsin', 'Army', 'Oklahoma', 'Nevada', 'BallState', 'LouisianaState']
# node: Duke, source: Duke, destination: Duke, value: 0.0528835534597053
# choosing maximum action >>>>node: Duke, source: Duke, destination: Duke, value: 0.0528835534597053
# neighbor communities ['Wyoming', 'Oregon', 'Duke', 'Rutgers', 'Wisconsin', 'Oklahoma', 'BallState', 'Nevada', 'Army', 'LouisianaState']
# node: Wisconsin, source: Wisconsin, destination: Wisconsin, value: 0.06241068315906846
# choosing maximum action >>>>node: Wisconsin, source: Wisconsin, destination: Wisconsin, value: 0.06241068315906846
# neighbor communities ['Wyoming', 'Rutgers', 'Duke', 'Oregon', 'Oklahoma', 'Wisconsin', 'BallState', 'Nevada', 'Army', 'LouisianaState']
# node: Oklahoma, source: Oklahoma, destination: Oklahoma, value: 0.09324877783957697
# choosing maximum action >>>>node: Oklahoma, source: Oklahoma, destination: Oklahoma, value: 0.09324877783957697
# neighbor communities ['Wyoming', 'Oregon', 'Rutgers', 'Oklahoma', 'Nevada', 'Wisconsin', 'LouisianaState']
# node: Oregon, source: Oregon, destination: Oregon, value: 0.057801468455354214
# choosing maximum action >>>>node: Oregon, source: Oregon, destination: Oregon, value: 0.057801468455354214
# neighbor communities ['Wyoming', 'Rutgers', 'Duke', 'Oklahoma', 'Wisconsin', 'BallState', 'Army', 'LouisianaState']
# node: BallState, source: BallState, destination: BallState, value: 0.07887824700813531
# choosing maximum action >>>>node: BallState, source: BallState, destination: BallState, value: 0.07887824700813531
# neighbor communities ['Wyoming', 'Oregon', 'Duke', 'Oklahoma', 'Wisconsin', 'BallState', 'Army', 'LouisianaState']
# node: LouisianaState, source: LouisianaState, destination: LouisianaState, value: 0.07348397552751823
# choosing maximum action >>>>node: LouisianaState, source: LouisianaState, destination: LouisianaState, value: 0.07348397552751823
# neighbor communities ['Wyoming', 'Oregon', 'Duke', 'Rutgers', 'Oklahoma', 'Wisconsin', 'BallState', 'Army', 'Nevada']
# node: Rutgers, source: Rutgers, destination: Rutgers, value: 0.05717342303383195
# choosing maximum action >>>>node: Rutgers, source: Rutgers, destination: Rutgers, value: 0.05717342303383195
# neighbor communities ['Wyoming', 'Oregon', 'Duke', 'Rutgers', 'Oklahoma', 'Wisconsin', 'Nevada', 'Army']
# node: Nevada, source: Nevada, destination: Nevada, value: 0.05240453576532391
# choosing maximum action >>>>node: Nevada, source: Nevada, destination: Nevada, value: 0.05240453576532391
# neighbor communities ['Rutgers', 'Duke', 'Oklahoma', 'Wisconsin', 'BallState', 'Nevada', 'Army', 'LouisianaState']
# node: Army, source: Army, destination: Army, value: 0.026681285577043343
# choosing maximum action >>>>node: Army, source: Army, destination: Army, value: 0.026681285577043343
#
# {'Wyoming': {'community': 'Wyoming', 'people_nodes': ['BrighamYoung', 'NewMexico', 'SanDiegoState', 'Wyoming', 'Utah', 'ColoradoState', 'AirForce', 'NevadaLasVegas']}, 'Duke': {'community': 'Duke', 'people_nodes': ['FloridaState', 'NorthCarolinaState', 'Virginia', 'GeorgiaTech', 'Duke', 'NorthCarolina', 'Clemson', 'WakeForest', 'Maryland']}, 'Wisconsin': {'community': 'Wisconsin', 'people_nodes': ['Iowa', 'Northwestern', 'Wisconsin', 'Michigan', 'Purdue', 'OhioState', 'Minnesota', 'Illinois', 'MichiganState', 'Indiana', 'PennState']}, 'Oklahoma': {'community': 'Oklahoma', 'people_nodes': ['KansasState', 'LouisianaTech', 'TexasTech', 'Baylor', 'NorthTexas', 'ArkansasState', 'BoiseState', 'Idaho', 'Kansas', 'NewMexicoState', 'IowaState', 'Nebraska', 'TexasA&M', 'Oklahoma', 'UtahState', 'LouisianaLafayette', 'Texas', 'Missouri', 'OklahomaState', 'Colorado']}, 'Oregon': {'community': 'Oregon', 'people_nodes': ['SouthernCalifornia', 'ArizonaState', 'UCLA', 'Arizona', 'Washington', 'Oregon', 'Stanford', 'WashingtonState', 'OregonState', 'California']}, 'BallState': {'community': 'BallState', 'people_nodes': ['NorthernIllinois', 'WesternMichigan', 'BallState', 'Buffalo', 'CentralMichigan', 'Connecticut', 'EasternMichigan', 'Kent', 'MiamiOhio', 'Ohio', 'Toledo', 'Marshall', 'Akron', 'CentralFlorida', 'BowlingGreenState']}, 'LouisianaState': {'community': 'LouisianaState', 'people_nodes': ['Auburn', 'Alabama', 'Florida', 'Kentucky', 'Vanderbilt', 'MississippiState', 'SouthCarolina', 'Tennessee', 'Mississippi', 'Georgia', 'LouisianaState', 'Arkansas', 'LouisianaMonroe', 'MiddleTennesseeState']}, 'Rutgers': {'community': 'Rutgers', 'people_nodes': ['VirginiaTech', 'BostonCollege', 'WestVirginia', 'Syracuse', 'EastCarolina', 'Pittsburgh', 'Temple', 'Navy', 'NotreDame', 'Army', 'Rutgers', 'MiamiFlorida']}, 'Nevada': {'community': 'Nevada', 'people_nodes': ['FresnoState', 'Rice', 'SouthernMethodist', 'Nevada', 'SanJoseState', 'TexasElPaso', 'Tulsa', 'TexasChristian', 'Hawaii']}, 'Army': {'community': 'Army', 'people_nodes': ['Houston', 'Louisville', 'Tulane', 'Cincinnati', 'AlabamaBirmingham', 'Memphis', 'SouthernMississippi']}}
# adding edges from necessary

# %%
louvain.display_graph_history_tables(display_fn=lambda x: display(x))
# Out:
# --------------------------Graph in the phase: 1--------------------------
#                  nodes          community         people_nodes
# 0         BrighamYoung       BrighamYoung       [BrighamYoung]
# 1         FloridaState       FloridaState       [FloridaState]
# 2                 Iowa               Iowa               [Iowa]
# 3          KansasState        KansasState        [KansasState]
# 4            NewMexico          NewMexico          [NewMexico]
# ..                 ...                ...                  ...
# 110     TexasChristian     TexasChristian     [TexasChristian]
# 111         California         California         [California]
# 112  AlabamaBirmingham  AlabamaBirmingham  [AlabamaBirmingham]
# 113           Arkansas           Arkansas           [Arkansas]
# 114             Hawaii             Hawaii             [Hawaii]
#
# [115 rows x 3 columns]
#      edges          node_a         node_b  weight
# 0        1    BrighamYoung   FloridaState       1
# 1        2    BrighamYoung      NewMexico       1
# 2        3    BrighamYoung  SanDiegoState       1
# 3        4    BrighamYoung        Wyoming       1
# 4        5    BrighamYoung           Utah       1
# ..     ...             ...            ...     ...
# 608    609         Clemson       Maryland       1
# 609    610  NevadaLasVegas         Hawaii       1
# 610    611      WakeForest       Maryland       1
# 611    612     OregonState     California       1
# 612    613  TexasChristian         Hawaii       1
#
# [613 rows x 4 columns]
# _______________________________________________________________________________________________________
# ---------------Possible actions for node BrighamYoung in phase 1---------------
#             node        source       destination     value
# 0   BrighamYoung  BrighamYoung           Wyoming  0.001631
# 1   BrighamYoung  BrighamYoung    NevadaLasVegas  0.001631
# 2   BrighamYoung  BrighamYoung     ColoradoState  0.001631
# 3   BrighamYoung  BrighamYoung          Syracuse  0.001631
# 4   BrighamYoung  BrighamYoung          AirForce  0.001631
# 5   BrighamYoung  BrighamYoung         UtahState  0.001631
# 6   BrighamYoung  BrighamYoung      FloridaState  0.001631
# 7   BrighamYoung  BrighamYoung  MississippiState  0.001631
# 8   BrighamYoung  BrighamYoung          Virginia  0.001631
# 9   BrighamYoung  BrighamYoung              Utah  0.001631
# 10  BrighamYoung  BrighamYoung         NewMexico  0.001631
# 11  BrighamYoung  BrighamYoung     SanDiegoState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: BrighamYoung, source: BrighamYoung, destination: Wyoming, value: 0.0016313213703099511
# ---------------Possible actions for node FloridaState in phase 1---------------
#             node        source         destination     value
# 0   FloridaState  FloridaState             Wyoming  0.001599
# 1   FloridaState  FloridaState                Duke  0.001631
# 2   FloridaState  FloridaState             Clemson  0.001631
# 3   FloridaState  FloridaState          WakeForest  0.001631
# 4   FloridaState  FloridaState  NorthCarolinaState  0.001631
# 5   FloridaState  FloridaState            Maryland  0.001631
# 6   FloridaState  FloridaState       NorthCarolina  0.001631
# 7   FloridaState  FloridaState         GeorgiaTech  0.001631
# 8   FloridaState  FloridaState            Virginia  0.001631
# 9   FloridaState  FloridaState        MiamiFlorida  0.001631
# 10  FloridaState  FloridaState          Louisville  0.001631
# 11  FloridaState  FloridaState             Florida  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: FloridaState, source: FloridaState, destination: Duke, value: 0.0016313213703099511
# ---------------Possible actions for node Iowa in phase 1---------------
#     node source      destination     value
# 0   Iowa   Iowa        Wisconsin  0.001631
# 1   Iowa   Iowa        Minnesota  0.001631
# 2   Iowa   Iowa        IowaState  0.001631
# 3   Iowa   Iowa    MichiganState  0.001631
# 4   Iowa   Iowa     Northwestern  0.001631
# 5   Iowa   Iowa  WesternMichigan  0.001631
# 6   Iowa   Iowa          Indiana  0.001631
# 7   Iowa   Iowa        OhioState  0.001631
# 8   Iowa   Iowa         Nebraska  0.001631
# 9   Iowa   Iowa      KansasState  0.001631
# 10  Iowa   Iowa         Illinois  0.001631
# 11  Iowa   Iowa        PennState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Iowa, source: Iowa, destination: Wisconsin, value: 0.0016313213703099511
# ---------------Possible actions for node KansasState in phase 1---------------
#            node       source    destination     value
# 0   KansasState  KansasState       Colorado  0.001631
# 1   KansasState  KansasState      Wisconsin  0.001599
# 2   KansasState  KansasState      IowaState  0.001631
# 3   KansasState  KansasState      BallState  0.001631
# 4   KansasState  KansasState         Kansas  0.001631
# 5   KansasState  KansasState     NorthTexas  0.001631
# 6   KansasState  KansasState       TexasA&M  0.001631
# 7   KansasState  KansasState       Oklahoma  0.001631
# 8   KansasState  KansasState       Missouri  0.001631
# 9   KansasState  KansasState  LouisianaTech  0.001631
# 10  KansasState  KansasState      TexasTech  0.001631
# 11  KansasState  KansasState       Nebraska  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: KansasState, source: KansasState, destination: Colorado, value: 0.0016313213703099511
# ---------------Possible actions for node NewMexico in phase 1---------------
#         node     source     destination     value
# 0  NewMexico  NewMexico         Wyoming  0.003233
# 1  NewMexico  NewMexico  NewMexicoState  0.001631
# 2  NewMexico  NewMexico  NevadaLasVegas  0.001631
# 3  NewMexico  NewMexico      BoiseState  0.001631
# 4  NewMexico  NewMexico   ColoradoState  0.001631
# 5  NewMexico  NewMexico        AirForce  0.001631
# 6  NewMexico  NewMexico       TexasTech  0.001631
# 7  NewMexico  NewMexico     OregonState  0.001631
# 8  NewMexico  NewMexico            Utah  0.001631
# 9  NewMexico  NewMexico   SanDiegoState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: NewMexico, source: NewMexico, destination: Wyoming, value: 0.003233369437074373
# ---------------Possible actions for node TexasTech in phase 1---------------
#          node     source         destination     value
# 0   TexasTech  TexasTech             Wyoming  0.001536
# 1   TexasTech  TexasTech            Colorado  0.001599
# 2   TexasTech  TexasTech            Oklahoma  0.001631
# 3   TexasTech  TexasTech               Texas  0.001631
# 4   TexasTech  TexasTech              Kansas  0.001631
# 5   TexasTech  TexasTech            TexasA&M  0.001631
# 6   TexasTech  TexasTech              Baylor  0.001631
# 7   TexasTech  TexasTech          NorthTexas  0.001631
# 8   TexasTech  TexasTech       OklahomaState  0.001631
# 9   TexasTech  TexasTech  LouisianaLafayette  0.001631
# 10  TexasTech  TexasTech           UtahState  0.001631
# 11  TexasTech  TexasTech            Nebraska  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: TexasTech, source: TexasTech, destination: Oklahoma, value: 0.0016313213703099511
# ---------------Possible actions for node PennState in phase 1---------------
#          node     source         destination     value
# 0   PennState  PennState           Wisconsin  0.001599
# 1   PennState  PennState            Michigan  0.001631
# 2   PennState  PennState       MichiganState  0.001631
# 3   PennState  PennState              Purdue  0.001631
# 4   PennState  PennState       LouisianaTech  0.001631
# 5   PennState  PennState              Toledo  0.001631
# 6   PennState  PennState           Minnesota  0.001631
# 7   PennState  PennState  SouthernCalifornia  0.001631
# 8   PennState  PennState             Indiana  0.001631
# 9   PennState  PennState          Pittsburgh  0.001631
# 10  PennState  PennState           OhioState  0.001631
# 11  PennState  PennState            Illinois  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: PennState, source: PennState, destination: Michigan, value: 0.0016313213703099511
# ---------------Possible actions for node SouthernCalifornia in phase 1---------------
#                   node              source      destination     value
# 0   SouthernCalifornia  SouthernCalifornia           Oregon  0.001631
# 1   SouthernCalifornia  SouthernCalifornia          Arizona  0.001631
# 2   SouthernCalifornia  SouthernCalifornia  WashingtonState  0.001631
# 3   SouthernCalifornia  SouthernCalifornia         Colorado  0.001599
# 4   SouthernCalifornia  SouthernCalifornia         Michigan  0.001599
# 5   SouthernCalifornia  SouthernCalifornia     ArizonaState  0.001631
# 6   SouthernCalifornia  SouthernCalifornia       California  0.001631
# 7   SouthernCalifornia  SouthernCalifornia         Stanford  0.001631
# 8   SouthernCalifornia  SouthernCalifornia      OregonState  0.001631
# 9   SouthernCalifornia  SouthernCalifornia             UCLA  0.001631
# 10  SouthernCalifornia  SouthernCalifornia        NotreDame  0.001631
# 11  SouthernCalifornia  SouthernCalifornia     SanJoseState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: SouthernCalifornia, source: SouthernCalifornia, destination: Oregon, value: 0.0016313213703099511
# ---------------Possible actions for node ArizonaState in phase 1---------------
#            node        source      destination     value
# 0  ArizonaState  ArizonaState           Oregon  0.003233
# 1  ArizonaState  ArizonaState          Arizona  0.001631
# 2  ArizonaState  ArizonaState  WashingtonState  0.001631
# 3  ArizonaState  ArizonaState       Washington  0.001631
# 4  ArizonaState  ArizonaState    ColoradoState  0.001631
# 5  ArizonaState  ArizonaState       California  0.001631
# 6  ArizonaState  ArizonaState         Stanford  0.001631
# 7  ArizonaState  ArizonaState        UtahState  0.001631
# 8  ArizonaState  ArizonaState             UCLA  0.001631
# 9  ArizonaState  ArizonaState    SanDiegoState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: ArizonaState, source: ArizonaState, destination: Oregon, value: 0.003233369437074373
# ---------------Possible actions for node SanDiegoState in phase 1---------------
#             node         source     destination     value
# 0  SanDiegoState  SanDiegoState         Wyoming  0.004806
# 1  SanDiegoState  SanDiegoState          Oregon  0.001544
# 2  SanDiegoState  SanDiegoState         Arizona  0.001631
# 3  SanDiegoState  SanDiegoState  NevadaLasVegas  0.001631
# 4  SanDiegoState  SanDiegoState   ColoradoState  0.001631
# 5  SanDiegoState  SanDiegoState        AirForce  0.001631
# 6  SanDiegoState  SanDiegoState     OregonState  0.001631
# 7  SanDiegoState  SanDiegoState            Utah  0.001631
# 8  SanDiegoState  SanDiegoState        Illinois  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: SanDiegoState, source: SanDiegoState, destination: Wyoming, value: 0.004806144200293265
# ---------------Possible actions for node Baylor in phase 1---------------
#      node  source    destination     value
# 0  Baylor  Baylor       Oklahoma  0.003236
# 1  Baylor  Baylor      IowaState  0.001631
# 2  Baylor  Baylor          Texas  0.001631
# 3  Baylor  Baylor       TexasA&M  0.001631
# 4  Baylor  Baylor     NorthTexas  0.001631
# 5  Baylor  Baylor  OklahomaState  0.001631
# 6  Baylor  Baylor       Missouri  0.001631
# 7  Baylor  Baylor      Minnesota  0.001631
# 8  Baylor  Baylor       Nebraska  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Baylor, source: Baylor, destination: Oklahoma, value: 0.003236030646487603
# ---------------Possible actions for node NorthTexas in phase 1---------------
#          node      source         destination     value
# 0  NorthTexas  NorthTexas      NewMexicoState  0.001631
# 1  NorthTexas  NorthTexas            Colorado  0.001605
# 2  NorthTexas  NorthTexas            Oklahoma  0.003183
# 3  NorthTexas  NorthTexas      NevadaLasVegas  0.001631
# 4  NorthTexas  NorthTexas          BoiseState  0.001631
# 5  NorthTexas  NorthTexas  LouisianaLafayette  0.001631
# 6  NorthTexas  NorthTexas           UtahState  0.001631
# 7  NorthTexas  NorthTexas       ArkansasState  0.001631
# 8  NorthTexas  NorthTexas               Idaho  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: NorthTexas, source: NorthTexas, destination: Oklahoma, value: 0.003182806458223004
# ---------------Possible actions for node NorthernIllinois in phase 1---------------
#                node            source      destination     value
# 0  NorthernIllinois  NorthernIllinois        BallState  0.001631
# 1  NorthernIllinois  NorthernIllinois  EasternMichigan  0.001631
# 2  NorthernIllinois  NorthernIllinois            Akron  0.001631
# 3  NorthernIllinois  NorthernIllinois     Northwestern  0.001631
# 4  NorthernIllinois  NorthernIllinois   CentralFlorida  0.001631
# 5  NorthernIllinois  NorthernIllinois          Buffalo  0.001631
# 6  NorthernIllinois  NorthernIllinois           Toledo  0.001631
# 7  NorthernIllinois  NorthernIllinois  WesternMichigan  0.001631
# 8  NorthernIllinois  NorthernIllinois           Auburn  0.001631
# 9  NorthernIllinois  NorthernIllinois  CentralMichigan  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: NorthernIllinois, source: NorthernIllinois, destination: BallState, value: 0.0016313213703099511
# ---------------Possible actions for node Northwestern in phase 1---------------
#            node        source     destination     value
# 0  Northwestern  Northwestern            Duke  0.001602
# 1  Northwestern  Northwestern       Wisconsin  0.003233
# 2  Northwestern  Northwestern       BallState  0.001602
# 3  Northwestern  Northwestern        Michigan  0.001602
# 4  Northwestern  Northwestern   MichiganState  0.001631
# 5  Northwestern  Northwestern          Purdue  0.001631
# 6  Northwestern  Northwestern         Indiana  0.001631
# 7  Northwestern  Northwestern       Minnesota  0.001631
# 8  Northwestern  Northwestern  TexasChristian  0.001631
# 9  Northwestern  Northwestern        Illinois  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Northwestern, source: Northwestern, destination: Wisconsin, value: 0.003233369437074373
# ---------------Possible actions for node WesternMichigan in phase 1---------------
#               node           source      destination     value
# 0  WesternMichigan  WesternMichigan        Wisconsin  0.003183
# 1  WesternMichigan  WesternMichigan        BallState  0.003236
# 2  WesternMichigan  WesternMichigan  EasternMichigan  0.001631
# 3  WesternMichigan  WesternMichigan             Ohio  0.001631
# 4  WesternMichigan  WesternMichigan             Kent  0.001631
# 5  WesternMichigan  WesternMichigan           Toledo  0.001631
# 6  WesternMichigan  WesternMichigan         Marshall  0.001631
# 7  WesternMichigan  WesternMichigan  CentralMichigan  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: WesternMichigan, source: WesternMichigan, destination: BallState, value: 0.003236030646487603
# ---------------Possible actions for node Wisconsin in phase 1---------------
#          node     source    destination     value
# 0   Wisconsin  Wisconsin         Oregon  0.001536
# 1   Wisconsin  Wisconsin      Wisconsin  0.003167
# 2   Wisconsin  Wisconsin      BallState  0.001536
# 3   Wisconsin  Wisconsin       Michigan  0.001599
# 4   Wisconsin  Wisconsin     Cincinnati  0.001631
# 5   Wisconsin  Wisconsin  MichiganState  0.001631
# 6   Wisconsin  Wisconsin         Hawaii  0.001631
# 7   Wisconsin  Wisconsin         Purdue  0.001631
# 8   Wisconsin  Wisconsin      Minnesota  0.001631
# 9   Wisconsin  Wisconsin        Indiana  0.001631
# 10  Wisconsin  Wisconsin      OhioState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Wisconsin, source: Wisconsin, destination: Wisconsin, value: 0.0031668392017436247
# ---------------Possible actions for node Wyoming in phase 1---------------
#       node   source      destination     value
# 0  Wyoming  Wyoming          Wyoming  0.004718
# 1  Wyoming  Wyoming   NevadaLasVegas  0.001631
# 2  Wyoming  Wyoming           Nevada  0.001631
# 3  Wyoming  Wyoming         TexasA&M  0.001631
# 4  Wyoming  Wyoming    ColoradoState  0.001631
# 5  Wyoming  Wyoming         AirForce  0.001631
# 6  Wyoming  Wyoming             Utah  0.001631
# 7  Wyoming  Wyoming           Auburn  0.001631
# 8  Wyoming  Wyoming  CentralMichigan  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.0047183242896566766
# ---------------Possible actions for node Auburn in phase 1---------------
#       node  source       destination     value
# 0   Auburn  Auburn           Wyoming  0.001456
# 1   Auburn  Auburn         BallState  0.001544
# 2   Auburn  Auburn    LouisianaState  0.001631
# 3   Auburn  Auburn       Mississippi  0.001631
# 4   Auburn  Auburn     LouisianaTech  0.001631
# 5   Auburn  Auburn           Alabama  0.001631
# 6   Auburn  Auburn          Arkansas  0.001631
# 7   Auburn  Auburn  MississippiState  0.001631
# 8   Auburn  Auburn           Georgia  0.001631
# 9   Auburn  Auburn        Vanderbilt  0.001631
# 10  Auburn  Auburn           Florida  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Auburn, source: Auburn, destination: LouisianaState, value: 0.0016313213703099511
# ---------------Possible actions for node Akron in phase 1---------------
#      node source        destination     value
# 0   Akron  Akron  BowlingGreenState  0.001631
# 1   Akron  Akron        Connecticut  0.001631
# 2   Akron  Akron          BallState  0.001544
# 3   Akron  Akron               Ohio  0.001631
# 4   Akron  Akron     CentralFlorida  0.001631
# 5   Akron  Akron               Kent  0.001631
# 6   Akron  Akron            Buffalo  0.001631
# 7   Akron  Akron       VirginiaTech  0.001631
# 8   Akron  Akron           Marshall  0.001631
# 9   Akron  Akron          MiamiOhio  0.001631
# 10  Akron  Akron    CentralMichigan  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Akron, source: Akron, destination: BowlingGreenState, value: 0.0016313213703099511
# ---------------Possible actions for node VirginiaTech in phase 1---------------
#             node        source        destination     value
# 0   VirginiaTech  VirginiaTech  BowlingGreenState  0.001602
# 1   VirginiaTech  VirginiaTech            Rutgers  0.001631
# 2   VirginiaTech  VirginiaTech      BostonCollege  0.001631
# 3   VirginiaTech  VirginiaTech       WestVirginia  0.001631
# 4   VirginiaTech  VirginiaTech       EastCarolina  0.001631
# 5   VirginiaTech  VirginiaTech     CentralFlorida  0.001631
# 6   VirginiaTech  VirginiaTech             Temple  0.001631
# 7   VirginiaTech  VirginiaTech           Virginia  0.001631
# 8   VirginiaTech  VirginiaTech       MiamiFlorida  0.001631
# 9   VirginiaTech  VirginiaTech         Pittsburgh  0.001631
# 10  VirginiaTech  VirginiaTech           Syracuse  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: VirginiaTech, source: VirginiaTech, destination: Rutgers, value: 0.0016313213703099511
# ---------------Possible actions for node Alabama in phase 1---------------
#       node   source          destination     value
# 0  Alabama  Alabama  SouthernMississippi  0.001631
# 1  Alabama  Alabama          Mississippi  0.001631
# 2  Alabama  Alabama       CentralFlorida  0.001631
# 3  Alabama  Alabama            Tennessee  0.001631
# 4  Alabama  Alabama             Arkansas  0.001631
# 5  Alabama  Alabama     MississippiState  0.001631
# 6  Alabama  Alabama                 UCLA  0.001631
# 7  Alabama  Alabama        SouthCarolina  0.001631
# 8  Alabama  Alabama       LouisianaState  0.003233
# 9  Alabama  Alabama           Vanderbilt  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Alabama, source: Alabama, destination: LouisianaState, value: 0.003233369437074373
# ---------------Possible actions for node UCLA in phase 1---------------
#    node source     destination     value
# 0  UCLA   UCLA          Oregon  0.004806
# 1  UCLA   UCLA         Arizona  0.001631
# 2  UCLA   UCLA      Washington  0.001631
# 3  UCLA   UCLA        Michigan  0.001602
# 4  UCLA   UCLA      California  0.001631
# 5  UCLA   UCLA        Stanford  0.001631
# 6  UCLA   UCLA     OregonState  0.001631
# 7  UCLA   UCLA     FresnoState  0.001631
# 8  UCLA   UCLA  LouisianaState  0.001544
# the action among the previous actions that maximizes modularity gain is:
# node: UCLA, source: UCLA, destination: Oregon, value: 0.004806144200293265
# ---------------Possible actions for node Arizona in phase 1---------------
#       node   source      destination     value
# 0  Arizona  Arizona           Oregon  0.006350
# 1  Arizona  Arizona          Wyoming  0.001456
# 2  Arizona  Arizona  WashingtonState  0.001631
# 3  Arizona  Arizona       Washington  0.001631
# 4  Arizona  Arizona         Stanford  0.001631
# 5  Arizona  Arizona      OregonState  0.001631
# 6  Arizona  Arizona             Utah  0.001631
# 7  Arizona  Arizona        OhioState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Arizona, source: Arizona, destination: Oregon, value: 0.006349645659966628
# ---------------Possible actions for node Utah in phase 1---------------
#    node source      destination     value
# 0  Utah   Utah          Wyoming  0.006350
# 1  Utah   Utah           Oregon  0.001339
# 2  Utah   Utah  WashingtonState  0.001631
# 3  Utah   Utah   NevadaLasVegas  0.001631
# 4  Utah   Utah    ColoradoState  0.001631
# 5  Utah   Utah         AirForce  0.001631
# 6  Utah   Utah       California  0.001631
# 7  Utah   Utah        UtahState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Utah, source: Utah, destination: Wyoming, value: 0.006349645659966628
# ---------------Possible actions for node ArkansasState in phase 1---------------
#             node         source         destination     value
# 0  ArkansasState  ArkansasState      NewMexicoState  0.001631
# 1  ArkansasState  ArkansasState            Oklahoma  0.003130
# 2  ArkansasState  ArkansasState  NorthCarolinaState  0.001631
# 3  ArkansasState  ArkansasState             Memphis  0.001631
# 4  ArkansasState  ArkansasState         Mississippi  0.001631
# 5  ArkansasState  ArkansasState          BoiseState  0.001631
# 6  ArkansasState  ArkansasState           UtahState  0.001631
# 7  ArkansasState  ArkansasState               Idaho  0.001631
# 8  ArkansasState  ArkansasState      TexasChristian  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: ArkansasState, source: ArkansasState, destination: Oklahoma, value: 0.0031295822699584056
# ---------------Possible actions for node NorthCarolinaState in phase 1---------------
#                  node              source        destination     value
# 0  NorthCarolinaState  NorthCarolinaState               Duke  0.003233
# 1  NorthCarolinaState  NorthCarolinaState            Clemson  0.001631
# 2  NorthCarolinaState  NorthCarolinaState           Oklahoma  0.001426
# 3  NorthCarolinaState  NorthCarolinaState         WakeForest  0.001631
# 4  NorthCarolinaState  NorthCarolinaState  SouthernMethodist  0.001631
# 5  NorthCarolinaState  NorthCarolinaState           Maryland  0.001631
# 6  NorthCarolinaState  NorthCarolinaState      NorthCarolina  0.001631
# 7  NorthCarolinaState  NorthCarolinaState        GeorgiaTech  0.001631
# 8  NorthCarolinaState  NorthCarolinaState           Virginia  0.001631
# 9  NorthCarolinaState  NorthCarolinaState            Indiana  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: NorthCarolinaState, source: NorthCarolinaState, destination: Duke, value: 0.003233369437074373
# ---------------Possible actions for node BallState in phase 1---------------
#         node     source      destination     value
# 0  BallState  BallState      Connecticut  0.001631
# 1  BallState  BallState         Colorado  0.001605
# 2  BallState  BallState        BallState  0.003183
# 3  BallState  BallState  EasternMichigan  0.001631
# 4  BallState  BallState          Buffalo  0.001631
# 5  BallState  BallState           Toledo  0.001631
# 6  BallState  BallState        MiamiOhio  0.001631
# 7  BallState  BallState          Florida  0.001631
# 8  BallState  BallState  CentralMichigan  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: BallState, source: BallState, destination: BallState, value: 0.003182806458223004
# ---------------Possible actions for node Florida in phase 1---------------
#       node   source           destination     value
# 0  Florida  Florida                  Duke  0.001544
# 1  Florida  Florida             BallState  0.001544
# 2  Florida  Florida  MiddleTennesseeState  0.001631
# 3  Florida  Florida             Tennessee  0.001631
# 4  Florida  Florida      MississippiState  0.001631
# 5  Florida  Florida         SouthCarolina  0.001631
# 6  Florida  Florida               Georgia  0.001631
# 7  Florida  Florida        LouisianaState  0.003175
# 8  Florida  Florida            Vanderbilt  0.001631
# 9  Florida  Florida              Kentucky  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Florida, source: Florida, destination: LouisianaState, value: 0.003174822829983314
# ---------------Possible actions for node BoiseState in phase 1---------------
#          node      source      destination     value
# 0  BoiseState  BoiseState          Wyoming  0.001392
# 1  BoiseState  BoiseState   NewMexicoState  0.001631
# 2  BoiseState  BoiseState  WashingtonState  0.001631
# 3  BoiseState  BoiseState         Oklahoma  0.003095
# 4  BoiseState  BoiseState        UtahState  0.001631
# 5  BoiseState  BoiseState         Arkansas  0.001631
# 6  BoiseState  BoiseState            Idaho  0.001631
# 7  BoiseState  BoiseState  CentralMichigan  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: BoiseState, source: BoiseState, destination: Oklahoma, value: 0.0030949865475864164
# ---------------Possible actions for node BostonCollege in phase 1---------------
#             node         source   destination     value
# 0  BostonCollege  BostonCollege       Rutgers  0.003233
# 1  BostonCollege  BostonCollege  WestVirginia  0.001631
# 2  BostonCollege  BostonCollege   Connecticut  0.001631
# 3  BostonCollege  BostonCollege          Army  0.001631
# 4  BostonCollege  BostonCollege          Navy  0.001631
# 5  BostonCollege  BostonCollege        Temple  0.001631
# 6  BostonCollege  BostonCollege     NotreDame  0.001631
# 7  BostonCollege  BostonCollege  MiamiFlorida  0.001631
# 8  BostonCollege  BostonCollege    Pittsburgh  0.001631
# 9  BostonCollege  BostonCollege      Syracuse  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: BostonCollege, source: BostonCollege, destination: Rutgers, value: 0.003233369437074373
# ---------------Possible actions for node WestVirginia in phase 1---------------
#            node        source   destination     value
# 0  WestVirginia  WestVirginia       Rutgers  0.004806
# 1  WestVirginia  WestVirginia  EastCarolina  0.001631
# 2  WestVirginia  WestVirginia      Maryland  0.001631
# 3  WestVirginia  WestVirginia        Temple  0.001631
# 4  WestVirginia  WestVirginia     NotreDame  0.001631
# 5  WestVirginia  WestVirginia  MiamiFlorida  0.001631
# 6  WestVirginia  WestVirginia         Idaho  0.001631
# 7  WestVirginia  WestVirginia    Pittsburgh  0.001631
# 8  WestVirginia  WestVirginia      Syracuse  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: WestVirginia, source: WestVirginia, destination: Rutgers, value: 0.004806144200293265
# ---------------Possible actions for node BowlingGreenState in phase 1---------------
#                  node             source        destination     value
# 0   BowlingGreenState  BowlingGreenState  BowlingGreenState  0.001602
# 1   BowlingGreenState  BowlingGreenState    EasternMichigan  0.001631
# 2   BowlingGreenState  BowlingGreenState           Michigan  0.001602
# 3   BowlingGreenState  BowlingGreenState               Ohio  0.001631
# 4   BowlingGreenState  BowlingGreenState               Kent  0.001631
# 5   BowlingGreenState  BowlingGreenState            Buffalo  0.001631
# 6   BowlingGreenState  BowlingGreenState             Temple  0.001631
# 7   BowlingGreenState  BowlingGreenState             Toledo  0.001631
# 8   BowlingGreenState  BowlingGreenState           Marshall  0.001631
# 9   BowlingGreenState  BowlingGreenState         Pittsburgh  0.001631
# 10  BowlingGreenState  BowlingGreenState          MiamiOhio  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: BowlingGreenState, source: BowlingGreenState, destination: EasternMichigan, value: 0.0016313213703099511
# ---------------Possible actions for node Michigan in phase 1---------------
#        node    source      destination     value
# 0  Michigan  Michigan           Oregon  0.001339
# 1  Michigan  Michigan        Wisconsin  0.003175
# 2  Michigan  Michigan  EasternMichigan  0.001602
# 3  Michigan  Michigan         Michigan  0.001602
# 4  Michigan  Michigan    MichiganState  0.001631
# 5  Michigan  Michigan           Purdue  0.001631
# 6  Michigan  Michigan             Rice  0.001631
# 7  Michigan  Michigan          Indiana  0.001631
# 8  Michigan  Michigan        OhioState  0.001631
# 9  Michigan  Michigan         Illinois  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Michigan, source: Michigan, destination: Wisconsin, value: 0.003174822829983314
# ---------------Possible actions for node Virginia in phase 1---------------
#        node    source    destination     value
# 0  Virginia  Virginia        Wyoming  0.001365
# 1  Virginia  Virginia        Rutgers  0.001472
# 2  Virginia  Virginia           Duke  0.004814
# 3  Virginia  Virginia        Clemson  0.001631
# 4  Virginia  Virginia     WakeForest  0.001631
# 5  Virginia  Virginia       Maryland  0.001631
# 6  Virginia  Virginia  NorthCarolina  0.001631
# 7  Virginia  Virginia    GeorgiaTech  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Virginia, source: Virginia, destination: Duke, value: 0.0048141278285329546
# ---------------Possible actions for node Buffalo in phase 1---------------
#       node   source        destination     value
# 0  Buffalo  Buffalo  BowlingGreenState  0.001631
# 1  Buffalo  Buffalo            Rutgers  0.001456
# 2  Buffalo  Buffalo        Connecticut  0.001631
# 3  Buffalo  Buffalo          BallState  0.003175
# 4  Buffalo  Buffalo    EasternMichigan  0.001602
# 5  Buffalo  Buffalo               Ohio  0.001631
# 6  Buffalo  Buffalo               Kent  0.001631
# 7  Buffalo  Buffalo           Marshall  0.001631
# 8  Buffalo  Buffalo          MiamiOhio  0.001631
# 9  Buffalo  Buffalo           Syracuse  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Buffalo, source: Buffalo, destination: BallState, value: 0.003174822829983314
# ---------------Possible actions for node Syracuse in phase 1---------------
#        node    source   destination     value
# 0  Syracuse  Syracuse       Wyoming  0.001339
# 1  Syracuse  Syracuse       Rutgers  0.006350
# 2  Syracuse  Syracuse  EastCarolina  0.001631
# 3  Syracuse  Syracuse     BallState  0.001485
# 4  Syracuse  Syracuse    Cincinnati  0.001631
# 5  Syracuse  Syracuse        Temple  0.001631
# 6  Syracuse  Syracuse  MiamiFlorida  0.001631
# 7  Syracuse  Syracuse    Pittsburgh  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Syracuse, source: Syracuse, destination: Rutgers, value: 0.006349645659966628
# ---------------Possible actions for node CentralFlorida in phase 1---------------
#              node          source        destination     value
# 0  CentralFlorida  CentralFlorida  BowlingGreenState  0.001631
# 1  CentralFlorida  CentralFlorida            Rutgers  0.001418
# 2  CentralFlorida  CentralFlorida          BallState  0.001525
# 3  CentralFlorida  CentralFlorida    EasternMichigan  0.001610
# 4  CentralFlorida  CentralFlorida      LouisianaTech  0.001631
# 5  CentralFlorida  CentralFlorida        GeorgiaTech  0.001631
# 6  CentralFlorida  CentralFlorida     LouisianaState  0.001525
# 7  CentralFlorida  CentralFlorida    LouisianaMonroe  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: CentralFlorida, source: CentralFlorida, destination: BowlingGreenState, value: 0.0016313213703099511
# ---------------Possible actions for node GeorgiaTech in phase 1---------------
#           node       source        destination     value
# 0  GeorgiaTech  GeorgiaTech  BowlingGreenState  0.001602
# 1  GeorgiaTech  GeorgiaTech               Duke  0.006350
# 2  GeorgiaTech  GeorgiaTech            Clemson  0.001631
# 3  GeorgiaTech  GeorgiaTech         WakeForest  0.001631
# 4  GeorgiaTech  GeorgiaTech           Maryland  0.001631
# 5  GeorgiaTech  GeorgiaTech               Navy  0.001631
# 6  GeorgiaTech  GeorgiaTech      NorthCarolina  0.001631
# 7  GeorgiaTech  GeorgiaTech            Georgia  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: GeorgiaTech, source: GeorgiaTech, destination: Duke, value: 0.006349645659966628
# ---------------Possible actions for node CentralMichigan in phase 1---------------
#               node           source        destination     value
# 0  CentralMichigan  CentralMichigan            Wyoming  0.001339
# 1  CentralMichigan  CentralMichigan  BowlingGreenState  0.001602
# 2  CentralMichigan  CentralMichigan           Oklahoma  0.001368
# 3  CentralMichigan  CentralMichigan          BallState  0.004748
# 4  CentralMichigan  CentralMichigan    EasternMichigan  0.001602
# 5  CentralMichigan  CentralMichigan               Ohio  0.001631
# 6  CentralMichigan  CentralMichigan             Purdue  0.001631
# 7  CentralMichigan  CentralMichigan               Kent  0.001631
# 8  CentralMichigan  CentralMichigan             Toledo  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: CentralMichigan, source: CentralMichigan, destination: BallState, value: 0.004747597593202206
# ---------------Possible actions for node Purdue in phase 1---------------
#      node  source    destination     value
# 0  Purdue  Purdue      Wisconsin  0.004748
# 1  Purdue  Purdue      BallState  0.001397
# 2  Purdue  Purdue       Michigan  0.001631
# 3  Purdue  Purdue  MichiganState  0.001631
# 4  Purdue  Purdue           Kent  0.001631
# 5  Purdue  Purdue      NotreDame  0.001631
# 6  Purdue  Purdue      Minnesota  0.001631
# 7  Purdue  Purdue        Indiana  0.001631
# 8  Purdue  Purdue      OhioState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Purdue, source: Purdue, destination: Wisconsin, value: 0.004747597593202206
# ---------------Possible actions for node Colorado in phase 1---------------
#         node    source    destination     value
# 0   Colorado  Colorado         Oregon  0.001339
# 1   Colorado  Colorado       Colorado  0.001602
# 2   Colorado  Colorado     Washington  0.001631
# 3   Colorado  Colorado      IowaState  0.001631
# 4   Colorado  Colorado         Kansas  0.001631
# 5   Colorado  Colorado       TexasA&M  0.001631
# 6   Colorado  Colorado          Texas  0.001631
# 7   Colorado  Colorado  OklahomaState  0.001631
# 8   Colorado  Colorado  ColoradoState  0.001631
# 9   Colorado  Colorado       Missouri  0.001631
# 10  Colorado  Colorado       Nebraska  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Colorado, source: Colorado, destination: Washington, value: 0.0016313213703099511
# ---------------Possible actions for node ColoradoState in phase 1---------------
#             node         source     destination     value
# 0  ColoradoState  ColoradoState         Wyoming  0.007890
# 1  ColoradoState  ColoradoState          Oregon  0.001365
# 2  ColoradoState  ColoradoState      Washington  0.001605
# 3  ColoradoState  ColoradoState          Nevada  0.001631
# 4  ColoradoState  ColoradoState  NevadaLasVegas  0.001631
# 5  ColoradoState  ColoradoState        AirForce  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: ColoradoState, source: ColoradoState, destination: Wyoming, value: 0.007890485910226761
# ---------------Possible actions for node Connecticut in phase 1---------------
#           node       source           destination     value
# 0  Connecticut  Connecticut     BowlingGreenState  0.001613
# 1  Connecticut  Connecticut               Rutgers  0.001445
# 2  Connecticut  Connecticut             BallState  0.003114
# 3  Connecticut  Connecticut       EasternMichigan  0.001613
# 4  Connecticut  Connecticut  MiddleTennesseeState  0.001631
# 5  Connecticut  Connecticut            Louisville  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Connecticut, source: Connecticut, destination: BallState, value: 0.0031136150134790258
# ---------------Possible actions for node EasternMichigan in phase 1---------------
#               node           source        destination     value
# 0  EasternMichigan  EasternMichigan  BowlingGreenState  0.001602
# 1  EasternMichigan  EasternMichigan          BallState  0.007864
# 2  EasternMichigan  EasternMichigan    EasternMichigan  0.001602
# 3  EasternMichigan  EasternMichigan             Toledo  0.001631
# 4  EasternMichigan  EasternMichigan             Temple  0.001631
# 5  EasternMichigan  EasternMichigan      SouthCarolina  0.001631
# 6  EasternMichigan  EasternMichigan          MiamiOhio  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: EasternMichigan, source: EasternMichigan, destination: BallState, value: 0.007863873816094461
# ---------------Possible actions for node EastCarolina in phase 1---------------
#            node        source          destination     value
# 0  EastCarolina  EastCarolina              Rutgers  0.004601
# 1  EastCarolina  EastCarolina                 Duke  0.001339
# 2  EastCarolina  EastCarolina                 Army  0.001631
# 3  EastCarolina  EastCarolina  SouthernMississippi  0.001631
# 4  EastCarolina  EastCarolina              Memphis  0.001631
# 5  EastCarolina  EastCarolina              Houston  0.001631
# 6  EastCarolina  EastCarolina               Tulane  0.001631
# 7  EastCarolina  EastCarolina           Louisville  0.001631
# 8  EastCarolina  EastCarolina    AlabamaBirmingham  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: EastCarolina, source: EastCarolina, destination: Rutgers, value: 0.00460123107547456
# ---------------Possible actions for node Duke in phase 1---------------
#    node source    destination     value
# 0  Duke   Duke        Rutgers  0.001251
# 1  Duke   Duke           Duke  0.006233
# 2  Duke   Duke        Clemson  0.001631
# 3  Duke   Duke      Wisconsin  0.001397
# 4  Duke   Duke     WakeForest  0.001631
# 5  Duke   Duke       Maryland  0.001631
# 6  Duke   Duke  NorthCarolina  0.001631
# 7  Duke   Duke     Vanderbilt  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Duke, source: Duke, destination: Duke, value: 0.0062325524457845114
# ---------------Possible actions for node FresnoState in phase 1---------------
#            node       source        destination     value
# 0   FresnoState  FresnoState             Oregon  0.001339
# 1   FresnoState  FresnoState             Nevada  0.001631
# 2   FresnoState  FresnoState  SouthernMethodist  0.001631
# 3   FresnoState  FresnoState              Tulsa  0.001631
# 4   FresnoState  FresnoState        TexasElPaso  0.001631
# 5   FresnoState  FresnoState         California  0.001631
# 6   FresnoState  FresnoState             Hawaii  0.001631
# 7   FresnoState  FresnoState               Rice  0.001631
# 8   FresnoState  FresnoState       SanJoseState  0.001631
# 9   FresnoState  FresnoState          OhioState  0.001631
# 10  FresnoState  FresnoState     TexasChristian  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: FresnoState, source: FresnoState, destination: Nevada, value: 0.0016313213703099511
# ---------------Possible actions for node OhioState in phase 1---------------
#         node     source    destination     value
# 0  OhioState  OhioState         Oregon  0.001339
# 1  OhioState  OhioState      Wisconsin  0.006291
# 2  OhioState  OhioState         Nevada  0.001602
# 3  OhioState  OhioState       Michigan  0.001631
# 4  OhioState  OhioState  MichiganState  0.001631
# 5  OhioState  OhioState       Illinois  0.001631
# 6  OhioState  OhioState      Minnesota  0.001631
# 7  OhioState  OhioState      MiamiOhio  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: OhioState, source: OhioState, destination: Wisconsin, value: 0.00629109905287557
# ---------------Possible actions for node Houston in phase 1---------------
#        node   source          destination     value
# 0   Houston  Houston              Rutgers  0.001251
# 1   Houston  Houston                Texas  0.001631
# 2   Houston  Houston                 Army  0.001631
# 3   Houston  Houston  SouthernMississippi  0.001631
# 4   Houston  Houston              Memphis  0.001631
# 5   Houston  Houston    SouthernMethodist  0.001631
# 6   Houston  Houston           Cincinnati  0.001631
# 7   Houston  Houston               Tulane  0.001631
# 8   Houston  Houston                 Rice  0.001631
# 9   Houston  Houston       LouisianaState  0.001485
# 10  Houston  Houston           Louisville  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Houston, source: Houston, destination: Texas, value: 0.0016313213703099511
# ---------------Possible actions for node Rice in phase 1---------------
#    node source        destination     value
# 0  Rice   Rice              Texas  0.001602
# 1  Rice   Rice          Wisconsin  0.001280
# 2  Rice   Rice             Nevada  0.003233
# 3  Rice   Rice           Oklahoma  0.001368
# 4  Rice   Rice  SouthernMethodist  0.001631
# 5  Rice   Rice              Tulsa  0.001631
# 6  Rice   Rice        TexasElPaso  0.001631
# 7  Rice   Rice             Hawaii  0.001631
# 8  Rice   Rice       SanJoseState  0.001631
# 9  Rice   Rice     TexasChristian  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Rice, source: Rice, destination: Nevada, value: 0.003233369437074373
# ---------------Possible actions for node Idaho in phase 1---------------
#     node source      destination     value
# 0  Idaho  Idaho          Rutgers  0.001320
# 1  Idaho  Idaho           Oregon  0.001392
# 2  Idaho  Idaho   NewMexicoState  0.001631
# 3  Idaho  Idaho  WashingtonState  0.001631
# 4  Idaho  Idaho       Washington  0.001607
# 5  Idaho  Idaho         Oklahoma  0.004678
# 6  Idaho  Idaho        UtahState  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Idaho, source: Idaho, destination: Oklahoma, value: 0.004678406148458228
# ---------------Possible actions for node Washington in phase 1---------------
#          node      source      destination     value
# 0  Washington  Washington           Oregon  0.006233
# 1  Washington  Washington  WashingtonState  0.001631
# 2  Washington  Washington         Oklahoma  0.001280
# 3  Washington  Washington       Washington  0.001602
# 4  Washington  Washington       California  0.001631
# 5  Washington  Washington         Stanford  0.001631
# 6  Washington  Washington      OregonState  0.001631
# 7  Washington  Washington     MiamiFlorida  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Washington, source: Washington, destination: Oregon, value: 0.0062325524457845114
# ---------------Possible actions for node Kansas in phase 1---------------
#      node  source        destination     value
# 0  Kansas  Kansas           Colorado  0.001631
# 1  Kansas  Kansas         Washington  0.001631
# 2  Kansas  Kansas           Oklahoma  0.002943
# 3  Kansas  Kansas          IowaState  0.001631
# 4  Kansas  Kansas              Texas  0.001605
# 5  Kansas  Kansas  SouthernMethodist  0.001631
# 6  Kansas  Kansas           Missouri  0.001631
# 7  Kansas  Kansas           Nebraska  0.001631
# 8  Kansas  Kansas  AlabamaBirmingham  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Kansas, source: Kansas, destination: Oklahoma, value: 0.00294329761103231
# ---------------Possible actions for node SouthernMethodist in phase 1---------------
#                 node             source     destination     value
# 0  SouthernMethodist  SouthernMethodist            Duke  0.001312
# 1  SouthernMethodist  SouthernMethodist        Oklahoma  0.001184
# 2  SouthernMethodist  SouthernMethodist           Texas  0.001599
# 3  SouthernMethodist  SouthernMethodist          Nevada  0.004798
# 4  SouthernMethodist  SouthernMethodist           Tulsa  0.001631
# 5  SouthernMethodist  SouthernMethodist     TexasElPaso  0.001631
# 6  SouthernMethodist  SouthernMethodist          Hawaii  0.001631
# 7  SouthernMethodist  SouthernMethodist    SanJoseState  0.001631
# 8  SouthernMethodist  SouthernMethodist          Tulane  0.001631
# 9  SouthernMethodist  SouthernMethodist  TexasChristian  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: SouthernMethodist, source: SouthernMethodist, destination: Nevada, value: 0.004798160572053575
# ---------------Possible actions for node Kent in phase 1---------------
#    node source        destination     value
# 0  Kent   Kent  BowlingGreenState  0.001605
# 1  Kent   Kent          Wisconsin  0.001312
# 2  Kent   Kent          BallState  0.004495
# 3  Kent   Kent    EasternMichigan  0.001631
# 4  Kent   Kent               Ohio  0.001631
# 5  Kent   Kent           Marshall  0.001631
# 6  Kent   Kent         Pittsburgh  0.001631
# 7  Kent   Kent          MiamiOhio  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Kent, source: Kent, destination: BallState, value: 0.004494782698945363
# ---------------Possible actions for node Pittsburgh in phase 1---------------
#          node      source      destination     value
# 0  Pittsburgh  Pittsburgh          Rutgers  0.007776
# 1  Pittsburgh  Pittsburgh        BallState  0.001104
# 2  Pittsburgh  Pittsburgh  EasternMichigan  0.001631
# 3  Pittsburgh  Pittsburgh         Michigan  0.001631
# 4  Pittsburgh  Pittsburgh    NorthCarolina  0.001631
# 5  Pittsburgh  Pittsburgh           Temple  0.001631
# 6  Pittsburgh  Pittsburgh     MiamiFlorida  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Pittsburgh, source: Pittsburgh, destination: Rutgers, value: 0.007776053905457873
# ---------------Possible actions for node Kentucky in phase 1---------------
#        node    source       destination     value
# 0  Kentucky  Kentucky       Mississippi  0.001631
# 1  Kentucky  Kentucky         Tennessee  0.001631
# 2  Kentucky  Kentucky  MississippiState  0.001631
# 3  Kentucky  Kentucky     SouthCarolina  0.001631
# 4  Kentucky  Kentucky           Indiana  0.001631
# 5  Kentucky  Kentucky           Georgia  0.001631
# 6  Kentucky  Kentucky    LouisianaState  0.003130
# 7  Kentucky  Kentucky        Louisville  0.001631
# 8  Kentucky  Kentucky        Vanderbilt  0.001631
# the action among the previous actions that maximizes modularity gain is:
# node: Kentucky, source: Kentucky, destination: LouisianaState, value: 0.0031295822699584056
# ---------------Possible actions for node Louisville in phase 1---------------
#          node      source          destination     value
# 0  Louisville  Louisville              Rutgers  0.001152
# 1  Louisville  Louisville                 Duke  0.001365
# 2  Louisville  Louisville                Texas  0.001605
# 3  Louisville  Louisville                 Army  0.001631
# 4  Louisville  Louisville            BallState  0.001152
# 5  Louisville  Louisville  SouthernMississippi  0.001631
# 6  Louisville  Louisville           Cincinnati  0.001631
# 7  Louisville  Louisville       LouisianaState  0.001445
# 8  Louisville  Louisville               Tulane  0.001631
# 9  Louisville  Louisville    AlabamaBirmingham  0.001631
# ...
# 1  EasternMichigan  EasternMichigan     Rutgers  0.002062
# 2  EasternMichigan  EasternMichigan   Wisconsin  0.000343
# the action among the previous actions that maximizes modularity gain is:
# node: EasternMichigan, source: EasternMichigan, destination: BallState, value: 0.011616179088748672
# ---------------Possible actions for node Washington in phase 2---------------
#          node      source destination     value
# 0  Washington  Washington     Wyoming  0.000812
# 1  Washington  Washington    Oklahoma  0.011148
# 2  Washington  Washington      Oregon  0.002092
# the action among the previous actions that maximizes modularity gain is:
# node: Washington, source: Washington, destination: Oklahoma, value: 0.011147806232020205
# ---------------Possible actions for node Nevada in phase 2---------------
#      node  source destination     value
# 0  Nevada  Nevada     Wyoming  0.001607
# 1  Nevada  Nevada      Oregon  0.001131
# 2  Nevada  Nevada        Duke -0.003060
# 3  Nevada  Nevada     Rutgers -0.005570
# 4  Nevada  Nevada    Oklahoma  0.005123
# 5  Nevada  Nevada   Wisconsin -0.001203
# 6  Nevada  Nevada      Nevada  0.052405
# 7  Nevada  Nevada       Texas  0.003263
# 8  Nevada  Nevada        Army  0.000753
# the action among the previous actions that maximizes modularity gain is:
# node: Nevada, source: Nevada, destination: Nevada, value: 0.05240453576532391
# ---------------Possible actions for node Texas in phase 2---------------
#     node source          destination     value
# 0  Texas  Texas              Rutgers  0.002062
# 1  Texas  Texas             Oklahoma -0.000506
# 2  Texas  Texas                 Army  0.004748
# 3  Texas  Texas               Nevada  0.002209
# 4  Texas  Texas  SouthernMississippi  0.001631
# 5  Texas  Texas        OklahomaState  0.001631
# 6  Texas  Texas       LouisianaState  0.000226
# the action among the previous actions that maximizes modularity gain is:
# node: Texas, source: Texas, destination: Army, value: 0.004747597593202206
# ---------------Possible actions for node Army in phase 2---------------
#     node source          destination     value
# 0   Army   Army              Rutgers  0.010645
# 1   Army   Army                 Duke -0.001913
# 2   Army   Army             Oklahoma -0.002294
# 3   Army   Army            Wisconsin -0.001070
# 4   Army   Army            BallState -0.002350
# 5   Army   Army               Nevada -0.001913
# 6   Army   Army                 Army  0.012263
# 7   Army   Army        OklahomaState  0.006525
# 8   Army   Army  SouthernMississippi  0.004894
# 9   Army   Army             Maryland  0.001631
# 10  Army   Army       LouisianaState  0.000168
# the action among the previous actions that maximizes modularity gain is:
# node: Army, source: Army, destination: Army, value: 0.012262852976163547
# ---------------Possible actions for node MiddleTennesseeState in phase 2---------------
#                    node                source          destination     value
# 0  MiddleTennesseeState  MiddleTennesseeState             Oklahoma  0.001708
# 1  MiddleTennesseeState  MiddleTennesseeState            Wisconsin  0.000695
# 2  MiddleTennesseeState  MiddleTennesseeState            BallState  0.000418
# 3  MiddleTennesseeState  MiddleTennesseeState  SouthernMississippi  0.001631
# 4  MiddleTennesseeState  MiddleTennesseeState             Maryland  0.001631
# 5  MiddleTennesseeState  MiddleTennesseeState       LouisianaState  0.002241
# the action among the previous actions that maximizes modularity gain is:
# node: MiddleTennesseeState, source: MiddleTennesseeState, destination: LouisianaState, value: 0.002240738325939607
# ---------------Possible actions for node Maryland in phase 2---------------
#        node    source     destination     value
# 0  Maryland  Maryland            Duke  0.000769
# 1  Maryland  Maryland        Oklahoma  0.001514
# 2  Maryland  Maryland       Wisconsin  0.000577
# 3  Maryland  Maryland       BallState  0.000266
# 4  Maryland  Maryland            Army  0.001440
# 5  Maryland  Maryland  LouisianaState  0.003696
# the action among the previous actions that maximizes modularity gain is:
# node: Maryland, source: Maryland, destination: LouisianaState, value: 0.0036964198749763815
# ---------------Possible actions for node SouthernMississippi in phase 2---------------
#                   node               source     destination     value
# 0  SouthernMississippi  SouthernMississippi         Rutgers  0.002062
# 1  SouthernMississippi  SouthernMississippi   OklahomaState  0.001631
# 2  SouthernMississippi  SouthernMississippi        Oklahoma -0.000506
# 3  SouthernMississippi  SouthernMississippi            Army  0.006291
# 4  SouthernMississippi  SouthernMississippi  LouisianaState  0.003342
# the action among the previous actions that maximizes modularity gain is:
# node: SouthernMississippi, source: SouthernMississippi, destination: Army, value: 0.00629109905287557
# ---------------Possible actions for node OklahomaState in phase 2---------------
#             node         source     destination     value
# 0  OklahomaState  OklahomaState         Rutgers  0.000540
# 1  OklahomaState  OklahomaState  LouisianaState  0.001852
# 2  OklahomaState  OklahomaState        Oklahoma -0.000311
# 3  OklahomaState  OklahomaState            Army  0.009469
# the action among the previous actions that maximizes modularity gain is:
# node: OklahomaState, source: OklahomaState, destination: Army, value: 0.009468583092272113
# displayed possible actions for all the nodes in phase: 2
# ----------------------------------------------------------------
#
#
# --------------------------Graph in the phase: 3--------------------------
#             nodes       community  \
# 0         Wyoming         Wyoming
# 1            Duke            Duke
# 2       Wisconsin       Wisconsin
# 3        Oklahoma        Oklahoma
# 4          Oregon          Oregon
# 5       BallState       BallState
# 6  LouisianaState  LouisianaState
# 7         Rutgers         Rutgers
# 8          Nevada          Nevada
# 9            Army            Army
#
#                                         people_nodes
# 0  [BrighamYoung, NewMexico, SanDiegoState, Wyomi...
# 1  [FloridaState, NorthCarolinaState, Virginia, G...
# 2  [Iowa, Northwestern, Wisconsin, Michigan, Purd...
# 3  [KansasState, LouisianaTech, TexasTech, Baylor...
# 4  [SouthernCalifornia, ArizonaState, UCLA, Arizo...
# 5  [NorthernIllinois, WesternMichigan, BallState,...
# 6  [Auburn, Alabama, Florida, Kentucky, Vanderbil...
# 7  [VirginiaTech, BostonCollege, WestVirginia, Sy...
# 8  [FresnoState, Rice, SouthernMethodist, Nevada,...
# 9  [Houston, Louisville, Tulane, Cincinnati, Alab...
#     edges          node_a          node_b  weight
# 0       1         Wyoming            Duke       2
# 1       2         Wyoming         Wyoming      28
# 2       3         Wyoming         Rutgers       4
# 3       4         Wyoming  LouisianaState       3
# 4       5         Wyoming        Oklahoma       9
# 5       6         Wyoming          Oregon       8
# 6       7         Wyoming       Wisconsin       1
# 7       8         Wyoming       BallState       1
# 8       9         Wyoming          Nevada       4
# 9      10            Duke            Duke      36
# 10     11            Duke  LouisianaState       6
# 11     12            Duke            Army       1
# 12     13            Duke         Rutgers       8
# 13     14            Duke       Wisconsin       2
# 14     15            Duke        Oklahoma       2
# 15     16            Duke          Nevada       2
# 16     17            Duke       BallState       2
# 17     18       Wisconsin        Oklahoma       6
# 18     19       Wisconsin       Wisconsin      44
# 19     20       Wisconsin       BallState      10
# 20     21       Wisconsin          Nevada       4
# 21     22       Wisconsin          Oregon       5
# 22     23       Wisconsin            Army       2
# 23     24       Wisconsin         Rutgers       3
# 24     25       Wisconsin  LouisianaState       3
# 25     26        Oklahoma        Oklahoma      73
# 26     27        Oklahoma       BallState       4
# 27     28        Oklahoma  LouisianaState       9
# 28     29        Oklahoma          Nevada      11
# 29     30        Oklahoma         Rutgers       5
# 30     31        Oklahoma          Oregon       8
# 31     32        Oklahoma            Army       6
# 32     33          Oregon          Oregon      40
# 33     34          Oregon          Nevada       5
# 34     35          Oregon         Rutgers       3
# 35     36          Oregon  LouisianaState       1
# 36     37       BallState       BallState      57
# 37     38       BallState  LouisianaState       7
# 38     39       BallState         Rutgers      10
# 39     40       BallState            Army       2
# 40     41  LouisianaState  LouisianaState      53
# 41     42  LouisianaState            Army      10
# 42     43         Rutgers         Rutgers      41
# 43     44         Rutgers            Army      14
# 44     45         Rutgers          Nevada       1
# 45     46          Nevada          Nevada      36
# 46     47          Nevada            Army       3
# 47     48            Army            Army      18
# _______________________________________________________________________________________________________
# ---------------Possible actions for node Wyoming in phase 3---------------
#       node   source     destination     value
# 0  Wyoming  Wyoming         Wyoming  0.041206
# 1  Wyoming  Wyoming         Rutgers -0.000021
# 2  Wyoming  Wyoming            Duke -0.002486
# 3  Wyoming  Wyoming          Oregon  0.006664
# 4  Wyoming  Wyoming        Oklahoma  0.003026
# 5  Wyoming  Wyoming       Wisconsin -0.005394
# 6  Wyoming  Wyoming       BallState -0.007470
# 7  Wyoming  Wyoming          Nevada  0.000777
# 8  Wyoming  Wyoming  LouisianaState -0.003569
# the action among the previous actions that maximizes modularity gain is:
# node: Wyoming, source: Wyoming, destination: Wyoming, value: 0.04120616655445234
# ---------------Possible actions for node Duke in phase 3---------------
#    node source     destination     value
# 0  Duke   Duke         Wyoming -0.001283
# 1  Duke   Duke         Rutgers  0.006395
# 2  Duke   Duke            Duke  0.052884
# 3  Duke   Duke       Wisconsin -0.003880
# 4  Duke   Duke            Army -0.001291
# 5  Duke   Duke        Oklahoma -0.008588
# 6  Duke   Duke          Nevada -0.002581
# 7  Duke   Duke       BallState -0.005990
# 8  Duke   Duke  LouisianaState  0.001184
# the action among the previous actions that maximizes modularity gain is:
# node: Duke, source: Duke, destination: Duke, value: 0.0528835534597053
# ---------------Possible actions for node Wisconsin in phase 3---------------
#         node     source     destination     value
# 0  Wisconsin  Wisconsin         Wyoming -0.004330
# 1  Wisconsin  Wisconsin          Oregon -0.000359
# 2  Wisconsin  Wisconsin            Duke -0.004402
# 3  Wisconsin  Wisconsin         Rutgers -0.003835
# 4  Wisconsin  Wisconsin       Wisconsin  0.062411
# 5  Wisconsin  Wisconsin        Oklahoma -0.005754
# 6  Wisconsin  Wisconsin       BallState  0.004178
# 7  Wisconsin  Wisconsin          Nevada -0.001139
# 8  Wisconsin  Wisconsin            Army -0.000569
# 9  Wisconsin  Wisconsin  LouisianaState -0.006390
# the action among the previous actions that maximizes modularity gain is:
# node: Wisconsin, source: Wisconsin, destination: Wisconsin, value: 0.06241068315906846
# ---------------Possible actions for node Oklahoma in phase 3---------------
#        node    source     destination     value
# 0  Oklahoma  Oklahoma         Wyoming  0.004772
# 1  Oklahoma  Oklahoma         Rutgers -0.006355
# 2  Oklahoma  Oklahoma            Duke -0.009479
# 3  Oklahoma  Oklahoma          Oregon -0.001107
# 4  Oklahoma  Oklahoma        Oklahoma  0.093249
# 5  Oklahoma  Oklahoma       Wisconsin -0.005785
# 6  Oklahoma  Oklahoma       BallState -0.013649
# 7  Oklahoma  Oklahoma          Nevada  0.005203
# 8  Oklahoma  Oklahoma            Army  0.003417
# 9  Oklahoma  Oklahoma  LouisianaState -0.004077
# the action among the previous actions that maximizes modularity gain is:
# node: Oklahoma, source: Oklahoma, destination: Oklahoma, value: 0.09324877783957697
# ---------------Possible actions for node Oregon in phase 3---------------
#      node  source     destination     value
# 0  Oregon  Oregon         Wyoming  0.007835
# 1  Oregon  Oregon          Oregon  0.057801
# 2  Oregon  Oregon         Rutgers -0.002744
# 3  Oregon  Oregon        Oklahoma -0.000548
# 4  Oregon  Oregon          Nevada  0.001450
# 5  Oregon  Oregon       Wisconsin -0.000040
# 6  Oregon  Oregon  LouisianaState -0.008242
# the action among the previous actions that maximizes modularity gain is:
# node: Oregon, source: Oregon, destination: Oregon, value: 0.057801468455354214
# ---------------Possible actions for node BallState in phase 3---------------
#         node     source     destination     value
# 0  BallState  BallState         Wyoming -0.005298
# 1  BallState  BallState         Rutgers  0.006166
# 2  BallState  BallState            Duke -0.005647
# 3  BallState  BallState        Oklahoma -0.011542
# 4  BallState  BallState       Wisconsin  0.005424
# 5  BallState  BallState       BallState  0.078878
# 6  BallState  BallState            Army -0.001192
# 7  BallState  BallState  LouisianaState -0.001698
# the action among the previous actions that maximizes modularity gain is:
# node: BallState, source: BallState, destination: BallState, value: 0.07887824700813531
# ---------------Possible actions for node LouisianaState in phase 3---------------
#              node          source     destination     value
# 0  LouisianaState  LouisianaState         Wyoming -0.001961
# 1  LouisianaState  LouisianaState          Oregon -0.008162
# 2  LouisianaState  LouisianaState            Duke  0.000974
# 3  LouisianaState  LouisianaState        Oklahoma -0.003191
# 4  LouisianaState  LouisianaState       Wisconsin -0.005879
# 5  LouisianaState  LouisianaState       BallState -0.002536
# 6  LouisianaState  LouisianaState            Army  0.011906
# 7  LouisianaState  LouisianaState  LouisianaState  0.073484
# the action among the previous actions that maximizes modularity gain is:
# node: LouisianaState, source: LouisianaState, destination: LouisianaState, value: 0.07348397552751823
# ---------------Possible actions for node Rutgers in phase 3---------------
#       node   source destination     value
# 0  Rutgers  Rutgers     Wyoming -0.000106
# 1  Rutgers  Rutgers      Oregon -0.004580
# 2  Rutgers  Rutgers        Duke  0.004524
# 3  Rutgers  Rutgers     Rutgers  0.057173
# 4  Rutgers  Rutgers    Oklahoma -0.009133
# 5  Rutgers  Rutgers   Wisconsin -0.005527
# 6  Rutgers  Rutgers   BallState  0.002813
# 7  Rutgers  Rutgers        Army  0.018575
# 8  Rutgers  Rutgers      Nevada -0.006895
# the action among the previous actions that maximizes modularity gain is:
# node: Rutgers, source: Rutgers, destination: Rutgers, value: 0.05717342303383195
# ---------------Possible actions for node Nevada in phase 3---------------
#      node  source destination     value
# 0  Nevada  Nevada     Wyoming  0.001607
# 1  Nevada  Nevada      Oregon  0.001131
# 2  Nevada  Nevada        Duke -0.003060
# 3  Nevada  Nevada     Rutgers -0.005570
# 4  Nevada  Nevada    Oklahoma  0.005123
# 5  Nevada  Nevada   Wisconsin -0.001203
# 6  Nevada  Nevada      Nevada  0.052405
# 7  Nevada  Nevada        Army  0.001732
# the action among the previous actions that maximizes modularity gain is:
# node: Nevada, source: Nevada, destination: Nevada, value: 0.05240453576532391
# ---------------Possible actions for node Army in phase 3---------------
#    node source     destination     value
# 0  Army   Army         Rutgers  0.016728
# 1  Army   Army            Duke -0.003734
# 2  Army   Army        Oklahoma -0.001091
# 3  Army   Army       Wisconsin -0.003295
# 4  Army   Army       BallState -0.005232
# 5  Army   Army          Nevada -0.000471
# 6  Army   Army            Army  0.026681
# 7  Army   Army  LouisianaState  0.008415
# the action among the previous actions that maximizes modularity gain is:
# node: Army, source: Army, destination: Army, value: 0.026681285577043343
# displayed possible actions for all the nodes in phase: 3
# ----------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
for g in louvain.graph_history:
    plt.figure(figsize=(12, 7))
    nx.draw(
            g,
            with_labels=True,
            alpha=0.9,
            pos=nx.spring_layout(g, k=0.9),
            node_color='skyblue',
            node_size=4000,
            font_size=8, 
            font_color='black', 
            font_weight='bold',
            edge_color='red', width=1
            )
    plt.show()

# %%
# we need a way to map the fina obtained communities to the group truth
# this is doable
football_graph = nx.read_gml('./../data/evaluation/DataSets/réels/football/football.gml')
